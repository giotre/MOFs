# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from lolopy.learners import RandomForestRegressor
from sklearn.model_selection import KFold
import tqdm
import pandas as pd
import numpy as np
import combo

# %%
def MEI(X, y, n_steps, T):
    
    arr = y
    minima = arr.argsort()[0:100]
    in_train = np.zeros(len(X), dtype=np.bool)
    in_train[minima] = True

    all_inds = set(range(len(y)))
    F = np.zeros(n_steps)
    G = np.zeros(n_steps)
    mei_train = [list(set(np.where(in_train)[0].tolist()))]
    mei_train_inds = []

    for i in tqdm.tqdm(range(n_steps)):
        mei_train_inds = mei_train[-1].copy()    
        mei_search_inds = list(all_inds.difference(mei_train_inds))


        mei_selection_index = []
        for j in range(T):
            model.fit(X[mei_train_inds], y[mei_train_inds])
            mei_y_pred_prov = model.predict(X[mei_search_inds])
            mei_selection_index.append(np.argmax(mei_y_pred_prov)) 

        mei_index_G = max(set(mei_selection_index), key = mei_selection_index.count)
        mei_index = mei_search_inds[mei_index_G]
        mei_train_inds.append(mei_search_inds[mei_index_G])     # Pick entry with the largest maximum value
        mei_train.append(mei_train_inds)
        G[i] = mei_index
        F[i] = mei_train_inds[-1]
        if mei_train_inds[-1] == np.argmax(y):
            break
            
    return(F)



def MLI(X, y, n_steps, T):
    
    arr = y
    minima = arr.argsort()[0:100]
    in_train = np.zeros(len(X), dtype=np.bool)
    in_train[minima] = True
    
    all_inds = set(range(len(y)))
    K = np.zeros(n_steps)
    L = np.zeros(n_steps)
    mli_train = [list(set(np.where(in_train)[0].tolist()))]
    mli_train_inds = []


    for i in tqdm.tqdm(range(n_steps)):
        mli_train_inds = mli_train[-1].copy()    
        mli_search_inds = list(all_inds.difference(mli_train_inds))


        mli_selection_index = []
        for j in range(T):
            model.fit(X[mli_train_inds], y[mli_train_inds])
            mli_y_pred_prov, mli_y_std_prov = model.predict(X[mli_search_inds], return_std=True)
            mli_selection_index.append(np.argmax(np.divide(mli_y_pred_prov - np.max(y[mli_train_inds]), mli_y_std_prov))) 
            

        mli_index_L = max(set(mli_selection_index), key = mli_selection_index.count)
        mli_index = mli_search_inds[mli_index_L]

        mli_train_inds.append(mli_search_inds[mli_index_L])     # Pick entry with the largest maximum value
        mli_train.append(mli_train_inds)
        L[i] = mli_index
        K[i] = mli_train_inds[-1]
        if mli_train_inds[-1] == np.argmax(y):
            break

    return (K)


def MU(X, y, n_steps, T):
    
    arr = y
    minima = arr.argsort()[0:100]
    in_train = np.zeros(len(X), dtype=np.bool)
    in_train[minima] = True
    
    all_inds = set(range(len(y)))
    R = np.zeros(n_steps)
    S = np.zeros(n_steps)
    mu_train = [list(set(np.where(in_train)[0].tolist()))]
    mu_train_inds = []


    for i in tqdm.tqdm(range(n_steps)):
        mu_train_inds = mu_train[-1].copy()    
        mu_search_inds = list(all_inds.difference(mu_train_inds))


        mu_selection_index = []
        for j in range(T):
            model.fit(X[mu_train_inds], y[mu_train_inds])
            mu_y_pred_prov, mu_y_std_prov = model.predict(X[mu_search_inds], return_std=True)
            mu_selection_index.append(np.argmax(mu_y_std_prov)) 

        mu_index_R = max(set(mu_selection_index), key = mu_selection_index.count)
        mu_index = mu_search_inds[mu_index_R]

        mu_train_inds.append(mu_search_inds[mu_index_R])     # Pick entry with the largest maximum value
        mu_train.append(mu_train_inds)
        R[i] = mu_index
        S[i] = mu_train_inds[-1]
        if mu_train_inds[-1] == np.argmax(y):
            break

    return (S)

# %%
def COMBO(Data, acq_fcn):

    class simulator:
        def __init__( self ):
            _, self.y = load_data()

        def __call__( self, action ):
            return self.y[action]
    
    def load_data():
        X = Data.iloc[:, :-1].values
        y = Data.iloc[:, -1].values
        return X, y
    
    X, y = load_data()
    X = combo.misc.centering(X)
        
    arr = y
    minima = arr.argsort()[0:100]
    
    policy = combo.search.discrete.policy(test_X = X) 
    t  = simulator()(minima)
    res = policy.write(minima, t)
    
    res = policy.bayes_search(max_num_probes = 400, simulator=simulator(), score = acq_fcn, interval=50, num_rand_basis=0)
    
    return(res)

# %%
def produce_Data_SL(Data, Output_mean_shap, n_relevant, target_property):

    relevant_features = list(Output_mean_shap.iloc[:n_relevant].index)
    unrelevant_features = list(Output_mean_shap.sort_values('mean').iloc[:int(100-n_relevant)].index)
    all_features = relevant_features + unrelevant_features

    relevant_features.append(target_property)
    all_features.append(target_property)

    Data_sampled = Data.sample(n = 500, random_state = 0)
    
    if target_property == 'henry_coefficient_CO2_298K [mol/kg/bar]' or target_property == 'henry_coefficient_H2O_298K [mol/kg/bar]':
        Data_sampled[target_property] = np.log(Data_sampled[target_property])
        
    Data_relevant_features = pd.DataFrame(Data_sampled, columns = relevant_features)
    Data_unrelevant_features = pd.DataFrame(Data_sampled, columns = all_features)
    
    return (Data_relevant_features, Data_unrelevant_features)

# %%
Data_Henry_CO2        = pd.read_excel(r'Data_Henry_CO2.xlsx', index_col = 0)
Data_Working_Capacity = pd.read_excel(r'Data_Working_Capacity.xlsx', index_col = 0)
Data_Henry_H2O        = pd.read_excel(r'Data_Henry_H2O.xlsx', index_col = 0)
#Data_Surface_area     = pd.read_excel(r'Data_Surface_area.xlsx', index_col = 0)

# %%
Output_mean_shap_Henry_CO2        = pd.read_excel(r'Output_mean_shap_Henry_CO2.xlsx', index_col = 0)
Output_mean_shap_Working_Capacity = pd.read_excel(r'Output_mean_shap_Working_capacity.xlsx', index_col = 0)
Output_mean_shap_Henry_H2O        = pd.read_excel(r'Output_mean_shap_Henry_H2O.xlsx', index_col = 0)
#Output_mean_shap_surface_area     = pd.read_excel(r'Output_mean_shap_surface_area.xlsx', index_col = 0)

# %%
Data_relevant_features_Henry_CO2, Data_unrelevant_features_Henry_CO2               = produce_Data_SL(Data_Henry_CO2, Output_mean_shap_Henry_CO2, 33, 'henry_coefficient_CO2_298K [mol/kg/bar]')
Data_relevant_features_Working_Capacity, Data_unrelevant_features_Working_Capacity = produce_Data_SL(Data_Working_Capacity, Output_mean_shap_Working_Capacity, 62, 'working_capacity_vacuum_swing_REPEAT_chg [mmol/g]')
Data_relevant_features_Henry_H2O, Data_unrelevant_features_Henry_H2O               = produce_Data_SL(Data_Henry_H2O, Output_mean_shap_Henry_H2O, 15, 'henry_coefficient_H2O_298K [mol/kg/bar]')
#Data_relevant_features_surface_area, Data_unrelevant_features_surface_area         = produce_Data_SL(Data_Surface_area, Output_mean_shap_surface_area, 14, 'surface_area [m^2/g]')

# %%
#Data_unrelevant_features_Henry_H2O.to_excel('C:\\Users\\giovanni\\Desktop\\Excels Matlab\\Data_unrelevant_features_Henry_H2O.xlsx')

# %% [markdown]
# ## Henry CO2
# #### Relevant features

# %%
model = RandomForestRegressor()

# %%
MEI_index_Henry_CO2_relevant = MEI(Data_relevant_features_Henry_CO2.iloc[:, :-1].values, Data_relevant_features_Henry_CO2.iloc[:, -1].values, 400, 100)
# Out:
#  28%|██▊       | 111/400 [1:09:43<3:01:31, 37.69s/it]

# %%
MLI_index_Henry_CO2_relevant = MLI(Data_relevant_features_Henry_CO2.iloc[:, :-1].values, Data_relevant_features_Henry_CO2.iloc[:, -1].values, 400, 100)
# Out:
#  18%|█▊        | 74/400 [41:39<3:03:30, 33.77s/it]

# %%
MU_index_Henry_CO2_relevant = MU(Data_relevant_features_Henry_CO2.iloc[:, :-1].values, Data_relevant_features_Henry_CO2.iloc[:, -1].values, 400, 100)
# Out:
#  34%|███▎      | 134/400 [1:43:47<3:26:01, 46.47s/it]

# %%
COMBO_PI_Henry_CO2_relevant = COMBO(Data_relevant_features_Henry_CO2, 'PI')
# Out:
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 54.76843695353331
# 50-th epoch, marginal likelihood 32.61917843281164
# 100-th epoch, marginal likelihood 19.318970303584706
# 150-th epoch, marginal likelihood 10.321649484617453
# 200-th epoch, marginal likelihood 4.148311083608718
# 250-th epoch, marginal likelihood -0.07154457746423759
# 300-th epoch, marginal likelihood -2.9058282773172834
# 350-th epoch, marginal likelihood -5.169621934066711
# 400-th epoch, marginal likelihood -6.4519848474028265
# 450-th epoch, marginal likelihood -7.858639216611543
# 500-th epoch, marginal likelihood -8.884347277564217
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.]
#  scale  =  1.0
#  scale2 =  1.0
#
#
# 0101-th step: f(x) = 11.087779 (action=150)
#    current best f(x) = 11.087779 (best action=150)
#
# 0102-th step: f(x) = 11.193615 (action=277)
#    current best f(x) = 11.193615 (best action=277)
#
# 0103-th step: f(x) = 10.909970 (action=166)
#    current best f(x) = 11.193615 (best action=277)
#
# 0104-th step: f(x) = 11.570194 (action=29)
#    current best f(x) = 11.570194 (best action=29)
#
# 0105-th step: f(x) = 11.109756 (action=87)
#    current best f(x) = 11.570194 (best action=29)
#
# 0106-th step: f(x) = 11.363592 (action=463)
#    current best f(x) = 11.570194 (best action=29)
#
# 0107-th step: f(x) = 12.104178 (action=23)
#    current best f(x) = 12.104178 (best action=23)
#
# 0108-th step: f(x) = 13.433437 (action=165)
#    current best f(x) = 13.433437 (best action=165)
#
# 0109-th step: f(x) = 13.936604 (action=495)
#    current best f(x) = 13.936604 (best action=495)
#
# 0110-th step: f(x) = 12.206058 (action=194)
#    current best f(x) = 13.936604 (best action=495)
#
# 0111-th step: f(x) = 11.078800 (action=400)
#    current best f(x) = 13.936604 (best action=495)
#
# 0112-th step: f(x) = 12.007353 (action=69)
#    current best f(x) = 13.936604 (best action=495)
#
# 0113-th step: f(x) = 13.687319 (action=313)
#    current best f(x) = 13.936604 (best action=495)
#
# 0114-th step: f(x) = 10.905152 (action=307)
#    current best f(x) = 13.936604 (best action=495)
#
# 0115-th step: f(x) = 12.356719 (action=7)
#    current best f(x) = 13.936604 (best action=495)
#
# 0116-th step: f(x) = 12.468145 (action=334)
#    current best f(x) = 13.936604 (best action=495)
#
# 0117-th step: f(x) = 11.816188 (action=156)
#    current best f(x) = 13.936604 (best action=495)
#
# 0118-th step: f(x) = 12.504769 (action=453)
#    current best f(x) = 13.936604 (best action=495)
#
# 0119-th step: f(x) = 11.853454 (action=228)
#    current best f(x) = 13.936604 (best action=495)
#
# 0120-th step: f(x) = 11.695947 (action=151)
#    current best f(x) = 13.936604 (best action=495)
#
# 0121-th step: f(x) = 12.187471 (action=101)
#    current best f(x) = 13.936604 (best action=495)
#
# 0122-th step: f(x) = 11.498842 (action=153)
#    current best f(x) = 13.936604 (best action=495)
#
# 0123-th step: f(x) = 14.907075 (action=342)
#    current best f(x) = 14.907075 (best action=342)
#
# 0124-th step: f(x) = 14.162195 (action=392)
#    current best f(x) = 14.907075 (best action=342)
#
# 0125-th step: f(x) = 13.439160 (action=340)
#    current best f(x) = 14.907075 (best action=342)
#
# 0126-th step: f(x) = 14.004915 (action=407)
#    current best f(x) = 14.907075 (best action=342)
#
# 0127-th step: f(x) = 13.231695 (action=238)
#    current best f(x) = 14.907075 (best action=342)
#
# 0128-th step: f(x) = 13.113238 (action=470)
#    current best f(x) = 14.907075 (best action=342)
#
# 0129-th step: f(x) = 12.815232 (action=177)
#    current best f(x) = 14.907075 (best action=342)
#
# 0130-th step: f(x) = 13.371976 (action=320)
#    current best f(x) = 14.907075 (best action=342)
#
# 0131-th step: f(x) = 14.054575 (action=279)
#    current best f(x) = 14.907075 (best action=342)
#
# 0132-th step: f(x) = 13.550647 (action=341)
#    current best f(x) = 14.907075 (best action=342)
#
# 0133-th step: f(x) = 13.613529 (action=360)
#    current best f(x) = 14.907075 (best action=342)
#
# 0134-th step: f(x) = 14.608082 (action=79)
#    current best f(x) = 14.907075 (best action=342)
#
# 0135-th step: f(x) = 12.241179 (action=499)
#    current best f(x) = 14.907075 (best action=342)
#
# 0136-th step: f(x) = 13.388470 (action=142)
#    current best f(x) = 14.907075 (best action=342)
#
# 0137-th step: f(x) = 13.840730 (action=154)
#    current best f(x) = 14.907075 (best action=342)
#
# 0138-th step: f(x) = 12.199556 (action=149)
#    current best f(x) = 14.907075 (best action=342)
#
# 0139-th step: f(x) = 14.143965 (action=234)
#    current best f(x) = 14.907075 (best action=342)
#
# 0140-th step: f(x) = 12.625490 (action=216)
#    current best f(x) = 14.907075 (best action=342)
#
# 0141-th step: f(x) = 12.701863 (action=370)
#    current best f(x) = 14.907075 (best action=342)
#
# 0142-th step: f(x) = 14.045971 (action=436)
#    current best f(x) = 14.907075 (best action=342)
#
# 0143-th step: f(x) = 12.949820 (action=94)
#    current best f(x) = 14.907075 (best action=342)
#
# 0144-th step: f(x) = 13.546707 (action=429)
#    current best f(x) = 14.907075 (best action=342)
#
# 0145-th step: f(x) = 13.588520 (action=213)
#    current best f(x) = 14.907075 (best action=342)
#
# 0146-th step: f(x) = 13.355414 (action=472)
#    current best f(x) = 14.907075 (best action=342)
#
# 0147-th step: f(x) = 13.294333 (action=409)
#    current best f(x) = 14.907075 (best action=342)
#
# 0148-th step: f(x) = 12.713068 (action=141)
#    current best f(x) = 14.907075 (best action=342)
#
# 0149-th step: f(x) = 13.774910 (action=57)
#    current best f(x) = 14.907075 (best action=342)
#
# 0150-th step: f(x) = 13.849071 (action=408)
#    current best f(x) = 14.907075 (best action=342)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 115.33773108235927
# 50-th epoch, marginal likelihood 114.9664666895057
# 100-th epoch, marginal likelihood 115.67102987673587
# 150-th epoch, marginal likelihood 114.69859454467338
# 200-th epoch, marginal likelihood 113.3235837048981
# 250-th epoch, marginal likelihood 111.86522242471177
# 300-th epoch, marginal likelihood 110.0137886291406
# 350-th epoch, marginal likelihood 108.70588460782979
# 400-th epoch, marginal likelihood 106.86800134721162
# 450-th epoch, marginal likelihood 105.20020262200745
# 500-th epoch, marginal likelihood 103.83538129729588
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [2.6209242]
#  scale  =  0.25917360621381863
#  scale2 =  0.06717095815787552
#
#
# 0151-th step: f(x) = 12.623443 (action=134)
#    current best f(x) = 14.907075 (best action=342)
#
# 0152-th step: f(x) = 14.562293 (action=481)
#    current best f(x) = 14.907075 (best action=342)
#
# 0153-th step: f(x) = 14.470462 (action=478)
#    current best f(x) = 14.907075 (best action=342)
#
# 0154-th step: f(x) = 13.359511 (action=86)
#    current best f(x) = 14.907075 (best action=342)
#
# 0155-th step: f(x) = 11.837441 (action=348)
#    current best f(x) = 14.907075 (best action=342)
#
# 0156-th step: f(x) = 12.729697 (action=158)
#    current best f(x) = 14.907075 (best action=342)
#
# 0157-th step: f(x) = 13.985827 (action=326)
#    current best f(x) = 14.907075 (best action=342)
#
# 0158-th step: f(x) = 14.455732 (action=84)
#    current best f(x) = 14.907075 (best action=342)
#
# 0159-th step: f(x) = 13.666899 (action=62)
#    current best f(x) = 14.907075 (best action=342)
#
# 0160-th step: f(x) = 13.663556 (action=40)
#    current best f(x) = 14.907075 (best action=342)
#
# 0161-th step: f(x) = 12.943906 (action=487)
#    current best f(x) = 14.907075 (best action=342)
#
# 0162-th step: f(x) = 12.091924 (action=475)
#    current best f(x) = 14.907075 (best action=342)
#
# 0163-th step: f(x) = 10.906163 (action=383)
#    current best f(x) = 14.907075 (best action=342)
#
# 0164-th step: f(x) = 12.775475 (action=263)
#    current best f(x) = 14.907075 (best action=342)
#
# 0165-th step: f(x) = 13.346476 (action=292)
#    current best f(x) = 14.907075 (best action=342)
#
# 0166-th step: f(x) = 13.023539 (action=45)
#    current best f(x) = 14.907075 (best action=342)
#
# 0167-th step: f(x) = 13.545193 (action=215)
#    current best f(x) = 14.907075 (best action=342)
#
# 0168-th step: f(x) = 12.391548 (action=396)
#    current best f(x) = 14.907075 (best action=342)
#
# 0169-th step: f(x) = 12.678346 (action=428)
#    current best f(x) = 14.907075 (best action=342)
#
# 0170-th step: f(x) = 12.654977 (action=172)
#    current best f(x) = 14.907075 (best action=342)
#
# 0171-th step: f(x) = 10.817089 (action=102)
#    current best f(x) = 14.907075 (best action=342)
#
# 0172-th step: f(x) = 11.620990 (action=219)
#    current best f(x) = 14.907075 (best action=342)
#
# 0173-th step: f(x) = 12.177282 (action=498)
#    current best f(x) = 14.907075 (best action=342)
#
# 0174-th step: f(x) = 10.597839 (action=129)
#    current best f(x) = 14.907075 (best action=342)
#
# 0175-th step: f(x) = 12.521989 (action=309)
#    current best f(x) = 14.907075 (best action=342)
#
# 0176-th step: f(x) = 12.064163 (action=77)
#    current best f(x) = 14.907075 (best action=342)
#
# 0177-th step: f(x) = 12.238690 (action=483)
#    current best f(x) = 14.907075 (best action=342)
#
# 0178-th step: f(x) = 11.201851 (action=178)
#    current best f(x) = 14.907075 (best action=342)
#
# 0179-th step: f(x) = 13.539830 (action=417)
#    current best f(x) = 14.907075 (best action=342)
#
# 0180-th step: f(x) = 10.685140 (action=268)
#    current best f(x) = 14.907075 (best action=342)
#
# 0181-th step: f(x) = 14.477286 (action=76)
#    current best f(x) = 14.907075 (best action=342)
#
# 0182-th step: f(x) = 13.252711 (action=59)
#    current best f(x) = 14.907075 (best action=342)
#
# 0183-th step: f(x) = 12.169875 (action=276)
#    current best f(x) = 14.907075 (best action=342)
#
# 0184-th step: f(x) = 12.147808 (action=162)
#    current best f(x) = 14.907075 (best action=342)
#
# 0185-th step: f(x) = 11.457136 (action=67)
#    current best f(x) = 14.907075 (best action=342)
#
# 0186-th step: f(x) = 12.980763 (action=36)
#    current best f(x) = 14.907075 (best action=342)
#
# 0187-th step: f(x) = 11.840141 (action=488)
#    current best f(x) = 14.907075 (best action=342)
#
# 0188-th step: f(x) = 12.291456 (action=20)
#    current best f(x) = 14.907075 (best action=342)
#
# 0189-th step: f(x) = 11.099243 (action=184)
#    current best f(x) = 14.907075 (best action=342)
#
# 0190-th step: f(x) = 11.472237 (action=461)
#    current best f(x) = 14.907075 (best action=342)
#
# 0191-th step: f(x) = 12.299736 (action=128)
#    current best f(x) = 14.907075 (best action=342)
#
# 0192-th step: f(x) = 12.893953 (action=64)
#    current best f(x) = 14.907075 (best action=342)
#
# 0193-th step: f(x) = 10.717455 (action=250)
#    current best f(x) = 14.907075 (best action=342)
#
# 0194-th step: f(x) = 12.541712 (action=377)
#    current best f(x) = 14.907075 (best action=342)
#
# 0195-th step: f(x) = 10.768940 (action=83)
#    current best f(x) = 14.907075 (best action=342)
#
# 0196-th step: f(x) = 11.478575 (action=81)
#    current best f(x) = 14.907075 (best action=342)
#
# 0197-th step: f(x) = 12.305130 (action=270)
#    current best f(x) = 14.907075 (best action=342)
#
# 0198-th step: f(x) = 12.871684 (action=148)
#    current best f(x) = 14.907075 (best action=342)
#
# 0199-th step: f(x) = 11.738139 (action=259)
#    current best f(x) = 14.907075 (best action=342)
#
# 0200-th step: f(x) = 13.603537 (action=431)
#    current best f(x) = 14.907075 (best action=342)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 175.73542566251194
# 50-th epoch, marginal likelihood 174.99130444789907
# 100-th epoch, marginal likelihood 172.33731640527748
# 150-th epoch, marginal likelihood 169.18701865093135
# 200-th epoch, marginal likelihood 165.9830562843092
# 250-th epoch, marginal likelihood 163.34403544525526
# 300-th epoch, marginal likelihood 161.11195922140155
# 350-th epoch, marginal likelihood 159.23378387245953
# 400-th epoch, marginal likelihood 157.92421239096734
# 450-th epoch, marginal likelihood 157.135291455931
# 500-th epoch, marginal likelihood 156.58861748268652
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.04985588]
#  scale  =  1.0971968987838119
#  scale2 =  1.2038410347008144
#
#
# 0201-th step: f(x) = 13.392218 (action=437)
#    current best f(x) = 14.907075 (best action=342)
#
# 0202-th step: f(x) = 14.769074 (action=252)
#    current best f(x) = 14.907075 (best action=342)
#
# 0203-th step: f(x) = 13.003787 (action=169)
#    current best f(x) = 14.907075 (best action=342)
#
# 0204-th step: f(x) = 12.109578 (action=443)
#    current best f(x) = 14.907075 (best action=342)
#
# 0205-th step: f(x) = 12.054249 (action=73)
#    current best f(x) = 14.907075 (best action=342)
#
# 0206-th step: f(x) = 12.626932 (action=235)
#    current best f(x) = 14.907075 (best action=342)
#
# 0207-th step: f(x) = 12.707236 (action=338)
#    current best f(x) = 14.907075 (best action=342)
#
# 0208-th step: f(x) = 13.672768 (action=321)
#    current best f(x) = 14.907075 (best action=342)
#
# 0209-th step: f(x) = 12.516340 (action=18)
#    current best f(x) = 14.907075 (best action=342)
#
# 0210-th step: f(x) = 11.349901 (action=42)
#    current best f(x) = 14.907075 (best action=342)
#
# 0211-th step: f(x) = 13.460839 (action=424)
#    current best f(x) = 14.907075 (best action=342)
#
# 0212-th step: f(x) = 12.267379 (action=70)
#    current best f(x) = 14.907075 (best action=342)
#
# 0213-th step: f(x) = 12.105849 (action=30)
#    current best f(x) = 14.907075 (best action=342)
#
# 0214-th step: f(x) = 12.986748 (action=209)
#    current best f(x) = 14.907075 (best action=342)
#
# 0215-th step: f(x) = 12.272534 (action=352)
#    current best f(x) = 14.907075 (best action=342)
#
# 0216-th step: f(x) = 12.713222 (action=50)
#    current best f(x) = 14.907075 (best action=342)
#
# 0217-th step: f(x) = 11.553520 (action=88)
#    current best f(x) = 14.907075 (best action=342)
#
# 0218-th step: f(x) = 11.352042 (action=444)
#    current best f(x) = 14.907075 (best action=342)
#
# 0219-th step: f(x) = 12.163645 (action=343)
#    current best f(x) = 14.907075 (best action=342)
#
# 0220-th step: f(x) = 12.174262 (action=295)
#    current best f(x) = 14.907075 (best action=342)
#
# 0221-th step: f(x) = 11.936276 (action=112)
#    current best f(x) = 14.907075 (best action=342)
#
# 0222-th step: f(x) = 12.180021 (action=221)
#    current best f(x) = 14.907075 (best action=342)
#
# 0223-th step: f(x) = 12.923593 (action=471)
#    current best f(x) = 14.907075 (best action=342)
#
# 0224-th step: f(x) = 10.954454 (action=273)
#    current best f(x) = 14.907075 (best action=342)
#
# 0225-th step: f(x) = 10.927216 (action=231)
#    current best f(x) = 14.907075 (best action=342)
#
# 0226-th step: f(x) = 12.848931 (action=257)
#    current best f(x) = 14.907075 (best action=342)
#
# 0227-th step: f(x) = 11.747760 (action=56)
#    current best f(x) = 14.907075 (best action=342)
#
# 0228-th step: f(x) = 12.747664 (action=243)
#    current best f(x) = 14.907075 (best action=342)
#
# 0229-th step: f(x) = 12.321462 (action=207)
#    current best f(x) = 14.907075 (best action=342)
#
# 0230-th step: f(x) = 12.255220 (action=125)
#    current best f(x) = 14.907075 (best action=342)
#
# 0231-th step: f(x) = 12.232607 (action=346)
#    current best f(x) = 14.907075 (best action=342)
#
# 0232-th step: f(x) = 10.777144 (action=411)
#    current best f(x) = 14.907075 (best action=342)
#
# 0233-th step: f(x) = 10.824694 (action=13)
#    current best f(x) = 14.907075 (best action=342)
#
# 0234-th step: f(x) = 12.500025 (action=48)
#    current best f(x) = 14.907075 (best action=342)
#
# 0235-th step: f(x) = 11.561811 (action=58)
#    current best f(x) = 14.907075 (best action=342)
#
# 0236-th step: f(x) = 11.289444 (action=226)
#    current best f(x) = 14.907075 (best action=342)
#
# 0237-th step: f(x) = 11.979479 (action=384)
#    current best f(x) = 14.907075 (best action=342)
#
# 0238-th step: f(x) = 11.797578 (action=266)
#    current best f(x) = 14.907075 (best action=342)
#
# 0239-th step: f(x) = 15.199978 (action=31)
#    current best f(x) = 15.199978 (best action=31)
#
# 0240-th step: f(x) = 11.712260 (action=486)
#    current best f(x) = 15.199978 (best action=31)
#
# 0241-th step: f(x) = 13.114851 (action=176)
#    current best f(x) = 15.199978 (best action=31)
#
# 0242-th step: f(x) = 11.292059 (action=63)
#    current best f(x) = 15.199978 (best action=31)
#
# 0243-th step: f(x) = 11.807682 (action=425)
#    current best f(x) = 15.199978 (best action=31)
#
# 0244-th step: f(x) = 11.131331 (action=28)
#    current best f(x) = 15.199978 (best action=31)
#
# 0245-th step: f(x) = 11.017555 (action=39)
#    current best f(x) = 15.199978 (best action=31)
#
# 0246-th step: f(x) = 10.972662 (action=306)
#    current best f(x) = 15.199978 (best action=31)
#
# 0247-th step: f(x) = 12.283302 (action=438)
#    current best f(x) = 15.199978 (best action=31)
#
# 0248-th step: f(x) = 11.772817 (action=393)
#    current best f(x) = 15.199978 (best action=31)
#
# 0249-th step: f(x) = 11.982223 (action=51)
#    current best f(x) = 15.199978 (best action=31)
#
# 0250-th step: f(x) = 10.896921 (action=91)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 266.4193103394017
# 50-th epoch, marginal likelihood 263.26034403012625
# 100-th epoch, marginal likelihood 258.9206184408584
# 150-th epoch, marginal likelihood 254.35493773312137
# 200-th epoch, marginal likelihood 248.25549520653377
# 250-th epoch, marginal likelihood 242.6070309456606
# 300-th epoch, marginal likelihood 237.52714680059674
# 350-th epoch, marginal likelihood 234.03567485371622
# 400-th epoch, marginal likelihood 230.1607144230012
# 450-th epoch, marginal likelihood 227.080717774404
# 500-th epoch, marginal likelihood 224.40315475252208
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [7.0320953]
#  scale  =  1.227556849436395
#  scale2 =  1.5068958185982084
#
#
# 0251-th step: f(x) = 11.948305 (action=288)
#    current best f(x) = 15.199978 (best action=31)
#
# 0252-th step: f(x) = 13.813066 (action=416)
#    current best f(x) = 15.199978 (best action=31)
#
# 0253-th step: f(x) = 12.849255 (action=412)
#    current best f(x) = 15.199978 (best action=31)
#
# 0254-th step: f(x) = 11.967225 (action=115)
#    current best f(x) = 15.199978 (best action=31)
#
# 0255-th step: f(x) = 11.085025 (action=261)
#    current best f(x) = 15.199978 (best action=31)
#
# 0256-th step: f(x) = 12.248461 (action=351)
#    current best f(x) = 15.199978 (best action=31)
#
# 0257-th step: f(x) = 12.078785 (action=206)
#    current best f(x) = 15.199978 (best action=31)
#
# 0258-th step: f(x) = 11.394897 (action=46)
#    current best f(x) = 15.199978 (best action=31)
#
# 0259-th step: f(x) = 11.458730 (action=208)
#    current best f(x) = 15.199978 (best action=31)
#
# 0260-th step: f(x) = 11.254489 (action=420)
#    current best f(x) = 15.199978 (best action=31)
#
# 0261-th step: f(x) = 11.618852 (action=121)
#    current best f(x) = 15.199978 (best action=31)
#
# 0262-th step: f(x) = 11.536828 (action=456)
#    current best f(x) = 15.199978 (best action=31)
#
# 0263-th step: f(x) = 12.650088 (action=179)
#    current best f(x) = 15.199978 (best action=31)
#
# 0264-th step: f(x) = 11.142889 (action=335)
#    current best f(x) = 15.199978 (best action=31)
#
# 0265-th step: f(x) = 12.050471 (action=427)
#    current best f(x) = 15.199978 (best action=31)
#
# 0266-th step: f(x) = 10.900656 (action=330)
#    current best f(x) = 15.199978 (best action=31)
#
# 0267-th step: f(x) = 11.554115 (action=404)
#    current best f(x) = 15.199978 (best action=31)
#
# 0268-th step: f(x) = 13.580027 (action=394)
#    current best f(x) = 15.199978 (best action=31)
#
# 0269-th step: f(x) = 12.535761 (action=109)
#    current best f(x) = 15.199978 (best action=31)
#
# 0270-th step: f(x) = 13.948974 (action=439)
#    current best f(x) = 15.199978 (best action=31)
#
# 0271-th step: f(x) = 11.219797 (action=325)
#    current best f(x) = 15.199978 (best action=31)
#
# 0272-th step: f(x) = 11.418648 (action=324)
#    current best f(x) = 15.199978 (best action=31)
#
# 0273-th step: f(x) = 10.595449 (action=225)
#    current best f(x) = 15.199978 (best action=31)
#
# 0274-th step: f(x) = 11.415023 (action=5)
#    current best f(x) = 15.199978 (best action=31)
#
# 0275-th step: f(x) = 11.172079 (action=373)
#    current best f(x) = 15.199978 (best action=31)
#
# 0276-th step: f(x) = 12.775605 (action=466)
#    current best f(x) = 15.199978 (best action=31)
#
# 0277-th step: f(x) = 11.579883 (action=21)
#    current best f(x) = 15.199978 (best action=31)
#
# 0278-th step: f(x) = 10.675901 (action=280)
#    current best f(x) = 15.199978 (best action=31)
#
# 0279-th step: f(x) = 11.419107 (action=308)
#    current best f(x) = 15.199978 (best action=31)
#
# 0280-th step: f(x) = 11.749893 (action=391)
#    current best f(x) = 15.199978 (best action=31)
#
# 0281-th step: f(x) = 11.303925 (action=136)
#    current best f(x) = 15.199978 (best action=31)
#
# 0282-th step: f(x) = 11.268019 (action=401)
#    current best f(x) = 15.199978 (best action=31)
#
# 0283-th step: f(x) = 12.115880 (action=196)
#    current best f(x) = 15.199978 (best action=31)
#
# 0284-th step: f(x) = 14.117251 (action=205)
#    current best f(x) = 15.199978 (best action=31)
#
# 0285-th step: f(x) = 13.430452 (action=38)
#    current best f(x) = 15.199978 (best action=31)
#
# 0286-th step: f(x) = 11.680616 (action=422)
#    current best f(x) = 15.199978 (best action=31)
#
# 0287-th step: f(x) = 10.601990 (action=78)
#    current best f(x) = 15.199978 (best action=31)
#
# 0288-th step: f(x) = 10.850362 (action=10)
#    current best f(x) = 15.199978 (best action=31)
#
# 0289-th step: f(x) = 10.822187 (action=97)
#    current best f(x) = 15.199978 (best action=31)
#
# 0290-th step: f(x) = 12.148417 (action=374)
#    current best f(x) = 15.199978 (best action=31)
#
# 0291-th step: f(x) = 10.538441 (action=183)
#    current best f(x) = 15.199978 (best action=31)
#
# 0292-th step: f(x) = 12.154274 (action=246)
#    current best f(x) = 15.199978 (best action=31)
#
# 0293-th step: f(x) = 11.074610 (action=253)
#    current best f(x) = 15.199978 (best action=31)
#
# 0294-th step: f(x) = 11.350903 (action=364)
#    current best f(x) = 15.199978 (best action=31)
#
# 0295-th step: f(x) = 12.359274 (action=233)
#    current best f(x) = 15.199978 (best action=31)
#
# 0296-th step: f(x) = 11.372283 (action=271)
#    current best f(x) = 15.199978 (best action=31)
#
# 0297-th step: f(x) = 11.121164 (action=15)
#    current best f(x) = 15.199978 (best action=31)
#
# 0298-th step: f(x) = 11.626058 (action=464)
#    current best f(x) = 15.199978 (best action=31)
#
# 0299-th step: f(x) = 13.629201 (action=171)
#    current best f(x) = 15.199978 (best action=31)
#
# 0300-th step: f(x) = 11.224135 (action=173)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 349.76975174920744
# 50-th epoch, marginal likelihood 339.91265197563496
# 100-th epoch, marginal likelihood 329.28987187333894
# 150-th epoch, marginal likelihood 319.24320470025725
# 200-th epoch, marginal likelihood 309.0514921341951
# 250-th epoch, marginal likelihood 299.5362535328777
# 300-th epoch, marginal likelihood 289.9030419737981
# 350-th epoch, marginal likelihood 283.79211832372494
# 400-th epoch, marginal likelihood 279.18299007183987
# 450-th epoch, marginal likelihood 276.31594740752803
# 500-th epoch, marginal likelihood 274.9249992847055
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.27321214]
#  scale  =  1.1653964173583768
#  scale2 =  1.35814880959174
#
#
# 0301-th step: f(x) = 12.107213 (action=296)
#    current best f(x) = 15.199978 (best action=31)
#
# 0302-th step: f(x) = 11.933062 (action=98)
#    current best f(x) = 15.199978 (best action=31)
#
# 0303-th step: f(x) = 12.558981 (action=385)
#    current best f(x) = 15.199978 (best action=31)
#
# 0304-th step: f(x) = 10.910575 (action=242)
#    current best f(x) = 15.199978 (best action=31)
#
# 0305-th step: f(x) = 11.420773 (action=224)
#    current best f(x) = 15.199978 (best action=31)
#
# 0306-th step: f(x) = 10.790007 (action=382)
#    current best f(x) = 15.199978 (best action=31)
#
# 0307-th step: f(x) = 11.342603 (action=12)
#    current best f(x) = 15.199978 (best action=31)
#
# 0308-th step: f(x) = 11.167719 (action=181)
#    current best f(x) = 15.199978 (best action=31)
#
# 0309-th step: f(x) = 10.867553 (action=355)
#    current best f(x) = 15.199978 (best action=31)
#
# 0310-th step: f(x) = 11.605596 (action=237)
#    current best f(x) = 15.199978 (best action=31)
#
# 0311-th step: f(x) = 12.291323 (action=380)
#    current best f(x) = 15.199978 (best action=31)
#
# 0312-th step: f(x) = 11.279764 (action=433)
#    current best f(x) = 15.199978 (best action=31)
#
# 0313-th step: f(x) = 11.595602 (action=459)
#    current best f(x) = 15.199978 (best action=31)
#
# 0314-th step: f(x) = 11.479613 (action=1)
#    current best f(x) = 15.199978 (best action=31)
#
# 0315-th step: f(x) = 10.589897 (action=435)
#    current best f(x) = 15.199978 (best action=31)
#
# 0316-th step: f(x) = 11.315061 (action=127)
#    current best f(x) = 15.199978 (best action=31)
#
# 0317-th step: f(x) = 12.074579 (action=449)
#    current best f(x) = 15.199978 (best action=31)
#
# 0318-th step: f(x) = 12.914692 (action=440)
#    current best f(x) = 15.199978 (best action=31)
#
# 0319-th step: f(x) = 10.838168 (action=451)
#    current best f(x) = 15.199978 (best action=31)
#
# 0320-th step: f(x) = 12.592154 (action=490)
#    current best f(x) = 15.199978 (best action=31)
#
# 0321-th step: f(x) = 12.236354 (action=96)
#    current best f(x) = 15.199978 (best action=31)
#
# 0322-th step: f(x) = 11.393145 (action=200)
#    current best f(x) = 15.199978 (best action=31)
#
# 0323-th step: f(x) = 12.034246 (action=361)
#    current best f(x) = 15.199978 (best action=31)
#
# 0324-th step: f(x) = 11.959142 (action=290)
#    current best f(x) = 15.199978 (best action=31)
#
# 0325-th step: f(x) = 10.834332 (action=331)
#    current best f(x) = 15.199978 (best action=31)
#
# 0326-th step: f(x) = 12.189333 (action=316)
#    current best f(x) = 15.199978 (best action=31)
#
# 0327-th step: f(x) = 12.042058 (action=240)
#    current best f(x) = 15.199978 (best action=31)
#
# 0328-th step: f(x) = 11.912748 (action=130)
#    current best f(x) = 15.199978 (best action=31)
#
# 0329-th step: f(x) = 12.093939 (action=107)
#    current best f(x) = 15.199978 (best action=31)
#
# 0330-th step: f(x) = 13.241262 (action=305)
#    current best f(x) = 15.199978 (best action=31)
#
# 0331-th step: f(x) = 10.886835 (action=6)
#    current best f(x) = 15.199978 (best action=31)
#
# 0332-th step: f(x) = 12.201452 (action=479)
#    current best f(x) = 15.199978 (best action=31)
#
# 0333-th step: f(x) = 10.852501 (action=358)
#    current best f(x) = 15.199978 (best action=31)
#
# 0334-th step: f(x) = 10.740441 (action=211)
#    current best f(x) = 15.199978 (best action=31)
#
# 0335-th step: f(x) = 10.998358 (action=8)
#    current best f(x) = 15.199978 (best action=31)
#
# 0336-th step: f(x) = 11.468653 (action=484)
#    current best f(x) = 15.199978 (best action=31)
#
# 0337-th step: f(x) = 12.429956 (action=117)
#    current best f(x) = 15.199978 (best action=31)
#
# 0338-th step: f(x) = 12.029485 (action=34)
#    current best f(x) = 15.199978 (best action=31)
#
# 0339-th step: f(x) = 11.463772 (action=353)
#    current best f(x) = 15.199978 (best action=31)
#
# 0340-th step: f(x) = 11.448708 (action=315)
#    current best f(x) = 15.199978 (best action=31)
#
# 0341-th step: f(x) = 11.383509 (action=17)
#    current best f(x) = 15.199978 (best action=31)
#
# 0342-th step: f(x) = 11.458059 (action=442)
#    current best f(x) = 15.199978 (best action=31)
#
# 0343-th step: f(x) = 11.551213 (action=251)
#    current best f(x) = 15.199978 (best action=31)
#
# 0344-th step: f(x) = 12.421889 (action=452)
#    current best f(x) = 15.199978 (best action=31)
#
# 0345-th step: f(x) = 11.425267 (action=362)
#    current best f(x) = 15.199978 (best action=31)
#
# 0346-th step: f(x) = 10.529290 (action=80)
#    current best f(x) = 15.199978 (best action=31)
#
# 0347-th step: f(x) = 12.078285 (action=267)
#    current best f(x) = 15.199978 (best action=31)
#
# 0348-th step: f(x) = 11.203542 (action=155)
#    current best f(x) = 15.199978 (best action=31)
#
# 0349-th step: f(x) = 10.695788 (action=182)
#    current best f(x) = 15.199978 (best action=31)
#
# 0350-th step: f(x) = 10.295165 (action=114)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 431.27401928746883
# 50-th epoch, marginal likelihood 408.2591492359245
# 100-th epoch, marginal likelihood 391.3764284801756
# 150-th epoch, marginal likelihood 372.58903323447134
# 200-th epoch, marginal likelihood 357.1349080134394
# 250-th epoch, marginal likelihood 343.49652359857396
# 300-th epoch, marginal likelihood 332.0660940050208
# 350-th epoch, marginal likelihood 324.4414662548161
# 400-th epoch, marginal likelihood 320.716695727332
# 450-th epoch, marginal likelihood 319.2512596164029
# 500-th epoch, marginal likelihood 318.4742953975915
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.34557255]
#  scale  =  1.1074596813872035
#  scale2 =  1.2264669458982462
#
#
# 0351-th step: f(x) = 12.107765 (action=93)
#    current best f(x) = 15.199978 (best action=31)
#
# 0352-th step: f(x) = 11.797548 (action=397)
#    current best f(x) = 15.199978 (best action=31)
#
# 0353-th step: f(x) = 10.900095 (action=327)
#    current best f(x) = 15.199978 (best action=31)
#
# 0354-th step: f(x) = 10.971218 (action=232)
#    current best f(x) = 15.199978 (best action=31)
#
# 0355-th step: f(x) = 12.254696 (action=293)
#    current best f(x) = 15.199978 (best action=31)
#
# 0356-th step: f(x) = 12.073152 (action=388)
#    current best f(x) = 15.199978 (best action=31)
#
# 0357-th step: f(x) = 11.906237 (action=124)
#    current best f(x) = 15.199978 (best action=31)
#
# 0358-th step: f(x) = 11.787142 (action=105)
#    current best f(x) = 15.199978 (best action=31)
#
# 0359-th step: f(x) = 11.063046 (action=278)
#    current best f(x) = 15.199978 (best action=31)
#
# 0360-th step: f(x) = 11.282694 (action=192)
#    current best f(x) = 15.199978 (best action=31)
#
# 0361-th step: f(x) = 10.251253 (action=406)
#    current best f(x) = 15.199978 (best action=31)
#
# 0362-th step: f(x) = 10.406131 (action=106)
#    current best f(x) = 15.199978 (best action=31)
#
# 0363-th step: f(x) = 12.616376 (action=202)
#    current best f(x) = 15.199978 (best action=31)
#
# 0364-th step: f(x) = 11.333810 (action=22)
#    current best f(x) = 15.199978 (best action=31)
#
# 0365-th step: f(x) = 10.699392 (action=198)
#    current best f(x) = 15.199978 (best action=31)
#
# 0366-th step: f(x) = 10.552137 (action=108)
#    current best f(x) = 15.199978 (best action=31)
#
# 0367-th step: f(x) = 12.219334 (action=469)
#    current best f(x) = 15.199978 (best action=31)
#
# 0368-th step: f(x) = 10.176099 (action=480)
#    current best f(x) = 15.199978 (best action=31)
#
# 0369-th step: f(x) = 11.713823 (action=329)
#    current best f(x) = 15.199978 (best action=31)
#
# 0370-th step: f(x) = 11.739615 (action=430)
#    current best f(x) = 15.199978 (best action=31)
#
# 0371-th step: f(x) = 10.563776 (action=301)
#    current best f(x) = 15.199978 (best action=31)
#
# 0372-th step: f(x) = 11.496893 (action=99)
#    current best f(x) = 15.199978 (best action=31)
#
# 0373-th step: f(x) = 11.565319 (action=371)
#    current best f(x) = 15.199978 (best action=31)
#
# 0374-th step: f(x) = 11.311431 (action=103)
#    current best f(x) = 15.199978 (best action=31)
#
# 0375-th step: f(x) = 12.062006 (action=298)
#    current best f(x) = 15.199978 (best action=31)
#
# 0376-th step: f(x) = 10.662862 (action=143)
#    current best f(x) = 15.199978 (best action=31)
#
# 0377-th step: f(x) = 11.191332 (action=204)
#    current best f(x) = 15.199978 (best action=31)
#
# 0378-th step: f(x) = 10.952023 (action=214)
#    current best f(x) = 15.199978 (best action=31)
#
# 0379-th step: f(x) = 12.864745 (action=220)
#    current best f(x) = 15.199978 (best action=31)
#
# 0380-th step: f(x) = 11.576867 (action=75)
#    current best f(x) = 15.199978 (best action=31)
#
# 0381-th step: f(x) = 11.728504 (action=294)
#    current best f(x) = 15.199978 (best action=31)
#
# 0382-th step: f(x) = 12.415357 (action=163)
#    current best f(x) = 15.199978 (best action=31)
#
# 0383-th step: f(x) = 11.263245 (action=195)
#    current best f(x) = 15.199978 (best action=31)
#
# 0384-th step: f(x) = 9.615372 (action=318)
#    current best f(x) = 15.199978 (best action=31)
#
# 0385-th step: f(x) = 10.792849 (action=199)
#    current best f(x) = 15.199978 (best action=31)
#
# 0386-th step: f(x) = 11.395841 (action=85)
#    current best f(x) = 15.199978 (best action=31)
#
# 0387-th step: f(x) = 11.259156 (action=229)
#    current best f(x) = 15.199978 (best action=31)
#
# 0388-th step: f(x) = 10.957054 (action=302)
#    current best f(x) = 15.199978 (best action=31)
#
# 0389-th step: f(x) = 10.227403 (action=300)
#    current best f(x) = 15.199978 (best action=31)
#
# 0390-th step: f(x) = 11.599598 (action=447)
#    current best f(x) = 15.199978 (best action=31)
#
# 0391-th step: f(x) = 12.091834 (action=369)
#    current best f(x) = 15.199978 (best action=31)
#
# 0392-th step: f(x) = 10.760911 (action=275)
#    current best f(x) = 15.199978 (best action=31)
#
# 0393-th step: f(x) = 10.443396 (action=457)
#    current best f(x) = 15.199978 (best action=31)
#
# 0394-th step: f(x) = 11.831146 (action=32)
#    current best f(x) = 15.199978 (best action=31)
#
# 0395-th step: f(x) = 9.865594 (action=365)
#    current best f(x) = 15.199978 (best action=31)
#
# 0396-th step: f(x) = 10.894236 (action=44)
#    current best f(x) = 15.199978 (best action=31)
#
# 0397-th step: f(x) = 10.578881 (action=90)
#    current best f(x) = 15.199978 (best action=31)
#
# 0398-th step: f(x) = 10.052558 (action=337)
#    current best f(x) = 15.199978 (best action=31)
#
# 0399-th step: f(x) = 10.367574 (action=333)
#    current best f(x) = 15.199978 (best action=31)
#
# 0400-th step: f(x) = 11.483278 (action=193)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 456.56673551742347
# 50-th epoch, marginal likelihood 433.73767403922153
# 100-th epoch, marginal likelihood 413.07048071473906
# 150-th epoch, marginal likelihood 395.17700587681105
# 200-th epoch, marginal likelihood 376.1437619764444
# 250-th epoch, marginal likelihood 361.9917063889468
# 300-th epoch, marginal likelihood 351.5850698593914
# 350-th epoch, marginal likelihood 345.8313731931897
# 400-th epoch, marginal likelihood 343.80611804822274
# 450-th epoch, marginal likelihood 343.02836700771155
# 500-th epoch, marginal likelihood 342.9610601173124
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.4862824]
#  scale  =  1.111500984820707
#  scale2 =  1.2354344392574013
#
#
# 0401-th step: f(x) = 10.140392 (action=473)
#    current best f(x) = 15.199978 (best action=31)
#
# 0402-th step: f(x) = 10.292034 (action=274)
#    current best f(x) = 15.199978 (best action=31)
#
# 0403-th step: f(x) = 10.222708 (action=161)
#    current best f(x) = 15.199978 (best action=31)
#
# 0404-th step: f(x) = 10.085563 (action=140)
#    current best f(x) = 15.199978 (best action=31)
#
# 0405-th step: f(x) = 10.310142 (action=319)
#    current best f(x) = 15.199978 (best action=31)
#
# 0406-th step: f(x) = 11.688885 (action=339)
#    current best f(x) = 15.199978 (best action=31)
#
# 0407-th step: f(x) = 11.862293 (action=414)
#    current best f(x) = 15.199978 (best action=31)
#
# 0408-th step: f(x) = 11.863730 (action=175)
#    current best f(x) = 15.199978 (best action=31)
#
# 0409-th step: f(x) = 10.831972 (action=494)
#    current best f(x) = 15.199978 (best action=31)
#
# 0410-th step: f(x) = 10.778927 (action=376)
#    current best f(x) = 15.199978 (best action=31)
#
# 0411-th step: f(x) = 9.988954 (action=53)
#    current best f(x) = 15.199978 (best action=31)
#
# 0412-th step: f(x) = 10.985828 (action=350)
#    current best f(x) = 15.199978 (best action=31)
#
# 0413-th step: f(x) = 11.691699 (action=304)
#    current best f(x) = 15.199978 (best action=31)
#
# 0414-th step: f(x) = 10.741203 (action=4)
#    current best f(x) = 15.199978 (best action=31)
#
# 0415-th step: f(x) = 10.435767 (action=144)
#    current best f(x) = 15.199978 (best action=31)
#
# 0416-th step: f(x) = 11.103749 (action=264)
#    current best f(x) = 15.199978 (best action=31)
#
# 0417-th step: f(x) = 11.558682 (action=256)
#    current best f(x) = 15.199978 (best action=31)
#
# 0418-th step: f(x) = 11.054344 (action=244)
#    current best f(x) = 15.199978 (best action=31)
#
# 0419-th step: f(x) = 11.809855 (action=113)
#    current best f(x) = 15.199978 (best action=31)
#
# 0420-th step: f(x) = 10.257400 (action=265)
#    current best f(x) = 15.199978 (best action=31)
#
# 0421-th step: f(x) = 11.835342 (action=132)
#    current best f(x) = 15.199978 (best action=31)
#
# 0422-th step: f(x) = 10.460537 (action=248)
#    current best f(x) = 15.199978 (best action=31)
#
# 0423-th step: f(x) = 10.491460 (action=170)
#    current best f(x) = 15.199978 (best action=31)
#
# 0424-th step: f(x) = 10.655811 (action=54)
#    current best f(x) = 15.199978 (best action=31)
#
# 0425-th step: f(x) = 11.859829 (action=390)
#    current best f(x) = 15.199978 (best action=31)
#
# 0426-th step: f(x) = 10.513623 (action=415)
#    current best f(x) = 15.199978 (best action=31)
#
# 0427-th step: f(x) = 11.249624 (action=218)
#    current best f(x) = 15.199978 (best action=31)
#
# 0428-th step: f(x) = 10.382457 (action=33)
#    current best f(x) = 15.199978 (best action=31)
#
# 0429-th step: f(x) = 10.372103 (action=418)
#    current best f(x) = 15.199978 (best action=31)
#
# 0430-th step: f(x) = 10.226846 (action=311)
#    current best f(x) = 15.199978 (best action=31)
#
# 0431-th step: f(x) = 12.083606 (action=66)
#    current best f(x) = 15.199978 (best action=31)
#
# 0432-th step: f(x) = 12.424244 (action=133)
#    current best f(x) = 15.199978 (best action=31)
#
# 0433-th step: f(x) = 10.159478 (action=441)
#    current best f(x) = 15.199978 (best action=31)
#
# 0434-th step: f(x) = 11.955911 (action=389)
#    current best f(x) = 15.199978 (best action=31)
#
# 0435-th step: f(x) = 10.699004 (action=492)
#    current best f(x) = 15.199978 (best action=31)
#
# 0436-th step: f(x) = 12.379227 (action=19)
#    current best f(x) = 15.199978 (best action=31)
#
# 0437-th step: f(x) = 9.760194 (action=41)
#    current best f(x) = 15.199978 (best action=31)
#
# 0438-th step: f(x) = 11.084139 (action=89)
#    current best f(x) = 15.199978 (best action=31)
#
# 0439-th step: f(x) = 12.353320 (action=281)
#    current best f(x) = 15.199978 (best action=31)
#
# 0440-th step: f(x) = 11.631375 (action=201)
#    current best f(x) = 15.199978 (best action=31)
#
# 0441-th step: f(x) = 11.221656 (action=497)
#    current best f(x) = 15.199978 (best action=31)
#
# 0442-th step: f(x) = 10.161434 (action=188)
#    current best f(x) = 15.199978 (best action=31)
#
# 0443-th step: f(x) = 10.622980 (action=303)
#    current best f(x) = 15.199978 (best action=31)
#
# 0444-th step: f(x) = 10.448575 (action=403)
#    current best f(x) = 15.199978 (best action=31)
#
# 0445-th step: f(x) = 10.512002 (action=314)
#    current best f(x) = 15.199978 (best action=31)
#
# 0446-th step: f(x) = 11.295484 (action=185)
#    current best f(x) = 15.199978 (best action=31)
#
# 0447-th step: f(x) = 11.381211 (action=354)
#    current best f(x) = 15.199978 (best action=31)
#
# 0448-th step: f(x) = 10.449700 (action=462)
#    current best f(x) = 15.199978 (best action=31)
#
# 0449-th step: f(x) = 11.461425 (action=357)
#    current best f(x) = 15.199978 (best action=31)
#
# 0450-th step: f(x) = 11.254207 (action=14)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 483.6696981946903
# 50-th epoch, marginal likelihood 458.34797180291923
# 100-th epoch, marginal likelihood 438.7399793383975
# 150-th epoch, marginal likelihood 418.47354834925477
# 200-th epoch, marginal likelihood 399.79692837145217
# 250-th epoch, marginal likelihood 384.55987594435624
# 300-th epoch, marginal likelihood 374.1445282612857
# 350-th epoch, marginal likelihood 369.51652118579784
# 400-th epoch, marginal likelihood 368.6042102675618
# 450-th epoch, marginal likelihood 368.360587560799
# 500-th epoch, marginal likelihood 368.5388298894118
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.83624621]
#  scale  =  1.1116344580700699
#  scale2 =  1.235731168368738
#
#
# 0451-th step: f(x) = 11.026365 (action=27)
#    current best f(x) = 15.199978 (best action=31)
#
# 0452-th step: f(x) = 10.761484 (action=222)
#    current best f(x) = 15.199978 (best action=31)
#
# 0453-th step: f(x) = 10.398979 (action=152)
#    current best f(x) = 15.199978 (best action=31)
#
# 0454-th step: f(x) = 12.221931 (action=249)
#    current best f(x) = 15.199978 (best action=31)
#
# 0455-th step: f(x) = 11.855082 (action=26)
#    current best f(x) = 15.199978 (best action=31)
#
# 0456-th step: f(x) = 10.287872 (action=168)
#    current best f(x) = 15.199978 (best action=31)
#
# 0457-th step: f(x) = 10.297588 (action=71)
#    current best f(x) = 15.199978 (best action=31)
#
# 0458-th step: f(x) = 10.172338 (action=297)
#    current best f(x) = 15.199978 (best action=31)
#
# 0459-th step: f(x) = 11.137141 (action=118)
#    current best f(x) = 15.199978 (best action=31)
#
# 0460-th step: f(x) = 10.775902 (action=227)
#    current best f(x) = 15.199978 (best action=31)
#
# 0461-th step: f(x) = 11.064199 (action=283)
#    current best f(x) = 15.199978 (best action=31)
#
# 0462-th step: f(x) = 10.655057 (action=167)
#    current best f(x) = 15.199978 (best action=31)
#
# 0463-th step: f(x) = 12.157838 (action=386)
#    current best f(x) = 15.199978 (best action=31)
#
# 0464-th step: f(x) = 10.523844 (action=262)
#    current best f(x) = 15.199978 (best action=31)
#
# 0465-th step: f(x) = 10.875941 (action=212)
#    current best f(x) = 15.199978 (best action=31)
#
# 0466-th step: f(x) = 11.183939 (action=379)
#    current best f(x) = 15.199978 (best action=31)
#
# 0467-th step: f(x) = 10.243322 (action=100)
#    current best f(x) = 15.199978 (best action=31)
#
# 0468-th step: f(x) = 10.261693 (action=496)
#    current best f(x) = 15.199978 (best action=31)
#
# 0469-th step: f(x) = 10.989860 (action=359)
#    current best f(x) = 15.199978 (best action=31)
#
# 0470-th step: f(x) = 10.383930 (action=468)
#    current best f(x) = 15.199978 (best action=31)
#
# 0471-th step: f(x) = 10.840919 (action=345)
#    current best f(x) = 15.199978 (best action=31)
#
# 0472-th step: f(x) = 10.957787 (action=328)
#    current best f(x) = 15.199978 (best action=31)
#
# 0473-th step: f(x) = 11.285673 (action=160)
#    current best f(x) = 15.199978 (best action=31)
#
# 0474-th step: f(x) = 11.365277 (action=289)
#    current best f(x) = 15.199978 (best action=31)
#
# 0475-th step: f(x) = 10.642205 (action=3)
#    current best f(x) = 15.199978 (best action=31)
#
# 0476-th step: f(x) = 11.240781 (action=432)
#    current best f(x) = 15.199978 (best action=31)
#
# 0477-th step: f(x) = 10.907350 (action=95)
#    current best f(x) = 15.199978 (best action=31)
#
# 0478-th step: f(x) = 11.247225 (action=217)
#    current best f(x) = 15.199978 (best action=31)
#
# 0479-th step: f(x) = 10.886038 (action=405)
#    current best f(x) = 15.199978 (best action=31)
#
# 0480-th step: f(x) = 11.631695 (action=2)
#    current best f(x) = 15.199978 (best action=31)
#
# 0481-th step: f(x) = 11.438319 (action=203)
#    current best f(x) = 15.199978 (best action=31)
#
# 0482-th step: f(x) = 11.317897 (action=434)
#    current best f(x) = 15.199978 (best action=31)
#
# 0483-th step: f(x) = 9.732569 (action=187)
#    current best f(x) = 15.199978 (best action=31)
#
# 0484-th step: f(x) = 11.069586 (action=465)
#    current best f(x) = 15.199978 (best action=31)
#
# 0485-th step: f(x) = 10.343708 (action=239)
#    current best f(x) = 15.199978 (best action=31)
#
# 0486-th step: f(x) = 11.561058 (action=474)
#    current best f(x) = 15.199978 (best action=31)
#
# 0487-th step: f(x) = 10.745824 (action=299)
#    current best f(x) = 15.199978 (best action=31)
#
# 0488-th step: f(x) = 10.488821 (action=489)
#    current best f(x) = 15.199978 (best action=31)
#
# 0489-th step: f(x) = 10.326802 (action=317)
#    current best f(x) = 15.199978 (best action=31)
#
# 0490-th step: f(x) = 11.788183 (action=419)
#    current best f(x) = 15.199978 (best action=31)
#
# 0491-th step: f(x) = 10.692779 (action=454)
#    current best f(x) = 15.199978 (best action=31)
#
# 0492-th step: f(x) = 10.584904 (action=190)
#    current best f(x) = 15.199978 (best action=31)
#
# 0493-th step: f(x) = 10.337475 (action=336)
#    current best f(x) = 15.199978 (best action=31)
#
# 0494-th step: f(x) = 11.113185 (action=116)
#    current best f(x) = 15.199978 (best action=31)
#
# 0495-th step: f(x) = 11.666445 (action=24)
#    current best f(x) = 15.199978 (best action=31)
#
# 0496-th step: f(x) = 11.793213 (action=247)
#    current best f(x) = 15.199978 (best action=31)
#
# 0497-th step: f(x) = 10.287620 (action=55)
#    current best f(x) = 15.199978 (best action=31)
#
# 0498-th step: f(x) = 10.839522 (action=65)
#    current best f(x) = 15.199978 (best action=31)
#
# 0499-th step: f(x) = 10.154558 (action=458)
#    current best f(x) = 15.199978 (best action=31)
#
# 0500-th step: f(x) = 11.446247 (action=446)
#    current best f(x) = 15.199978 (best action=31)

# %%
COMBO_EI_Henry_CO2_relevant = COMBO(Data_relevant_features_Henry_CO2, 'EI')
# Out:
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 56.00539489632693
# 50-th epoch, marginal likelihood 34.30956982227708
# 100-th epoch, marginal likelihood 19.79177385033826
# 150-th epoch, marginal likelihood 10.345404382056643
# 200-th epoch, marginal likelihood 4.303356923470417
# 250-th epoch, marginal likelihood 0.029641843070564278
# 300-th epoch, marginal likelihood -3.1173144060657165
# 350-th epoch, marginal likelihood -5.163857730630539
# 400-th epoch, marginal likelihood -6.881446361871198
# 450-th epoch, marginal likelihood -8.063612144640793
# 500-th epoch, marginal likelihood -8.990515971721933
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.]
#  scale  =  1.0
#  scale2 =  1.0
#
#
# 0101-th step: f(x) = 10.578881 (action=90)
#    current best f(x) = 10.578881 (best action=90)
#
# 0102-th step: f(x) = 11.087779 (action=150)
#    current best f(x) = 11.087779 (best action=150)
#
# 0103-th step: f(x) = 11.193615 (action=277)
#    current best f(x) = 11.193615 (best action=277)
#
# 0104-th step: f(x) = 10.909970 (action=166)
#    current best f(x) = 11.193615 (best action=277)
#
# 0105-th step: f(x) = 11.570194 (action=29)
#    current best f(x) = 11.570194 (best action=29)
#
# 0106-th step: f(x) = 11.363592 (action=463)
#    current best f(x) = 11.570194 (best action=29)
#
# 0107-th step: f(x) = 12.104178 (action=23)
#    current best f(x) = 12.104178 (best action=23)
#
# 0108-th step: f(x) = 13.433437 (action=165)
#    current best f(x) = 13.433437 (best action=165)
#
# 0109-th step: f(x) = 13.936604 (action=495)
#    current best f(x) = 13.936604 (best action=495)
#
# 0110-th step: f(x) = 12.206058 (action=194)
#    current best f(x) = 13.936604 (best action=495)
#
# 0111-th step: f(x) = 11.078800 (action=400)
#    current best f(x) = 13.936604 (best action=495)
#
# 0112-th step: f(x) = 12.007353 (action=69)
#    current best f(x) = 13.936604 (best action=495)
#
# 0113-th step: f(x) = 13.687319 (action=313)
#    current best f(x) = 13.936604 (best action=495)
#
# 0114-th step: f(x) = 10.905152 (action=307)
#    current best f(x) = 13.936604 (best action=495)
#
# 0115-th step: f(x) = 12.356719 (action=7)
#    current best f(x) = 13.936604 (best action=495)
#
# 0116-th step: f(x) = 12.468145 (action=334)
#    current best f(x) = 13.936604 (best action=495)
#
# 0117-th step: f(x) = 11.816188 (action=156)
#    current best f(x) = 13.936604 (best action=495)
#
# 0118-th step: f(x) = 12.504769 (action=453)
#    current best f(x) = 13.936604 (best action=495)
#
# 0119-th step: f(x) = 11.853454 (action=228)
#    current best f(x) = 13.936604 (best action=495)
#
# 0120-th step: f(x) = 11.695947 (action=151)
#    current best f(x) = 13.936604 (best action=495)
#
# 0121-th step: f(x) = 12.187471 (action=101)
#    current best f(x) = 13.936604 (best action=495)
#
# 0122-th step: f(x) = 11.498842 (action=153)
#    current best f(x) = 13.936604 (best action=495)
#
# 0123-th step: f(x) = 14.907075 (action=342)
#    current best f(x) = 14.907075 (best action=342)
#
# 0124-th step: f(x) = 14.162195 (action=392)
#    current best f(x) = 14.907075 (best action=342)
#
# 0125-th step: f(x) = 13.439160 (action=340)
#    current best f(x) = 14.907075 (best action=342)
#
# 0126-th step: f(x) = 14.004915 (action=407)
#    current best f(x) = 14.907075 (best action=342)
#
# 0127-th step: f(x) = 13.231695 (action=238)
#    current best f(x) = 14.907075 (best action=342)
#
# 0128-th step: f(x) = 13.113238 (action=470)
#    current best f(x) = 14.907075 (best action=342)
#
# 0129-th step: f(x) = 12.815232 (action=177)
#    current best f(x) = 14.907075 (best action=342)
#
# 0130-th step: f(x) = 13.371976 (action=320)
#    current best f(x) = 14.907075 (best action=342)
#
# 0131-th step: f(x) = 14.054575 (action=279)
#    current best f(x) = 14.907075 (best action=342)
#
# 0132-th step: f(x) = 13.550647 (action=341)
#    current best f(x) = 14.907075 (best action=342)
#
# 0133-th step: f(x) = 13.613529 (action=360)
#    current best f(x) = 14.907075 (best action=342)
#
# 0134-th step: f(x) = 14.608082 (action=79)
#    current best f(x) = 14.907075 (best action=342)
#
# 0135-th step: f(x) = 12.241179 (action=499)
#    current best f(x) = 14.907075 (best action=342)
#
# 0136-th step: f(x) = 13.388470 (action=142)
#    current best f(x) = 14.907075 (best action=342)
#
# 0137-th step: f(x) = 13.840730 (action=154)
#    current best f(x) = 14.907075 (best action=342)
#
# 0138-th step: f(x) = 12.199556 (action=149)
#    current best f(x) = 14.907075 (best action=342)
#
# 0139-th step: f(x) = 14.143965 (action=234)
#    current best f(x) = 14.907075 (best action=342)
#
# 0140-th step: f(x) = 12.625490 (action=216)
#    current best f(x) = 14.907075 (best action=342)
#
# 0141-th step: f(x) = 12.701863 (action=370)
#    current best f(x) = 14.907075 (best action=342)
#
# 0142-th step: f(x) = 14.045971 (action=436)
#    current best f(x) = 14.907075 (best action=342)
#
# 0143-th step: f(x) = 12.949820 (action=94)
#    current best f(x) = 14.907075 (best action=342)
#
# 0144-th step: f(x) = 13.546707 (action=429)
#    current best f(x) = 14.907075 (best action=342)
#
# 0145-th step: f(x) = 13.588520 (action=213)
#    current best f(x) = 14.907075 (best action=342)
#
# 0146-th step: f(x) = 13.355414 (action=472)
#    current best f(x) = 14.907075 (best action=342)
#
# 0147-th step: f(x) = 13.294333 (action=409)
#    current best f(x) = 14.907075 (best action=342)
#
# 0148-th step: f(x) = 12.713068 (action=141)
#    current best f(x) = 14.907075 (best action=342)
#
# 0149-th step: f(x) = 13.774910 (action=57)
#    current best f(x) = 14.907075 (best action=342)
#
# 0150-th step: f(x) = 13.849071 (action=408)
#    current best f(x) = 14.907075 (best action=342)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 115.77064984905536
# 50-th epoch, marginal likelihood 115.0373550442544
# 100-th epoch, marginal likelihood 115.36990954220347
# 150-th epoch, marginal likelihood 114.71209162158017
# 200-th epoch, marginal likelihood 113.38444778537176
# 250-th epoch, marginal likelihood 111.8830754830851
# 300-th epoch, marginal likelihood 110.24811866195643
# 350-th epoch, marginal likelihood 108.54766763437239
# 400-th epoch, marginal likelihood 107.00804771676553
# 450-th epoch, marginal likelihood 105.64438552501593
# 500-th epoch, marginal likelihood 104.43396669845825
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [2.61301648]
#  scale  =  0.25867359211445085
#  scale2 =  0.06691202725739329
#
#
# 0151-th step: f(x) = 12.623443 (action=134)
#    current best f(x) = 14.907075 (best action=342)
#
# 0152-th step: f(x) = 14.562293 (action=481)
#    current best f(x) = 14.907075 (best action=342)
#
# 0153-th step: f(x) = 14.470462 (action=478)
#    current best f(x) = 14.907075 (best action=342)
#
# 0154-th step: f(x) = 13.359511 (action=86)
#    current best f(x) = 14.907075 (best action=342)
#
# 0155-th step: f(x) = 11.837441 (action=348)
#    current best f(x) = 14.907075 (best action=342)
#
# 0156-th step: f(x) = 12.729697 (action=158)
#    current best f(x) = 14.907075 (best action=342)
#
# 0157-th step: f(x) = 13.985827 (action=326)
#    current best f(x) = 14.907075 (best action=342)
#
# 0158-th step: f(x) = 14.455732 (action=84)
#    current best f(x) = 14.907075 (best action=342)
#
# 0159-th step: f(x) = 10.906163 (action=383)
#    current best f(x) = 14.907075 (best action=342)
#
# 0160-th step: f(x) = 13.666899 (action=62)
#    current best f(x) = 14.907075 (best action=342)
#
# 0161-th step: f(x) = 12.091924 (action=475)
#    current best f(x) = 14.907075 (best action=342)
#
# 0162-th step: f(x) = 13.663556 (action=40)
#    current best f(x) = 14.907075 (best action=342)
#
# 0163-th step: f(x) = 12.943906 (action=487)
#    current best f(x) = 14.907075 (best action=342)
#
# 0164-th step: f(x) = 12.775475 (action=263)
#    current best f(x) = 14.907075 (best action=342)
#
# 0165-th step: f(x) = 13.346476 (action=292)
#    current best f(x) = 14.907075 (best action=342)
#
# 0166-th step: f(x) = 13.545193 (action=215)
#    current best f(x) = 14.907075 (best action=342)
#
# 0167-th step: f(x) = 12.391548 (action=396)
#    current best f(x) = 14.907075 (best action=342)
#
# 0168-th step: f(x) = 10.817089 (action=102)
#    current best f(x) = 14.907075 (best action=342)
#
# 0169-th step: f(x) = 13.023539 (action=45)
#    current best f(x) = 14.907075 (best action=342)
#
# 0170-th step: f(x) = 12.678346 (action=428)
#    current best f(x) = 14.907075 (best action=342)
#
# 0171-th step: f(x) = 12.177282 (action=498)
#    current best f(x) = 14.907075 (best action=342)
#
# 0172-th step: f(x) = 11.620990 (action=219)
#    current best f(x) = 14.907075 (best action=342)
#
# 0173-th step: f(x) = 12.654977 (action=172)
#    current best f(x) = 14.907075 (best action=342)
#
# 0174-th step: f(x) = 10.597839 (action=129)
#    current best f(x) = 14.907075 (best action=342)
#
# 0175-th step: f(x) = 12.064163 (action=77)
#    current best f(x) = 14.907075 (best action=342)
#
# 0176-th step: f(x) = 12.521989 (action=309)
#    current best f(x) = 14.907075 (best action=342)
#
# 0177-th step: f(x) = 11.201851 (action=178)
#    current best f(x) = 14.907075 (best action=342)
#
# 0178-th step: f(x) = 12.238690 (action=483)
#    current best f(x) = 14.907075 (best action=342)
#
# 0179-th step: f(x) = 10.685140 (action=268)
#    current best f(x) = 14.907075 (best action=342)
#
# 0180-th step: f(x) = 13.539830 (action=417)
#    current best f(x) = 14.907075 (best action=342)
#
# 0181-th step: f(x) = 14.477286 (action=76)
#    current best f(x) = 14.907075 (best action=342)
#
# 0182-th step: f(x) = 13.252711 (action=59)
#    current best f(x) = 14.907075 (best action=342)
#
# 0183-th step: f(x) = 12.169875 (action=276)
#    current best f(x) = 14.907075 (best action=342)
#
# 0184-th step: f(x) = 11.457136 (action=67)
#    current best f(x) = 14.907075 (best action=342)
#
# 0185-th step: f(x) = 12.147808 (action=162)
#    current best f(x) = 14.907075 (best action=342)
#
# 0186-th step: f(x) = 11.099243 (action=184)
#    current best f(x) = 14.907075 (best action=342)
#
# 0187-th step: f(x) = 11.840141 (action=488)
#    current best f(x) = 14.907075 (best action=342)
#
# 0188-th step: f(x) = 12.291456 (action=20)
#    current best f(x) = 14.907075 (best action=342)
#
# 0189-th step: f(x) = 11.472237 (action=461)
#    current best f(x) = 14.907075 (best action=342)
#
# 0190-th step: f(x) = 11.448708 (action=315)
#    current best f(x) = 14.907075 (best action=342)
#
# 0191-th step: f(x) = 10.717455 (action=250)
#    current best f(x) = 14.907075 (best action=342)
#
# 0192-th step: f(x) = 12.541712 (action=377)
#    current best f(x) = 14.907075 (best action=342)
#
# 0193-th step: f(x) = 10.768940 (action=83)
#    current best f(x) = 14.907075 (best action=342)
#
# 0194-th step: f(x) = 12.299736 (action=128)
#    current best f(x) = 14.907075 (best action=342)
#
# 0195-th step: f(x) = 12.893953 (action=64)
#    current best f(x) = 14.907075 (best action=342)
#
# 0196-th step: f(x) = 11.478575 (action=81)
#    current best f(x) = 14.907075 (best action=342)
#
# 0197-th step: f(x) = 13.603537 (action=431)
#    current best f(x) = 14.907075 (best action=342)
#
# 0198-th step: f(x) = 11.738139 (action=259)
#    current best f(x) = 14.907075 (best action=342)
#
# 0199-th step: f(x) = 12.305130 (action=270)
#    current best f(x) = 14.907075 (best action=342)
#
# 0200-th step: f(x) = 12.871684 (action=148)
#    current best f(x) = 14.907075 (best action=342)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 176.93191721998306
# 50-th epoch, marginal likelihood 177.29879967577384
# 100-th epoch, marginal likelihood 173.62206201439125
# 150-th epoch, marginal likelihood 170.240028413745
# 200-th epoch, marginal likelihood 167.1900313626235
# 250-th epoch, marginal likelihood 163.6254454755894
# 300-th epoch, marginal likelihood 161.16528003244903
# 350-th epoch, marginal likelihood 159.1962800179669
# 400-th epoch, marginal likelihood 157.67703848039332
# 450-th epoch, marginal likelihood 156.5630331257584
# 500-th epoch, marginal likelihood 155.8816228947545
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [5.99754024]
#  scale  =  1.091154782783429
#  scale2 =  1.190618759991152
#
#
# 0201-th step: f(x) = 12.980763 (action=36)
#    current best f(x) = 14.907075 (best action=342)
#
# 0202-th step: f(x) = 13.392218 (action=437)
#    current best f(x) = 14.907075 (best action=342)
#
# 0203-th step: f(x) = 14.769074 (action=252)
#    current best f(x) = 14.907075 (best action=342)
#
# 0204-th step: f(x) = 13.003787 (action=169)
#    current best f(x) = 14.907075 (best action=342)
#
# 0205-th step: f(x) = 12.054249 (action=73)
#    current best f(x) = 14.907075 (best action=342)
#
# 0206-th step: f(x) = 12.707236 (action=338)
#    current best f(x) = 14.907075 (best action=342)
#
# 0207-th step: f(x) = 13.672768 (action=321)
#    current best f(x) = 14.907075 (best action=342)
#
# 0208-th step: f(x) = 12.516340 (action=18)
#    current best f(x) = 14.907075 (best action=342)
#
# 0209-th step: f(x) = 12.626932 (action=235)
#    current best f(x) = 14.907075 (best action=342)
#
# 0210-th step: f(x) = 11.349901 (action=42)
#    current best f(x) = 14.907075 (best action=342)
#
# 0211-th step: f(x) = 12.109578 (action=443)
#    current best f(x) = 14.907075 (best action=342)
#
# 0212-th step: f(x) = 13.460839 (action=424)
#    current best f(x) = 14.907075 (best action=342)
#
# 0213-th step: f(x) = 12.267379 (action=70)
#    current best f(x) = 14.907075 (best action=342)
#
# 0214-th step: f(x) = 12.105849 (action=30)
#    current best f(x) = 14.907075 (best action=342)
#
# 0215-th step: f(x) = 12.713222 (action=50)
#    current best f(x) = 14.907075 (best action=342)
#
# 0216-th step: f(x) = 12.986748 (action=209)
#    current best f(x) = 14.907075 (best action=342)
#
# 0217-th step: f(x) = 12.272534 (action=352)
#    current best f(x) = 14.907075 (best action=342)
#
# 0218-th step: f(x) = 11.553520 (action=88)
#    current best f(x) = 14.907075 (best action=342)
#
# 0219-th step: f(x) = 11.352042 (action=444)
#    current best f(x) = 14.907075 (best action=342)
#
# 0220-th step: f(x) = 12.174262 (action=295)
#    current best f(x) = 14.907075 (best action=342)
#
# 0221-th step: f(x) = 12.180021 (action=221)
#    current best f(x) = 14.907075 (best action=342)
#
# 0222-th step: f(x) = 11.936276 (action=112)
#    current best f(x) = 14.907075 (best action=342)
#
# 0223-th step: f(x) = 10.954454 (action=273)
#    current best f(x) = 14.907075 (best action=342)
#
# 0224-th step: f(x) = 12.923593 (action=471)
#    current best f(x) = 14.907075 (best action=342)
#
# 0225-th step: f(x) = 10.927216 (action=231)
#    current best f(x) = 14.907075 (best action=342)
#
# 0226-th step: f(x) = 11.747760 (action=56)
#    current best f(x) = 14.907075 (best action=342)
#
# 0227-th step: f(x) = 12.848931 (action=257)
#    current best f(x) = 14.907075 (best action=342)
#
# 0228-th step: f(x) = 12.747664 (action=243)
#    current best f(x) = 14.907075 (best action=342)
#
# 0229-th step: f(x) = 12.321462 (action=207)
#    current best f(x) = 14.907075 (best action=342)
#
# 0230-th step: f(x) = 12.163645 (action=343)
#    current best f(x) = 14.907075 (best action=342)
#
# 0231-th step: f(x) = 10.824694 (action=13)
#    current best f(x) = 14.907075 (best action=342)
#
# 0232-th step: f(x) = 12.232607 (action=346)
#    current best f(x) = 14.907075 (best action=342)
#
# 0233-th step: f(x) = 10.777144 (action=411)
#    current best f(x) = 14.907075 (best action=342)
#
# 0234-th step: f(x) = 12.500025 (action=48)
#    current best f(x) = 14.907075 (best action=342)
#
# 0235-th step: f(x) = 11.561811 (action=58)
#    current best f(x) = 14.907075 (best action=342)
#
# 0236-th step: f(x) = 11.289444 (action=226)
#    current best f(x) = 14.907075 (best action=342)
#
# 0237-th step: f(x) = 11.797578 (action=266)
#    current best f(x) = 14.907075 (best action=342)
#
# 0238-th step: f(x) = 11.979479 (action=384)
#    current best f(x) = 14.907075 (best action=342)
#
# 0239-th step: f(x) = 15.199978 (action=31)
#    current best f(x) = 15.199978 (best action=31)
#
# 0240-th step: f(x) = 12.255220 (action=125)
#    current best f(x) = 15.199978 (best action=31)
#
# 0241-th step: f(x) = 13.114851 (action=176)
#    current best f(x) = 15.199978 (best action=31)
#
# 0242-th step: f(x) = 11.292059 (action=63)
#    current best f(x) = 15.199978 (best action=31)
#
# 0243-th step: f(x) = 11.131331 (action=28)
#    current best f(x) = 15.199978 (best action=31)
#
# 0244-th step: f(x) = 10.972662 (action=306)
#    current best f(x) = 15.199978 (best action=31)
#
# 0245-th step: f(x) = 11.807682 (action=425)
#    current best f(x) = 15.199978 (best action=31)
#
# 0246-th step: f(x) = 11.017555 (action=39)
#    current best f(x) = 15.199978 (best action=31)
#
# 0247-th step: f(x) = 11.712260 (action=486)
#    current best f(x) = 15.199978 (best action=31)
#
# 0248-th step: f(x) = 12.283302 (action=438)
#    current best f(x) = 15.199978 (best action=31)
#
# 0249-th step: f(x) = 11.982223 (action=51)
#    current best f(x) = 15.199978 (best action=31)
#
# 0250-th step: f(x) = 11.772817 (action=393)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 269.1554515316416
# 50-th epoch, marginal likelihood 263.5200766457317
# 100-th epoch, marginal likelihood 257.50193917537183
# 150-th epoch, marginal likelihood 253.50208922148713
# 200-th epoch, marginal likelihood 247.9967485853542
# 250-th epoch, marginal likelihood 242.18713905196086
# 300-th epoch, marginal likelihood 237.13989031641216
# 350-th epoch, marginal likelihood 232.99834165815088
# 400-th epoch, marginal likelihood 229.27041589342818
# 450-th epoch, marginal likelihood 226.5031962148514
# 500-th epoch, marginal likelihood 224.15863677619228
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.99229369]
#  scale  =  1.2187609382018572
#  scale2 =  1.4853782244866711
#
#
# 0251-th step: f(x) = 11.948305 (action=288)
#    current best f(x) = 15.199978 (best action=31)
#
# 0252-th step: f(x) = 12.849255 (action=412)
#    current best f(x) = 15.199978 (best action=31)
#
# 0253-th step: f(x) = 11.967225 (action=115)
#    current best f(x) = 15.199978 (best action=31)
#
# 0254-th step: f(x) = 11.085025 (action=261)
#    current best f(x) = 15.199978 (best action=31)
#
# 0255-th step: f(x) = 13.813066 (action=416)
#    current best f(x) = 15.199978 (best action=31)
#
# 0256-th step: f(x) = 12.248461 (action=351)
#    current best f(x) = 15.199978 (best action=31)
#
# 0257-th step: f(x) = 11.394897 (action=46)
#    current best f(x) = 15.199978 (best action=31)
#
# 0258-th step: f(x) = 14.117251 (action=205)
#    current best f(x) = 15.199978 (best action=31)
#
# 0259-th step: f(x) = 12.078785 (action=206)
#    current best f(x) = 15.199978 (best action=31)
#
# 0260-th step: f(x) = 12.650088 (action=179)
#    current best f(x) = 15.199978 (best action=31)
#
# 0261-th step: f(x) = 11.458730 (action=208)
#    current best f(x) = 15.199978 (best action=31)
#
# 0262-th step: f(x) = 11.254489 (action=420)
#    current best f(x) = 15.199978 (best action=31)
#
# 0263-th step: f(x) = 10.896921 (action=91)
#    current best f(x) = 15.199978 (best action=31)
#
# 0264-th step: f(x) = 11.618852 (action=121)
#    current best f(x) = 15.199978 (best action=31)
#
# 0265-th step: f(x) = 11.536828 (action=456)
#    current best f(x) = 15.199978 (best action=31)
#
# 0266-th step: f(x) = 12.050471 (action=427)
#    current best f(x) = 15.199978 (best action=31)
#
# 0267-th step: f(x) = 11.554115 (action=404)
#    current best f(x) = 15.199978 (best action=31)
#
# 0268-th step: f(x) = 11.142889 (action=335)
#    current best f(x) = 15.199978 (best action=31)
#
# 0269-th step: f(x) = 10.900656 (action=330)
#    current best f(x) = 15.199978 (best action=31)
#
# 0270-th step: f(x) = 11.418648 (action=324)
#    current best f(x) = 15.199978 (best action=31)
#
# 0271-th step: f(x) = 12.535761 (action=109)
#    current best f(x) = 15.199978 (best action=31)
#
# 0272-th step: f(x) = 10.601990 (action=78)
#    current best f(x) = 15.199978 (best action=31)
#
# 0273-th step: f(x) = 11.579883 (action=21)
#    current best f(x) = 15.199978 (best action=31)
#
# 0274-th step: f(x) = 11.074610 (action=253)
#    current best f(x) = 15.199978 (best action=31)
#
# 0275-th step: f(x) = 11.415023 (action=5)
#    current best f(x) = 15.199978 (best action=31)
#
# 0276-th step: f(x) = 11.172079 (action=373)
#    current best f(x) = 15.199978 (best action=31)
#
# 0277-th step: f(x) = 12.775605 (action=466)
#    current best f(x) = 15.199978 (best action=31)
#
# 0278-th step: f(x) = 11.303925 (action=136)
#    current best f(x) = 15.199978 (best action=31)
#
# 0279-th step: f(x) = 13.948974 (action=439)
#    current best f(x) = 15.199978 (best action=31)
#
# 0280-th step: f(x) = 13.580027 (action=394)
#    current best f(x) = 15.199978 (best action=31)
#
# 0281-th step: f(x) = 10.595449 (action=225)
#    current best f(x) = 15.199978 (best action=31)
#
# 0282-th step: f(x) = 11.419107 (action=308)
#    current best f(x) = 15.199978 (best action=31)
#
# 0283-th step: f(x) = 10.675901 (action=280)
#    current best f(x) = 15.199978 (best action=31)
#
# 0284-th step: f(x) = 11.749893 (action=391)
#    current best f(x) = 15.199978 (best action=31)
#
# 0285-th step: f(x) = 11.268019 (action=401)
#    current best f(x) = 15.199978 (best action=31)
#
# 0286-th step: f(x) = 13.430452 (action=38)
#    current best f(x) = 15.199978 (best action=31)
#
# 0287-th step: f(x) = 12.115880 (action=196)
#    current best f(x) = 15.199978 (best action=31)
#
# 0288-th step: f(x) = 10.850362 (action=10)
#    current best f(x) = 15.199978 (best action=31)
#
# 0289-th step: f(x) = 10.822187 (action=97)
#    current best f(x) = 15.199978 (best action=31)
#
# 0290-th step: f(x) = 11.680616 (action=422)
#    current best f(x) = 15.199978 (best action=31)
#
# 0291-th step: f(x) = 10.538441 (action=183)
#    current best f(x) = 15.199978 (best action=31)
#
# 0292-th step: f(x) = 12.148417 (action=374)
#    current best f(x) = 15.199978 (best action=31)
#
# 0293-th step: f(x) = 12.154274 (action=246)
#    current best f(x) = 15.199978 (best action=31)
#
# 0294-th step: f(x) = 11.121164 (action=15)
#    current best f(x) = 15.199978 (best action=31)
#
# 0295-th step: f(x) = 11.350903 (action=364)
#    current best f(x) = 15.199978 (best action=31)
#
# 0296-th step: f(x) = 11.372283 (action=271)
#    current best f(x) = 15.199978 (best action=31)
#
# 0297-th step: f(x) = 12.359274 (action=233)
#    current best f(x) = 15.199978 (best action=31)
#
# 0298-th step: f(x) = 12.291323 (action=380)
#    current best f(x) = 15.199978 (best action=31)
#
# 0299-th step: f(x) = 10.790007 (action=382)
#    current best f(x) = 15.199978 (best action=31)
#
# 0300-th step: f(x) = 11.342603 (action=12)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 352.14420001469284
# 50-th epoch, marginal likelihood 339.14720364860557
# 100-th epoch, marginal likelihood 329.21851922208685
# 150-th epoch, marginal likelihood 318.14744632232475
# 200-th epoch, marginal likelihood 307.7908084491972
# 250-th epoch, marginal likelihood 297.8628285401161
# 300-th epoch, marginal likelihood 290.203883781699
# 350-th epoch, marginal likelihood 283.4038543411747
# 400-th epoch, marginal likelihood 278.1668362632695
# 450-th epoch, marginal likelihood 274.1100360330667
# 500-th epoch, marginal likelihood 272.0305139869698
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.26414124]
#  scale  =  1.1767546257508017
#  scale2 =  1.3847514492259094
#
#
# 0301-th step: f(x) = 13.629201 (action=171)
#    current best f(x) = 15.199978 (best action=31)
#
# 0302-th step: f(x) = 11.224135 (action=173)
#    current best f(x) = 15.199978 (best action=31)
#
# 0303-th step: f(x) = 12.034246 (action=361)
#    current best f(x) = 15.199978 (best action=31)
#
# 0304-th step: f(x) = 10.910575 (action=242)
#    current best f(x) = 15.199978 (best action=31)
#
# 0305-th step: f(x) = 11.167719 (action=181)
#    current best f(x) = 15.199978 (best action=31)
#
# 0306-th step: f(x) = 11.933062 (action=98)
#    current best f(x) = 15.199978 (best action=31)
#
# 0307-th step: f(x) = 12.107213 (action=296)
#    current best f(x) = 15.199978 (best action=31)
#
# 0308-th step: f(x) = 11.605596 (action=237)
#    current best f(x) = 15.199978 (best action=31)
#
# 0309-th step: f(x) = 10.867553 (action=355)
#    current best f(x) = 15.199978 (best action=31)
#
# 0310-th step: f(x) = 11.279764 (action=433)
#    current best f(x) = 15.199978 (best action=31)
#
# 0311-th step: f(x) = 11.219797 (action=325)
#    current best f(x) = 15.199978 (best action=31)
#
# 0312-th step: f(x) = 12.558981 (action=385)
#    current best f(x) = 15.199978 (best action=31)
#
# 0313-th step: f(x) = 11.479613 (action=1)
#    current best f(x) = 15.199978 (best action=31)
#
# 0314-th step: f(x) = 11.595602 (action=459)
#    current best f(x) = 15.199978 (best action=31)
#
# 0315-th step: f(x) = 11.626058 (action=464)
#    current best f(x) = 15.199978 (best action=31)
#
# 0316-th step: f(x) = 10.589897 (action=435)
#    current best f(x) = 15.199978 (best action=31)
#
# 0317-th step: f(x) = 11.315061 (action=127)
#    current best f(x) = 15.199978 (best action=31)
#
# 0318-th step: f(x) = 12.074579 (action=449)
#    current best f(x) = 15.199978 (best action=31)
#
# 0319-th step: f(x) = 11.420773 (action=224)
#    current best f(x) = 15.199978 (best action=31)
#
# 0320-th step: f(x) = 12.914692 (action=440)
#    current best f(x) = 15.199978 (best action=31)
#
# 0321-th step: f(x) = 10.838168 (action=451)
#    current best f(x) = 15.199978 (best action=31)
#
# 0322-th step: f(x) = 12.236354 (action=96)
#    current best f(x) = 15.199978 (best action=31)
#
# 0323-th step: f(x) = 11.393145 (action=200)
#    current best f(x) = 15.199978 (best action=31)
#
# 0324-th step: f(x) = 10.834332 (action=331)
#    current best f(x) = 15.199978 (best action=31)
#
# 0325-th step: f(x) = 12.189333 (action=316)
#    current best f(x) = 15.199978 (best action=31)
#
# 0326-th step: f(x) = 12.592154 (action=490)
#    current best f(x) = 15.199978 (best action=31)
#
# 0327-th step: f(x) = 11.912748 (action=130)
#    current best f(x) = 15.199978 (best action=31)
#
# 0328-th step: f(x) = 12.093939 (action=107)
#    current best f(x) = 15.199978 (best action=31)
#
# 0329-th step: f(x) = 11.959142 (action=290)
#    current best f(x) = 15.199978 (best action=31)
#
# 0330-th step: f(x) = 10.740441 (action=211)
#    current best f(x) = 15.199978 (best action=31)
#
# 0331-th step: f(x) = 10.886835 (action=6)
#    current best f(x) = 15.199978 (best action=31)
#
# 0332-th step: f(x) = 10.852501 (action=358)
#    current best f(x) = 15.199978 (best action=31)
#
# 0333-th step: f(x) = 12.201452 (action=479)
#    current best f(x) = 15.199978 (best action=31)
#
# 0334-th step: f(x) = 11.468653 (action=484)
#    current best f(x) = 15.199978 (best action=31)
#
# 0335-th step: f(x) = 12.042058 (action=240)
#    current best f(x) = 15.199978 (best action=31)
#
# 0336-th step: f(x) = 10.998358 (action=8)
#    current best f(x) = 15.199978 (best action=31)
#
# 0337-th step: f(x) = 11.425267 (action=362)
#    current best f(x) = 15.199978 (best action=31)
#
# 0338-th step: f(x) = 12.029485 (action=34)
#    current best f(x) = 15.199978 (best action=31)
#
# 0339-th step: f(x) = 10.695788 (action=182)
#    current best f(x) = 15.199978 (best action=31)
#
# 0340-th step: f(x) = 10.900095 (action=327)
#    current best f(x) = 15.199978 (best action=31)
#
# 0341-th step: f(x) = 12.429956 (action=117)
#    current best f(x) = 15.199978 (best action=31)
#
# 0342-th step: f(x) = 11.463772 (action=353)
#    current best f(x) = 15.199978 (best action=31)
#
# 0343-th step: f(x) = 11.203542 (action=155)
#    current best f(x) = 15.199978 (best action=31)
#
# 0344-th step: f(x) = 11.551213 (action=251)
#    current best f(x) = 15.199978 (best action=31)
#
# 0345-th step: f(x) = 11.458059 (action=442)
#    current best f(x) = 15.199978 (best action=31)
#
# 0346-th step: f(x) = 11.383509 (action=17)
#    current best f(x) = 15.199978 (best action=31)
#
# 0347-th step: f(x) = 10.971218 (action=232)
#    current best f(x) = 15.199978 (best action=31)
#
# 0348-th step: f(x) = 12.254696 (action=293)
#    current best f(x) = 15.199978 (best action=31)
#
# 0349-th step: f(x) = 12.421889 (action=452)
#    current best f(x) = 15.199978 (best action=31)
#
# 0350-th step: f(x) = 11.282694 (action=192)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 419.6171201244484
# 50-th epoch, marginal likelihood 400.4796037875265
# 100-th epoch, marginal likelihood 383.967662832108
# 150-th epoch, marginal likelihood 368.06787481854343
# 200-th epoch, marginal likelihood 356.2366784149555
# 250-th epoch, marginal likelihood 342.65737067165264
# 300-th epoch, marginal likelihood 331.9652705171951
# 350-th epoch, marginal likelihood 325.7288673033052
# 400-th epoch, marginal likelihood 321.5624049576627
# 450-th epoch, marginal likelihood 319.17507431479555
# 500-th epoch, marginal likelihood 318.29520528529986
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.09151441]
#  scale  =  1.113131889679109
#  scale2 =  1.2390626038205839
#
#
# 0351-th step: f(x) = 10.295165 (action=114)
#    current best f(x) = 15.199978 (best action=31)
#
# 0352-th step: f(x) = 10.529290 (action=80)
#    current best f(x) = 15.199978 (best action=31)
#
# 0353-th step: f(x) = 12.078285 (action=267)
#    current best f(x) = 15.199978 (best action=31)
#
# 0354-th step: f(x) = 12.107765 (action=93)
#    current best f(x) = 15.199978 (best action=31)
#
# 0355-th step: f(x) = 12.073152 (action=388)
#    current best f(x) = 15.199978 (best action=31)
#
# 0356-th step: f(x) = 12.062006 (action=298)
#    current best f(x) = 15.199978 (best action=31)
#
# 0357-th step: f(x) = 11.906237 (action=124)
#    current best f(x) = 15.199978 (best action=31)
#
# 0358-th step: f(x) = 11.787142 (action=105)
#    current best f(x) = 15.199978 (best action=31)
#
# 0359-th step: f(x) = 11.797548 (action=397)
#    current best f(x) = 15.199978 (best action=31)
#
# 0360-th step: f(x) = 11.063046 (action=278)
#    current best f(x) = 15.199978 (best action=31)
#
# 0361-th step: f(x) = 10.552137 (action=108)
#    current best f(x) = 15.199978 (best action=31)
#
# 0362-th step: f(x) = 12.219334 (action=469)
#    current best f(x) = 15.199978 (best action=31)
#
# 0363-th step: f(x) = 10.251253 (action=406)
#    current best f(x) = 15.199978 (best action=31)
#
# 0364-th step: f(x) = 10.406131 (action=106)
#    current best f(x) = 15.199978 (best action=31)
#
# 0365-th step: f(x) = 11.713823 (action=329)
#    current best f(x) = 15.199978 (best action=31)
#
# 0366-th step: f(x) = 12.616376 (action=202)
#    current best f(x) = 15.199978 (best action=31)
#
# 0367-th step: f(x) = 11.496893 (action=99)
#    current best f(x) = 15.199978 (best action=31)
#
# 0368-th step: f(x) = 11.739615 (action=430)
#    current best f(x) = 15.199978 (best action=31)
#
# 0369-th step: f(x) = 10.563776 (action=301)
#    current best f(x) = 15.199978 (best action=31)
#
# 0370-th step: f(x) = 11.565319 (action=371)
#    current best f(x) = 15.199978 (best action=31)
#
# 0371-th step: f(x) = 10.176099 (action=480)
#    current best f(x) = 15.199978 (best action=31)
#
# 0372-th step: f(x) = 11.333810 (action=22)
#    current best f(x) = 15.199978 (best action=31)
#
# 0373-th step: f(x) = 10.699392 (action=198)
#    current best f(x) = 15.199978 (best action=31)
#
# 0374-th step: f(x) = 11.311431 (action=103)
#    current best f(x) = 15.199978 (best action=31)
#
# 0375-th step: f(x) = 10.662862 (action=143)
#    current best f(x) = 15.199978 (best action=31)
#
# 0376-th step: f(x) = 11.191332 (action=204)
#    current best f(x) = 15.199978 (best action=31)
#
# 0377-th step: f(x) = 10.952023 (action=214)
#    current best f(x) = 15.199978 (best action=31)
#
# 0378-th step: f(x) = 12.864745 (action=220)
#    current best f(x) = 15.199978 (best action=31)
#
# 0379-th step: f(x) = 13.241262 (action=305)
#    current best f(x) = 15.199978 (best action=31)
#
# 0380-th step: f(x) = 11.576867 (action=75)
#    current best f(x) = 15.199978 (best action=31)
#
# 0381-th step: f(x) = 11.728504 (action=294)
#    current best f(x) = 15.199978 (best action=31)
#
# 0382-th step: f(x) = 11.263245 (action=195)
#    current best f(x) = 15.199978 (best action=31)
#
# 0383-th step: f(x) = 12.415357 (action=163)
#    current best f(x) = 15.199978 (best action=31)
#
# 0384-th step: f(x) = 10.792849 (action=199)
#    current best f(x) = 15.199978 (best action=31)
#
# 0385-th step: f(x) = 11.395841 (action=85)
#    current best f(x) = 15.199978 (best action=31)
#
# 0386-th step: f(x) = 11.259156 (action=229)
#    current best f(x) = 15.199978 (best action=31)
#
# 0387-th step: f(x) = 10.957054 (action=302)
#    current best f(x) = 15.199978 (best action=31)
#
# 0388-th step: f(x) = 9.615372 (action=318)
#    current best f(x) = 15.199978 (best action=31)
#
# 0389-th step: f(x) = 11.599598 (action=447)
#    current best f(x) = 15.199978 (best action=31)
#
# 0390-th step: f(x) = 10.760911 (action=275)
#    current best f(x) = 15.199978 (best action=31)
#
# 0391-th step: f(x) = 11.831146 (action=32)
#    current best f(x) = 15.199978 (best action=31)
#
# 0392-th step: f(x) = 12.091834 (action=369)
#    current best f(x) = 15.199978 (best action=31)
#
# 0393-th step: f(x) = 10.227403 (action=300)
#    current best f(x) = 15.199978 (best action=31)
#
# 0394-th step: f(x) = 10.894236 (action=44)
#    current best f(x) = 15.199978 (best action=31)
#
# 0395-th step: f(x) = 11.483278 (action=193)
#    current best f(x) = 15.199978 (best action=31)
#
# 0396-th step: f(x) = 10.443396 (action=457)
#    current best f(x) = 15.199978 (best action=31)
#
# 0397-th step: f(x) = 9.865594 (action=365)
#    current best f(x) = 15.199978 (best action=31)
#
# 0398-th step: f(x) = 11.863730 (action=175)
#    current best f(x) = 15.199978 (best action=31)
#
# 0399-th step: f(x) = 11.688885 (action=339)
#    current best f(x) = 15.199978 (best action=31)
#
# 0400-th step: f(x) = 10.367574 (action=333)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 456.80875936884917
# 50-th epoch, marginal likelihood 436.3363370987646
# 100-th epoch, marginal likelihood 410.25827087022185
# 150-th epoch, marginal likelihood 392.203394891992
# 200-th epoch, marginal likelihood 374.24059845672326
# 250-th epoch, marginal likelihood 360.5235914603047
# 300-th epoch, marginal likelihood 350.7087707073299
# 350-th epoch, marginal likelihood 346.5327093570096
# 400-th epoch, marginal likelihood 345.0016534707474
# 450-th epoch, marginal likelihood 344.4757244399156
# 500-th epoch, marginal likelihood 344.3500823145681
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.334496]
#  scale  =  1.093844733300972
#  scale2 =  1.1964963005702745
#
#
# 0401-th step: f(x) = 10.052558 (action=337)
#    current best f(x) = 15.199978 (best action=31)
#
# 0402-th step: f(x) = 10.140392 (action=473)
#    current best f(x) = 15.199978 (best action=31)
#
# 0403-th step: f(x) = 10.085563 (action=140)
#    current best f(x) = 15.199978 (best action=31)
#
# 0404-th step: f(x) = 10.292034 (action=274)
#    current best f(x) = 15.199978 (best action=31)
#
# 0405-th step: f(x) = 10.222708 (action=161)
#    current best f(x) = 15.199978 (best action=31)
#
# 0406-th step: f(x) = 10.310142 (action=319)
#    current best f(x) = 15.199978 (best action=31)
#
# 0407-th step: f(x) = 11.862293 (action=414)
#    current best f(x) = 15.199978 (best action=31)
#
# 0408-th step: f(x) = 9.988954 (action=53)
#    current best f(x) = 15.199978 (best action=31)
#
# 0409-th step: f(x) = 10.831972 (action=494)
#    current best f(x) = 15.199978 (best action=31)
#
# 0410-th step: f(x) = 10.778927 (action=376)
#    current best f(x) = 15.199978 (best action=31)
#
# 0411-th step: f(x) = 10.435767 (action=144)
#    current best f(x) = 15.199978 (best action=31)
#
# 0412-th step: f(x) = 10.741203 (action=4)
#    current best f(x) = 15.199978 (best action=31)
#
# 0413-th step: f(x) = 10.985828 (action=350)
#    current best f(x) = 15.199978 (best action=31)
#
# 0414-th step: f(x) = 11.691699 (action=304)
#    current best f(x) = 15.199978 (best action=31)
#
# 0415-th step: f(x) = 11.103749 (action=264)
#    current best f(x) = 15.199978 (best action=31)
#
# 0416-th step: f(x) = 11.558682 (action=256)
#    current best f(x) = 15.199978 (best action=31)
#
# 0417-th step: f(x) = 10.257400 (action=265)
#    current best f(x) = 15.199978 (best action=31)
#
# 0418-th step: f(x) = 11.054344 (action=244)
#    current best f(x) = 15.199978 (best action=31)
#
# 0419-th step: f(x) = 11.809855 (action=113)
#    current best f(x) = 15.199978 (best action=31)
#
# 0420-th step: f(x) = 10.460537 (action=248)
#    current best f(x) = 15.199978 (best action=31)
#
# 0421-th step: f(x) = 10.491460 (action=170)
#    current best f(x) = 15.199978 (best action=31)
#
# 0422-th step: f(x) = 11.835342 (action=132)
#    current best f(x) = 15.199978 (best action=31)
#
# 0423-th step: f(x) = 10.655811 (action=54)
#    current best f(x) = 15.199978 (best action=31)
#
# 0424-th step: f(x) = 10.513623 (action=415)
#    current best f(x) = 15.199978 (best action=31)
#
# 0425-th step: f(x) = 10.382457 (action=33)
#    current best f(x) = 15.199978 (best action=31)
#
# 0426-th step: f(x) = 11.249624 (action=218)
#    current best f(x) = 15.199978 (best action=31)
#
# 0427-th step: f(x) = 11.859829 (action=390)
#    current best f(x) = 15.199978 (best action=31)
#
# 0428-th step: f(x) = 10.372103 (action=418)
#    current best f(x) = 15.199978 (best action=31)
#
# 0429-th step: f(x) = 10.226846 (action=311)
#    current best f(x) = 15.199978 (best action=31)
#
# 0430-th step: f(x) = 10.159478 (action=441)
#    current best f(x) = 15.199978 (best action=31)
#
# 0431-th step: f(x) = 12.083606 (action=66)
#    current best f(x) = 15.199978 (best action=31)
#
# 0432-th step: f(x) = 12.424244 (action=133)
#    current best f(x) = 15.199978 (best action=31)
#
# 0433-th step: f(x) = 11.955911 (action=389)
#    current best f(x) = 15.199978 (best action=31)
#
# 0434-th step: f(x) = 10.699004 (action=492)
#    current best f(x) = 15.199978 (best action=31)
#
# 0435-th step: f(x) = 9.760194 (action=41)
#    current best f(x) = 15.199978 (best action=31)
#
# 0436-th step: f(x) = 11.084139 (action=89)
#    current best f(x) = 15.199978 (best action=31)
#
# 0437-th step: f(x) = 12.379227 (action=19)
#    current best f(x) = 15.199978 (best action=31)
#
# 0438-th step: f(x) = 12.353320 (action=281)
#    current best f(x) = 15.199978 (best action=31)
#
# 0439-th step: f(x) = 11.631375 (action=201)
#    current best f(x) = 15.199978 (best action=31)
#
# 0440-th step: f(x) = 10.161434 (action=188)
#    current best f(x) = 15.199978 (best action=31)
#
# 0441-th step: f(x) = 11.221656 (action=497)
#    current best f(x) = 15.199978 (best action=31)
#
# 0442-th step: f(x) = 10.448575 (action=403)
#    current best f(x) = 15.199978 (best action=31)
#
# 0443-th step: f(x) = 10.622980 (action=303)
#    current best f(x) = 15.199978 (best action=31)
#
# 0444-th step: f(x) = 10.512002 (action=314)
#    current best f(x) = 15.199978 (best action=31)
#
# 0445-th step: f(x) = 10.449700 (action=462)
#    current best f(x) = 15.199978 (best action=31)
#
# 0446-th step: f(x) = 11.381211 (action=354)
#    current best f(x) = 15.199978 (best action=31)
#
# 0447-th step: f(x) = 11.461425 (action=357)
#    current best f(x) = 15.199978 (best action=31)
#
# 0448-th step: f(x) = 11.295484 (action=185)
#    current best f(x) = 15.199978 (best action=31)
#
# 0449-th step: f(x) = 11.254207 (action=14)
#    current best f(x) = 15.199978 (best action=31)
#
# 0450-th step: f(x) = 10.398979 (action=152)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 479.7797776365075
# 50-th epoch, marginal likelihood 456.27175963831957
# 100-th epoch, marginal likelihood 437.1949139564614
# 150-th epoch, marginal likelihood 417.4638285998287
# 200-th epoch, marginal likelihood 400.87276839321254
# 250-th epoch, marginal likelihood 385.2110433698374
# 300-th epoch, marginal likelihood 375.1579670749364
# 350-th epoch, marginal likelihood 369.75688481461395
# 400-th epoch, marginal likelihood 368.14617688647013
# 450-th epoch, marginal likelihood 367.93966416530225
# 500-th epoch, marginal likelihood 368.0257460948262
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.91779439]
#  scale  =  1.120303714086835
#  scale2 =  1.2550804117967571
#
#
# 0451-th step: f(x) = 11.026365 (action=27)
#    current best f(x) = 15.199978 (best action=31)
#
# 0452-th step: f(x) = 10.761484 (action=222)
#    current best f(x) = 15.199978 (best action=31)
#
# 0453-th step: f(x) = 12.221931 (action=249)
#    current best f(x) = 15.199978 (best action=31)
#
# 0454-th step: f(x) = 11.855082 (action=26)
#    current best f(x) = 15.199978 (best action=31)
#
# 0455-th step: f(x) = 10.287872 (action=168)
#    current best f(x) = 15.199978 (best action=31)
#
# 0456-th step: f(x) = 10.297588 (action=71)
#    current best f(x) = 15.199978 (best action=31)
#
# 0457-th step: f(x) = 10.172338 (action=297)
#    current best f(x) = 15.199978 (best action=31)
#
# 0458-th step: f(x) = 11.137141 (action=118)
#    current best f(x) = 15.199978 (best action=31)
#
# 0459-th step: f(x) = 10.775902 (action=227)
#    current best f(x) = 15.199978 (best action=31)
#
# 0460-th step: f(x) = 11.064199 (action=283)
#    current best f(x) = 15.199978 (best action=31)
#
# 0461-th step: f(x) = 10.655057 (action=167)
#    current best f(x) = 15.199978 (best action=31)
#
# 0462-th step: f(x) = 12.157838 (action=386)
#    current best f(x) = 15.199978 (best action=31)
#
# 0463-th step: f(x) = 10.989860 (action=359)
#    current best f(x) = 15.199978 (best action=31)
#
# 0464-th step: f(x) = 10.523844 (action=262)
#    current best f(x) = 15.199978 (best action=31)
#
# 0465-th step: f(x) = 10.875941 (action=212)
#    current best f(x) = 15.199978 (best action=31)
#
# 0466-th step: f(x) = 11.183939 (action=379)
#    current best f(x) = 15.199978 (best action=31)
#
# 0467-th step: f(x) = 10.261693 (action=496)
#    current best f(x) = 15.199978 (best action=31)
#
# 0468-th step: f(x) = 10.243322 (action=100)
#    current best f(x) = 15.199978 (best action=31)
#
# 0469-th step: f(x) = 10.840919 (action=345)
#    current best f(x) = 15.199978 (best action=31)
#
# 0470-th step: f(x) = 11.240781 (action=432)
#    current best f(x) = 15.199978 (best action=31)
#
# 0471-th step: f(x) = 10.957787 (action=328)
#    current best f(x) = 15.199978 (best action=31)
#
# 0472-th step: f(x) = 11.285673 (action=160)
#    current best f(x) = 15.199978 (best action=31)
#
# 0473-th step: f(x) = 11.365277 (action=289)
#    current best f(x) = 15.199978 (best action=31)
#
# 0474-th step: f(x) = 10.642205 (action=3)
#    current best f(x) = 15.199978 (best action=31)
#
# 0475-th step: f(x) = 10.383930 (action=468)
#    current best f(x) = 15.199978 (best action=31)
#
# 0476-th step: f(x) = 11.247225 (action=217)
#    current best f(x) = 15.199978 (best action=31)
#
# 0477-th step: f(x) = 10.907350 (action=95)
#    current best f(x) = 15.199978 (best action=31)
#
# 0478-th step: f(x) = 10.886038 (action=405)
#    current best f(x) = 15.199978 (best action=31)
#
# 0479-th step: f(x) = 11.631695 (action=2)
#    current best f(x) = 15.199978 (best action=31)
#
# 0480-th step: f(x) = 11.438319 (action=203)
#    current best f(x) = 15.199978 (best action=31)
#
# 0481-th step: f(x) = 11.317897 (action=434)
#    current best f(x) = 15.199978 (best action=31)
#
# 0482-th step: f(x) = 11.069586 (action=465)
#    current best f(x) = 15.199978 (best action=31)
#
# 0483-th step: f(x) = 9.732569 (action=187)
#    current best f(x) = 15.199978 (best action=31)
#
# 0484-th step: f(x) = 11.561058 (action=474)
#    current best f(x) = 15.199978 (best action=31)
#
# 0485-th step: f(x) = 10.745824 (action=299)
#    current best f(x) = 15.199978 (best action=31)
#
# 0486-th step: f(x) = 10.343708 (action=239)
#    current best f(x) = 15.199978 (best action=31)
#
# 0487-th step: f(x) = 10.488821 (action=489)
#    current best f(x) = 15.199978 (best action=31)
#
# 0488-th step: f(x) = 10.326802 (action=317)
#    current best f(x) = 15.199978 (best action=31)
#
# 0489-th step: f(x) = 10.692779 (action=454)
#    current best f(x) = 15.199978 (best action=31)
#
# 0490-th step: f(x) = 11.788183 (action=419)
#    current best f(x) = 15.199978 (best action=31)
#
# 0491-th step: f(x) = 10.584904 (action=190)
#    current best f(x) = 15.199978 (best action=31)
#
# 0492-th step: f(x) = 11.113185 (action=116)
#    current best f(x) = 15.199978 (best action=31)
#
# 0493-th step: f(x) = 10.337475 (action=336)
#    current best f(x) = 15.199978 (best action=31)
#
# 0494-th step: f(x) = 11.666445 (action=24)
#    current best f(x) = 15.199978 (best action=31)
#
# 0495-th step: f(x) = 11.793213 (action=247)
#    current best f(x) = 15.199978 (best action=31)
#
# 0496-th step: f(x) = 10.839522 (action=65)
#    current best f(x) = 15.199978 (best action=31)
#
# 0497-th step: f(x) = 10.287620 (action=55)
#    current best f(x) = 15.199978 (best action=31)
#
# 0498-th step: f(x) = 10.154558 (action=458)
#    current best f(x) = 15.199978 (best action=31)
#
# 0499-th step: f(x) = 11.446247 (action=446)
#    current best f(x) = 15.199978 (best action=31)
#
# 0500-th step: f(x) = 11.651286 (action=25)
#    current best f(x) = 15.199978 (best action=31)

# %%
index_Henry_CO2 = np.argmax(Data_relevant_features_Henry_CO2.iloc[:, -1].values)
import numpy as np
from sklearn.manifold import TSNE

X_embedded = TSNE(n_components=2).fit_transform(Data_relevant_features_Henry_CO2.iloc[:, :-1].values)
X_embedded.shape

SC1 = np.transpose(X_embedded)[0]
SC2 = np.transpose(X_embedded)[1]

fig, ax = plt.subplots(figsize=(3,3), dpi=150)
ax.scatter(SC1, SC2, c='tab:blue', alpha=0.3)
initial_set = ax.scatter(SC1[minima], SC2[minima], c='gold', label = 'Initial set', alpha = 0.5)
optimum = ax.scatter(SC1[index_Henry_CO2], SC2[index_Henry_CO2], c='red', label = 'Optimum')

ax.legend([initial_set, optimum], ['Initial set', 'Optimum'])
#labels = ['Initial set', 'Optimum']
#ax.legend(labels)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
plt.show()

# %% [markdown]
# #### Non relevant features

# %%
MEI_index_Henry_CO2_unrelevant = MEI(Data_unrelevant_features_Henry_CO2.iloc[:, :-1].values, Data_unrelevant_features_Henry_CO2.iloc[:, -1].values, 400, 100)
# Out:
#  28%|██▊       | 114/400 [3:00:32<7:32:56, 95.02s/it]

# %%
MLI_index_Henry_CO2_unrelevant = MLI(Data_unrelevant_features_Henry_CO2.iloc[:, :-1].values, Data_unrelevant_features_Henry_CO2.iloc[:, -1].values, 400, 100)
# Out:
#  10%|▉         | 39/400 [39:22<6:04:27, 60.57s/it]

# %%
MU_index_Henry_CO2_unrelevant = MU(Data_unrelevant_features_Henry_CO2.iloc[:, :-1].values, Data_unrelevant_features_Henry_CO2.iloc[:, -1].values, 400, 100)
# Out:
#  31%|███       | 123/400 [3:52:27<8:43:29, 113.39s/it]

# %%
COMBO_PI_Henry_CO2_unrelevant = COMBO(Data_unrelevant_features_Henry_CO2, 'PI')
# Out:
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 20.85855926998478
# 50-th epoch, marginal likelihood 6.070687674273955
# 100-th epoch, marginal likelihood -3.285136444975862
# 150-th epoch, marginal likelihood -8.551105984942652
# 200-th epoch, marginal likelihood -11.84579721844429
# 250-th epoch, marginal likelihood -13.995875715619647
# 300-th epoch, marginal likelihood -15.508744845716578
# 350-th epoch, marginal likelihood -16.44409457615987
# 400-th epoch, marginal likelihood -17.136503746925683
# 450-th epoch, marginal likelihood -17.637876998915154
# 500-th epoch, marginal likelihood -18.053278414860685
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.]
#  scale  =  1.0
#  scale2 =  1.0
#
#
# 0101-th step: f(x) = 11.087779 (action=150)
#    current best f(x) = 11.087779 (best action=150)
#
# 0102-th step: f(x) = 11.377510 (action=210)
#    current best f(x) = 11.377510 (best action=210)
#
# 0103-th step: f(x) = 11.509843 (action=344)
#    current best f(x) = 11.509843 (best action=344)
#
# 0104-th step: f(x) = 11.363592 (action=463)
#    current best f(x) = 11.509843 (best action=344)
#
# 0105-th step: f(x) = 12.654977 (action=172)
#    current best f(x) = 12.654977 (best action=172)
#
# 0106-th step: f(x) = 14.045971 (action=436)
#    current best f(x) = 14.045971 (best action=436)
#
# 0107-th step: f(x) = 13.546707 (action=429)
#    current best f(x) = 14.045971 (best action=436)
#
# 0108-th step: f(x) = 12.625490 (action=216)
#    current best f(x) = 14.045971 (best action=436)
#
# 0109-th step: f(x) = 13.231695 (action=238)
#    current best f(x) = 14.045971 (best action=436)
#
# 0110-th step: f(x) = 14.117251 (action=205)
#    current best f(x) = 14.117251 (best action=205)
#
# 0111-th step: f(x) = 14.143965 (action=234)
#    current best f(x) = 14.143965 (best action=234)
#
# 0112-th step: f(x) = 13.392218 (action=437)
#    current best f(x) = 14.143965 (best action=234)
#
# 0113-th step: f(x) = 13.813066 (action=416)
#    current best f(x) = 14.143965 (best action=234)
#
# 0114-th step: f(x) = 12.713068 (action=141)
#    current best f(x) = 14.143965 (best action=234)
#
# 0115-th step: f(x) = 14.907075 (action=342)
#    current best f(x) = 14.907075 (best action=342)
#
# 0116-th step: f(x) = 14.162195 (action=392)
#    current best f(x) = 14.907075 (best action=342)
#
# 0117-th step: f(x) = 14.004915 (action=407)
#    current best f(x) = 14.907075 (best action=342)
#
# 0118-th step: f(x) = 13.439160 (action=340)
#    current best f(x) = 14.907075 (best action=342)
#
# 0119-th step: f(x) = 12.893953 (action=64)
#    current best f(x) = 14.907075 (best action=342)
#
# 0120-th step: f(x) = 12.815232 (action=177)
#    current best f(x) = 14.907075 (best action=342)
#
# 0121-th step: f(x) = 14.054575 (action=279)
#    current best f(x) = 14.907075 (best action=342)
#
# 0122-th step: f(x) = 14.608082 (action=79)
#    current best f(x) = 14.907075 (best action=342)
#
# 0123-th step: f(x) = 13.371976 (action=320)
#    current best f(x) = 14.907075 (best action=342)
#
# 0124-th step: f(x) = 13.388470 (action=142)
#    current best f(x) = 14.907075 (best action=342)
#
# 0125-th step: f(x) = 12.199556 (action=149)
#    current best f(x) = 14.907075 (best action=342)
#
# 0126-th step: f(x) = 10.886835 (action=6)
#    current best f(x) = 14.907075 (best action=342)
#
# 0127-th step: f(x) = 13.840730 (action=154)
#    current best f(x) = 14.907075 (best action=342)
#
# 0128-th step: f(x) = 12.701863 (action=370)
#    current best f(x) = 14.907075 (best action=342)
#
# 0129-th step: f(x) = 12.054249 (action=73)
#    current best f(x) = 14.907075 (best action=342)
#
# 0130-th step: f(x) = 14.470462 (action=478)
#    current best f(x) = 14.907075 (best action=342)
#
# 0131-th step: f(x) = 13.774910 (action=57)
#    current best f(x) = 14.907075 (best action=342)
#
# 0132-th step: f(x) = 14.562293 (action=481)
#    current best f(x) = 14.907075 (best action=342)
#
# 0133-th step: f(x) = 13.849071 (action=408)
#    current best f(x) = 14.907075 (best action=342)
#
# 0134-th step: f(x) = 13.985827 (action=326)
#    current best f(x) = 14.907075 (best action=342)
#
# 0135-th step: f(x) = 14.769074 (action=252)
#    current best f(x) = 14.907075 (best action=342)
#
# 0136-th step: f(x) = 13.666899 (action=62)
#    current best f(x) = 14.907075 (best action=342)
#
# 0137-th step: f(x) = 13.023539 (action=45)
#    current best f(x) = 14.907075 (best action=342)
#
# 0138-th step: f(x) = 12.521989 (action=309)
#    current best f(x) = 14.907075 (best action=342)
#
# 0139-th step: f(x) = 12.980763 (action=36)
#    current best f(x) = 14.907075 (best action=342)
#
# 0140-th step: f(x) = 13.114851 (action=176)
#    current best f(x) = 14.907075 (best action=342)
#
# 0141-th step: f(x) = 13.663556 (action=40)
#    current best f(x) = 14.907075 (best action=342)
#
# 0142-th step: f(x) = 12.107213 (action=296)
#    current best f(x) = 14.907075 (best action=342)
#
# 0143-th step: f(x) = 13.252711 (action=59)
#    current best f(x) = 14.907075 (best action=342)
#
# 0144-th step: f(x) = 13.672768 (action=321)
#    current best f(x) = 14.907075 (best action=342)
#
# 0145-th step: f(x) = 12.775475 (action=263)
#    current best f(x) = 14.907075 (best action=342)
#
# 0146-th step: f(x) = 13.113238 (action=470)
#    current best f(x) = 14.907075 (best action=342)
#
# 0147-th step: f(x) = 13.550647 (action=341)
#    current best f(x) = 14.907075 (best action=342)
#
# 0148-th step: f(x) = 13.613529 (action=360)
#    current best f(x) = 14.907075 (best action=342)
#
# 0149-th step: f(x) = 12.241179 (action=499)
#    current best f(x) = 14.907075 (best action=342)
#
# 0150-th step: f(x) = 13.294333 (action=409)
#    current best f(x) = 14.907075 (best action=342)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 138.38560277247265
# 50-th epoch, marginal likelihood 137.42688111549492
# 100-th epoch, marginal likelihood 137.29750828470264
# 150-th epoch, marginal likelihood 136.95040074097784
# 200-th epoch, marginal likelihood 136.73191168160758
# 250-th epoch, marginal likelihood 136.60436884630394
# 300-th epoch, marginal likelihood 136.4522788753046
# 350-th epoch, marginal likelihood 136.1745135186167
# 400-th epoch, marginal likelihood 136.06799195004567
# 450-th epoch, marginal likelihood 135.99965677776913
# 500-th epoch, marginal likelihood 135.95015387980277
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [5.34297725]
#  scale  =  0.2547623604805678
#  scale2 =  0.06490386031763076
#
#
# 0151-th step: f(x) = 13.359511 (action=86)
#    current best f(x) = 14.907075 (best action=342)
#
# 0152-th step: f(x) = 12.623443 (action=134)
#    current best f(x) = 14.907075 (best action=342)
#
# 0153-th step: f(x) = 13.588520 (action=213)
#    current best f(x) = 14.907075 (best action=342)
#
# 0154-th step: f(x) = 12.871684 (action=148)
#    current best f(x) = 14.907075 (best action=342)
#
# 0155-th step: f(x) = 12.678346 (action=428)
#    current best f(x) = 14.907075 (best action=342)
#
# 0156-th step: f(x) = 12.073152 (action=388)
#    current best f(x) = 14.907075 (best action=342)
#
# 0157-th step: f(x) = 12.729697 (action=158)
#    current best f(x) = 14.907075 (best action=342)
#
# 0158-th step: f(x) = 10.817089 (action=102)
#    current best f(x) = 14.907075 (best action=342)
#
# 0159-th step: f(x) = 13.936604 (action=495)
#    current best f(x) = 14.907075 (best action=342)
#
# 0160-th step: f(x) = 11.936276 (action=112)
#    current best f(x) = 14.907075 (best action=342)
#
# 0161-th step: f(x) = 11.570194 (action=29)
#    current best f(x) = 14.907075 (best action=342)
#
# 0162-th step: f(x) = 14.455732 (action=84)
#    current best f(x) = 14.907075 (best action=342)
#
# 0163-th step: f(x) = 13.346476 (action=292)
#    current best f(x) = 14.907075 (best action=342)
#
# 0164-th step: f(x) = 13.539830 (action=417)
#    current best f(x) = 14.907075 (best action=342)
#
# 0165-th step: f(x) = 12.174262 (action=295)
#    current best f(x) = 14.907075 (best action=342)
#
# 0166-th step: f(x) = 13.545193 (action=215)
#    current best f(x) = 14.907075 (best action=342)
#
# 0167-th step: f(x) = 11.620990 (action=219)
#    current best f(x) = 14.907075 (best action=342)
#
# 0168-th step: f(x) = 12.391548 (action=396)
#    current best f(x) = 14.907075 (best action=342)
#
# 0169-th step: f(x) = 11.553520 (action=88)
#    current best f(x) = 14.907075 (best action=342)
#
# 0170-th step: f(x) = 11.352042 (action=444)
#    current best f(x) = 14.907075 (best action=342)
#
# 0171-th step: f(x) = 12.169875 (action=276)
#    current best f(x) = 14.907075 (best action=342)
#
# 0172-th step: f(x) = 12.949820 (action=94)
#    current best f(x) = 14.907075 (best action=342)
#
# 0173-th step: f(x) = 11.457136 (action=67)
#    current best f(x) = 14.907075 (best action=342)
#
# 0174-th step: f(x) = 11.172079 (action=373)
#    current best f(x) = 14.907075 (best action=342)
#
# 0175-th step: f(x) = 10.906163 (action=383)
#    current best f(x) = 14.907075 (best action=342)
#
# 0176-th step: f(x) = 11.747760 (action=56)
#    current best f(x) = 14.907075 (best action=342)
#
# 0177-th step: f(x) = 12.535761 (action=109)
#    current best f(x) = 14.907075 (best action=342)
#
# 0178-th step: f(x) = 12.147808 (action=162)
#    current best f(x) = 14.907075 (best action=342)
#
# 0179-th step: f(x) = 12.091924 (action=475)
#    current best f(x) = 14.907075 (best action=342)
#
# 0180-th step: f(x) = 12.713222 (action=50)
#    current best f(x) = 14.907075 (best action=342)
#
# 0181-th step: f(x) = 12.500025 (action=48)
#    current best f(x) = 14.907075 (best action=342)
#
# 0182-th step: f(x) = 10.822187 (action=97)
#    current best f(x) = 14.907075 (best action=342)
#
# 0183-th step: f(x) = 12.029485 (action=34)
#    current best f(x) = 14.907075 (best action=342)
#
# 0184-th step: f(x) = 14.477286 (action=76)
#    current best f(x) = 14.907075 (best action=342)
#
# 0185-th step: f(x) = 12.626932 (action=235)
#    current best f(x) = 14.907075 (best action=342)
#
# 0186-th step: f(x) = 12.305130 (action=270)
#    current best f(x) = 14.907075 (best action=342)
#
# 0187-th step: f(x) = 11.840141 (action=488)
#    current best f(x) = 14.907075 (best action=342)
#
# 0188-th step: f(x) = 12.232607 (action=346)
#    current best f(x) = 14.907075 (best action=342)
#
# 0189-th step: f(x) = 13.355414 (action=472)
#    current best f(x) = 14.907075 (best action=342)
#
# 0190-th step: f(x) = 12.516340 (action=18)
#    current best f(x) = 14.907075 (best action=342)
#
# 0191-th step: f(x) = 11.349901 (action=42)
#    current best f(x) = 14.907075 (best action=342)
#
# 0192-th step: f(x) = 10.597839 (action=129)
#    current best f(x) = 14.907075 (best action=342)
#
# 0193-th step: f(x) = 11.415023 (action=5)
#    current best f(x) = 14.907075 (best action=342)
#
# 0194-th step: f(x) = 12.189333 (action=316)
#    current best f(x) = 14.907075 (best action=342)
#
# 0195-th step: f(x) = 11.099243 (action=184)
#    current best f(x) = 14.907075 (best action=342)
#
# 0196-th step: f(x) = 12.429956 (action=117)
#    current best f(x) = 14.907075 (best action=342)
#
# 0197-th step: f(x) = 10.954454 (action=273)
#    current best f(x) = 14.907075 (best action=342)
#
# 0198-th step: f(x) = 12.558981 (action=385)
#    current best f(x) = 14.907075 (best action=342)
#
# 0199-th step: f(x) = 12.707236 (action=338)
#    current best f(x) = 14.907075 (best action=342)
#
# 0200-th step: f(x) = 12.177282 (action=498)
#    current best f(x) = 14.907075 (best action=342)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 195.45093259256583
# 50-th epoch, marginal likelihood 194.26580458209105
# 100-th epoch, marginal likelihood 192.83811010228573
# 150-th epoch, marginal likelihood 191.55146374782169
# 200-th epoch, marginal likelihood 190.06290614417787
# 250-th epoch, marginal likelihood 188.91698882406882
# 300-th epoch, marginal likelihood 187.7922279954263
# 350-th epoch, marginal likelihood 186.85538672640837
# 400-th epoch, marginal likelihood 186.2700888921897
# 450-th epoch, marginal likelihood 185.77755949257818
# 500-th epoch, marginal likelihood 185.5132016455188
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [9.49456287]
#  scale  =  1.2435522576801517
#  scale2 =  1.5464222175814022
#
#
# 0201-th step: f(x) = 13.003787 (action=169)
#    current best f(x) = 14.907075 (best action=342)
#
# 0202-th step: f(x) = 12.943906 (action=487)
#    current best f(x) = 14.907075 (best action=342)
#
# 0203-th step: f(x) = 12.206058 (action=194)
#    current best f(x) = 14.907075 (best action=342)
#
# 0204-th step: f(x) = 12.109578 (action=443)
#    current best f(x) = 14.907075 (best action=342)
#
# 0205-th step: f(x) = 11.472237 (action=461)
#    current best f(x) = 14.907075 (best action=342)
#
# 0206-th step: f(x) = 12.848931 (action=257)
#    current best f(x) = 14.907075 (best action=342)
#
# 0207-th step: f(x) = 12.849255 (action=412)
#    current best f(x) = 14.907075 (best action=342)
#
# 0208-th step: f(x) = 12.064163 (action=77)
#    current best f(x) = 14.907075 (best action=342)
#
# 0209-th step: f(x) = 12.187471 (action=101)
#    current best f(x) = 14.907075 (best action=342)
#
# 0210-th step: f(x) = 11.749893 (action=391)
#    current best f(x) = 14.907075 (best action=342)
#
# 0211-th step: f(x) = 12.238690 (action=483)
#    current best f(x) = 14.907075 (best action=342)
#
# 0212-th step: f(x) = 11.787142 (action=105)
#    current best f(x) = 14.907075 (best action=342)
#
# 0213-th step: f(x) = 11.078800 (action=400)
#    current best f(x) = 14.907075 (best action=342)
#
# 0214-th step: f(x) = 10.622980 (action=303)
#    current best f(x) = 14.907075 (best action=342)
#
# 0215-th step: f(x) = 12.272534 (action=352)
#    current best f(x) = 14.907075 (best action=342)
#
# 0216-th step: f(x) = 12.083606 (action=66)
#    current best f(x) = 14.907075 (best action=342)
#
# 0217-th step: f(x) = 11.017555 (action=39)
#    current best f(x) = 14.907075 (best action=342)
#
# 0218-th step: f(x) = 13.460839 (action=424)
#    current best f(x) = 14.907075 (best action=342)
#
# 0219-th step: f(x) = 11.478575 (action=81)
#    current best f(x) = 14.907075 (best action=342)
#
# 0220-th step: f(x) = 11.561811 (action=58)
#    current best f(x) = 14.907075 (best action=342)
#
# 0221-th step: f(x) = 11.912748 (action=130)
#    current best f(x) = 14.907075 (best action=342)
#
# 0222-th step: f(x) = 11.618852 (action=121)
#    current best f(x) = 14.907075 (best action=342)
#
# 0223-th step: f(x) = 10.685140 (action=268)
#    current best f(x) = 14.907075 (best action=342)
#
# 0224-th step: f(x) = 15.199978 (action=31)
#    current best f(x) = 15.199978 (best action=31)
#
# 0225-th step: f(x) = 13.603537 (action=431)
#    current best f(x) = 15.199978 (best action=31)
#
# 0226-th step: f(x) = 11.712260 (action=486)
#    current best f(x) = 15.199978 (best action=31)
#
# 0227-th step: f(x) = 12.248461 (action=351)
#    current best f(x) = 15.199978 (best action=31)
#
# 0228-th step: f(x) = 11.797578 (action=266)
#    current best f(x) = 15.199978 (best action=31)
#
# 0229-th step: f(x) = 12.104178 (action=23)
#    current best f(x) = 15.199978 (best action=31)
#
# 0230-th step: f(x) = 11.835342 (action=132)
#    current best f(x) = 15.199978 (best action=31)
#
# 0231-th step: f(x) = 10.717455 (action=250)
#    current best f(x) = 15.199978 (best action=31)
#
# 0232-th step: f(x) = 10.760911 (action=275)
#    current best f(x) = 15.199978 (best action=31)
#
# 0233-th step: f(x) = 12.267379 (action=70)
#    current best f(x) = 15.199978 (best action=31)
#
# 0234-th step: f(x) = 10.972662 (action=306)
#    current best f(x) = 15.199978 (best action=31)
#
# 0235-th step: f(x) = 10.768940 (action=83)
#    current best f(x) = 15.199978 (best action=31)
#
# 0236-th step: f(x) = 11.201851 (action=178)
#    current best f(x) = 15.199978 (best action=31)
#
# 0237-th step: f(x) = 11.579883 (action=21)
#    current best f(x) = 15.199978 (best action=31)
#
# 0238-th step: f(x) = 12.180021 (action=221)
#    current best f(x) = 15.199978 (best action=31)
#
# 0239-th step: f(x) = 11.554115 (action=404)
#    current best f(x) = 15.199978 (best action=31)
#
# 0240-th step: f(x) = 12.504769 (action=453)
#    current best f(x) = 15.199978 (best action=31)
#
# 0241-th step: f(x) = 11.853454 (action=228)
#    current best f(x) = 15.199978 (best action=31)
#
# 0242-th step: f(x) = 11.979479 (action=384)
#    current best f(x) = 15.199978 (best action=31)
#
# 0243-th step: f(x) = 11.133030 (action=491)
#    current best f(x) = 15.199978 (best action=31)
#
# 0244-th step: f(x) = 11.131331 (action=28)
#    current best f(x) = 15.199978 (best action=31)
#
# 0245-th step: f(x) = 12.299736 (action=128)
#    current best f(x) = 15.199978 (best action=31)
#
# 0246-th step: f(x) = 13.629201 (action=171)
#    current best f(x) = 15.199978 (best action=31)
#
# 0247-th step: f(x) = 12.650088 (action=179)
#    current best f(x) = 15.199978 (best action=31)
#
# 0248-th step: f(x) = 10.867553 (action=355)
#    current best f(x) = 15.199978 (best action=31)
#
# 0249-th step: f(x) = 12.421889 (action=452)
#    current best f(x) = 15.199978 (best action=31)
#
# 0250-th step: f(x) = 11.420773 (action=224)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 264.85006823460577
# 50-th epoch, marginal likelihood 263.66142446013714
# 100-th epoch, marginal likelihood 260.36297736375445
# 150-th epoch, marginal likelihood 258.3532308530375
# 200-th epoch, marginal likelihood 255.28342602277576
# 250-th epoch, marginal likelihood 252.7390273279695
# 300-th epoch, marginal likelihood 249.9458573012065
# 350-th epoch, marginal likelihood 247.1921834253827
# 400-th epoch, marginal likelihood 244.44271645837014
# 450-th epoch, marginal likelihood 242.7294302878222
# 500-th epoch, marginal likelihood 241.40101623564186
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [11.44368894]
#  scale  =  1.3086160542712804
#  scale2 =  1.7124759774965346
#
#
# 0251-th step: f(x) = 12.105849 (action=30)
#    current best f(x) = 15.199978 (best action=31)
#
# 0252-th step: f(x) = 11.372283 (action=271)
#    current best f(x) = 15.199978 (best action=31)
#
# 0253-th step: f(x) = 11.254489 (action=420)
#    current best f(x) = 15.199978 (best action=31)
#
# 0254-th step: f(x) = 12.864745 (action=220)
#    current best f(x) = 15.199978 (best action=31)
#
# 0255-th step: f(x) = 11.259156 (action=229)
#    current best f(x) = 15.199978 (best action=31)
#
# 0256-th step: f(x) = 11.680616 (action=422)
#    current best f(x) = 15.199978 (best action=31)
#
# 0257-th step: f(x) = 11.315061 (action=127)
#    current best f(x) = 15.199978 (best action=31)
#
# 0258-th step: f(x) = 10.589897 (action=435)
#    current best f(x) = 15.199978 (best action=31)
#
# 0259-th step: f(x) = 10.578881 (action=90)
#    current best f(x) = 15.199978 (best action=31)
#
# 0260-th step: f(x) = 11.837441 (action=348)
#    current best f(x) = 15.199978 (best action=31)
#
# 0261-th step: f(x) = 11.599598 (action=447)
#    current best f(x) = 15.199978 (best action=31)
#
# 0262-th step: f(x) = 12.163645 (action=343)
#    current best f(x) = 15.199978 (best action=31)
#
# 0263-th step: f(x) = 12.007353 (action=69)
#    current best f(x) = 15.199978 (best action=31)
#
# 0264-th step: f(x) = 10.998358 (action=8)
#    current best f(x) = 15.199978 (best action=31)
#
# 0265-th step: f(x) = 11.268019 (action=401)
#    current best f(x) = 15.199978 (best action=31)
#
# 0266-th step: f(x) = 10.985828 (action=350)
#    current best f(x) = 15.199978 (best action=31)
#
# 0267-th step: f(x) = 11.142889 (action=335)
#    current best f(x) = 15.199978 (best action=31)
#
# 0268-th step: f(x) = 12.236354 (action=96)
#    current best f(x) = 15.199978 (best action=31)
#
# 0269-th step: f(x) = 11.816188 (action=156)
#    current best f(x) = 15.199978 (best action=31)
#
# 0270-th step: f(x) = 12.775605 (action=466)
#    current best f(x) = 15.199978 (best action=31)
#
# 0271-th step: f(x) = 11.479613 (action=1)
#    current best f(x) = 15.199978 (best action=31)
#
# 0272-th step: f(x) = 10.927216 (action=231)
#    current best f(x) = 15.199978 (best action=31)
#
# 0273-th step: f(x) = 12.359274 (action=233)
#    current best f(x) = 15.199978 (best action=31)
#
# 0274-th step: f(x) = 12.219334 (action=469)
#    current best f(x) = 15.199978 (best action=31)
#
# 0275-th step: f(x) = 12.291456 (action=20)
#    current best f(x) = 15.199978 (best action=31)
#
# 0276-th step: f(x) = 11.738139 (action=259)
#    current best f(x) = 15.199978 (best action=31)
#
# 0277-th step: f(x) = 11.691699 (action=304)
#    current best f(x) = 15.199978 (best action=31)
#
# 0278-th step: f(x) = 11.137141 (action=118)
#    current best f(x) = 15.199978 (best action=31)
#
# 0279-th step: f(x) = 11.807682 (action=425)
#    current best f(x) = 15.199978 (best action=31)
#
# 0280-th step: f(x) = 11.468653 (action=484)
#    current best f(x) = 15.199978 (best action=31)
#
# 0281-th step: f(x) = 11.859829 (action=390)
#    current best f(x) = 15.199978 (best action=31)
#
# 0282-th step: f(x) = 12.986748 (action=209)
#    current best f(x) = 15.199978 (best action=31)
#
# 0283-th step: f(x) = 11.292059 (action=63)
#    current best f(x) = 15.199978 (best action=31)
#
# 0284-th step: f(x) = 13.433437 (action=165)
#    current best f(x) = 15.199978 (best action=31)
#
# 0285-th step: f(x) = 11.383509 (action=17)
#    current best f(x) = 15.199978 (best action=31)
#
# 0286-th step: f(x) = 11.458059 (action=442)
#    current best f(x) = 15.199978 (best action=31)
#
# 0287-th step: f(x) = 10.900656 (action=330)
#    current best f(x) = 15.199978 (best action=31)
#
# 0288-th step: f(x) = 10.831972 (action=494)
#    current best f(x) = 15.199978 (best action=31)
#
# 0289-th step: f(x) = 10.989860 (action=359)
#    current best f(x) = 15.199978 (best action=31)
#
# 0290-th step: f(x) = 10.850362 (action=10)
#    current best f(x) = 15.199978 (best action=31)
#
# 0291-th step: f(x) = 11.959142 (action=290)
#    current best f(x) = 15.199978 (best action=31)
#
# 0292-th step: f(x) = 11.063046 (action=278)
#    current best f(x) = 15.199978 (best action=31)
#
# 0293-th step: f(x) = 11.948305 (action=288)
#    current best f(x) = 15.199978 (best action=31)
#
# 0294-th step: f(x) = 11.933062 (action=98)
#    current best f(x) = 15.199978 (best action=31)
#
# 0295-th step: f(x) = 12.283302 (action=438)
#    current best f(x) = 15.199978 (best action=31)
#
# 0296-th step: f(x) = 11.797548 (action=397)
#    current best f(x) = 15.199978 (best action=31)
#
# 0297-th step: f(x) = 12.541712 (action=377)
#    current best f(x) = 15.199978 (best action=31)
#
# 0298-th step: f(x) = 12.157838 (action=386)
#    current best f(x) = 15.199978 (best action=31)
#
# 0299-th step: f(x) = 10.601990 (action=78)
#    current best f(x) = 15.199978 (best action=31)
#
# 0300-th step: f(x) = 10.896921 (action=91)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 311.97047437923334
# 50-th epoch, marginal likelihood 308.9419889452108
# 100-th epoch, marginal likelihood 304.16044832248093
# 150-th epoch, marginal likelihood 300.40439664677604
# 200-th epoch, marginal likelihood 296.4214948985837
# 250-th epoch, marginal likelihood 291.74662073130537
# 300-th epoch, marginal likelihood 287.4528920005914
# 350-th epoch, marginal likelihood 284.0456127928273
# 400-th epoch, marginal likelihood 281.6863754374099
# 450-th epoch, marginal likelihood 279.9127133917436
# 500-th epoch, marginal likelihood 278.9059309339092
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [10.8797204]
#  scale  =  1.2689119409543015
#  scale2 =  1.6101375138964127
#
#
# 0301-th step: f(x) = 11.605596 (action=237)
#    current best f(x) = 15.199978 (best action=31)
#
# 0302-th step: f(x) = 12.115880 (action=196)
#    current best f(x) = 15.199978 (best action=31)
#
# 0303-th step: f(x) = 11.085025 (action=261)
#    current best f(x) = 15.199978 (best action=31)
#
# 0304-th step: f(x) = 11.167719 (action=181)
#    current best f(x) = 15.199978 (best action=31)
#
# 0305-th step: f(x) = 11.809855 (action=113)
#    current best f(x) = 15.199978 (best action=31)
#
# 0306-th step: f(x) = 12.078785 (action=206)
#    current best f(x) = 15.199978 (best action=31)
#
# 0307-th step: f(x) = 11.982223 (action=51)
#    current best f(x) = 15.199978 (best action=31)
#
# 0308-th step: f(x) = 10.699392 (action=198)
#    current best f(x) = 15.199978 (best action=31)
#
# 0309-th step: f(x) = 11.772817 (action=393)
#    current best f(x) = 15.199978 (best action=31)
#
# 0310-th step: f(x) = 11.419107 (action=308)
#    current best f(x) = 15.199978 (best action=31)
#
# 0311-th step: f(x) = 13.580027 (action=394)
#    current best f(x) = 15.199978 (best action=31)
#
# 0312-th step: f(x) = 12.923593 (action=471)
#    current best f(x) = 15.199978 (best action=31)
#
# 0313-th step: f(x) = 11.862293 (action=414)
#    current best f(x) = 15.199978 (best action=31)
#
# 0314-th step: f(x) = 11.536828 (action=456)
#    current best f(x) = 15.199978 (best action=31)
#
# 0315-th step: f(x) = 12.034246 (action=361)
#    current best f(x) = 15.199978 (best action=31)
#
# 0316-th step: f(x) = 11.254207 (action=14)
#    current best f(x) = 15.199978 (best action=31)
#
# 0317-th step: f(x) = 10.824694 (action=13)
#    current best f(x) = 15.199978 (best action=31)
#
# 0318-th step: f(x) = 10.538441 (action=183)
#    current best f(x) = 15.199978 (best action=31)
#
# 0319-th step: f(x) = 11.728504 (action=294)
#    current best f(x) = 15.199978 (best action=31)
#
# 0320-th step: f(x) = 11.418648 (action=324)
#    current best f(x) = 15.199978 (best action=31)
#
# 0321-th step: f(x) = 11.365277 (action=289)
#    current best f(x) = 15.199978 (best action=31)
#
# 0322-th step: f(x) = 12.747664 (action=243)
#    current best f(x) = 15.199978 (best action=31)
#
# 0323-th step: f(x) = 12.042058 (action=240)
#    current best f(x) = 15.199978 (best action=31)
#
# 0324-th step: f(x) = 10.563776 (action=301)
#    current best f(x) = 15.199978 (best action=31)
#
# 0325-th step: f(x) = 11.113649 (action=477)
#    current best f(x) = 15.199978 (best action=31)
#
# 0326-th step: f(x) = 12.415357 (action=163)
#    current best f(x) = 15.199978 (best action=31)
#
# 0327-th step: f(x) = 11.103749 (action=264)
#    current best f(x) = 15.199978 (best action=31)
#
# 0328-th step: f(x) = 11.394897 (action=46)
#    current best f(x) = 15.199978 (best action=31)
#
# 0329-th step: f(x) = 10.740441 (action=211)
#    current best f(x) = 15.199978 (best action=31)
#
# 0330-th step: f(x) = 12.221931 (action=249)
#    current best f(x) = 15.199978 (best action=31)
#
# 0331-th step: f(x) = 10.948105 (action=485)
#    current best f(x) = 15.199978 (best action=31)
#
# 0332-th step: f(x) = 12.255220 (action=125)
#    current best f(x) = 15.199978 (best action=31)
#
# 0333-th step: f(x) = 12.321462 (action=207)
#    current best f(x) = 15.199978 (best action=31)
#
# 0334-th step: f(x) = 12.154274 (action=246)
#    current best f(x) = 15.199978 (best action=31)
#
# 0335-th step: f(x) = 12.074579 (action=449)
#    current best f(x) = 15.199978 (best action=31)
#
# 0336-th step: f(x) = 12.050471 (action=427)
#    current best f(x) = 15.199978 (best action=31)
#
# 0337-th step: f(x) = 10.777144 (action=411)
#    current best f(x) = 15.199978 (best action=31)
#
# 0338-th step: f(x) = 13.430452 (action=38)
#    current best f(x) = 15.199978 (best action=31)
#
# 0339-th step: f(x) = 11.576867 (action=75)
#    current best f(x) = 15.199978 (best action=31)
#
# 0340-th step: f(x) = 13.241262 (action=305)
#    current best f(x) = 15.199978 (best action=31)
#
# 0341-th step: f(x) = 12.148417 (action=374)
#    current best f(x) = 15.199978 (best action=31)
#
# 0342-th step: f(x) = 12.468145 (action=334)
#    current best f(x) = 15.199978 (best action=31)
#
# 0343-th step: f(x) = 13.687319 (action=313)
#    current best f(x) = 15.199978 (best action=31)
#
# 0344-th step: f(x) = 11.967225 (action=115)
#    current best f(x) = 15.199978 (best action=31)
#
# 0345-th step: f(x) = 11.558682 (action=256)
#    current best f(x) = 15.199978 (best action=31)
#
# 0346-th step: f(x) = 12.592154 (action=490)
#    current best f(x) = 15.199978 (best action=31)
#
# 0347-th step: f(x) = 11.295484 (action=185)
#    current best f(x) = 15.199978 (best action=31)
#
# 0348-th step: f(x) = 11.713823 (action=329)
#    current best f(x) = 15.199978 (best action=31)
#
# 0349-th step: f(x) = 11.279764 (action=433)
#    current best f(x) = 15.199978 (best action=31)
#
# 0350-th step: f(x) = 12.107765 (action=93)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 363.53747679724165
# 50-th epoch, marginal likelihood 359.58485783144886
# 100-th epoch, marginal likelihood 353.8549678421583
# 150-th epoch, marginal likelihood 346.6722892545174
# 200-th epoch, marginal likelihood 338.7853607279222
# 250-th epoch, marginal likelihood 332.88001090406226
# 300-th epoch, marginal likelihood 328.0239648463027
# 350-th epoch, marginal likelihood 324.69610788389315
# 400-th epoch, marginal likelihood 322.87629660387177
# 450-th epoch, marginal likelihood 321.38005658014026
# 500-th epoch, marginal likelihood 320.84872143806126
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [10.98545552]
#  scale  =  1.2337161800774432
#  scale2 =  1.5220556129848783
#
#
# 0351-th step: f(x) = 11.739615 (action=430)
#    current best f(x) = 15.199978 (best action=31)
#
# 0352-th step: f(x) = 12.356719 (action=7)
#    current best f(x) = 15.199978 (best action=31)
#
# 0353-th step: f(x) = 10.894236 (action=44)
#    current best f(x) = 15.199978 (best action=31)
#
# 0354-th step: f(x) = 11.026365 (action=27)
#    current best f(x) = 15.199978 (best action=31)
#
# 0355-th step: f(x) = 11.463772 (action=353)
#    current best f(x) = 15.199978 (best action=31)
#
# 0356-th step: f(x) = 11.688885 (action=339)
#    current best f(x) = 15.199978 (best action=31)
#
# 0357-th step: f(x) = 11.342603 (action=12)
#    current best f(x) = 15.199978 (best action=31)
#
# 0358-th step: f(x) = 11.193615 (action=277)
#    current best f(x) = 15.199978 (best action=31)
#
# 0359-th step: f(x) = 11.425267 (action=362)
#    current best f(x) = 15.199978 (best action=31)
#
# 0360-th step: f(x) = 10.595449 (action=225)
#    current best f(x) = 15.199978 (best action=31)
#
# 0361-th step: f(x) = 10.971218 (action=232)
#    current best f(x) = 15.199978 (best action=31)
#
# 0362-th step: f(x) = 11.845368 (action=37)
#    current best f(x) = 15.199978 (best action=31)
#
# 0363-th step: f(x) = 10.838168 (action=451)
#    current best f(x) = 15.199978 (best action=31)
#
# 0364-th step: f(x) = 12.201452 (action=479)
#    current best f(x) = 15.199978 (best action=31)
#
# 0365-th step: f(x) = 11.498842 (action=153)
#    current best f(x) = 15.199978 (best action=31)
#
# 0366-th step: f(x) = 11.054344 (action=244)
#    current best f(x) = 15.199978 (best action=31)
#
# 0367-th step: f(x) = 10.952023 (action=214)
#    current best f(x) = 15.199978 (best action=31)
#
# 0368-th step: f(x) = 11.395841 (action=85)
#    current best f(x) = 15.199978 (best action=31)
#
# 0369-th step: f(x) = 11.631695 (action=2)
#    current best f(x) = 15.199978 (best action=31)
#
# 0370-th step: f(x) = 11.350903 (action=364)
#    current best f(x) = 15.199978 (best action=31)
#
# 0371-th step: f(x) = 11.461425 (action=357)
#    current best f(x) = 15.199978 (best action=31)
#
# 0372-th step: f(x) = 11.831146 (action=32)
#    current best f(x) = 15.199978 (best action=31)
#
# 0373-th step: f(x) = 11.793213 (action=247)
#    current best f(x) = 15.199978 (best action=31)
#
# 0374-th step: f(x) = 11.458730 (action=208)
#    current best f(x) = 15.199978 (best action=31)
#
# 0375-th step: f(x) = 10.852501 (action=358)
#    current best f(x) = 15.199978 (best action=31)
#
# 0376-th step: f(x) = 11.863730 (action=175)
#    current best f(x) = 15.199978 (best action=31)
#
# 0377-th step: f(x) = 11.121164 (action=15)
#    current best f(x) = 15.199978 (best action=31)
#
# 0378-th step: f(x) = 13.948974 (action=439)
#    current best f(x) = 15.199978 (best action=31)
#
# 0379-th step: f(x) = 10.675901 (action=280)
#    current best f(x) = 15.199978 (best action=31)
#
# 0380-th step: f(x) = 11.219797 (action=325)
#    current best f(x) = 15.199978 (best action=31)
#
# 0381-th step: f(x) = 11.788183 (action=419)
#    current best f(x) = 15.199978 (best action=31)
#
# 0382-th step: f(x) = 11.393145 (action=200)
#    current best f(x) = 15.199978 (best action=31)
#
# 0383-th step: f(x) = 12.291323 (action=380)
#    current best f(x) = 15.199978 (best action=31)
#
# 0384-th step: f(x) = 11.311431 (action=103)
#    current best f(x) = 15.199978 (best action=31)
#
# 0385-th step: f(x) = 11.561058 (action=474)
#    current best f(x) = 15.199978 (best action=31)
#
# 0386-th step: f(x) = 11.595602 (action=459)
#    current best f(x) = 15.199978 (best action=31)
#
# 0387-th step: f(x) = 12.078285 (action=267)
#    current best f(x) = 15.199978 (best action=31)
#
# 0388-th step: f(x) = 11.289444 (action=226)
#    current best f(x) = 15.199978 (best action=31)
#
# 0389-th step: f(x) = 10.792849 (action=199)
#    current best f(x) = 15.199978 (best action=31)
#
# 0390-th step: f(x) = 12.062006 (action=298)
#    current best f(x) = 15.199978 (best action=31)
#
# 0391-th step: f(x) = 10.778927 (action=376)
#    current best f(x) = 15.199978 (best action=31)
#
# 0392-th step: f(x) = 10.910575 (action=242)
#    current best f(x) = 15.199978 (best action=31)
#
# 0393-th step: f(x) = 11.109756 (action=87)
#    current best f(x) = 15.199978 (best action=31)
#
# 0394-th step: f(x) = 10.552137 (action=108)
#    current best f(x) = 15.199978 (best action=31)
#
# 0395-th step: f(x) = 11.434854 (action=378)
#    current best f(x) = 15.199978 (best action=31)
#
# 0396-th step: f(x) = 11.191332 (action=204)
#    current best f(x) = 15.199978 (best action=31)
#
# 0397-th step: f(x) = 10.655057 (action=167)
#    current best f(x) = 15.199978 (best action=31)
#
# 0398-th step: f(x) = 11.303925 (action=136)
#    current best f(x) = 15.199978 (best action=31)
#
# 0399-th step: f(x) = 12.914692 (action=440)
#    current best f(x) = 15.199978 (best action=31)
#
# 0400-th step: f(x) = 10.900095 (action=327)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 423.8477346212573
# 50-th epoch, marginal likelihood 415.26212440505896
# 100-th epoch, marginal likelihood 404.43817637769
# 150-th epoch, marginal likelihood 392.35998450026943
# 200-th epoch, marginal likelihood 382.0768566717252
# 250-th epoch, marginal likelihood 372.51707172391264
# 300-th epoch, marginal likelihood 365.5065169862221
# 350-th epoch, marginal likelihood 362.1329184631706
# 400-th epoch, marginal likelihood 360.12325400553823
# 450-th epoch, marginal likelihood 359.04958277710216
# 500-th epoch, marginal likelihood 358.79199910265925
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [10.99209112]
#  scale  =  1.2254263359720723
#  scale2 =  1.5016697048939383
#
#
# 0401-th step: f(x) = 11.996111 (action=332)
#    current best f(x) = 15.199978 (best action=31)
#
# 0402-th step: f(x) = 11.224135 (action=173)
#    current best f(x) = 15.199978 (best action=31)
#
# 0403-th step: f(x) = 11.249624 (action=218)
#    current best f(x) = 15.199978 (best action=31)
#
# 0404-th step: f(x) = 10.655811 (action=54)
#    current best f(x) = 15.199978 (best action=31)
#
# 0405-th step: f(x) = 11.651286 (action=25)
#    current best f(x) = 15.199978 (best action=31)
#
# 0406-th step: f(x) = 10.957054 (action=302)
#    current best f(x) = 15.199978 (best action=31)
#
# 0407-th step: f(x) = 12.424244 (action=133)
#    current best f(x) = 15.199978 (best action=31)
#
# 0408-th step: f(x) = 11.074610 (action=253)
#    current best f(x) = 15.199978 (best action=31)
#
# 0409-th step: f(x) = 11.695947 (action=151)
#    current best f(x) = 15.199978 (best action=31)
#
# 0410-th step: f(x) = 11.263245 (action=195)
#    current best f(x) = 15.199978 (best action=31)
#
# 0411-th step: f(x) = 10.767790 (action=426)
#    current best f(x) = 15.199978 (best action=31)
#
# 0412-th step: f(x) = 10.695788 (action=182)
#    current best f(x) = 15.199978 (best action=31)
#
# 0413-th step: f(x) = 10.790007 (action=382)
#    current best f(x) = 15.199978 (best action=31)
#
# 0414-th step: f(x) = 11.446247 (action=446)
#    current best f(x) = 15.199978 (best action=31)
#
# 0415-th step: f(x) = 10.909970 (action=166)
#    current best f(x) = 15.199978 (best action=31)
#
# 0416-th step: f(x) = 10.662862 (action=143)
#    current best f(x) = 15.199978 (best action=31)
#
# 0417-th step: f(x) = 11.106744 (action=131)
#    current best f(x) = 15.199978 (best action=31)
#
# 0418-th step: f(x) = 11.461218 (action=286)
#    current best f(x) = 15.199978 (best action=31)
#
# 0419-th step: f(x) = 11.082569 (action=455)
#    current best f(x) = 15.199978 (best action=31)
#
# 0420-th step: f(x) = 10.905152 (action=307)
#    current best f(x) = 15.199978 (best action=31)
#
# 0421-th step: f(x) = 12.616376 (action=202)
#    current best f(x) = 15.199978 (best action=31)
#
# 0422-th step: f(x) = 11.565319 (action=371)
#    current best f(x) = 15.199978 (best action=31)
#
# 0423-th step: f(x) = 10.745824 (action=299)
#    current best f(x) = 15.199978 (best action=31)
#
# 0424-th step: f(x) = 11.906237 (action=124)
#    current best f(x) = 15.199978 (best action=31)
#
# 0425-th step: f(x) = 11.496893 (action=99)
#    current best f(x) = 15.199978 (best action=31)
#
# 0426-th step: f(x) = 10.816318 (action=493)
#    current best f(x) = 15.199978 (best action=31)
#
# 0427-th step: f(x) = 11.551213 (action=251)
#    current best f(x) = 15.199978 (best action=31)
#
# 0428-th step: f(x) = 12.379227 (action=19)
#    current best f(x) = 15.199978 (best action=31)
#
# 0429-th step: f(x) = 10.957787 (action=328)
#    current best f(x) = 15.199978 (best action=31)
#
# 0430-th step: f(x) = 10.834332 (action=331)
#    current best f(x) = 15.199978 (best action=31)
#
# 0431-th step: f(x) = 11.041490 (action=145)
#    current best f(x) = 15.199978 (best action=31)
#
# 0432-th step: f(x) = 10.540480 (action=258)
#    current best f(x) = 15.199978 (best action=31)
#
# 0433-th step: f(x) = 11.483278 (action=193)
#    current best f(x) = 15.199978 (best action=31)
#
# 0434-th step: f(x) = 12.353320 (action=281)
#    current best f(x) = 15.199978 (best action=31)
#
# 0435-th step: f(x) = 11.203542 (action=155)
#    current best f(x) = 15.199978 (best action=31)
#
# 0436-th step: f(x) = 12.093939 (action=107)
#    current best f(x) = 15.199978 (best action=31)
#
# 0437-th step: f(x) = 11.064199 (action=283)
#    current best f(x) = 15.199978 (best action=31)
#
# 0438-th step: f(x) = 11.855082 (action=26)
#    current best f(x) = 15.199978 (best action=31)
#
# 0439-th step: f(x) = 10.741203 (action=4)
#    current best f(x) = 15.199978 (best action=31)
#
# 0440-th step: f(x) = 11.448708 (action=315)
#    current best f(x) = 15.199978 (best action=31)
#
# 0441-th step: f(x) = 10.443396 (action=457)
#    current best f(x) = 15.199978 (best action=31)
#
# 0442-th step: f(x) = 11.626058 (action=464)
#    current best f(x) = 15.199978 (best action=31)
#
# 0443-th step: f(x) = 11.240781 (action=432)
#    current best f(x) = 15.199978 (best action=31)
#
# 0444-th step: f(x) = 10.295165 (action=114)
#    current best f(x) = 15.199978 (best action=31)
#
# 0445-th step: f(x) = 11.084139 (action=89)
#    current best f(x) = 15.199978 (best action=31)
#
# 0446-th step: f(x) = 11.285673 (action=160)
#    current best f(x) = 15.199978 (best action=31)
#
# 0447-th step: f(x) = 11.132425 (action=260)
#    current best f(x) = 15.199978 (best action=31)
#
# 0448-th step: f(x) = 10.839522 (action=65)
#    current best f(x) = 15.199978 (best action=31)
#
# 0449-th step: f(x) = 10.406131 (action=106)
#    current best f(x) = 15.199978 (best action=31)
#
# 0450-th step: f(x) = 12.091834 (action=369)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 468.02620877800496
# 50-th epoch, marginal likelihood 455.03464528349724
# 100-th epoch, marginal likelihood 443.4311927103967
# 150-th epoch, marginal likelihood 431.62139461011714
# 200-th epoch, marginal likelihood 418.40359026104676
# 250-th epoch, marginal likelihood 407.6894136403298
# 300-th epoch, marginal likelihood 399.95041864544874
# 350-th epoch, marginal likelihood 395.84893499517216
# 400-th epoch, marginal likelihood 394.31789107115844
# 450-th epoch, marginal likelihood 393.4626477686723
# 500-th epoch, marginal likelihood 393.2209688385329
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [11.03349437]
#  scale  =  1.2075837270878134
#  scale2 =  1.4582584579272946
#
#
# 0451-th step: f(x) = 10.140392 (action=473)
#    current best f(x) = 15.199978 (best action=31)
#
# 0452-th step: f(x) = 10.529290 (action=80)
#    current best f(x) = 15.199978 (best action=31)
#
# 0453-th step: f(x) = 10.343708 (action=239)
#    current best f(x) = 15.199978 (best action=31)
#
# 0454-th step: f(x) = 10.257400 (action=265)
#    current best f(x) = 15.199978 (best action=31)
#
# 0455-th step: f(x) = 10.642205 (action=3)
#    current best f(x) = 15.199978 (best action=31)
#
# 0456-th step: f(x) = 11.317897 (action=434)
#    current best f(x) = 15.199978 (best action=31)
#
# 0457-th step: f(x) = 10.448575 (action=403)
#    current best f(x) = 15.199978 (best action=31)
#
# 0458-th step: f(x) = 10.176099 (action=480)
#    current best f(x) = 15.199978 (best action=31)
#
# 0459-th step: f(x) = 11.631375 (action=201)
#    current best f(x) = 15.199978 (best action=31)
#
# 0460-th step: f(x) = 11.381211 (action=354)
#    current best f(x) = 15.199978 (best action=31)
#
# 0461-th step: f(x) = 11.221656 (action=497)
#    current best f(x) = 15.199978 (best action=31)
#
# 0462-th step: f(x) = 10.699004 (action=492)
#    current best f(x) = 15.199978 (best action=31)
#
# 0463-th step: f(x) = 10.886038 (action=405)
#    current best f(x) = 15.199978 (best action=31)
#
# 0464-th step: f(x) = 11.205741 (action=421)
#    current best f(x) = 15.199978 (best action=31)
#
# 0465-th step: f(x) = 11.347387 (action=92)
#    current best f(x) = 15.199978 (best action=31)
#
# 0466-th step: f(x) = 12.254696 (action=293)
#    current best f(x) = 15.199978 (best action=31)
#
# 0467-th step: f(x) = 10.840919 (action=345)
#    current best f(x) = 15.199978 (best action=31)
#
# 0468-th step: f(x) = 10.226846 (action=311)
#    current best f(x) = 15.199978 (best action=31)
#
# 0469-th step: f(x) = 10.052558 (action=337)
#    current best f(x) = 15.199978 (best action=31)
#
# 0470-th step: f(x) = 10.692779 (action=454)
#    current best f(x) = 15.199978 (best action=31)
#
# 0471-th step: f(x) = 11.955911 (action=389)
#    current best f(x) = 15.199978 (best action=31)
#
# 0472-th step: f(x) = 10.513623 (action=415)
#    current best f(x) = 15.199978 (best action=31)
#
# 0473-th step: f(x) = 10.523844 (action=262)
#    current best f(x) = 15.199978 (best action=31)
#
# 0474-th step: f(x) = 10.085563 (action=140)
#    current best f(x) = 15.199978 (best action=31)
#
# 0475-th step: f(x) = 11.438319 (action=203)
#    current best f(x) = 15.199978 (best action=31)
#
# 0476-th step: f(x) = 11.282694 (action=192)
#    current best f(x) = 15.199978 (best action=31)
#
# 0477-th step: f(x) = 10.824435 (action=375)
#    current best f(x) = 15.199978 (best action=31)
#
# 0478-th step: f(x) = 9.615372 (action=318)
#    current best f(x) = 15.199978 (best action=31)
#
# 0479-th step: f(x) = 11.340874 (action=460)
#    current best f(x) = 15.199978 (best action=31)
#
# 0480-th step: f(x) = 10.398979 (action=152)
#    current best f(x) = 15.199978 (best action=31)
#
# 0481-th step: f(x) = 10.243322 (action=100)
#    current best f(x) = 15.199978 (best action=31)
#
# 0482-th step: f(x) = 10.449700 (action=462)
#    current best f(x) = 15.199978 (best action=31)
#
# 0483-th step: f(x) = 10.875941 (action=212)
#    current best f(x) = 15.199978 (best action=31)
#
# 0484-th step: f(x) = 10.578947 (action=164)
#    current best f(x) = 15.199978 (best action=31)
#
# 0485-th step: f(x) = 9.865594 (action=365)
#    current best f(x) = 15.199978 (best action=31)
#
# 0486-th step: f(x) = 10.251253 (action=406)
#    current best f(x) = 15.199978 (best action=31)
#
# 0487-th step: f(x) = 10.775902 (action=227)
#    current best f(x) = 15.199978 (best action=31)
#
# 0488-th step: f(x) = 10.382457 (action=33)
#    current best f(x) = 15.199978 (best action=31)
#
# 0489-th step: f(x) = 11.666445 (action=24)
#    current best f(x) = 15.199978 (best action=31)
#
# 0490-th step: f(x) = 10.797852 (action=282)
#    current best f(x) = 15.199978 (best action=31)
#
# 0491-th step: f(x) = 10.310142 (action=319)
#    current best f(x) = 15.199978 (best action=31)
#
# 0492-th step: f(x) = 10.222708 (action=161)
#    current best f(x) = 15.199978 (best action=31)
#
# 0493-th step: f(x) = 11.247225 (action=217)
#    current best f(x) = 15.199978 (best action=31)
#
# 0494-th step: f(x) = 10.161434 (action=188)
#    current best f(x) = 15.199978 (best action=31)
#
# 0495-th step: f(x) = 10.292034 (action=274)
#    current best f(x) = 15.199978 (best action=31)
#
# 0496-th step: f(x) = 10.372103 (action=418)
#    current best f(x) = 15.199978 (best action=31)
#
# 0497-th step: f(x) = 10.172338 (action=297)
#    current best f(x) = 15.199978 (best action=31)
#
# 0498-th step: f(x) = 11.069586 (action=465)
#    current best f(x) = 15.199978 (best action=31)
#
# 0499-th step: f(x) = 10.460537 (action=248)
#    current best f(x) = 15.199978 (best action=31)
#
# 0500-th step: f(x) = 10.435767 (action=144)
#    current best f(x) = 15.199978 (best action=31)

# %%
COMBO_EI_Henry_CO2_unrelevant = COMBO(Data_unrelevant_features_Henry_CO2, 'EI')
# Out:
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 13.676339491936204
# 50-th epoch, marginal likelihood 1.5279730760355363
# 100-th epoch, marginal likelihood -5.742561308898502
# 150-th epoch, marginal likelihood -10.457303952423402
# 200-th epoch, marginal likelihood -13.23056107130705
# 250-th epoch, marginal likelihood -14.900032021357404
# 300-th epoch, marginal likelihood -16.18627656600708
# 350-th epoch, marginal likelihood -17.098878590329377
# 400-th epoch, marginal likelihood -17.764790297770162
# 450-th epoch, marginal likelihood -18.203218491323028
# 500-th epoch, marginal likelihood -18.67673942269773
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.]
#  scale  =  1.0
#  scale2 =  1.0
#
#
# 0101-th step: f(x) = 11.087779 (action=150)
#    current best f(x) = 11.087779 (best action=150)
#
# 0102-th step: f(x) = 11.377510 (action=210)
#    current best f(x) = 11.377510 (best action=210)
#
# 0103-th step: f(x) = 11.509843 (action=344)
#    current best f(x) = 11.509843 (best action=344)
#
# 0104-th step: f(x) = 11.363592 (action=463)
#    current best f(x) = 11.509843 (best action=344)
#
# 0105-th step: f(x) = 12.654977 (action=172)
#    current best f(x) = 12.654977 (best action=172)
#
# 0106-th step: f(x) = 14.045971 (action=436)
#    current best f(x) = 14.045971 (best action=436)
#
# 0107-th step: f(x) = 13.546707 (action=429)
#    current best f(x) = 14.045971 (best action=436)
#
# 0108-th step: f(x) = 12.625490 (action=216)
#    current best f(x) = 14.045971 (best action=436)
#
# 0109-th step: f(x) = 13.231695 (action=238)
#    current best f(x) = 14.045971 (best action=436)
#
# 0110-th step: f(x) = 14.117251 (action=205)
#    current best f(x) = 14.117251 (best action=205)
#
# 0111-th step: f(x) = 14.143965 (action=234)
#    current best f(x) = 14.143965 (best action=234)
#
# 0112-th step: f(x) = 13.392218 (action=437)
#    current best f(x) = 14.143965 (best action=234)
#
# 0113-th step: f(x) = 13.813066 (action=416)
#    current best f(x) = 14.143965 (best action=234)
#
# 0114-th step: f(x) = 12.713068 (action=141)
#    current best f(x) = 14.143965 (best action=234)
#
# 0115-th step: f(x) = 14.477286 (action=76)
#    current best f(x) = 14.477286 (best action=76)
#
# 0116-th step: f(x) = 12.255220 (action=125)
#    current best f(x) = 14.477286 (best action=76)
#
# 0117-th step: f(x) = 15.199978 (action=31)
#    current best f(x) = 15.199978 (best action=31)
#
# 0118-th step: f(x) = 14.455732 (action=84)
#    current best f(x) = 15.199978 (best action=31)
#
# 0119-th step: f(x) = 12.626932 (action=235)
#    current best f(x) = 15.199978 (best action=31)
#
# 0120-th step: f(x) = 13.603537 (action=431)
#    current best f(x) = 15.199978 (best action=31)
#
# 0121-th step: f(x) = 14.907075 (action=342)
#    current best f(x) = 15.199978 (best action=31)
#
# 0122-th step: f(x) = 14.162195 (action=392)
#    current best f(x) = 15.199978 (best action=31)
#
# 0123-th step: f(x) = 12.815232 (action=177)
#    current best f(x) = 15.199978 (best action=31)
#
# 0124-th step: f(x) = 14.004915 (action=407)
#    current best f(x) = 15.199978 (best action=31)
#
# 0125-th step: f(x) = 13.439160 (action=340)
#    current best f(x) = 15.199978 (best action=31)
#
# 0126-th step: f(x) = 12.893953 (action=64)
#    current best f(x) = 15.199978 (best action=31)
#
# 0127-th step: f(x) = 14.054575 (action=279)
#    current best f(x) = 15.199978 (best action=31)
#
# 0128-th step: f(x) = 13.371976 (action=320)
#    current best f(x) = 15.199978 (best action=31)
#
# 0129-th step: f(x) = 14.608082 (action=79)
#    current best f(x) = 15.199978 (best action=31)
#
# 0130-th step: f(x) = 12.199556 (action=149)
#    current best f(x) = 15.199978 (best action=31)
#
# 0131-th step: f(x) = 13.355414 (action=472)
#    current best f(x) = 15.199978 (best action=31)
#
# 0132-th step: f(x) = 13.388470 (action=142)
#    current best f(x) = 15.199978 (best action=31)
#
# 0133-th step: f(x) = 12.054249 (action=73)
#    current best f(x) = 15.199978 (best action=31)
#
# 0134-th step: f(x) = 13.252711 (action=59)
#    current best f(x) = 15.199978 (best action=31)
#
# 0135-th step: f(x) = 13.774910 (action=57)
#    current best f(x) = 15.199978 (best action=31)
#
# 0136-th step: f(x) = 14.470462 (action=478)
#    current best f(x) = 15.199978 (best action=31)
#
# 0137-th step: f(x) = 13.849071 (action=408)
#    current best f(x) = 15.199978 (best action=31)
#
# 0138-th step: f(x) = 14.562293 (action=481)
#    current best f(x) = 15.199978 (best action=31)
#
# 0139-th step: f(x) = 13.985827 (action=326)
#    current best f(x) = 15.199978 (best action=31)
#
# 0140-th step: f(x) = 13.666899 (action=62)
#    current best f(x) = 15.199978 (best action=31)
#
# 0141-th step: f(x) = 14.769074 (action=252)
#    current best f(x) = 15.199978 (best action=31)
#
# 0142-th step: f(x) = 13.023539 (action=45)
#    current best f(x) = 15.199978 (best action=31)
#
# 0143-th step: f(x) = 13.663556 (action=40)
#    current best f(x) = 15.199978 (best action=31)
#
# 0144-th step: f(x) = 12.521989 (action=309)
#    current best f(x) = 15.199978 (best action=31)
#
# 0145-th step: f(x) = 13.114851 (action=176)
#    current best f(x) = 15.199978 (best action=31)
#
# 0146-th step: f(x) = 10.886835 (action=6)
#    current best f(x) = 15.199978 (best action=31)
#
# 0147-th step: f(x) = 13.672768 (action=321)
#    current best f(x) = 15.199978 (best action=31)
#
# 0148-th step: f(x) = 13.629201 (action=171)
#    current best f(x) = 15.199978 (best action=31)
#
# 0149-th step: f(x) = 12.107213 (action=296)
#    current best f(x) = 15.199978 (best action=31)
#
# 0150-th step: f(x) = 12.157838 (action=386)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 159.26054732118607
# 50-th epoch, marginal likelihood 158.48345350528749
# 100-th epoch, marginal likelihood 157.87273063448362
# 150-th epoch, marginal likelihood 157.15463511854347
# 200-th epoch, marginal likelihood 156.5858333049291
# 250-th epoch, marginal likelihood 155.79302952797136
# 300-th epoch, marginal likelihood 155.04865421818772
# 350-th epoch, marginal likelihood 154.13594090924457
# 400-th epoch, marginal likelihood 153.46364630013608
# 450-th epoch, marginal likelihood 152.7471800220514
# 500-th epoch, marginal likelihood 152.16057588786174
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [5.18488644]
#  scale  =  0.2507527532996265
#  scale2 =  0.06287694328734333
#
#
# 0151-th step: f(x) = 13.359511 (action=86)
#    current best f(x) = 15.199978 (best action=31)
#
# 0152-th step: f(x) = 13.294333 (action=409)
#    current best f(x) = 15.199978 (best action=31)
#
# 0153-th step: f(x) = 13.113238 (action=470)
#    current best f(x) = 15.199978 (best action=31)
#
# 0154-th step: f(x) = 13.588520 (action=213)
#    current best f(x) = 15.199978 (best action=31)
#
# 0155-th step: f(x) = 13.936604 (action=495)
#    current best f(x) = 15.199978 (best action=31)
#
# 0156-th step: f(x) = 11.936276 (action=112)
#    current best f(x) = 15.199978 (best action=31)
#
# 0157-th step: f(x) = 12.678346 (action=428)
#    current best f(x) = 15.199978 (best action=31)
#
# 0158-th step: f(x) = 13.613529 (action=360)
#    current best f(x) = 15.199978 (best action=31)
#
# 0159-th step: f(x) = 12.623443 (action=134)
#    current best f(x) = 15.199978 (best action=31)
#
# 0160-th step: f(x) = 12.871684 (action=148)
#    current best f(x) = 15.199978 (best action=31)
#
# 0161-th step: f(x) = 13.550647 (action=341)
#    current best f(x) = 15.199978 (best action=31)
#
# 0162-th step: f(x) = 10.817089 (action=102)
#    current best f(x) = 15.199978 (best action=31)
#
# 0163-th step: f(x) = 12.073152 (action=388)
#    current best f(x) = 15.199978 (best action=31)
#
# 0164-th step: f(x) = 12.729697 (action=158)
#    current best f(x) = 15.199978 (best action=31)
#
# 0165-th step: f(x) = 12.241179 (action=499)
#    current best f(x) = 15.199978 (best action=31)
#
# 0166-th step: f(x) = 11.570194 (action=29)
#    current best f(x) = 15.199978 (best action=31)
#
# 0167-th step: f(x) = 13.346476 (action=292)
#    current best f(x) = 15.199978 (best action=31)
#
# 0168-th step: f(x) = 12.713222 (action=50)
#    current best f(x) = 15.199978 (best action=31)
#
# 0169-th step: f(x) = 12.500025 (action=48)
#    current best f(x) = 15.199978 (best action=31)
#
# 0170-th step: f(x) = 12.091924 (action=475)
#    current best f(x) = 15.199978 (best action=31)
#
# 0171-th step: f(x) = 12.169875 (action=276)
#    current best f(x) = 15.199978 (best action=31)
#
# 0172-th step: f(x) = 13.539830 (action=417)
#    current best f(x) = 15.199978 (best action=31)
#
# 0173-th step: f(x) = 13.545193 (action=215)
#    current best f(x) = 15.199978 (best action=31)
#
# 0174-th step: f(x) = 11.620990 (action=219)
#    current best f(x) = 15.199978 (best action=31)
#
# 0175-th step: f(x) = 12.174262 (action=295)
#    current best f(x) = 15.199978 (best action=31)
#
# 0176-th step: f(x) = 12.391548 (action=396)
#    current best f(x) = 15.199978 (best action=31)
#
# 0177-th step: f(x) = 11.553520 (action=88)
#    current best f(x) = 15.199978 (best action=31)
#
# 0178-th step: f(x) = 11.352042 (action=444)
#    current best f(x) = 15.199978 (best action=31)
#
# 0179-th step: f(x) = 10.906163 (action=383)
#    current best f(x) = 15.199978 (best action=31)
#
# 0180-th step: f(x) = 11.457136 (action=67)
#    current best f(x) = 15.199978 (best action=31)
#
# 0181-th step: f(x) = 12.949820 (action=94)
#    current best f(x) = 15.199978 (best action=31)
#
# 0182-th step: f(x) = 12.516340 (action=18)
#    current best f(x) = 15.199978 (best action=31)
#
# 0183-th step: f(x) = 12.848931 (action=257)
#    current best f(x) = 15.199978 (best action=31)
#
# 0184-th step: f(x) = 11.172079 (action=373)
#    current best f(x) = 15.199978 (best action=31)
#
# 0185-th step: f(x) = 11.787142 (action=105)
#    current best f(x) = 15.199978 (best action=31)
#
# 0186-th step: f(x) = 12.029485 (action=34)
#    current best f(x) = 15.199978 (best action=31)
#
# 0187-th step: f(x) = 12.147808 (action=162)
#    current best f(x) = 15.199978 (best action=31)
#
# 0188-th step: f(x) = 11.747760 (action=56)
#    current best f(x) = 15.199978 (best action=31)
#
# 0189-th step: f(x) = 12.429956 (action=117)
#    current best f(x) = 15.199978 (best action=31)
#
# 0190-th step: f(x) = 11.415023 (action=5)
#    current best f(x) = 15.199978 (best action=31)
#
# 0191-th step: f(x) = 10.822187 (action=97)
#    current best f(x) = 15.199978 (best action=31)
#
# 0192-th step: f(x) = 11.912748 (action=130)
#    current best f(x) = 15.199978 (best action=31)
#
# 0193-th step: f(x) = 11.840141 (action=488)
#    current best f(x) = 15.199978 (best action=31)
#
# 0194-th step: f(x) = 13.003787 (action=169)
#    current best f(x) = 15.199978 (best action=31)
#
# 0195-th step: f(x) = 12.232607 (action=346)
#    current best f(x) = 15.199978 (best action=31)
#
# 0196-th step: f(x) = 12.558981 (action=385)
#    current best f(x) = 15.199978 (best action=31)
#
# 0197-th step: f(x) = 12.707236 (action=338)
#    current best f(x) = 15.199978 (best action=31)
#
# 0198-th step: f(x) = 12.305130 (action=270)
#    current best f(x) = 15.199978 (best action=31)
#
# 0199-th step: f(x) = 10.597839 (action=129)
#    current best f(x) = 15.199978 (best action=31)
#
# 0200-th step: f(x) = 12.104178 (action=23)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 212.73787778758367
# 50-th epoch, marginal likelihood 211.4789358687974
# 100-th epoch, marginal likelihood 209.1265023666474
# 150-th epoch, marginal likelihood 207.00774123052713
# 200-th epoch, marginal likelihood 205.14041276431593
# 250-th epoch, marginal likelihood 202.67782870728195
# 300-th epoch, marginal likelihood 200.54793560854807
# 350-th epoch, marginal likelihood 198.6455410394599
# 400-th epoch, marginal likelihood 197.1698692480865
# 450-th epoch, marginal likelihood 196.300881106701
# 500-th epoch, marginal likelihood 195.70082653793625
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [9.17844512]
#  scale  =  1.2367500603273118
#  scale2 =  1.5295507117196094
#
#
# 0201-th step: f(x) = 12.980763 (action=36)
#    current best f(x) = 15.199978 (best action=31)
#
# 0202-th step: f(x) = 12.943906 (action=487)
#    current best f(x) = 15.199978 (best action=31)
#
# 0203-th step: f(x) = 12.535761 (action=109)
#    current best f(x) = 15.199978 (best action=31)
#
# 0204-th step: f(x) = 11.349901 (action=42)
#    current best f(x) = 15.199978 (best action=31)
#
# 0205-th step: f(x) = 12.109578 (action=443)
#    current best f(x) = 15.199978 (best action=31)
#
# 0206-th step: f(x) = 12.064163 (action=77)
#    current best f(x) = 15.199978 (best action=31)
#
# 0207-th step: f(x) = 11.472237 (action=461)
#    current best f(x) = 15.199978 (best action=31)
#
# 0208-th step: f(x) = 12.775475 (action=263)
#    current best f(x) = 15.199978 (best action=31)
#
# 0209-th step: f(x) = 10.954454 (action=273)
#    current best f(x) = 15.199978 (best action=31)
#
# 0210-th step: f(x) = 12.206058 (action=194)
#    current best f(x) = 15.199978 (best action=31)
#
# 0211-th step: f(x) = 12.248461 (action=351)
#    current best f(x) = 15.199978 (best action=31)
#
# 0212-th step: f(x) = 12.187471 (action=101)
#    current best f(x) = 15.199978 (best action=31)
#
# 0213-th step: f(x) = 11.099243 (action=184)
#    current best f(x) = 15.199978 (best action=31)
#
# 0214-th step: f(x) = 12.238690 (action=483)
#    current best f(x) = 15.199978 (best action=31)
#
# 0215-th step: f(x) = 12.189333 (action=316)
#    current best f(x) = 15.199978 (best action=31)
#
# 0216-th step: f(x) = 11.749893 (action=391)
#    current best f(x) = 15.199978 (best action=31)
#
# 0217-th step: f(x) = 12.504769 (action=453)
#    current best f(x) = 15.199978 (best action=31)
#
# 0218-th step: f(x) = 13.840730 (action=154)
#    current best f(x) = 15.199978 (best action=31)
#
# 0219-th step: f(x) = 12.177282 (action=498)
#    current best f(x) = 15.199978 (best action=31)
#
# 0220-th step: f(x) = 12.849255 (action=412)
#    current best f(x) = 15.199978 (best action=31)
#
# 0221-th step: f(x) = 10.622980 (action=303)
#    current best f(x) = 15.199978 (best action=31)
#
# 0222-th step: f(x) = 11.078800 (action=400)
#    current best f(x) = 15.199978 (best action=31)
#
# 0223-th step: f(x) = 13.460839 (action=424)
#    current best f(x) = 15.199978 (best action=31)
#
# 0224-th step: f(x) = 11.478575 (action=81)
#    current best f(x) = 15.199978 (best action=31)
#
# 0225-th step: f(x) = 11.835342 (action=132)
#    current best f(x) = 15.199978 (best action=31)
#
# 0226-th step: f(x) = 12.272534 (action=352)
#    current best f(x) = 15.199978 (best action=31)
#
# 0227-th step: f(x) = 11.561811 (action=58)
#    current best f(x) = 15.199978 (best action=31)
#
# 0228-th step: f(x) = 11.017555 (action=39)
#    current best f(x) = 15.199978 (best action=31)
#
# 0229-th step: f(x) = 11.618852 (action=121)
#    current best f(x) = 15.199978 (best action=31)
#
# 0230-th step: f(x) = 10.685140 (action=268)
#    current best f(x) = 15.199978 (best action=31)
#
# 0231-th step: f(x) = 10.717455 (action=250)
#    current best f(x) = 15.199978 (best action=31)
#
# 0232-th step: f(x) = 11.554115 (action=404)
#    current best f(x) = 15.199978 (best action=31)
#
# 0233-th step: f(x) = 11.797578 (action=266)
#    current best f(x) = 15.199978 (best action=31)
#
# 0234-th step: f(x) = 10.760911 (action=275)
#    current best f(x) = 15.199978 (best action=31)
#
# 0235-th step: f(x) = 12.267379 (action=70)
#    current best f(x) = 15.199978 (best action=31)
#
# 0236-th step: f(x) = 11.201851 (action=178)
#    current best f(x) = 15.199978 (best action=31)
#
# 0237-th step: f(x) = 10.768940 (action=83)
#    current best f(x) = 15.199978 (best action=31)
#
# 0238-th step: f(x) = 12.083606 (action=66)
#    current best f(x) = 15.199978 (best action=31)
#
# 0239-th step: f(x) = 11.579883 (action=21)
#    current best f(x) = 15.199978 (best action=31)
#
# 0240-th step: f(x) = 10.972662 (action=306)
#    current best f(x) = 15.199978 (best action=31)
#
# 0241-th step: f(x) = 12.180021 (action=221)
#    current best f(x) = 15.199978 (best action=31)
#
# 0242-th step: f(x) = 11.853454 (action=228)
#    current best f(x) = 15.199978 (best action=31)
#
# 0243-th step: f(x) = 11.979479 (action=384)
#    current best f(x) = 15.199978 (best action=31)
#
# 0244-th step: f(x) = 11.605596 (action=237)
#    current best f(x) = 15.199978 (best action=31)
#
# 0245-th step: f(x) = 12.650088 (action=179)
#    current best f(x) = 15.199978 (best action=31)
#
# 0246-th step: f(x) = 11.133030 (action=491)
#    current best f(x) = 15.199978 (best action=31)
#
# 0247-th step: f(x) = 10.867553 (action=355)
#    current best f(x) = 15.199978 (best action=31)
#
# 0248-th step: f(x) = 12.421889 (action=452)
#    current best f(x) = 15.199978 (best action=31)
#
# 0249-th step: f(x) = 12.701863 (action=370)
#    current best f(x) = 15.199978 (best action=31)
#
# 0250-th step: f(x) = 12.105849 (action=30)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 259.1066984911488
# 50-th epoch, marginal likelihood 257.8724173153069
# 100-th epoch, marginal likelihood 255.8637540150687
# 150-th epoch, marginal likelihood 253.8888326832429
# 200-th epoch, marginal likelihood 251.71066045901156
# 250-th epoch, marginal likelihood 249.31528713373206
# 300-th epoch, marginal likelihood 246.7568135454323
# 350-th epoch, marginal likelihood 244.2549277946168
# 400-th epoch, marginal likelihood 242.30253525069494
# 450-th epoch, marginal likelihood 240.508091547483
# 500-th epoch, marginal likelihood 238.9443315097792
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [11.37135589]
#  scale  =  1.3075138377616982
#  scale2 =  1.7095924359383243
#
#
# 0251-th step: f(x) = 11.372283 (action=271)
#    current best f(x) = 15.199978 (best action=31)
#
# 0252-th step: f(x) = 11.680616 (action=422)
#    current best f(x) = 15.199978 (best action=31)
#
# 0253-th step: f(x) = 11.420773 (action=224)
#    current best f(x) = 15.199978 (best action=31)
#
# 0254-th step: f(x) = 10.589897 (action=435)
#    current best f(x) = 15.199978 (best action=31)
#
# 0255-th step: f(x) = 11.254489 (action=420)
#    current best f(x) = 15.199978 (best action=31)
#
# 0256-th step: f(x) = 12.299736 (action=128)
#    current best f(x) = 15.199978 (best action=31)
#
# 0257-th step: f(x) = 12.864745 (action=220)
#    current best f(x) = 15.199978 (best action=31)
#
# 0258-th step: f(x) = 11.259156 (action=229)
#    current best f(x) = 15.199978 (best action=31)
#
# 0259-th step: f(x) = 11.315061 (action=127)
#    current best f(x) = 15.199978 (best action=31)
#
# 0260-th step: f(x) = 10.578881 (action=90)
#    current best f(x) = 15.199978 (best action=31)
#
# 0261-th step: f(x) = 12.007353 (action=69)
#    current best f(x) = 15.199978 (best action=31)
#
# 0262-th step: f(x) = 11.131331 (action=28)
#    current best f(x) = 15.199978 (best action=31)
#
# 0263-th step: f(x) = 11.837441 (action=348)
#    current best f(x) = 15.199978 (best action=31)
#
# 0264-th step: f(x) = 11.599598 (action=447)
#    current best f(x) = 15.199978 (best action=31)
#
# 0265-th step: f(x) = 11.268019 (action=401)
#    current best f(x) = 15.199978 (best action=31)
#
# 0266-th step: f(x) = 10.998358 (action=8)
#    current best f(x) = 15.199978 (best action=31)
#
# 0267-th step: f(x) = 12.163645 (action=343)
#    current best f(x) = 15.199978 (best action=31)
#
# 0268-th step: f(x) = 10.985828 (action=350)
#    current best f(x) = 15.199978 (best action=31)
#
# 0269-th step: f(x) = 11.142889 (action=335)
#    current best f(x) = 15.199978 (best action=31)
#
# 0270-th step: f(x) = 11.816188 (action=156)
#    current best f(x) = 15.199978 (best action=31)
#
# 0271-th step: f(x) = 12.219334 (action=469)
#    current best f(x) = 15.199978 (best action=31)
#
# 0272-th step: f(x) = 12.986748 (action=209)
#    current best f(x) = 15.199978 (best action=31)
#
# 0273-th step: f(x) = 10.927216 (action=231)
#    current best f(x) = 15.199978 (best action=31)
#
# 0274-th step: f(x) = 12.236354 (action=96)
#    current best f(x) = 15.199978 (best action=31)
#
# 0275-th step: f(x) = 12.775605 (action=466)
#    current best f(x) = 15.199978 (best action=31)
#
# 0276-th step: f(x) = 11.479613 (action=1)
#    current best f(x) = 15.199978 (best action=31)
#
# 0277-th step: f(x) = 12.291456 (action=20)
#    current best f(x) = 15.199978 (best action=31)
#
# 0278-th step: f(x) = 11.738139 (action=259)
#    current best f(x) = 15.199978 (best action=31)
#
# 0279-th step: f(x) = 11.137141 (action=118)
#    current best f(x) = 15.199978 (best action=31)
#
# 0280-th step: f(x) = 11.859829 (action=390)
#    current best f(x) = 15.199978 (best action=31)
#
# 0281-th step: f(x) = 11.691699 (action=304)
#    current best f(x) = 15.199978 (best action=31)
#
# 0282-th step: f(x) = 11.807682 (action=425)
#    current best f(x) = 15.199978 (best action=31)
#
# 0283-th step: f(x) = 12.359274 (action=233)
#    current best f(x) = 15.199978 (best action=31)
#
# 0284-th step: f(x) = 11.468653 (action=484)
#    current best f(x) = 15.199978 (best action=31)
#
# 0285-th step: f(x) = 11.292059 (action=63)
#    current best f(x) = 15.199978 (best action=31)
#
# 0286-th step: f(x) = 11.458059 (action=442)
#    current best f(x) = 15.199978 (best action=31)
#
# 0287-th step: f(x) = 10.900656 (action=330)
#    current best f(x) = 15.199978 (best action=31)
#
# 0288-th step: f(x) = 11.383509 (action=17)
#    current best f(x) = 15.199978 (best action=31)
#
# 0289-th step: f(x) = 13.433437 (action=165)
#    current best f(x) = 15.199978 (best action=31)
#
# 0290-th step: f(x) = 10.989860 (action=359)
#    current best f(x) = 15.199978 (best action=31)
#
# 0291-th step: f(x) = 10.831972 (action=494)
#    current best f(x) = 15.199978 (best action=31)
#
# 0292-th step: f(x) = 11.948305 (action=288)
#    current best f(x) = 15.199978 (best action=31)
#
# 0293-th step: f(x) = 12.283302 (action=438)
#    current best f(x) = 15.199978 (best action=31)
#
# 0294-th step: f(x) = 11.933062 (action=98)
#    current best f(x) = 15.199978 (best action=31)
#
# 0295-th step: f(x) = 11.063046 (action=278)
#    current best f(x) = 15.199978 (best action=31)
#
# 0296-th step: f(x) = 10.850362 (action=10)
#    current best f(x) = 15.199978 (best action=31)
#
# 0297-th step: f(x) = 11.797548 (action=397)
#    current best f(x) = 15.199978 (best action=31)
#
# 0298-th step: f(x) = 10.601990 (action=78)
#    current best f(x) = 15.199978 (best action=31)
#
# 0299-th step: f(x) = 12.541712 (action=377)
#    current best f(x) = 15.199978 (best action=31)
#
# 0300-th step: f(x) = 11.167719 (action=181)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 307.38099768566457
# 50-th epoch, marginal likelihood 304.956111624634
# 100-th epoch, marginal likelihood 302.07269077169883
# 150-th epoch, marginal likelihood 297.83143957081404
# 200-th epoch, marginal likelihood 294.6289040128012
# 250-th epoch, marginal likelihood 290.3455007477998
# 300-th epoch, marginal likelihood 286.3374148515071
# 350-th epoch, marginal likelihood 283.56003856317767
# 400-th epoch, marginal likelihood 281.288705235708
# 450-th epoch, marginal likelihood 279.734130990469
# 500-th epoch, marginal likelihood 278.91262121840793
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [10.81720531]
#  scale  =  1.2544253666864944
#  scale2 =  1.5735830005865459
#
#
# 0301-th step: f(x) = 12.115880 (action=196)
#    current best f(x) = 15.199978 (best action=31)
#
# 0302-th step: f(x) = 11.085025 (action=261)
#    current best f(x) = 15.199978 (best action=31)
#
# 0303-th step: f(x) = 11.959142 (action=290)
#    current best f(x) = 15.199978 (best action=31)
#
# 0304-th step: f(x) = 10.896921 (action=91)
#    current best f(x) = 15.199978 (best action=31)
#
# 0305-th step: f(x) = 11.809855 (action=113)
#    current best f(x) = 15.199978 (best action=31)
#
# 0306-th step: f(x) = 12.923593 (action=471)
#    current best f(x) = 15.199978 (best action=31)
#
# 0307-th step: f(x) = 11.712260 (action=486)
#    current best f(x) = 15.199978 (best action=31)
#
# 0308-th step: f(x) = 11.982223 (action=51)
#    current best f(x) = 15.199978 (best action=31)
#
# 0309-th step: f(x) = 10.699392 (action=198)
#    current best f(x) = 15.199978 (best action=31)
#
# 0310-th step: f(x) = 11.419107 (action=308)
#    current best f(x) = 15.199978 (best action=31)
#
# 0311-th step: f(x) = 11.772817 (action=393)
#    current best f(x) = 15.199978 (best action=31)
#
# 0312-th step: f(x) = 13.580027 (action=394)
#    current best f(x) = 15.199978 (best action=31)
#
# 0313-th step: f(x) = 11.862293 (action=414)
#    current best f(x) = 15.199978 (best action=31)
#
# 0314-th step: f(x) = 11.536828 (action=456)
#    current best f(x) = 15.199978 (best action=31)
#
# 0315-th step: f(x) = 11.254207 (action=14)
#    current best f(x) = 15.199978 (best action=31)
#
# 0316-th step: f(x) = 10.538441 (action=183)
#    current best f(x) = 15.199978 (best action=31)
#
# 0317-th step: f(x) = 10.824694 (action=13)
#    current best f(x) = 15.199978 (best action=31)
#
# 0318-th step: f(x) = 12.034246 (action=361)
#    current best f(x) = 15.199978 (best action=31)
#
# 0319-th step: f(x) = 11.728504 (action=294)
#    current best f(x) = 15.199978 (best action=31)
#
# 0320-th step: f(x) = 11.418648 (action=324)
#    current best f(x) = 15.199978 (best action=31)
#
# 0321-th step: f(x) = 11.365277 (action=289)
#    current best f(x) = 15.199978 (best action=31)
#
# 0322-th step: f(x) = 10.563776 (action=301)
#    current best f(x) = 15.199978 (best action=31)
#
# 0323-th step: f(x) = 11.113649 (action=477)
#    current best f(x) = 15.199978 (best action=31)
#
# 0324-th step: f(x) = 12.747664 (action=243)
#    current best f(x) = 15.199978 (best action=31)
#
# 0325-th step: f(x) = 12.042058 (action=240)
#    current best f(x) = 15.199978 (best action=31)
#
# 0326-th step: f(x) = 12.415357 (action=163)
#    current best f(x) = 15.199978 (best action=31)
#
# 0327-th step: f(x) = 10.740441 (action=211)
#    current best f(x) = 15.199978 (best action=31)
#
# 0328-th step: f(x) = 11.394897 (action=46)
#    current best f(x) = 15.199978 (best action=31)
#
# 0329-th step: f(x) = 11.103749 (action=264)
#    current best f(x) = 15.199978 (best action=31)
#
# 0330-th step: f(x) = 12.221931 (action=249)
#    current best f(x) = 15.199978 (best action=31)
#
# 0331-th step: f(x) = 10.948105 (action=485)
#    current best f(x) = 15.199978 (best action=31)
#
# 0332-th step: f(x) = 12.321462 (action=207)
#    current best f(x) = 15.199978 (best action=31)
#
# 0333-th step: f(x) = 12.074579 (action=449)
#    current best f(x) = 15.199978 (best action=31)
#
# 0334-th step: f(x) = 12.154274 (action=246)
#    current best f(x) = 15.199978 (best action=31)
#
# 0335-th step: f(x) = 12.050471 (action=427)
#    current best f(x) = 15.199978 (best action=31)
#
# 0336-th step: f(x) = 10.777144 (action=411)
#    current best f(x) = 15.199978 (best action=31)
#
# 0337-th step: f(x) = 12.468145 (action=334)
#    current best f(x) = 15.199978 (best action=31)
#
# 0338-th step: f(x) = 13.430452 (action=38)
#    current best f(x) = 15.199978 (best action=31)
#
# 0339-th step: f(x) = 11.576867 (action=75)
#    current best f(x) = 15.199978 (best action=31)
#
# 0340-th step: f(x) = 13.241262 (action=305)
#    current best f(x) = 15.199978 (best action=31)
#
# 0341-th step: f(x) = 12.148417 (action=374)
#    current best f(x) = 15.199978 (best action=31)
#
# 0342-th step: f(x) = 13.687319 (action=313)
#    current best f(x) = 15.199978 (best action=31)
#
# 0343-th step: f(x) = 12.078785 (action=206)
#    current best f(x) = 15.199978 (best action=31)
#
# 0344-th step: f(x) = 11.967225 (action=115)
#    current best f(x) = 15.199978 (best action=31)
#
# 0345-th step: f(x) = 11.558682 (action=256)
#    current best f(x) = 15.199978 (best action=31)
#
# 0346-th step: f(x) = 12.592154 (action=490)
#    current best f(x) = 15.199978 (best action=31)
#
# 0347-th step: f(x) = 11.295484 (action=185)
#    current best f(x) = 15.199978 (best action=31)
#
# 0348-th step: f(x) = 11.713823 (action=329)
#    current best f(x) = 15.199978 (best action=31)
#
# 0349-th step: f(x) = 12.107765 (action=93)
#    current best f(x) = 15.199978 (best action=31)
#
# 0350-th step: f(x) = 11.279764 (action=433)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 363.42182551011246
# 50-th epoch, marginal likelihood 358.41726985471223
# 100-th epoch, marginal likelihood 353.74262651794237
# 150-th epoch, marginal likelihood 346.27974528090874
# 200-th epoch, marginal likelihood 339.6481574967667
# 250-th epoch, marginal likelihood 333.7990984726888
# 300-th epoch, marginal likelihood 328.7675169326218
# 350-th epoch, marginal likelihood 324.96722085208546
# 400-th epoch, marginal likelihood 322.9027647159504
# 450-th epoch, marginal likelihood 321.7078352653989
# 500-th epoch, marginal likelihood 320.9959721049289
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [10.93351996]
#  scale  =  1.2219465511506618
#  scale2 =  1.4931533738689968
#
#
# 0351-th step: f(x) = 11.739615 (action=430)
#    current best f(x) = 15.199978 (best action=31)
#
# 0352-th step: f(x) = 12.356719 (action=7)
#    current best f(x) = 15.199978 (best action=31)
#
# 0353-th step: f(x) = 10.894236 (action=44)
#    current best f(x) = 15.199978 (best action=31)
#
# 0354-th step: f(x) = 11.026365 (action=27)
#    current best f(x) = 15.199978 (best action=31)
#
# 0355-th step: f(x) = 11.463772 (action=353)
#    current best f(x) = 15.199978 (best action=31)
#
# 0356-th step: f(x) = 11.342603 (action=12)
#    current best f(x) = 15.199978 (best action=31)
#
# 0357-th step: f(x) = 11.688885 (action=339)
#    current best f(x) = 15.199978 (best action=31)
#
# 0358-th step: f(x) = 11.193615 (action=277)
#    current best f(x) = 15.199978 (best action=31)
#
# 0359-th step: f(x) = 11.425267 (action=362)
#    current best f(x) = 15.199978 (best action=31)
#
# 0360-th step: f(x) = 10.971218 (action=232)
#    current best f(x) = 15.199978 (best action=31)
#
# 0361-th step: f(x) = 10.595449 (action=225)
#    current best f(x) = 15.199978 (best action=31)
#
# 0362-th step: f(x) = 11.845368 (action=37)
#    current best f(x) = 15.199978 (best action=31)
#
# 0363-th step: f(x) = 10.838168 (action=451)
#    current best f(x) = 15.199978 (best action=31)
#
# 0364-th step: f(x) = 12.201452 (action=479)
#    current best f(x) = 15.199978 (best action=31)
#
# 0365-th step: f(x) = 11.498842 (action=153)
#    current best f(x) = 15.199978 (best action=31)
#
# 0366-th step: f(x) = 11.054344 (action=244)
#    current best f(x) = 15.199978 (best action=31)
#
# 0367-th step: f(x) = 10.952023 (action=214)
#    current best f(x) = 15.199978 (best action=31)
#
# 0368-th step: f(x) = 11.395841 (action=85)
#    current best f(x) = 15.199978 (best action=31)
#
# 0369-th step: f(x) = 11.350903 (action=364)
#    current best f(x) = 15.199978 (best action=31)
#
# 0370-th step: f(x) = 11.631695 (action=2)
#    current best f(x) = 15.199978 (best action=31)
#
# 0371-th step: f(x) = 11.461425 (action=357)
#    current best f(x) = 15.199978 (best action=31)
#
# 0372-th step: f(x) = 10.852501 (action=358)
#    current best f(x) = 15.199978 (best action=31)
#
# 0373-th step: f(x) = 11.831146 (action=32)
#    current best f(x) = 15.199978 (best action=31)
#
# 0374-th step: f(x) = 11.793213 (action=247)
#    current best f(x) = 15.199978 (best action=31)
#
# 0375-th step: f(x) = 11.863730 (action=175)
#    current best f(x) = 15.199978 (best action=31)
#
# 0376-th step: f(x) = 11.458730 (action=208)
#    current best f(x) = 15.199978 (best action=31)
#
# 0377-th step: f(x) = 11.121164 (action=15)
#    current best f(x) = 15.199978 (best action=31)
#
# 0378-th step: f(x) = 13.948974 (action=439)
#    current best f(x) = 15.199978 (best action=31)
#
# 0379-th step: f(x) = 10.675901 (action=280)
#    current best f(x) = 15.199978 (best action=31)
#
# 0380-th step: f(x) = 11.219797 (action=325)
#    current best f(x) = 15.199978 (best action=31)
#
# 0381-th step: f(x) = 12.291323 (action=380)
#    current best f(x) = 15.199978 (best action=31)
#
# 0382-th step: f(x) = 11.393145 (action=200)
#    current best f(x) = 15.199978 (best action=31)
#
# 0383-th step: f(x) = 11.788183 (action=419)
#    current best f(x) = 15.199978 (best action=31)
#
# 0384-th step: f(x) = 11.311431 (action=103)
#    current best f(x) = 15.199978 (best action=31)
#
# 0385-th step: f(x) = 11.561058 (action=474)
#    current best f(x) = 15.199978 (best action=31)
#
# 0386-th step: f(x) = 11.595602 (action=459)
#    current best f(x) = 15.199978 (best action=31)
#
# 0387-th step: f(x) = 12.078285 (action=267)
#    current best f(x) = 15.199978 (best action=31)
#
# 0388-th step: f(x) = 10.792849 (action=199)
#    current best f(x) = 15.199978 (best action=31)
#
# 0389-th step: f(x) = 10.778927 (action=376)
#    current best f(x) = 15.199978 (best action=31)
#
# 0390-th step: f(x) = 12.062006 (action=298)
#    current best f(x) = 15.199978 (best action=31)
#
# 0391-th step: f(x) = 11.289444 (action=226)
#    current best f(x) = 15.199978 (best action=31)
#
# 0392-th step: f(x) = 10.910575 (action=242)
#    current best f(x) = 15.199978 (best action=31)
#
# 0393-th step: f(x) = 11.109756 (action=87)
#    current best f(x) = 15.199978 (best action=31)
#
# 0394-th step: f(x) = 10.552137 (action=108)
#    current best f(x) = 15.199978 (best action=31)
#
# 0395-th step: f(x) = 11.434854 (action=378)
#    current best f(x) = 15.199978 (best action=31)
#
# 0396-th step: f(x) = 11.191332 (action=204)
#    current best f(x) = 15.199978 (best action=31)
#
# 0397-th step: f(x) = 10.655057 (action=167)
#    current best f(x) = 15.199978 (best action=31)
#
# 0398-th step: f(x) = 11.303925 (action=136)
#    current best f(x) = 15.199978 (best action=31)
#
# 0399-th step: f(x) = 12.914692 (action=440)
#    current best f(x) = 15.199978 (best action=31)
#
# 0400-th step: f(x) = 10.900095 (action=327)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 424.4525845102213
# 50-th epoch, marginal likelihood 415.9697883030723
# 100-th epoch, marginal likelihood 403.43356105038
# 150-th epoch, marginal likelihood 391.16049462579036
# 200-th epoch, marginal likelihood 380.3707367120512
# 250-th epoch, marginal likelihood 371.21940914485805
# 300-th epoch, marginal likelihood 364.9493663581319
# 350-th epoch, marginal likelihood 361.8720496444639
# 400-th epoch, marginal likelihood 360.0679854649055
# 450-th epoch, marginal likelihood 359.05739316021095
# 500-th epoch, marginal likelihood 358.59715887768414
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [10.92103503]
#  scale  =  1.2225144170119306
#  scale2 =  1.4945414998020206
#
#
# 0401-th step: f(x) = 11.996111 (action=332)
#    current best f(x) = 15.199978 (best action=31)
#
# 0402-th step: f(x) = 10.655811 (action=54)
#    current best f(x) = 15.199978 (best action=31)
#
# 0403-th step: f(x) = 10.957054 (action=302)
#    current best f(x) = 15.199978 (best action=31)
#
# 0404-th step: f(x) = 11.224135 (action=173)
#    current best f(x) = 15.199978 (best action=31)
#
# 0405-th step: f(x) = 11.249624 (action=218)
#    current best f(x) = 15.199978 (best action=31)
#
# 0406-th step: f(x) = 11.651286 (action=25)
#    current best f(x) = 15.199978 (best action=31)
#
# 0407-th step: f(x) = 11.074610 (action=253)
#    current best f(x) = 15.199978 (best action=31)
#
# 0408-th step: f(x) = 12.424244 (action=133)
#    current best f(x) = 15.199978 (best action=31)
#
# 0409-th step: f(x) = 10.767790 (action=426)
#    current best f(x) = 15.199978 (best action=31)
#
# 0410-th step: f(x) = 11.263245 (action=195)
#    current best f(x) = 15.199978 (best action=31)
#
# 0411-th step: f(x) = 11.695947 (action=151)
#    current best f(x) = 15.199978 (best action=31)
#
# 0412-th step: f(x) = 10.695788 (action=182)
#    current best f(x) = 15.199978 (best action=31)
#
# 0413-th step: f(x) = 10.790007 (action=382)
#    current best f(x) = 15.199978 (best action=31)
#
# 0414-th step: f(x) = 11.446247 (action=446)
#    current best f(x) = 15.199978 (best action=31)
#
# 0415-th step: f(x) = 10.909970 (action=166)
#    current best f(x) = 15.199978 (best action=31)
#
# 0416-th step: f(x) = 10.662862 (action=143)
#    current best f(x) = 15.199978 (best action=31)
#
# 0417-th step: f(x) = 11.461218 (action=286)
#    current best f(x) = 15.199978 (best action=31)
#
# 0418-th step: f(x) = 11.106744 (action=131)
#    current best f(x) = 15.199978 (best action=31)
#
# 0419-th step: f(x) = 11.082569 (action=455)
#    current best f(x) = 15.199978 (best action=31)
#
# 0420-th step: f(x) = 10.905152 (action=307)
#    current best f(x) = 15.199978 (best action=31)
#
# 0421-th step: f(x) = 11.565319 (action=371)
#    current best f(x) = 15.199978 (best action=31)
#
# 0422-th step: f(x) = 12.616376 (action=202)
#    current best f(x) = 15.199978 (best action=31)
#
# 0423-th step: f(x) = 10.745824 (action=299)
#    current best f(x) = 15.199978 (best action=31)
#
# 0424-th step: f(x) = 11.906237 (action=124)
#    current best f(x) = 15.199978 (best action=31)
#
# 0425-th step: f(x) = 10.816318 (action=493)
#    current best f(x) = 15.199978 (best action=31)
#
# 0426-th step: f(x) = 11.496893 (action=99)
#    current best f(x) = 15.199978 (best action=31)
#
# 0427-th step: f(x) = 11.551213 (action=251)
#    current best f(x) = 15.199978 (best action=31)
#
# 0428-th step: f(x) = 12.379227 (action=19)
#    current best f(x) = 15.199978 (best action=31)
#
# 0429-th step: f(x) = 10.957787 (action=328)
#    current best f(x) = 15.199978 (best action=31)
#
# 0430-th step: f(x) = 10.834332 (action=331)
#    current best f(x) = 15.199978 (best action=31)
#
# 0431-th step: f(x) = 11.041490 (action=145)
#    current best f(x) = 15.199978 (best action=31)
#
# 0432-th step: f(x) = 10.540480 (action=258)
#    current best f(x) = 15.199978 (best action=31)
#
# 0433-th step: f(x) = 11.483278 (action=193)
#    current best f(x) = 15.199978 (best action=31)
#
# 0434-th step: f(x) = 12.353320 (action=281)
#    current best f(x) = 15.199978 (best action=31)
#
# 0435-th step: f(x) = 11.203542 (action=155)
#    current best f(x) = 15.199978 (best action=31)
#
# 0436-th step: f(x) = 12.093939 (action=107)
#    current best f(x) = 15.199978 (best action=31)
#
# 0437-th step: f(x) = 11.064199 (action=283)
#    current best f(x) = 15.199978 (best action=31)
#
# 0438-th step: f(x) = 11.855082 (action=26)
#    current best f(x) = 15.199978 (best action=31)
#
# 0439-th step: f(x) = 10.741203 (action=4)
#    current best f(x) = 15.199978 (best action=31)
#
# 0440-th step: f(x) = 11.448708 (action=315)
#    current best f(x) = 15.199978 (best action=31)
#
# 0441-th step: f(x) = 10.443396 (action=457)
#    current best f(x) = 15.199978 (best action=31)
#
# 0442-th step: f(x) = 11.626058 (action=464)
#    current best f(x) = 15.199978 (best action=31)
#
# 0443-th step: f(x) = 11.240781 (action=432)
#    current best f(x) = 15.199978 (best action=31)
#
# 0444-th step: f(x) = 11.084139 (action=89)
#    current best f(x) = 15.199978 (best action=31)
#
# 0445-th step: f(x) = 11.285673 (action=160)
#    current best f(x) = 15.199978 (best action=31)
#
# 0446-th step: f(x) = 10.839522 (action=65)
#    current best f(x) = 15.199978 (best action=31)
#
# 0447-th step: f(x) = 10.295165 (action=114)
#    current best f(x) = 15.199978 (best action=31)
#
# 0448-th step: f(x) = 11.132425 (action=260)
#    current best f(x) = 15.199978 (best action=31)
#
# 0449-th step: f(x) = 10.406131 (action=106)
#    current best f(x) = 15.199978 (best action=31)
#
# 0450-th step: f(x) = 10.642205 (action=3)
#    current best f(x) = 15.199978 (best action=31)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 470.74318487997436
# 50-th epoch, marginal likelihood 454.98815639844855
# 100-th epoch, marginal likelihood 441.89830954515355
# 150-th epoch, marginal likelihood 429.8431056708527
# 200-th epoch, marginal likelihood 416.9172991988894
# 250-th epoch, marginal likelihood 406.3564385992744
# 300-th epoch, marginal likelihood 399.10456603090387
# 350-th epoch, marginal likelihood 395.7940190642155
# 400-th epoch, marginal likelihood 394.2079008121787
# 450-th epoch, marginal likelihood 393.649485209206
# 500-th epoch, marginal likelihood 393.07442269814555
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [11.05431513]
#  scale  =  1.2025459211950944
#  scale2 =  1.4461166925829583
#
#
# 0451-th step: f(x) = 10.140392 (action=473)
#    current best f(x) = 15.199978 (best action=31)
#
# 0452-th step: f(x) = 10.529290 (action=80)
#    current best f(x) = 15.199978 (best action=31)
#
# 0453-th step: f(x) = 12.091834 (action=369)
#    current best f(x) = 15.199978 (best action=31)
#
# 0454-th step: f(x) = 10.343708 (action=239)
#    current best f(x) = 15.199978 (best action=31)
#
# 0455-th step: f(x) = 10.257400 (action=265)
#    current best f(x) = 15.199978 (best action=31)
#
# 0456-th step: f(x) = 11.317897 (action=434)
#    current best f(x) = 15.199978 (best action=31)
#
# 0457-th step: f(x) = 10.448575 (action=403)
#    current best f(x) = 15.199978 (best action=31)
#
# 0458-th step: f(x) = 11.381211 (action=354)
#    current best f(x) = 15.199978 (best action=31)
#
# 0459-th step: f(x) = 10.176099 (action=480)
#    current best f(x) = 15.199978 (best action=31)
#
# 0460-th step: f(x) = 11.631375 (action=201)
#    current best f(x) = 15.199978 (best action=31)
#
# 0461-th step: f(x) = 11.221656 (action=497)
#    current best f(x) = 15.199978 (best action=31)
#
# 0462-th step: f(x) = 10.699004 (action=492)
#    current best f(x) = 15.199978 (best action=31)
#
# 0463-th step: f(x) = 10.886038 (action=405)
#    current best f(x) = 15.199978 (best action=31)
#
# 0464-th step: f(x) = 11.205741 (action=421)
#    current best f(x) = 15.199978 (best action=31)
#
# 0465-th step: f(x) = 10.840919 (action=345)
#    current best f(x) = 15.199978 (best action=31)
#
# 0466-th step: f(x) = 11.347387 (action=92)
#    current best f(x) = 15.199978 (best action=31)
#
# 0467-th step: f(x) = 12.254696 (action=293)
#    current best f(x) = 15.199978 (best action=31)
#
# 0468-th step: f(x) = 10.692779 (action=454)
#    current best f(x) = 15.199978 (best action=31)
#
# 0469-th step: f(x) = 10.226846 (action=311)
#    current best f(x) = 15.199978 (best action=31)
#
# 0470-th step: f(x) = 10.052558 (action=337)
#    current best f(x) = 15.199978 (best action=31)
#
# 0471-th step: f(x) = 11.955911 (action=389)
#    current best f(x) = 15.199978 (best action=31)
#
# 0472-th step: f(x) = 10.513623 (action=415)
#    current best f(x) = 15.199978 (best action=31)
#
# 0473-th step: f(x) = 10.523844 (action=262)
#    current best f(x) = 15.199978 (best action=31)
#
# 0474-th step: f(x) = 10.085563 (action=140)
#    current best f(x) = 15.199978 (best action=31)
#
# 0475-th step: f(x) = 11.438319 (action=203)
#    current best f(x) = 15.199978 (best action=31)
#
# 0476-th step: f(x) = 10.824435 (action=375)
#    current best f(x) = 15.199978 (best action=31)
#
# 0477-th step: f(x) = 11.282694 (action=192)
#    current best f(x) = 15.199978 (best action=31)
#
# 0478-th step: f(x) = 9.615372 (action=318)
#    current best f(x) = 15.199978 (best action=31)
#
# 0479-th step: f(x) = 11.340874 (action=460)
#    current best f(x) = 15.199978 (best action=31)
#
# 0480-th step: f(x) = 10.875941 (action=212)
#    current best f(x) = 15.199978 (best action=31)
#
# 0481-th step: f(x) = 10.578947 (action=164)
#    current best f(x) = 15.199978 (best action=31)
#
# 0482-th step: f(x) = 10.398979 (action=152)
#    current best f(x) = 15.199978 (best action=31)
#
# 0483-th step: f(x) = 10.243322 (action=100)
#    current best f(x) = 15.199978 (best action=31)
#
# 0484-th step: f(x) = 10.449700 (action=462)
#    current best f(x) = 15.199978 (best action=31)
#
# 0485-th step: f(x) = 10.775902 (action=227)
#    current best f(x) = 15.199978 (best action=31)
#
# 0486-th step: f(x) = 9.865594 (action=365)
#    current best f(x) = 15.199978 (best action=31)
#
# 0487-th step: f(x) = 10.251253 (action=406)
#    current best f(x) = 15.199978 (best action=31)
#
# 0488-th step: f(x) = 10.797852 (action=282)
#    current best f(x) = 15.199978 (best action=31)
#
# 0489-th step: f(x) = 10.382457 (action=33)
#    current best f(x) = 15.199978 (best action=31)
#
# 0490-th step: f(x) = 11.666445 (action=24)
#    current best f(x) = 15.199978 (best action=31)
#
# 0491-th step: f(x) = 10.310142 (action=319)
#    current best f(x) = 15.199978 (best action=31)
#
# 0492-th step: f(x) = 11.247225 (action=217)
#    current best f(x) = 15.199978 (best action=31)
#
# 0493-th step: f(x) = 10.222708 (action=161)
#    current best f(x) = 15.199978 (best action=31)
#
# 0494-th step: f(x) = 10.161434 (action=188)
#    current best f(x) = 15.199978 (best action=31)
#
# 0495-th step: f(x) = 11.069586 (action=465)
#    current best f(x) = 15.199978 (best action=31)
#
# 0496-th step: f(x) = 10.292034 (action=274)
#    current best f(x) = 15.199978 (best action=31)
#
# 0497-th step: f(x) = 10.372103 (action=418)
#    current best f(x) = 15.199978 (best action=31)
#
# 0498-th step: f(x) = 10.172338 (action=297)
#    current best f(x) = 15.199978 (best action=31)
#
# 0499-th step: f(x) = 10.460537 (action=248)
#    current best f(x) = 15.199978 (best action=31)
#
# 0500-th step: f(x) = 10.435767 (action=144)
#    current best f(x) = 15.199978 (best action=31)

# %%
index_Henry_CO2_unrelevant = np.argmax(Data_unrelevant_features_Henry_CO2.iloc[:, -1].values)
import numpy as np
from sklearn.manifold import TSNE

X_embedded = TSNE(n_components=2).fit_transform(Data_relevant_features_Henry_CO2.iloc[:, :-1].values)
X_embedded.shape

SC1 = np.transpose(X_embedded)[0]
SC2 = np.transpose(X_embedded)[1]

fig, ax = plt.subplots(figsize=(3,3), dpi=150)
ax.scatter(SC1, SC2, c='tab:blue', alpha=0.3)
initial_set = ax.scatter(SC1[minima], SC2[minima], c='gold', label = 'Initial set', alpha = 0.5)
optimum = ax.scatter(SC1[index_Henry_CO2], SC2[index_Henry_CO2], c='red', label = 'Optimum')

ax.legend([initial_set, optimum], ['Initial set', 'Optimum'])
#labels = ['Initial set', 'Optimum']
#ax.legend(labels)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
plt.show()

# %% [markdown]
# ## Working capacity

# %% [markdown]
# #### Relevant features

# %%
MEI_index_Working_Capacity_relevant = MEI(Data_relevant_features_Working_Capacity.iloc[:, :-1].values, Data_relevant_features_Working_Capacity.iloc[:, -1].values, 400, 100)
# Out:
#  22%|██▏       | 89/400 [1:28:18<5:08:34, 59.53s/it]

# %%
MLI_index_Working_Capacity_relevant = MLI(Data_relevant_features_Working_Capacity.iloc[:, :-1].values, Data_relevant_features_Working_Capacity.iloc[:, -1].values, 400, 100)
# Out:
#  42%|████▏     | 169/400 [4:42:50<6:26:35, 100.41s/it]

# %%
MU_index_Working_Capacity_relevant = MU(Data_relevant_features_Working_Capacity.iloc[:, :-1].values, Data_relevant_features_Working_Capacity.iloc[:, -1].values, 400, 100)
# Out:
#  34%|███▎      | 134/400 [2:38:22<5:14:23, 70.92s/it]

# %%
COMBO_PI_Working_Capacity_relevant = COMBO(Data_relevant_features_Working_Capacity, 'PI')
# Out:
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 31.670002602534495
# 50-th epoch, marginal likelihood 12.27689920672934
# 100-th epoch, marginal likelihood -0.09855475291846005
# 150-th epoch, marginal likelihood -7.516357923504643
# 200-th epoch, marginal likelihood -12.367663096393414
# 250-th epoch, marginal likelihood -15.809650953321338
# 300-th epoch, marginal likelihood -17.875276536147
# 350-th epoch, marginal likelihood -19.336553379590278
# 400-th epoch, marginal likelihood -20.376980120076453
# 450-th epoch, marginal likelihood -21.003640227675014
# 500-th epoch, marginal likelihood -21.508151335235198
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.]
#  scale  =  1.0
#  scale2 =  1.0
#
#
# 0101-th step: f(x) = 1.954579 (action=267)
#    current best f(x) = 1.954579 (best action=267)
#
# 0102-th step: f(x) = 2.504622 (action=443)
#    current best f(x) = 2.504622 (best action=443)
#
# 0103-th step: f(x) = 2.317952 (action=10)
#    current best f(x) = 2.504622 (best action=443)
#
# 0104-th step: f(x) = 1.986916 (action=94)
#    current best f(x) = 2.504622 (best action=443)
#
# 0105-th step: f(x) = 2.843266 (action=478)
#    current best f(x) = 2.843266 (best action=478)
#
# 0106-th step: f(x) = 2.511968 (action=319)
#    current best f(x) = 2.843266 (best action=478)
#
# 0107-th step: f(x) = 2.557924 (action=260)
#    current best f(x) = 2.843266 (best action=478)
#
# 0108-th step: f(x) = 2.269370 (action=432)
#    current best f(x) = 2.843266 (best action=478)
#
# 0109-th step: f(x) = 2.710859 (action=179)
#    current best f(x) = 2.843266 (best action=478)
#
# 0110-th step: f(x) = 2.418407 (action=485)
#    current best f(x) = 2.843266 (best action=478)
#
# 0111-th step: f(x) = 2.359282 (action=428)
#    current best f(x) = 2.843266 (best action=478)
#
# 0112-th step: f(x) = 2.383186 (action=395)
#    current best f(x) = 2.843266 (best action=478)
#
# 0113-th step: f(x) = 3.373301 (action=140)
#    current best f(x) = 3.373301 (best action=140)
#
# 0114-th step: f(x) = 2.991167 (action=139)
#    current best f(x) = 3.373301 (best action=140)
#
# 0115-th step: f(x) = 2.830068 (action=189)
#    current best f(x) = 3.373301 (best action=140)
#
# 0116-th step: f(x) = 2.943834 (action=265)
#    current best f(x) = 3.373301 (best action=140)
#
# 0117-th step: f(x) = 2.692199 (action=17)
#    current best f(x) = 3.373301 (best action=140)
#
# 0118-th step: f(x) = 3.356339 (action=55)
#    current best f(x) = 3.373301 (best action=140)
#
# 0119-th step: f(x) = 2.240289 (action=151)
#    current best f(x) = 3.373301 (best action=140)
#
# 0120-th step: f(x) = 3.002695 (action=287)
#    current best f(x) = 3.373301 (best action=140)
#
# 0121-th step: f(x) = 2.796477 (action=412)
#    current best f(x) = 3.373301 (best action=140)
#
# 0122-th step: f(x) = 2.253350 (action=447)
#    current best f(x) = 3.373301 (best action=140)
#
# 0123-th step: f(x) = 2.116136 (action=205)
#    current best f(x) = 3.373301 (best action=140)
#
# 0124-th step: f(x) = 3.018996 (action=408)
#    current best f(x) = 3.373301 (best action=140)
#
# 0125-th step: f(x) = 3.292710 (action=492)
#    current best f(x) = 3.373301 (best action=140)
#
# 0126-th step: f(x) = 3.286539 (action=220)
#    current best f(x) = 3.373301 (best action=140)
#
# 0127-th step: f(x) = 4.042345 (action=482)
#    current best f(x) = 4.042345 (best action=482)
#
# 0128-th step: f(x) = 3.671379 (action=425)
#    current best f(x) = 4.042345 (best action=482)
#
# 0129-th step: f(x) = 3.122676 (action=213)
#    current best f(x) = 4.042345 (best action=482)
#
# 0130-th step: f(x) = 2.133533 (action=228)
#    current best f(x) = 4.042345 (best action=482)
#
# 0131-th step: f(x) = 4.015172 (action=471)
#    current best f(x) = 4.042345 (best action=482)
#
# 0132-th step: f(x) = 2.838673 (action=231)
#    current best f(x) = 4.042345 (best action=482)
#
# 0133-th step: f(x) = 3.408732 (action=120)
#    current best f(x) = 4.042345 (best action=482)
#
# 0134-th step: f(x) = 4.706231 (action=73)
#    current best f(x) = 4.706231 (best action=73)
#
# 0135-th step: f(x) = 4.508599 (action=168)
#    current best f(x) = 4.706231 (best action=73)
#
# 0136-th step: f(x) = 4.527239 (action=316)
#    current best f(x) = 4.706231 (best action=73)
#
# 0137-th step: f(x) = 3.047911 (action=252)
#    current best f(x) = 4.706231 (best action=73)
#
# 0138-th step: f(x) = 3.156001 (action=383)
#    current best f(x) = 4.706231 (best action=73)
#
# 0139-th step: f(x) = 3.071644 (action=446)
#    current best f(x) = 4.706231 (best action=73)
#
# 0140-th step: f(x) = 3.656655 (action=0)
#    current best f(x) = 4.706231 (best action=73)
#
# 0141-th step: f(x) = 2.935765 (action=158)
#    current best f(x) = 4.706231 (best action=73)
#
# 0142-th step: f(x) = 3.515651 (action=289)
#    current best f(x) = 4.706231 (best action=73)
#
# 0143-th step: f(x) = 3.359676 (action=24)
#    current best f(x) = 4.706231 (best action=73)
#
# 0144-th step: f(x) = 2.822646 (action=370)
#    current best f(x) = 4.706231 (best action=73)
#
# 0145-th step: f(x) = 3.945998 (action=268)
#    current best f(x) = 4.706231 (best action=73)
#
# 0146-th step: f(x) = 2.913231 (action=38)
#    current best f(x) = 4.706231 (best action=73)
#
# 0147-th step: f(x) = 4.725240 (action=247)
#    current best f(x) = 4.725240 (best action=247)
#
# 0148-th step: f(x) = 3.950354 (action=48)
#    current best f(x) = 4.725240 (best action=247)
#
# 0149-th step: f(x) = 4.067988 (action=448)
#    current best f(x) = 4.725240 (best action=247)
#
# 0150-th step: f(x) = 4.682727 (action=479)
#    current best f(x) = 4.725240 (best action=247)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 93.84287795208729
# 50-th epoch, marginal likelihood 93.72749297029449
# 100-th epoch, marginal likelihood 93.66116814678664
# 150-th epoch, marginal likelihood 93.59156953847105
# 200-th epoch, marginal likelihood 93.56612979407207
# 250-th epoch, marginal likelihood 93.42241901115507
# 300-th epoch, marginal likelihood 93.3329715219175
# 350-th epoch, marginal likelihood 93.30314759033875
# 400-th epoch, marginal likelihood 93.24089068021361
# 450-th epoch, marginal likelihood 93.2288883677171
# 500-th epoch, marginal likelihood 93.12523385768274
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [4.78112402]
#  scale  =  0.24540815717570305
#  scale2 =  0.06022516360837457
#
#
# 0151-th step: f(x) = 3.761592 (action=36)
#    current best f(x) = 4.725240 (best action=247)
#
# 0152-th step: f(x) = 2.650736 (action=331)
#    current best f(x) = 4.725240 (best action=247)
#
# 0153-th step: f(x) = 2.326354 (action=400)
#    current best f(x) = 4.725240 (best action=247)
#
# 0154-th step: f(x) = 2.433231 (action=128)
#    current best f(x) = 4.725240 (best action=247)
#
# 0155-th step: f(x) = 2.530396 (action=196)
#    current best f(x) = 4.725240 (best action=247)
#
# 0156-th step: f(x) = 2.789102 (action=93)
#    current best f(x) = 4.725240 (best action=247)
#
# 0157-th step: f(x) = 2.750888 (action=472)
#    current best f(x) = 4.725240 (best action=247)
#
# 0158-th step: f(x) = 2.244324 (action=352)
#    current best f(x) = 4.725240 (best action=247)
#
# 0159-th step: f(x) = 3.298290 (action=372)
#    current best f(x) = 4.725240 (best action=247)
#
# 0160-th step: f(x) = 4.107620 (action=223)
#    current best f(x) = 4.725240 (best action=247)
#
# 0161-th step: f(x) = 3.824264 (action=164)
#    current best f(x) = 4.725240 (best action=247)
#
# 0162-th step: f(x) = 3.901682 (action=462)
#    current best f(x) = 4.725240 (best action=247)
#
# 0163-th step: f(x) = 3.495000 (action=39)
#    current best f(x) = 4.725240 (best action=247)
#
# 0164-th step: f(x) = 3.909203 (action=338)
#    current best f(x) = 4.725240 (best action=247)
#
# 0165-th step: f(x) = 2.693562 (action=337)
#    current best f(x) = 4.725240 (best action=247)
#
# 0166-th step: f(x) = 2.148002 (action=403)
#    current best f(x) = 4.725240 (best action=247)
#
# 0167-th step: f(x) = 2.333648 (action=119)
#    current best f(x) = 4.725240 (best action=247)
#
# 0168-th step: f(x) = 2.166267 (action=387)
#    current best f(x) = 4.725240 (best action=247)
#
# 0169-th step: f(x) = 2.446035 (action=330)
#    current best f(x) = 4.725240 (best action=247)
#
# 0170-th step: f(x) = 3.264902 (action=355)
#    current best f(x) = 4.725240 (best action=247)
#
# 0171-th step: f(x) = 2.272024 (action=59)
#    current best f(x) = 4.725240 (best action=247)
#
# 0172-th step: f(x) = 2.489719 (action=171)
#    current best f(x) = 4.725240 (best action=247)
#
# 0173-th step: f(x) = 1.927450 (action=255)
#    current best f(x) = 4.725240 (best action=247)
#
# 0174-th step: f(x) = 3.286670 (action=77)
#    current best f(x) = 4.725240 (best action=247)
#
# 0175-th step: f(x) = 2.847173 (action=444)
#    current best f(x) = 4.725240 (best action=247)
#
# 0176-th step: f(x) = 3.095683 (action=130)
#    current best f(x) = 4.725240 (best action=247)
#
# 0177-th step: f(x) = 2.500998 (action=360)
#    current best f(x) = 4.725240 (best action=247)
#
# 0178-th step: f(x) = 2.784103 (action=438)
#    current best f(x) = 4.725240 (best action=247)
#
# 0179-th step: f(x) = 2.731978 (action=176)
#    current best f(x) = 4.725240 (best action=247)
#
# 0180-th step: f(x) = 2.086169 (action=364)
#    current best f(x) = 4.725240 (best action=247)
#
# 0181-th step: f(x) = 3.097235 (action=229)
#    current best f(x) = 4.725240 (best action=247)
#
# 0182-th step: f(x) = 3.548726 (action=97)
#    current best f(x) = 4.725240 (best action=247)
#
# 0183-th step: f(x) = 3.979143 (action=107)
#    current best f(x) = 4.725240 (best action=247)
#
# 0184-th step: f(x) = 3.400929 (action=35)
#    current best f(x) = 4.725240 (best action=247)
#
# 0185-th step: f(x) = 4.288360 (action=366)
#    current best f(x) = 4.725240 (best action=247)
#
# 0186-th step: f(x) = 3.603806 (action=493)
#    current best f(x) = 4.725240 (best action=247)
#
# 0187-th step: f(x) = 5.057711 (action=250)
#    current best f(x) = 5.057711 (best action=250)
#
# 0188-th step: f(x) = 2.143090 (action=288)
#    current best f(x) = 5.057711 (best action=250)
#
# 0189-th step: f(x) = 2.304067 (action=111)
#    current best f(x) = 5.057711 (best action=250)
#
# 0190-th step: f(x) = 1.958722 (action=167)
#    current best f(x) = 5.057711 (best action=250)
#
# 0191-th step: f(x) = 2.521384 (action=495)
#    current best f(x) = 5.057711 (best action=250)
#
# 0192-th step: f(x) = 1.982911 (action=320)
#    current best f(x) = 5.057711 (best action=250)
#
# 0193-th step: f(x) = 2.971935 (action=112)
#    current best f(x) = 5.057711 (best action=250)
#
# 0194-th step: f(x) = 1.978139 (action=498)
#    current best f(x) = 5.057711 (best action=250)
#
# 0195-th step: f(x) = 2.616944 (action=122)
#    current best f(x) = 5.057711 (best action=250)
#
# 0196-th step: f(x) = 2.517475 (action=15)
#    current best f(x) = 5.057711 (best action=250)
#
# 0197-th step: f(x) = 3.222779 (action=197)
#    current best f(x) = 5.057711 (best action=250)
#
# 0198-th step: f(x) = 2.721873 (action=90)
#    current best f(x) = 5.057711 (best action=250)
#
# 0199-th step: f(x) = 3.001148 (action=4)
#    current best f(x) = 5.057711 (best action=250)
#
# 0200-th step: f(x) = 4.270924 (action=426)
#    current best f(x) = 5.057711 (best action=250)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 154.70234171250428
# 50-th epoch, marginal likelihood 153.57637101269034
# 100-th epoch, marginal likelihood 152.88488123194955
# 150-th epoch, marginal likelihood 152.42259057688608
# 200-th epoch, marginal likelihood 152.16084654326534
# 250-th epoch, marginal likelihood 152.05001288132138
# 300-th epoch, marginal likelihood 152.03535091661365
# 350-th epoch, marginal likelihood 151.93448077376962
# 400-th epoch, marginal likelihood 151.99352479005208
# 450-th epoch, marginal likelihood 151.90462956385704
# 500-th epoch, marginal likelihood 151.89234134200362
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.27825569]
#  scale  =  0.7900203508974645
#  scale2 =  0.6241321548321529
#
#
# 0201-th step: f(x) = 4.190259 (action=218)
#    current best f(x) = 5.057711 (best action=250)
#
# 0202-th step: f(x) = 3.367598 (action=377)
#    current best f(x) = 5.057711 (best action=250)
#
# 0203-th step: f(x) = 3.209805 (action=484)
#    current best f(x) = 5.057711 (best action=250)
#
# 0204-th step: f(x) = 2.227650 (action=363)
#    current best f(x) = 5.057711 (best action=250)
#
# 0205-th step: f(x) = 2.109923 (action=58)
#    current best f(x) = 5.057711 (best action=250)
#
# 0206-th step: f(x) = 2.305546 (action=398)
#    current best f(x) = 5.057711 (best action=250)
#
# 0207-th step: f(x) = 3.170518 (action=40)
#    current best f(x) = 5.057711 (best action=250)
#
# 0208-th step: f(x) = 2.514247 (action=44)
#    current best f(x) = 5.057711 (best action=250)
#
# 0209-th step: f(x) = 2.104538 (action=21)
#    current best f(x) = 5.057711 (best action=250)
#
# 0210-th step: f(x) = 2.683243 (action=336)
#    current best f(x) = 5.057711 (best action=250)
#
# 0211-th step: f(x) = 1.925328 (action=386)
#    current best f(x) = 5.057711 (best action=250)
#
# 0212-th step: f(x) = 2.662879 (action=459)
#    current best f(x) = 5.057711 (best action=250)
#
# 0213-th step: f(x) = 3.310716 (action=261)
#    current best f(x) = 5.057711 (best action=250)
#
# 0214-th step: f(x) = 2.409400 (action=264)
#    current best f(x) = 5.057711 (best action=250)
#
# 0215-th step: f(x) = 3.052043 (action=195)
#    current best f(x) = 5.057711 (best action=250)
#
# 0216-th step: f(x) = 2.454971 (action=74)
#    current best f(x) = 5.057711 (best action=250)
#
# 0217-th step: f(x) = 2.272421 (action=18)
#    current best f(x) = 5.057711 (best action=250)
#
# 0218-th step: f(x) = 3.339624 (action=221)
#    current best f(x) = 5.057711 (best action=250)
#
# 0219-th step: f(x) = 2.453982 (action=109)
#    current best f(x) = 5.057711 (best action=250)
#
# 0220-th step: f(x) = 2.198917 (action=347)
#    current best f(x) = 5.057711 (best action=250)
#
# 0221-th step: f(x) = 2.072946 (action=147)
#    current best f(x) = 5.057711 (best action=250)
#
# 0222-th step: f(x) = 3.312010 (action=242)
#    current best f(x) = 5.057711 (best action=250)
#
# 0223-th step: f(x) = 3.709738 (action=103)
#    current best f(x) = 5.057711 (best action=250)
#
# 0224-th step: f(x) = 3.009214 (action=129)
#    current best f(x) = 5.057711 (best action=250)
#
# 0225-th step: f(x) = 2.399030 (action=351)
#    current best f(x) = 5.057711 (best action=250)
#
# 0226-th step: f(x) = 3.559743 (action=323)
#    current best f(x) = 5.057711 (best action=250)
#
# 0227-th step: f(x) = 2.680294 (action=357)
#    current best f(x) = 5.057711 (best action=250)
#
# 0228-th step: f(x) = 3.837505 (action=281)
#    current best f(x) = 5.057711 (best action=250)
#
# 0229-th step: f(x) = 2.793633 (action=475)
#    current best f(x) = 5.057711 (best action=250)
#
# 0230-th step: f(x) = 3.864941 (action=185)
#    current best f(x) = 5.057711 (best action=250)
#
# 0231-th step: f(x) = 3.571466 (action=117)
#    current best f(x) = 5.057711 (best action=250)
#
# 0232-th step: f(x) = 3.908885 (action=118)
#    current best f(x) = 5.057711 (best action=250)
#
# 0233-th step: f(x) = 3.112139 (action=311)
#    current best f(x) = 5.057711 (best action=250)
#
# 0234-th step: f(x) = 2.735916 (action=159)
#    current best f(x) = 5.057711 (best action=250)
#
# 0235-th step: f(x) = 2.218906 (action=262)
#    current best f(x) = 5.057711 (best action=250)
#
# 0236-th step: f(x) = 2.711763 (action=436)
#    current best f(x) = 5.057711 (best action=250)
#
# 0237-th step: f(x) = 2.812253 (action=491)
#    current best f(x) = 5.057711 (best action=250)
#
# 0238-th step: f(x) = 1.922565 (action=3)
#    current best f(x) = 5.057711 (best action=250)
#
# 0239-th step: f(x) = 2.390952 (action=381)
#    current best f(x) = 5.057711 (best action=250)
#
# 0240-th step: f(x) = 2.445585 (action=402)
#    current best f(x) = 5.057711 (best action=250)
#
# 0241-th step: f(x) = 2.637429 (action=13)
#    current best f(x) = 5.057711 (best action=250)
#
# 0242-th step: f(x) = 2.769902 (action=305)
#    current best f(x) = 5.057711 (best action=250)
#
# 0243-th step: f(x) = 2.032710 (action=361)
#    current best f(x) = 5.057711 (best action=250)
#
# 0244-th step: f(x) = 2.797378 (action=362)
#    current best f(x) = 5.057711 (best action=250)
#
# 0245-th step: f(x) = 2.352993 (action=210)
#    current best f(x) = 5.057711 (best action=250)
#
# 0246-th step: f(x) = 2.347726 (action=466)
#    current best f(x) = 5.057711 (best action=250)
#
# 0247-th step: f(x) = 2.006214 (action=302)
#    current best f(x) = 5.057711 (best action=250)
#
# 0248-th step: f(x) = 3.886743 (action=253)
#    current best f(x) = 5.057711 (best action=250)
#
# 0249-th step: f(x) = 4.287449 (action=182)
#    current best f(x) = 5.057711 (best action=250)
#
# 0250-th step: f(x) = 2.785436 (action=28)
#    current best f(x) = 5.057711 (best action=250)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 208.50388253776333
# 50-th epoch, marginal likelihood 203.2797962821955
# 100-th epoch, marginal likelihood 202.25494623491693
# 150-th epoch, marginal likelihood 201.65505748862387
# 200-th epoch, marginal likelihood 201.36085396516583
# 250-th epoch, marginal likelihood 201.22915871433236
# 300-th epoch, marginal likelihood 201.1458099636729
# 350-th epoch, marginal likelihood 201.13257035214912
# 400-th epoch, marginal likelihood 200.88868600377168
# 450-th epoch, marginal likelihood 200.9690602280052
# 500-th epoch, marginal likelihood 201.0570216043183
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.07457269]
#  scale  =  0.8241800219719454
#  scale2 =  0.6792727086176764
#
#
# 0251-th step: f(x) = 5.145519 (action=85)
#    current best f(x) = 5.145519 (best action=85)
#
# 0252-th step: f(x) = 2.755235 (action=102)
#    current best f(x) = 5.145519 (best action=85)
#
# 0253-th step: f(x) = 2.269903 (action=106)
#    current best f(x) = 5.145519 (best action=85)
#
# 0254-th step: f(x) = 2.543388 (action=350)
#    current best f(x) = 5.145519 (best action=85)
#
# 0255-th step: f(x) = 2.279116 (action=315)
#    current best f(x) = 5.145519 (best action=85)
#
# 0256-th step: f(x) = 2.043189 (action=141)
#    current best f(x) = 5.145519 (best action=85)
#
# 0257-th step: f(x) = 3.027862 (action=11)
#    current best f(x) = 5.145519 (best action=85)
#
# 0258-th step: f(x) = 2.269876 (action=86)
#    current best f(x) = 5.145519 (best action=85)
#
# 0259-th step: f(x) = 4.040700 (action=190)
#    current best f(x) = 5.145519 (best action=85)
#
# 0260-th step: f(x) = 3.877561 (action=68)
#    current best f(x) = 5.145519 (best action=85)
#
# 0261-th step: f(x) = 3.222111 (action=393)
#    current best f(x) = 5.145519 (best action=85)
#
# 0262-th step: f(x) = 3.976796 (action=173)
#    current best f(x) = 5.145519 (best action=85)
#
# 0263-th step: f(x) = 2.430162 (action=198)
#    current best f(x) = 5.145519 (best action=85)
#
# 0264-th step: f(x) = 2.637765 (action=458)
#    current best f(x) = 5.145519 (best action=85)
#
# 0265-th step: f(x) = 3.168273 (action=295)
#    current best f(x) = 5.145519 (best action=85)
#
# 0266-th step: f(x) = 2.788362 (action=270)
#    current best f(x) = 5.145519 (best action=85)
#
# 0267-th step: f(x) = 2.001193 (action=214)
#    current best f(x) = 5.145519 (best action=85)
#
# 0268-th step: f(x) = 2.535317 (action=269)
#    current best f(x) = 5.145519 (best action=85)
#
# 0269-th step: f(x) = 1.941175 (action=42)
#    current best f(x) = 5.145519 (best action=85)
#
# 0270-th step: f(x) = 1.999945 (action=480)
#    current best f(x) = 5.145519 (best action=85)
#
# 0271-th step: f(x) = 3.426586 (action=20)
#    current best f(x) = 5.145519 (best action=85)
#
# 0272-th step: f(x) = 3.597137 (action=257)
#    current best f(x) = 5.145519 (best action=85)
#
# 0273-th step: f(x) = 2.996586 (action=69)
#    current best f(x) = 5.145519 (best action=85)
#
# 0274-th step: f(x) = 2.086933 (action=327)
#    current best f(x) = 5.145519 (best action=85)
#
# 0275-th step: f(x) = 2.484639 (action=80)
#    current best f(x) = 5.145519 (best action=85)
#
# 0276-th step: f(x) = 2.023847 (action=435)
#    current best f(x) = 5.145519 (best action=85)
#
# 0277-th step: f(x) = 2.564279 (action=417)
#    current best f(x) = 5.145519 (best action=85)
#
# 0278-th step: f(x) = 2.549730 (action=184)
#    current best f(x) = 5.145519 (best action=85)
#
# 0279-th step: f(x) = 3.541771 (action=47)
#    current best f(x) = 5.145519 (best action=85)
#
# 0280-th step: f(x) = 2.471051 (action=1)
#    current best f(x) = 5.145519 (best action=85)
#
# 0281-th step: f(x) = 2.723290 (action=89)
#    current best f(x) = 5.145519 (best action=85)
#
# 0282-th step: f(x) = 2.608643 (action=454)
#    current best f(x) = 5.145519 (best action=85)
#
# 0283-th step: f(x) = 2.563363 (action=385)
#    current best f(x) = 5.145519 (best action=85)
#
# 0284-th step: f(x) = 2.145624 (action=115)
#    current best f(x) = 5.145519 (best action=85)
#
# 0285-th step: f(x) = 2.047329 (action=401)
#    current best f(x) = 5.145519 (best action=85)
#
# 0286-th step: f(x) = 3.835379 (action=219)
#    current best f(x) = 5.145519 (best action=85)
#
# 0287-th step: f(x) = 2.592288 (action=41)
#    current best f(x) = 5.145519 (best action=85)
#
# 0288-th step: f(x) = 2.680170 (action=461)
#    current best f(x) = 5.145519 (best action=85)
#
# 0289-th step: f(x) = 3.043263 (action=70)
#    current best f(x) = 5.145519 (best action=85)
#
# 0290-th step: f(x) = 2.476858 (action=124)
#    current best f(x) = 5.145519 (best action=85)
#
# 0291-th step: f(x) = 3.665991 (action=328)
#    current best f(x) = 5.145519 (best action=85)
#
# 0292-th step: f(x) = 2.576505 (action=32)
#    current best f(x) = 5.145519 (best action=85)
#
# 0293-th step: f(x) = 2.130986 (action=12)
#    current best f(x) = 5.145519 (best action=85)
#
# 0294-th step: f(x) = 2.301847 (action=227)
#    current best f(x) = 5.145519 (best action=85)
#
# 0295-th step: f(x) = 3.822884 (action=303)
#    current best f(x) = 5.145519 (best action=85)
#
# 0296-th step: f(x) = 2.047624 (action=100)
#    current best f(x) = 5.145519 (best action=85)
#
# 0297-th step: f(x) = 2.505775 (action=317)
#    current best f(x) = 5.145519 (best action=85)
#
# 0298-th step: f(x) = 2.705363 (action=312)
#    current best f(x) = 5.145519 (best action=85)
#
# 0299-th step: f(x) = 3.061915 (action=405)
#    current best f(x) = 5.145519 (best action=85)
#
# 0300-th step: f(x) = 1.977904 (action=451)
#    current best f(x) = 5.145519 (best action=85)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 259.77846691021364
# 50-th epoch, marginal likelihood 249.7779383406678
# 100-th epoch, marginal likelihood 248.5095729525026
# 150-th epoch, marginal likelihood 247.68213066684598
# 200-th epoch, marginal likelihood 247.34172780659284
# 250-th epoch, marginal likelihood 247.28269969086597
# 300-th epoch, marginal likelihood 247.2701277442662
# 350-th epoch, marginal likelihood 247.40151856156865
# 400-th epoch, marginal likelihood 246.9497089174458
# 450-th epoch, marginal likelihood 246.99320545787396
# 500-th epoch, marginal likelihood 247.27398179487216
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [5.5398359]
#  scale  =  0.8162745523594835
#  scale2 =  0.6663041448296753
#
#
# 0301-th step: f(x) = 2.367384 (action=175)
#    current best f(x) = 5.145519 (best action=85)
#
# 0302-th step: f(x) = 2.604621 (action=248)
#    current best f(x) = 5.145519 (best action=85)
#
# 0303-th step: f(x) = 1.981872 (action=322)
#    current best f(x) = 5.145519 (best action=85)
#
# 0304-th step: f(x) = 3.170505 (action=169)
#    current best f(x) = 5.145519 (best action=85)
#
# 0305-th step: f(x) = 2.492086 (action=359)
#    current best f(x) = 5.145519 (best action=85)
#
# 0306-th step: f(x) = 3.945812 (action=369)
#    current best f(x) = 5.145519 (best action=85)
#
# 0307-th step: f(x) = 2.237687 (action=193)
#    current best f(x) = 5.145519 (best action=85)
#
# 0308-th step: f(x) = 2.567850 (action=110)
#    current best f(x) = 5.145519 (best action=85)
#
# 0309-th step: f(x) = 3.654313 (action=293)
#    current best f(x) = 5.145519 (best action=85)
#
# 0310-th step: f(x) = 2.729645 (action=368)
#    current best f(x) = 5.145519 (best action=85)
#
# 0311-th step: f(x) = 2.354839 (action=72)
#    current best f(x) = 5.145519 (best action=85)
#
# 0312-th step: f(x) = 2.434968 (action=449)
#    current best f(x) = 5.145519 (best action=85)
#
# 0313-th step: f(x) = 4.315861 (action=81)
#    current best f(x) = 5.145519 (best action=85)
#
# 0314-th step: f(x) = 2.015308 (action=283)
#    current best f(x) = 5.145519 (best action=85)
#
# 0315-th step: f(x) = 2.488536 (action=142)
#    current best f(x) = 5.145519 (best action=85)
#
# 0316-th step: f(x) = 3.176120 (action=134)
#    current best f(x) = 5.145519 (best action=85)
#
# 0317-th step: f(x) = 2.253737 (action=477)
#    current best f(x) = 5.145519 (best action=85)
#
# 0318-th step: f(x) = 1.931224 (action=66)
#    current best f(x) = 5.145519 (best action=85)
#
# 0319-th step: f(x) = 2.866999 (action=445)
#    current best f(x) = 5.145519 (best action=85)
#
# 0320-th step: f(x) = 2.236429 (action=254)
#    current best f(x) = 5.145519 (best action=85)
#
# 0321-th step: f(x) = 2.382028 (action=414)
#    current best f(x) = 5.145519 (best action=85)
#
# 0322-th step: f(x) = 2.476953 (action=275)
#    current best f(x) = 5.145519 (best action=85)
#
# 0323-th step: f(x) = 2.090616 (action=465)
#    current best f(x) = 5.145519 (best action=85)
#
# 0324-th step: f(x) = 2.730672 (action=427)
#    current best f(x) = 5.145519 (best action=85)
#
# 0325-th step: f(x) = 2.527790 (action=440)
#    current best f(x) = 5.145519 (best action=85)
#
# 0326-th step: f(x) = 2.230777 (action=212)
#    current best f(x) = 5.145519 (best action=85)
#
# 0327-th step: f(x) = 3.026150 (action=152)
#    current best f(x) = 5.145519 (best action=85)
#
# 0328-th step: f(x) = 2.091194 (action=349)
#    current best f(x) = 5.145519 (best action=85)
#
# 0329-th step: f(x) = 2.595343 (action=135)
#    current best f(x) = 5.145519 (best action=85)
#
# 0330-th step: f(x) = 3.825027 (action=306)
#    current best f(x) = 5.145519 (best action=85)
#
# 0331-th step: f(x) = 2.583695 (action=376)
#    current best f(x) = 5.145519 (best action=85)
#
# 0332-th step: f(x) = 2.215422 (action=399)
#    current best f(x) = 5.145519 (best action=85)
#
# 0333-th step: f(x) = 2.852417 (action=217)
#    current best f(x) = 5.145519 (best action=85)
#
# 0334-th step: f(x) = 2.160947 (action=374)
#    current best f(x) = 5.145519 (best action=85)
#
# 0335-th step: f(x) = 2.207274 (action=208)
#    current best f(x) = 5.145519 (best action=85)
#
# 0336-th step: f(x) = 2.399007 (action=467)
#    current best f(x) = 5.145519 (best action=85)
#
# 0337-th step: f(x) = 2.120682 (action=27)
#    current best f(x) = 5.145519 (best action=85)
#
# 0338-th step: f(x) = 1.925936 (action=23)
#    current best f(x) = 5.145519 (best action=85)
#
# 0339-th step: f(x) = 1.971005 (action=225)
#    current best f(x) = 5.145519 (best action=85)
#
# 0340-th step: f(x) = 2.010560 (action=496)
#    current best f(x) = 5.145519 (best action=85)
#
# 0341-th step: f(x) = 2.205723 (action=233)
#    current best f(x) = 5.145519 (best action=85)
#
# 0342-th step: f(x) = 2.529742 (action=276)
#    current best f(x) = 5.145519 (best action=85)
#
# 0343-th step: f(x) = 2.246948 (action=63)
#    current best f(x) = 5.145519 (best action=85)
#
# 0344-th step: f(x) = 2.317962 (action=460)
#    current best f(x) = 5.145519 (best action=85)
#
# 0345-th step: f(x) = 1.975747 (action=406)
#    current best f(x) = 5.145519 (best action=85)
#
# 0346-th step: f(x) = 2.343225 (action=121)
#    current best f(x) = 5.145519 (best action=85)
#
# 0347-th step: f(x) = 2.181766 (action=410)
#    current best f(x) = 5.145519 (best action=85)
#
# 0348-th step: f(x) = 3.936592 (action=148)
#    current best f(x) = 5.145519 (best action=85)
#
# 0349-th step: f(x) = 2.663614 (action=52)
#    current best f(x) = 5.145519 (best action=85)
#
# 0350-th step: f(x) = 2.285828 (action=455)
#    current best f(x) = 5.145519 (best action=85)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 301.9568657367356
# 50-th epoch, marginal likelihood 286.394314038959
# 100-th epoch, marginal likelihood 284.15999918141574
# 150-th epoch, marginal likelihood 283.2650126699225
# 200-th epoch, marginal likelihood 282.98894294991777
# 250-th epoch, marginal likelihood 283.4741752368175
# 300-th epoch, marginal likelihood 283.3867344094881
# 350-th epoch, marginal likelihood 283.20526181558245
# 400-th epoch, marginal likelihood 283.6356266109947
# 450-th epoch, marginal likelihood 283.7233328885595
# 500-th epoch, marginal likelihood 283.5188269496711
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [5.17582745]
#  scale  =  0.8178788189098207
#  scale2 =  0.6689257624213233
#
#
# 0351-th step: f(x) = 2.136561 (action=348)
#    current best f(x) = 5.145519 (best action=85)
#
# 0352-th step: f(x) = 2.963136 (action=277)
#    current best f(x) = 5.145519 (best action=85)
#
# 0353-th step: f(x) = 2.104293 (action=280)
#    current best f(x) = 5.145519 (best action=85)
#
# 0354-th step: f(x) = 2.642557 (action=297)
#    current best f(x) = 5.145519 (best action=85)
#
# 0355-th step: f(x) = 2.180172 (action=456)
#    current best f(x) = 5.145519 (best action=85)
#
# 0356-th step: f(x) = 2.048103 (action=98)
#    current best f(x) = 5.145519 (best action=85)
#
# 0357-th step: f(x) = 2.749094 (action=202)
#    current best f(x) = 5.145519 (best action=85)
#
# 0358-th step: f(x) = 2.066790 (action=379)
#    current best f(x) = 5.145519 (best action=85)
#
# 0359-th step: f(x) = 2.555594 (action=429)
#    current best f(x) = 5.145519 (best action=85)
#
# 0360-th step: f(x) = 2.150653 (action=222)
#    current best f(x) = 5.145519 (best action=85)
#
# 0361-th step: f(x) = 1.971833 (action=356)
#    current best f(x) = 5.145519 (best action=85)
#
# 0362-th step: f(x) = 1.996939 (action=60)
#    current best f(x) = 5.145519 (best action=85)
#
# 0363-th step: f(x) = 2.324978 (action=5)
#    current best f(x) = 5.145519 (best action=85)
#
# 0364-th step: f(x) = 2.353441 (action=172)
#    current best f(x) = 5.145519 (best action=85)
#
# 0365-th step: f(x) = 2.355067 (action=282)
#    current best f(x) = 5.145519 (best action=85)
#
# 0366-th step: f(x) = 2.638413 (action=285)
#    current best f(x) = 5.145519 (best action=85)
#
# 0367-th step: f(x) = 2.688538 (action=431)
#    current best f(x) = 5.145519 (best action=85)
#
# 0368-th step: f(x) = 2.030449 (action=278)
#    current best f(x) = 5.145519 (best action=85)
#
# 0369-th step: f(x) = 2.377664 (action=453)
#    current best f(x) = 5.145519 (best action=85)
#
# 0370-th step: f(x) = 2.397857 (action=411)
#    current best f(x) = 5.145519 (best action=85)
#
# 0371-th step: f(x) = 3.160574 (action=422)
#    current best f(x) = 5.145519 (best action=85)
#
# 0372-th step: f(x) = 2.318994 (action=224)
#    current best f(x) = 5.145519 (best action=85)
#
# 0373-th step: f(x) = 2.502291 (action=62)
#    current best f(x) = 5.145519 (best action=85)
#
# 0374-th step: f(x) = 2.152891 (action=304)
#    current best f(x) = 5.145519 (best action=85)
#
# 0375-th step: f(x) = 3.004177 (action=25)
#    current best f(x) = 5.145519 (best action=85)
#
# 0376-th step: f(x) = 2.357116 (action=441)
#    current best f(x) = 5.145519 (best action=85)
#
# 0377-th step: f(x) = 2.047079 (action=174)
#    current best f(x) = 5.145519 (best action=85)
#
# 0378-th step: f(x) = 2.544702 (action=314)
#    current best f(x) = 5.145519 (best action=85)
#
# 0379-th step: f(x) = 2.228637 (action=335)
#    current best f(x) = 5.145519 (best action=85)
#
# 0380-th step: f(x) = 1.971275 (action=204)
#    current best f(x) = 5.145519 (best action=85)
#
# 0381-th step: f(x) = 2.572811 (action=310)
#    current best f(x) = 5.145519 (best action=85)
#
# 0382-th step: f(x) = 2.605861 (action=430)
#    current best f(x) = 5.145519 (best action=85)
#
# 0383-th step: f(x) = 2.912351 (action=101)
#    current best f(x) = 5.145519 (best action=85)
#
# 0384-th step: f(x) = 2.751306 (action=178)
#    current best f(x) = 5.145519 (best action=85)
#
# 0385-th step: f(x) = 2.344133 (action=136)
#    current best f(x) = 5.145519 (best action=85)
#
# 0386-th step: f(x) = 2.570621 (action=14)
#    current best f(x) = 5.145519 (best action=85)
#
# 0387-th step: f(x) = 3.237144 (action=290)
#    current best f(x) = 5.145519 (best action=85)
#
# 0388-th step: f(x) = 2.507806 (action=153)
#    current best f(x) = 5.145519 (best action=85)
#
# 0389-th step: f(x) = 3.555563 (action=183)
#    current best f(x) = 5.145519 (best action=85)
#
# 0390-th step: f(x) = 1.926639 (action=332)
#    current best f(x) = 5.145519 (best action=85)
#
# 0391-th step: f(x) = 2.370950 (action=43)
#    current best f(x) = 5.145519 (best action=85)
#
# 0392-th step: f(x) = 1.945712 (action=116)
#    current best f(x) = 5.145519 (best action=85)
#
# 0393-th step: f(x) = 2.129819 (action=394)
#    current best f(x) = 5.145519 (best action=85)
#
# 0394-th step: f(x) = 2.092934 (action=163)
#    current best f(x) = 5.145519 (best action=85)
#
# 0395-th step: f(x) = 2.987134 (action=8)
#    current best f(x) = 5.145519 (best action=85)
#
# 0396-th step: f(x) = 2.164168 (action=211)
#    current best f(x) = 5.145519 (best action=85)
#
# 0397-th step: f(x) = 2.666988 (action=433)
#    current best f(x) = 5.145519 (best action=85)
#
# 0398-th step: f(x) = 1.975886 (action=113)
#    current best f(x) = 5.145519 (best action=85)
#
# 0399-th step: f(x) = 2.645421 (action=434)
#    current best f(x) = 5.145519 (best action=85)
#
# 0400-th step: f(x) = 2.759216 (action=473)
#    current best f(x) = 5.145519 (best action=85)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 338.70716457370236
# 50-th epoch, marginal likelihood 319.4698354396546
# 100-th epoch, marginal likelihood 315.0620322815099
# 150-th epoch, marginal likelihood 313.71920316420324
# 200-th epoch, marginal likelihood 313.47798876274965
# 250-th epoch, marginal likelihood 313.6579585567446
# 300-th epoch, marginal likelihood 313.44446169958474
# 350-th epoch, marginal likelihood 313.6284848365493
# 400-th epoch, marginal likelihood 313.38628267600905
# 450-th epoch, marginal likelihood 313.5985203272479
# 500-th epoch, marginal likelihood 313.79212589880376
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [4.81976219]
#  scale  =  0.784108481056892
#  scale2 =  0.6148261100653464
#
#
# 0401-th step: f(x) = 3.256902 (action=150)
#    current best f(x) = 5.145519 (best action=85)
#
# 0402-th step: f(x) = 2.417828 (action=494)
#    current best f(x) = 5.145519 (best action=85)
#
# 0403-th step: f(x) = 2.307499 (action=439)
#    current best f(x) = 5.145519 (best action=85)
#
# 0404-th step: f(x) = 2.543780 (action=243)
#    current best f(x) = 5.145519 (best action=85)
#
# 0405-th step: f(x) = 2.212961 (action=76)
#    current best f(x) = 5.145519 (best action=85)
#
# 0406-th step: f(x) = 3.570696 (action=82)
#    current best f(x) = 5.145519 (best action=85)
#
# 0407-th step: f(x) = 2.482478 (action=318)
#    current best f(x) = 5.145519 (best action=85)
#
# 0408-th step: f(x) = 2.305563 (action=104)
#    current best f(x) = 5.145519 (best action=85)
#
# 0409-th step: f(x) = 2.741011 (action=468)
#    current best f(x) = 5.145519 (best action=85)
#
# 0410-th step: f(x) = 2.029610 (action=391)
#    current best f(x) = 5.145519 (best action=85)
#
# 0411-th step: f(x) = 2.767693 (action=450)
#    current best f(x) = 5.145519 (best action=85)
#
# 0412-th step: f(x) = 2.511826 (action=92)
#    current best f(x) = 5.145519 (best action=85)
#
# 0413-th step: f(x) = 2.262099 (action=416)
#    current best f(x) = 5.145519 (best action=85)
#
# 0414-th step: f(x) = 2.293619 (action=53)
#    current best f(x) = 5.145519 (best action=85)
#
# 0415-th step: f(x) = 2.092953 (action=137)
#    current best f(x) = 5.145519 (best action=85)
#
# 0416-th step: f(x) = 1.939002 (action=181)
#    current best f(x) = 5.145519 (best action=85)
#
# 0417-th step: f(x) = 2.338854 (action=61)
#    current best f(x) = 5.145519 (best action=85)
#
# 0418-th step: f(x) = 2.080482 (action=390)
#    current best f(x) = 5.145519 (best action=85)
#
# 0419-th step: f(x) = 2.353872 (action=392)
#    current best f(x) = 5.145519 (best action=85)
#
# 0420-th step: f(x) = 2.104863 (action=273)
#    current best f(x) = 5.145519 (best action=85)
#
# 0421-th step: f(x) = 2.544343 (action=114)
#    current best f(x) = 5.145519 (best action=85)
#
# 0422-th step: f(x) = 2.004677 (action=396)
#    current best f(x) = 5.145519 (best action=85)
#
# 0423-th step: f(x) = 2.167062 (action=2)
#    current best f(x) = 5.145519 (best action=85)
#
# 0424-th step: f(x) = 2.238520 (action=266)
#    current best f(x) = 5.145519 (best action=85)
#
# 0425-th step: f(x) = 2.338626 (action=78)
#    current best f(x) = 5.145519 (best action=85)
#
# 0426-th step: f(x) = 3.281901 (action=309)
#    current best f(x) = 5.145519 (best action=85)
#
# 0427-th step: f(x) = 2.428719 (action=206)
#    current best f(x) = 5.145519 (best action=85)
#
# 0428-th step: f(x) = 2.358697 (action=263)
#    current best f(x) = 5.145519 (best action=85)
#
# 0429-th step: f(x) = 1.981919 (action=75)
#    current best f(x) = 5.145519 (best action=85)
#
# 0430-th step: f(x) = 3.956854 (action=49)
#    current best f(x) = 5.145519 (best action=85)
#
# 0431-th step: f(x) = 2.482699 (action=234)
#    current best f(x) = 5.145519 (best action=85)
#
# 0432-th step: f(x) = 1.968002 (action=160)
#    current best f(x) = 5.145519 (best action=85)
#
# 0433-th step: f(x) = 2.048927 (action=186)
#    current best f(x) = 5.145519 (best action=85)
#
# 0434-th step: f(x) = 3.327093 (action=191)
#    current best f(x) = 5.145519 (best action=85)
#
# 0435-th step: f(x) = 3.202611 (action=329)
#    current best f(x) = 5.145519 (best action=85)
#
# 0436-th step: f(x) = 2.468714 (action=423)
#    current best f(x) = 5.145519 (best action=85)
#
# 0437-th step: f(x) = 2.250752 (action=251)
#    current best f(x) = 5.145519 (best action=85)
#
# 0438-th step: f(x) = 2.038031 (action=299)
#    current best f(x) = 5.145519 (best action=85)
#
# 0439-th step: f(x) = 2.797998 (action=108)
#    current best f(x) = 5.145519 (best action=85)
#
# 0440-th step: f(x) = 1.988187 (action=365)
#    current best f(x) = 5.145519 (best action=85)
#
# 0441-th step: f(x) = 2.412960 (action=421)
#    current best f(x) = 5.145519 (best action=85)
#
# 0442-th step: f(x) = 2.433500 (action=339)
#    current best f(x) = 5.145519 (best action=85)
#
# 0443-th step: f(x) = 1.978480 (action=237)
#    current best f(x) = 5.145519 (best action=85)
#
# 0444-th step: f(x) = 3.300166 (action=180)
#    current best f(x) = 5.145519 (best action=85)
#
# 0445-th step: f(x) = 2.501522 (action=415)
#    current best f(x) = 5.145519 (best action=85)
#
# 0446-th step: f(x) = 2.449975 (action=84)
#    current best f(x) = 5.145519 (best action=85)
#
# 0447-th step: f(x) = 2.125666 (action=50)
#    current best f(x) = 5.145519 (best action=85)
#
# 0448-th step: f(x) = 2.526117 (action=149)
#    current best f(x) = 5.145519 (best action=85)
#
# 0449-th step: f(x) = 1.990225 (action=91)
#    current best f(x) = 5.145519 (best action=85)
#
# 0450-th step: f(x) = 2.157175 (action=192)
#    current best f(x) = 5.145519 (best action=85)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 388.55048777601155
# 50-th epoch, marginal likelihood 361.1750981580598
# 100-th epoch, marginal likelihood 356.17724802993575
# 150-th epoch, marginal likelihood 354.87261945452815
# 200-th epoch, marginal likelihood 354.67763374562224
# 250-th epoch, marginal likelihood 354.76958748934214
# 300-th epoch, marginal likelihood 354.6063793663844
# 350-th epoch, marginal likelihood 354.53956433370615
# 400-th epoch, marginal likelihood 354.68732587742636
# 450-th epoch, marginal likelihood 354.56435332231104
# 500-th epoch, marginal likelihood 354.7831688275359
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [4.64892064]
#  scale  =  0.7582554173830617
#  scale2 =  0.5749512779907611
#
#
# 0451-th step: f(x) = 2.604530 (action=341)
#    current best f(x) = 5.145519 (best action=85)
#
# 0452-th step: f(x) = 2.914363 (action=145)
#    current best f(x) = 5.145519 (best action=85)
#
# 0453-th step: f(x) = 2.277437 (action=146)
#    current best f(x) = 5.145519 (best action=85)
#
# 0454-th step: f(x) = 2.429008 (action=88)
#    current best f(x) = 5.145519 (best action=85)
#
# 0455-th step: f(x) = 2.100603 (action=353)
#    current best f(x) = 5.145519 (best action=85)
#
# 0456-th step: f(x) = 2.617578 (action=397)
#    current best f(x) = 5.145519 (best action=85)
#
# 0457-th step: f(x) = 3.809868 (action=71)
#    current best f(x) = 5.145519 (best action=85)
#
# 0458-th step: f(x) = 2.753838 (action=235)
#    current best f(x) = 5.145519 (best action=85)
#
# 0459-th step: f(x) = 1.980514 (action=249)
#    current best f(x) = 5.145519 (best action=85)
#
# 0460-th step: f(x) = 1.922734 (action=215)
#    current best f(x) = 5.145519 (best action=85)
#
# 0461-th step: f(x) = 2.143475 (action=96)
#    current best f(x) = 5.145519 (best action=85)
#
# 0462-th step: f(x) = 2.166818 (action=126)
#    current best f(x) = 5.145519 (best action=85)
#
# 0463-th step: f(x) = 2.005578 (action=87)
#    current best f(x) = 5.145519 (best action=85)
#
# 0464-th step: f(x) = 2.886025 (action=9)
#    current best f(x) = 5.145519 (best action=85)
#
# 0465-th step: f(x) = 2.006099 (action=483)
#    current best f(x) = 5.145519 (best action=85)
#
# 0466-th step: f(x) = 2.039260 (action=389)
#    current best f(x) = 5.145519 (best action=85)
#
# 0467-th step: f(x) = 2.410179 (action=105)
#    current best f(x) = 5.145519 (best action=85)
#
# 0468-th step: f(x) = 2.542476 (action=37)
#    current best f(x) = 5.145519 (best action=85)
#
# 0469-th step: f(x) = 2.187679 (action=321)
#    current best f(x) = 5.145519 (best action=85)
#
# 0470-th step: f(x) = 2.039610 (action=132)
#    current best f(x) = 5.145519 (best action=85)
#
# 0471-th step: f(x) = 1.996575 (action=291)
#    current best f(x) = 5.145519 (best action=85)
#
# 0472-th step: f(x) = 1.960779 (action=19)
#    current best f(x) = 5.145519 (best action=85)
#
# 0473-th step: f(x) = 2.153066 (action=56)
#    current best f(x) = 5.145519 (best action=85)
#
# 0474-th step: f(x) = 1.981223 (action=354)
#    current best f(x) = 5.145519 (best action=85)
#
# 0475-th step: f(x) = 2.338016 (action=170)
#    current best f(x) = 5.145519 (best action=85)
#
# 0476-th step: f(x) = 2.314462 (action=200)
#    current best f(x) = 5.145519 (best action=85)
#
# 0477-th step: f(x) = 2.133326 (action=30)
#    current best f(x) = 5.145519 (best action=85)
#
# 0478-th step: f(x) = 2.336159 (action=31)
#    current best f(x) = 5.145519 (best action=85)
#
# 0479-th step: f(x) = 2.549729 (action=7)
#    current best f(x) = 5.145519 (best action=85)
#
# 0480-th step: f(x) = 2.196917 (action=166)
#    current best f(x) = 5.145519 (best action=85)
#
# 0481-th step: f(x) = 2.237073 (action=143)
#    current best f(x) = 5.145519 (best action=85)
#
# 0482-th step: f(x) = 1.984781 (action=404)
#    current best f(x) = 5.145519 (best action=85)
#
# 0483-th step: f(x) = 2.341118 (action=373)
#    current best f(x) = 5.145519 (best action=85)
#
# 0484-th step: f(x) = 2.176872 (action=487)
#    current best f(x) = 5.145519 (best action=85)
#
# 0485-th step: f(x) = 2.247411 (action=325)
#    current best f(x) = 5.145519 (best action=85)
#
# 0486-th step: f(x) = 2.462729 (action=46)
#    current best f(x) = 5.145519 (best action=85)
#
# 0487-th step: f(x) = 2.155686 (action=344)
#    current best f(x) = 5.145519 (best action=85)
#
# 0488-th step: f(x) = 2.457504 (action=258)
#    current best f(x) = 5.145519 (best action=85)
#
# 0489-th step: f(x) = 2.091224 (action=497)
#    current best f(x) = 5.145519 (best action=85)
#
# 0490-th step: f(x) = 2.676548 (action=95)
#    current best f(x) = 5.145519 (best action=85)
#
# 0491-th step: f(x) = 2.093679 (action=384)
#    current best f(x) = 5.145519 (best action=85)
#
# 0492-th step: f(x) = 2.035394 (action=125)
#    current best f(x) = 5.145519 (best action=85)
#
# 0493-th step: f(x) = 2.228130 (action=371)
#    current best f(x) = 5.145519 (best action=85)
#
# 0494-th step: f(x) = 2.420364 (action=380)
#    current best f(x) = 5.145519 (best action=85)
#
# 0495-th step: f(x) = 2.033832 (action=144)
#    current best f(x) = 5.145519 (best action=85)
#
# 0496-th step: f(x) = 2.495852 (action=238)
#    current best f(x) = 5.145519 (best action=85)
#
# 0497-th step: f(x) = 2.315783 (action=54)
#    current best f(x) = 5.145519 (best action=85)
#
# 0498-th step: f(x) = 2.651898 (action=457)
#    current best f(x) = 5.145519 (best action=85)
#
# 0499-th step: f(x) = 1.987644 (action=16)
#    current best f(x) = 5.145519 (best action=85)
#
# 0500-th step: f(x) = 2.244285 (action=286)
#    current best f(x) = 5.145519 (best action=85)

# %%
COMBO_EI_Working_Capacity_relevant = COMBO(Data_relevant_features_Working_Capacity, 'EI')
# Out:
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 29.90997320969744
# 50-th epoch, marginal likelihood 10.794170505191829
# 100-th epoch, marginal likelihood -0.9075471825976535
# 150-th epoch, marginal likelihood -8.368386914971154
# 200-th epoch, marginal likelihood -13.257961195127848
# 250-th epoch, marginal likelihood -16.014131550153778
# 300-th epoch, marginal likelihood -17.94129530471389
# 350-th epoch, marginal likelihood -19.372885445729196
# 400-th epoch, marginal likelihood -20.431542524574922
# 450-th epoch, marginal likelihood -21.181973189835446
# 500-th epoch, marginal likelihood -21.764358133226573
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.]
#  scale  =  1.0
#  scale2 =  1.0
#
#
# 0101-th step: f(x) = 1.954579 (action=267)
#    current best f(x) = 1.954579 (best action=267)
#
# 0102-th step: f(x) = 2.504622 (action=443)
#    current best f(x) = 2.504622 (best action=443)
#
# 0103-th step: f(x) = 2.317952 (action=10)
#    current best f(x) = 2.504622 (best action=443)
#
# 0104-th step: f(x) = 1.986916 (action=94)
#    current best f(x) = 2.504622 (best action=443)
#
# 0105-th step: f(x) = 2.843266 (action=478)
#    current best f(x) = 2.843266 (best action=478)
#
# 0106-th step: f(x) = 2.511968 (action=319)
#    current best f(x) = 2.843266 (best action=478)
#
# 0107-th step: f(x) = 2.418407 (action=485)
#    current best f(x) = 2.843266 (best action=478)
#
# 0108-th step: f(x) = 2.269370 (action=432)
#    current best f(x) = 2.843266 (best action=478)
#
# 0109-th step: f(x) = 2.557924 (action=260)
#    current best f(x) = 2.843266 (best action=478)
#
# 0110-th step: f(x) = 2.710859 (action=179)
#    current best f(x) = 2.843266 (best action=478)
#
# 0111-th step: f(x) = 2.359282 (action=428)
#    current best f(x) = 2.843266 (best action=478)
#
# 0112-th step: f(x) = 2.383186 (action=395)
#    current best f(x) = 2.843266 (best action=478)
#
# 0113-th step: f(x) = 3.373301 (action=140)
#    current best f(x) = 3.373301 (best action=140)
#
# 0114-th step: f(x) = 2.991167 (action=139)
#    current best f(x) = 3.373301 (best action=140)
#
# 0115-th step: f(x) = 2.830068 (action=189)
#    current best f(x) = 3.373301 (best action=140)
#
# 0116-th step: f(x) = 2.943834 (action=265)
#    current best f(x) = 3.373301 (best action=140)
#
# 0117-th step: f(x) = 2.692199 (action=17)
#    current best f(x) = 3.373301 (best action=140)
#
# 0118-th step: f(x) = 3.356339 (action=55)
#    current best f(x) = 3.373301 (best action=140)
#
# 0119-th step: f(x) = 2.240289 (action=151)
#    current best f(x) = 3.373301 (best action=140)
#
# 0120-th step: f(x) = 3.002695 (action=287)
#    current best f(x) = 3.373301 (best action=140)
#
# 0121-th step: f(x) = 2.796477 (action=412)
#    current best f(x) = 3.373301 (best action=140)
#
# 0122-th step: f(x) = 2.253350 (action=447)
#    current best f(x) = 3.373301 (best action=140)
#
# 0123-th step: f(x) = 2.116136 (action=205)
#    current best f(x) = 3.373301 (best action=140)
#
# 0124-th step: f(x) = 3.018996 (action=408)
#    current best f(x) = 3.373301 (best action=140)
#
# 0125-th step: f(x) = 3.292710 (action=492)
#    current best f(x) = 3.373301 (best action=140)
#
# 0126-th step: f(x) = 3.286539 (action=220)
#    current best f(x) = 3.373301 (best action=140)
#
# 0127-th step: f(x) = 4.042345 (action=482)
#    current best f(x) = 4.042345 (best action=482)
#
# 0128-th step: f(x) = 3.671379 (action=425)
#    current best f(x) = 4.042345 (best action=482)
#
# 0129-th step: f(x) = 3.122676 (action=213)
#    current best f(x) = 4.042345 (best action=482)
#
# 0130-th step: f(x) = 2.133533 (action=228)
#    current best f(x) = 4.042345 (best action=482)
#
# 0131-th step: f(x) = 4.015172 (action=471)
#    current best f(x) = 4.042345 (best action=482)
#
# 0132-th step: f(x) = 2.838673 (action=231)
#    current best f(x) = 4.042345 (best action=482)
#
# 0133-th step: f(x) = 3.408732 (action=120)
#    current best f(x) = 4.042345 (best action=482)
#
# 0134-th step: f(x) = 2.913231 (action=38)
#    current best f(x) = 4.042345 (best action=482)
#
# 0135-th step: f(x) = 3.071644 (action=446)
#    current best f(x) = 4.042345 (best action=482)
#
# 0136-th step: f(x) = 4.706231 (action=73)
#    current best f(x) = 4.706231 (best action=73)
#
# 0137-th step: f(x) = 4.508599 (action=168)
#    current best f(x) = 4.706231 (best action=73)
#
# 0138-th step: f(x) = 4.527239 (action=316)
#    current best f(x) = 4.706231 (best action=73)
#
# 0139-th step: f(x) = 3.156001 (action=383)
#    current best f(x) = 4.706231 (best action=73)
#
# 0140-th step: f(x) = 3.047911 (action=252)
#    current best f(x) = 4.706231 (best action=73)
#
# 0141-th step: f(x) = 3.656655 (action=0)
#    current best f(x) = 4.706231 (best action=73)
#
# 0142-th step: f(x) = 2.935765 (action=158)
#    current best f(x) = 4.706231 (best action=73)
#
# 0143-th step: f(x) = 3.515651 (action=289)
#    current best f(x) = 4.706231 (best action=73)
#
# 0144-th step: f(x) = 3.945998 (action=268)
#    current best f(x) = 4.706231 (best action=73)
#
# 0145-th step: f(x) = 3.359676 (action=24)
#    current best f(x) = 4.706231 (best action=73)
#
# 0146-th step: f(x) = 3.950354 (action=48)
#    current best f(x) = 4.706231 (best action=73)
#
# 0147-th step: f(x) = 4.725240 (action=247)
#    current best f(x) = 4.725240 (best action=247)
#
# 0148-th step: f(x) = 4.067988 (action=448)
#    current best f(x) = 4.725240 (best action=247)
#
# 0149-th step: f(x) = 4.682727 (action=479)
#    current best f(x) = 4.725240 (best action=247)
#
# 0150-th step: f(x) = 3.761592 (action=36)
#    current best f(x) = 4.725240 (best action=247)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 93.66841373317149
# 50-th epoch, marginal likelihood 93.60530626969994
# 100-th epoch, marginal likelihood 93.56041506412711
# 150-th epoch, marginal likelihood 93.47538668758062
# 200-th epoch, marginal likelihood 93.44235823754188
# 250-th epoch, marginal likelihood 93.3496485808421
# 300-th epoch, marginal likelihood 93.27276438181445
# 350-th epoch, marginal likelihood 93.16189793494893
# 400-th epoch, marginal likelihood 93.16095778945217
# 450-th epoch, marginal likelihood 93.09961728952395
# 500-th epoch, marginal likelihood 93.07182679014126
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [4.74589839]
#  scale  =  0.2449335301693771
#  scale2 =  0.059992434201233166
#
#
# 0151-th step: f(x) = 2.650736 (action=331)
#    current best f(x) = 4.725240 (best action=247)
#
# 0152-th step: f(x) = 2.326354 (action=400)
#    current best f(x) = 4.725240 (best action=247)
#
# 0153-th step: f(x) = 2.433231 (action=128)
#    current best f(x) = 4.725240 (best action=247)
#
# 0154-th step: f(x) = 2.530396 (action=196)
#    current best f(x) = 4.725240 (best action=247)
#
# 0155-th step: f(x) = 2.789102 (action=93)
#    current best f(x) = 4.725240 (best action=247)
#
# 0156-th step: f(x) = 2.750888 (action=472)
#    current best f(x) = 4.725240 (best action=247)
#
# 0157-th step: f(x) = 2.244324 (action=352)
#    current best f(x) = 4.725240 (best action=247)
#
# 0158-th step: f(x) = 2.822646 (action=370)
#    current best f(x) = 4.725240 (best action=247)
#
# 0159-th step: f(x) = 3.298290 (action=372)
#    current best f(x) = 4.725240 (best action=247)
#
# 0160-th step: f(x) = 4.107620 (action=223)
#    current best f(x) = 4.725240 (best action=247)
#
# 0161-th step: f(x) = 3.824264 (action=164)
#    current best f(x) = 4.725240 (best action=247)
#
# 0162-th step: f(x) = 3.901682 (action=462)
#    current best f(x) = 4.725240 (best action=247)
#
# 0163-th step: f(x) = 3.495000 (action=39)
#    current best f(x) = 4.725240 (best action=247)
#
# 0164-th step: f(x) = 3.909203 (action=338)
#    current best f(x) = 4.725240 (best action=247)
#
# 0165-th step: f(x) = 2.797378 (action=362)
#    current best f(x) = 4.725240 (best action=247)
#
# 0166-th step: f(x) = 2.693562 (action=337)
#    current best f(x) = 4.725240 (best action=247)
#
# 0167-th step: f(x) = 2.333648 (action=119)
#    current best f(x) = 4.725240 (best action=247)
#
# 0168-th step: f(x) = 2.166267 (action=387)
#    current best f(x) = 4.725240 (best action=247)
#
# 0169-th step: f(x) = 2.446035 (action=330)
#    current best f(x) = 4.725240 (best action=247)
#
# 0170-th step: f(x) = 1.927450 (action=255)
#    current best f(x) = 4.725240 (best action=247)
#
# 0171-th step: f(x) = 2.489719 (action=171)
#    current best f(x) = 4.725240 (best action=247)
#
# 0172-th step: f(x) = 2.272024 (action=59)
#    current best f(x) = 4.725240 (best action=247)
#
# 0173-th step: f(x) = 3.264902 (action=355)
#    current best f(x) = 4.725240 (best action=247)
#
# 0174-th step: f(x) = 3.286670 (action=77)
#    current best f(x) = 4.725240 (best action=247)
#
# 0175-th step: f(x) = 2.847173 (action=444)
#    current best f(x) = 4.725240 (best action=247)
#
# 0176-th step: f(x) = 3.095683 (action=130)
#    current best f(x) = 4.725240 (best action=247)
#
# 0177-th step: f(x) = 2.500998 (action=360)
#    current best f(x) = 4.725240 (best action=247)
#
# 0178-th step: f(x) = 2.731978 (action=176)
#    current best f(x) = 4.725240 (best action=247)
#
# 0179-th step: f(x) = 2.086169 (action=364)
#    current best f(x) = 4.725240 (best action=247)
#
# 0180-th step: f(x) = 2.784103 (action=438)
#    current best f(x) = 4.725240 (best action=247)
#
# 0181-th step: f(x) = 3.097235 (action=229)
#    current best f(x) = 4.725240 (best action=247)
#
# 0182-th step: f(x) = 2.143090 (action=288)
#    current best f(x) = 4.725240 (best action=247)
#
# 0183-th step: f(x) = 3.400929 (action=35)
#    current best f(x) = 4.725240 (best action=247)
#
# 0184-th step: f(x) = 4.288360 (action=366)
#    current best f(x) = 4.725240 (best action=247)
#
# 0185-th step: f(x) = 5.057711 (action=250)
#    current best f(x) = 5.057711 (best action=250)
#
# 0186-th step: f(x) = 3.603806 (action=493)
#    current best f(x) = 5.057711 (best action=250)
#
# 0187-th step: f(x) = 3.548726 (action=97)
#    current best f(x) = 5.057711 (best action=250)
#
# 0188-th step: f(x) = 2.304067 (action=111)
#    current best f(x) = 5.057711 (best action=250)
#
# 0189-th step: f(x) = 1.958722 (action=167)
#    current best f(x) = 5.057711 (best action=250)
#
# 0190-th step: f(x) = 1.982911 (action=320)
#    current best f(x) = 5.057711 (best action=250)
#
# 0191-th step: f(x) = 2.148002 (action=403)
#    current best f(x) = 5.057711 (best action=250)
#
# 0192-th step: f(x) = 1.978139 (action=498)
#    current best f(x) = 5.057711 (best action=250)
#
# 0193-th step: f(x) = 2.521384 (action=495)
#    current best f(x) = 5.057711 (best action=250)
#
# 0194-th step: f(x) = 2.971935 (action=112)
#    current best f(x) = 5.057711 (best action=250)
#
# 0195-th step: f(x) = 3.222779 (action=197)
#    current best f(x) = 5.057711 (best action=250)
#
# 0196-th step: f(x) = 2.517475 (action=15)
#    current best f(x) = 5.057711 (best action=250)
#
# 0197-th step: f(x) = 2.616944 (action=122)
#    current best f(x) = 5.057711 (best action=250)
#
# 0198-th step: f(x) = 2.109923 (action=58)
#    current best f(x) = 5.057711 (best action=250)
#
# 0199-th step: f(x) = 3.001148 (action=4)
#    current best f(x) = 5.057711 (best action=250)
#
# 0200-th step: f(x) = 2.104538 (action=21)
#    current best f(x) = 5.057711 (best action=250)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 149.8506302093871
# 50-th epoch, marginal likelihood 148.50026216056918
# 100-th epoch, marginal likelihood 147.69860106839627
# 150-th epoch, marginal likelihood 147.19476669172417
# 200-th epoch, marginal likelihood 146.9162591938557
# 250-th epoch, marginal likelihood 146.78352024234852
# 300-th epoch, marginal likelihood 146.7751415213508
# 350-th epoch, marginal likelihood 146.75690023669873
# 400-th epoch, marginal likelihood 146.66234602387257
# 450-th epoch, marginal likelihood 146.66007357935374
# 500-th epoch, marginal likelihood 146.60479991414655
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.291445]
#  scale  =  0.7973085045841783
#  scale2 =  0.6357008514822587
#
#
# 0201-th step: f(x) = 3.367598 (action=377)
#    current best f(x) = 5.057711 (best action=250)
#
# 0202-th step: f(x) = 3.170518 (action=40)
#    current best f(x) = 5.057711 (best action=250)
#
# 0203-th step: f(x) = 2.227650 (action=363)
#    current best f(x) = 5.057711 (best action=250)
#
# 0204-th step: f(x) = 4.270924 (action=426)
#    current best f(x) = 5.057711 (best action=250)
#
# 0205-th step: f(x) = 3.979143 (action=107)
#    current best f(x) = 5.057711 (best action=250)
#
# 0206-th step: f(x) = 4.190259 (action=218)
#    current best f(x) = 5.057711 (best action=250)
#
# 0207-th step: f(x) = 3.209805 (action=484)
#    current best f(x) = 5.057711 (best action=250)
#
# 0208-th step: f(x) = 2.721873 (action=90)
#    current best f(x) = 5.057711 (best action=250)
#
# 0209-th step: f(x) = 2.514247 (action=44)
#    current best f(x) = 5.057711 (best action=250)
#
# 0210-th step: f(x) = 3.709738 (action=103)
#    current best f(x) = 5.057711 (best action=250)
#
# 0211-th step: f(x) = 2.305546 (action=398)
#    current best f(x) = 5.057711 (best action=250)
#
# 0212-th step: f(x) = 2.683243 (action=336)
#    current best f(x) = 5.057711 (best action=250)
#
# 0213-th step: f(x) = 3.310716 (action=261)
#    current best f(x) = 5.057711 (best action=250)
#
# 0214-th step: f(x) = 1.925328 (action=386)
#    current best f(x) = 5.057711 (best action=250)
#
# 0215-th step: f(x) = 2.409400 (action=264)
#    current best f(x) = 5.057711 (best action=250)
#
# 0216-th step: f(x) = 2.662879 (action=459)
#    current best f(x) = 5.057711 (best action=250)
#
# 0217-th step: f(x) = 3.052043 (action=195)
#    current best f(x) = 5.057711 (best action=250)
#
# 0218-th step: f(x) = 2.272421 (action=18)
#    current best f(x) = 5.057711 (best action=250)
#
# 0219-th step: f(x) = 2.453982 (action=109)
#    current best f(x) = 5.057711 (best action=250)
#
# 0220-th step: f(x) = 2.454971 (action=74)
#    current best f(x) = 5.057711 (best action=250)
#
# 0221-th step: f(x) = 2.198917 (action=347)
#    current best f(x) = 5.057711 (best action=250)
#
# 0222-th step: f(x) = 3.339624 (action=221)
#    current best f(x) = 5.057711 (best action=250)
#
# 0223-th step: f(x) = 2.072946 (action=147)
#    current best f(x) = 5.057711 (best action=250)
#
# 0224-th step: f(x) = 3.312010 (action=242)
#    current best f(x) = 5.057711 (best action=250)
#
# 0225-th step: f(x) = 3.009214 (action=129)
#    current best f(x) = 5.057711 (best action=250)
#
# 0226-th step: f(x) = 3.559743 (action=323)
#    current best f(x) = 5.057711 (best action=250)
#
# 0227-th step: f(x) = 2.680294 (action=357)
#    current best f(x) = 5.057711 (best action=250)
#
# 0228-th step: f(x) = 3.837505 (action=281)
#    current best f(x) = 5.057711 (best action=250)
#
# 0229-th step: f(x) = 3.864941 (action=185)
#    current best f(x) = 5.057711 (best action=250)
#
# 0230-th step: f(x) = 3.571466 (action=117)
#    current best f(x) = 5.057711 (best action=250)
#
# 0231-th step: f(x) = 2.793633 (action=475)
#    current best f(x) = 5.057711 (best action=250)
#
# 0232-th step: f(x) = 2.218906 (action=262)
#    current best f(x) = 5.057711 (best action=250)
#
# 0233-th step: f(x) = 2.735916 (action=159)
#    current best f(x) = 5.057711 (best action=250)
#
# 0234-th step: f(x) = 1.922565 (action=3)
#    current best f(x) = 5.057711 (best action=250)
#
# 0235-th step: f(x) = 2.399030 (action=351)
#    current best f(x) = 5.057711 (best action=250)
#
# 0236-th step: f(x) = 3.908885 (action=118)
#    current best f(x) = 5.057711 (best action=250)
#
# 0237-th step: f(x) = 3.112139 (action=311)
#    current best f(x) = 5.057711 (best action=250)
#
# 0238-th step: f(x) = 2.812253 (action=491)
#    current best f(x) = 5.057711 (best action=250)
#
# 0239-th step: f(x) = 2.711763 (action=436)
#    current best f(x) = 5.057711 (best action=250)
#
# 0240-th step: f(x) = 2.445585 (action=402)
#    current best f(x) = 5.057711 (best action=250)
#
# 0241-th step: f(x) = 2.637429 (action=13)
#    current best f(x) = 5.057711 (best action=250)
#
# 0242-th step: f(x) = 2.390952 (action=381)
#    current best f(x) = 5.057711 (best action=250)
#
# 0243-th step: f(x) = 2.769902 (action=305)
#    current best f(x) = 5.057711 (best action=250)
#
# 0244-th step: f(x) = 2.032710 (action=361)
#    current best f(x) = 5.057711 (best action=250)
#
# 0245-th step: f(x) = 2.352993 (action=210)
#    current best f(x) = 5.057711 (best action=250)
#
# 0246-th step: f(x) = 2.347726 (action=466)
#    current best f(x) = 5.057711 (best action=250)
#
# 0247-th step: f(x) = 2.006214 (action=302)
#    current best f(x) = 5.057711 (best action=250)
#
# 0248-th step: f(x) = 2.269903 (action=106)
#    current best f(x) = 5.057711 (best action=250)
#
# 0249-th step: f(x) = 2.279116 (action=315)
#    current best f(x) = 5.057711 (best action=250)
#
# 0250-th step: f(x) = 2.001193 (action=214)
#    current best f(x) = 5.057711 (best action=250)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 203.88806775754867
# 50-th epoch, marginal likelihood 198.96986514100178
# 100-th epoch, marginal likelihood 198.0712811007799
# 150-th epoch, marginal likelihood 197.6527478781992
# 200-th epoch, marginal likelihood 197.45683475799044
# 250-th epoch, marginal likelihood 197.6029655484342
# 300-th epoch, marginal likelihood 197.59070761963363
# 350-th epoch, marginal likelihood 197.34771763627703
# 400-th epoch, marginal likelihood 197.3319286945915
# 450-th epoch, marginal likelihood 197.651910200474
# 500-th epoch, marginal likelihood 197.3335428128525
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.1448316]
#  scale  =  0.8089943171881571
#  scale2 =  0.6544718052427325
#
#
# 0251-th step: f(x) = 3.886743 (action=253)
#    current best f(x) = 5.057711 (best action=250)
#
# 0252-th step: f(x) = 4.287449 (action=182)
#    current best f(x) = 5.057711 (best action=250)
#
# 0253-th step: f(x) = 2.785436 (action=28)
#    current best f(x) = 5.057711 (best action=250)
#
# 0254-th step: f(x) = 5.145519 (action=85)
#    current best f(x) = 5.145519 (best action=85)
#
# 0255-th step: f(x) = 2.543388 (action=350)
#    current best f(x) = 5.145519 (best action=85)
#
# 0256-th step: f(x) = 2.755235 (action=102)
#    current best f(x) = 5.145519 (best action=85)
#
# 0257-th step: f(x) = 2.043189 (action=141)
#    current best f(x) = 5.145519 (best action=85)
#
# 0258-th step: f(x) = 2.269876 (action=86)
#    current best f(x) = 5.145519 (best action=85)
#
# 0259-th step: f(x) = 3.027862 (action=11)
#    current best f(x) = 5.145519 (best action=85)
#
# 0260-th step: f(x) = 3.976796 (action=173)
#    current best f(x) = 5.145519 (best action=85)
#
# 0261-th step: f(x) = 3.222111 (action=393)
#    current best f(x) = 5.145519 (best action=85)
#
# 0262-th step: f(x) = 2.637765 (action=458)
#    current best f(x) = 5.145519 (best action=85)
#
# 0263-th step: f(x) = 2.535317 (action=269)
#    current best f(x) = 5.145519 (best action=85)
#
# 0264-th step: f(x) = 2.430162 (action=198)
#    current best f(x) = 5.145519 (best action=85)
#
# 0265-th step: f(x) = 3.877561 (action=68)
#    current best f(x) = 5.145519 (best action=85)
#
# 0266-th step: f(x) = 4.040700 (action=190)
#    current best f(x) = 5.145519 (best action=85)
#
# 0267-th step: f(x) = 2.788362 (action=270)
#    current best f(x) = 5.145519 (best action=85)
#
# 0268-th step: f(x) = 3.168273 (action=295)
#    current best f(x) = 5.145519 (best action=85)
#
# 0269-th step: f(x) = 1.941175 (action=42)
#    current best f(x) = 5.145519 (best action=85)
#
# 0270-th step: f(x) = 1.999945 (action=480)
#    current best f(x) = 5.145519 (best action=85)
#
# 0271-th step: f(x) = 3.426586 (action=20)
#    current best f(x) = 5.145519 (best action=85)
#
# 0272-th step: f(x) = 2.086933 (action=327)
#    current best f(x) = 5.145519 (best action=85)
#
# 0273-th step: f(x) = 3.597137 (action=257)
#    current best f(x) = 5.145519 (best action=85)
#
# 0274-th step: f(x) = 2.996586 (action=69)
#    current best f(x) = 5.145519 (best action=85)
#
# 0275-th step: f(x) = 2.023847 (action=435)
#    current best f(x) = 5.145519 (best action=85)
#
# 0276-th step: f(x) = 2.484639 (action=80)
#    current best f(x) = 5.145519 (best action=85)
#
# 0277-th step: f(x) = 2.564279 (action=417)
#    current best f(x) = 5.145519 (best action=85)
#
# 0278-th step: f(x) = 2.759216 (action=473)
#    current best f(x) = 5.145519 (best action=85)
#
# 0279-th step: f(x) = 2.549730 (action=184)
#    current best f(x) = 5.145519 (best action=85)
#
# 0280-th step: f(x) = 3.541771 (action=47)
#    current best f(x) = 5.145519 (best action=85)
#
# 0281-th step: f(x) = 2.471051 (action=1)
#    current best f(x) = 5.145519 (best action=85)
#
# 0282-th step: f(x) = 2.608643 (action=454)
#    current best f(x) = 5.145519 (best action=85)
#
# 0283-th step: f(x) = 2.563363 (action=385)
#    current best f(x) = 5.145519 (best action=85)
#
# 0284-th step: f(x) = 2.145624 (action=115)
#    current best f(x) = 5.145519 (best action=85)
#
# 0285-th step: f(x) = 2.047329 (action=401)
#    current best f(x) = 5.145519 (best action=85)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-3031544d5156> in <module>
# ----> 1 COMBO_EI_Working_Capacity_relevant = COMBO(Data_relevant_features_Working_Capacity, 'EI')
#
# <ipython-input-61-b9e4d0bc9f32> in COMBO(Data, acq_fcn)
#      23     res = policy.write(minima, t)
#      24
# ---> 25     res = policy.bayes_search(max_num_probes = 400, simulator=simulator(), score = acq_fcn, interval=50, num_rand_basis=0)
#      26
#      27     return(res)
#
# ~\anaconda3\lib\site-packages\combo\search\discrete\policy.py in bayes_search(self, training, max_num_probes, num_search_each_probe, predictor, is_disp, simulator, score, interval, num_rand_basis)
#     114             K = self.config.search.multi_probe_num_sampling
#     115             alpha = self.config.search.alpha
# --> 116             action = self.get_actions(score, N, K, alpha)
#     117
#     118             if simulator is None:
#
# ~\anaconda3\lib\site-packages\combo\search\discrete\policy.py in get_actions(self, mode, N, K, alpha)
#     176         action_prov = np.zeros(Z)
#     177         for j in range(Z):
# --> 178             f = self.get_score(mode, self.predictor, self.training, alpha)
#     179             temp_prov[j] = np.argmax(f)
#     180             action_prov[j] = self.actions[int(temp_prov[j])]
#
# ~\anaconda3\lib\site-packages\combo\search\discrete\policy.py in get_score(self, mode, predictor, training, alpha)
#     135         test = self.test.get_subset(actions)
#     136         if mode == 'EI':
# --> 137             f = combo.search.score.EI(predictor, training, test)
#     138         elif mode == 'PI':
#     139             f = combo.search.score.PI(predictor, training, test)
#
# ~\anaconda3\lib\site-packages\combo\search\score.py in EI(predictor, training, test, fmax)
#       9
#      10     if fmax is None:
# ---> 11         fmax = np.max(predictor.get_post_fmean(training, training))
#      12
#      13     temp1 = (fmean - fmax)
#
# ~\anaconda3\lib\site-packages\combo\gp\predictor.py in get_post_fmean(self, training, test)
#      28         if self.model.stats is None:
#      29             self.prepare(training)
# ---> 30         return self.model.get_post_fmean(training.X, test.X)
#      31
#      32     def get_post_fcov(self, training, test, diag=True):
#
# ~\anaconda3\lib\site-packages\combo\gp\core\model.py in get_post_fmean(self, X, Z, params)
#     102
#     103         if self.inf is 'exact':
# --> 104             post_fmu = inf.exact.get_post_fmean(self, X, Z, params)
#     105
#     106         return post_fmu
#
# ~\anaconda3\lib\site-packages\combo\gp\inf\exact.py in get_post_fmean(gp, X, Z, params)
#      96
#      97     fmu = gp.prior.get_mean(ntest)
# ---> 98     G = gp.prior.get_cov(X=Z, Z=X, params=prior_params)
#      99
#     100     return G.dot(alpha) + fmu
#
# ~\anaconda3\lib\site-packages\combo\gp\core\prior.py in get_cov(self, X, Z, params, diag)
#      32
#      33         return self.cov.get_cov(X, Z, params=params[self.mean.num_params:],
# ---> 34                                 diag=diag)
#      35
#      36     def get_grad_mean(self, num_data, params=None):
#
# ~\anaconda3\lib\site-packages\combo\gp\cov\gauss.py in get_cov(self, X, Z, params, diag)
#      82         else:
#      83             pairwise_dists = spatial.distance.cdist(X/width, Z/width,
# ---> 84                                                     'euclidean')**2
#      85             G = np.exp(-0.5 * pairwise_dists) * scale2
#      86
#
# ~\anaconda3\lib\site-packages\scipy\spatial\distance.py in cdist(XA, XB, metric, *args, **kwargs)
#    2778             cdist_fn = getattr(_distance_wrap,
#    2779                                "cdist_%s_%s_wrap" % (metric_name, typ))
# -> 2780             cdist_fn(XA, XB, dm, **kwargs)
#    2781             return dm
#    2782
#
# KeyboardInterrupt:

# %%
index_Working_Capacity_relevant = np.argmax(Data_relevant_features_Working_Capacity.iloc[:, -1].values)
import numpy as np
from sklearn.manifold import TSNE

X_embedded = TSNE(n_components=2).fit_transform(Data_relevant_features_Henry_CO2.iloc[:, :-1].values)
X_embedded.shape

SC1 = np.transpose(X_embedded)[0]
SC2 = np.transpose(X_embedded)[1]

fig, ax = plt.subplots(figsize=(3,3), dpi=150)
ax.scatter(SC1, SC2, c='tab:blue', alpha=0.3)
initial_set = ax.scatter(SC1[minima], SC2[minima], c='gold', label = 'Initial set', alpha = 0.5)
optimum = ax.scatter(SC1[index_Working_Capacity_relevant], SC2[index_Working_Capacity_relevant], c='red', label = 'Optimum')

ax.legend([initial_set, optimum], ['Initial set', 'Optimum'])
#labels = ['Initial set', 'Optimum']
#ax.legend(labels)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
plt.show()

# %% [markdown]
# #### Unrelevant features

# %%
MEI_index_Working_Capacity_unrelevant = MEI(Data_unrelevant_features_Working_Capacity.iloc[:, :-1].values, Data_unrelevant_features_Working_Capacity.iloc[:, -1].values, 400, 100)
# Out:
#  21%|██        | 84/400 [1:44:46<6:34:10, 74.84s/it]

# %%
MLI_index_Working_Capacity_unrelevant = MLI(Data_unrelevant_features_Working_Capacity.iloc[:, :-1].values, Data_unrelevant_features_Working_Capacity.iloc[:, -1].values, 400, 100)
# Out:
#  43%|████▎     | 172/400 [6:34:42<8:43:13, 137.69s/it]

# %%
MU_index_Working_Capacity_unrelevant = MU(Data_unrelevant_features_Working_Capacity.iloc[:, :-1].values, Data_unrelevant_features_Working_Capacity.iloc[:, -1].values, 400, 100)
# Out:
#  34%|███▍      | 136/400 [4:29:25<8:42:59, 118.86s/it]

# %%
COMBO_PI_Working_Capacity_unrelevant = COMBO(Data_unrelevant_features_Working_Capacity, 'PI')
# Out:
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 20.23399653181788
# 50-th epoch, marginal likelihood 4.17222041902788
# 100-th epoch, marginal likelihood -6.08329759052495
# 150-th epoch, marginal likelihood -12.212935623798302
# 200-th epoch, marginal likelihood -16.229832835355737
# 250-th epoch, marginal likelihood -18.71919742589435
# 300-th epoch, marginal likelihood -20.17777184657949
# 350-th epoch, marginal likelihood -21.31155548617224
# 400-th epoch, marginal likelihood -21.995295207177733
# 450-th epoch, marginal likelihood -22.406180054205848
# 500-th epoch, marginal likelihood -22.764543446338358
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.]
#  scale  =  1.0
#  scale2 =  1.0
#
#
# 0101-th step: f(x) = 1.954579 (action=267)
#    current best f(x) = 1.954579 (best action=267)
#
# 0102-th step: f(x) = 2.244285 (action=286)
#    current best f(x) = 2.244285 (best action=286)
#
# 0103-th step: f(x) = 3.222779 (action=197)
#    current best f(x) = 3.222779 (best action=197)
#
# 0104-th step: f(x) = 2.272024 (action=59)
#    current best f(x) = 3.222779 (best action=197)
#
# 0105-th step: f(x) = 2.145624 (action=115)
#    current best f(x) = 3.222779 (best action=197)
#
# 0106-th step: f(x) = 2.116136 (action=205)
#    current best f(x) = 3.222779 (best action=197)
#
# 0107-th step: f(x) = 2.692199 (action=17)
#    current best f(x) = 3.222779 (best action=197)
#
# 0108-th step: f(x) = 3.002695 (action=287)
#    current best f(x) = 3.222779 (best action=197)
#
# 0109-th step: f(x) = 3.286539 (action=220)
#    current best f(x) = 3.286539 (best action=220)
#
# 0110-th step: f(x) = 3.018996 (action=408)
#    current best f(x) = 3.286539 (best action=220)
#
# 0111-th step: f(x) = 3.292710 (action=492)
#    current best f(x) = 3.292710 (best action=492)
#
# 0112-th step: f(x) = 2.822646 (action=370)
#    current best f(x) = 3.292710 (best action=492)
#
# 0113-th step: f(x) = 4.042345 (action=482)
#    current best f(x) = 4.042345 (best action=482)
#
# 0114-th step: f(x) = 3.671379 (action=425)
#    current best f(x) = 4.042345 (best action=482)
#
# 0115-th step: f(x) = 3.665991 (action=328)
#    current best f(x) = 4.042345 (best action=482)
#
# 0116-th step: f(x) = 3.122676 (action=213)
#    current best f(x) = 4.042345 (best action=482)
#
# 0117-th step: f(x) = 3.654313 (action=293)
#    current best f(x) = 4.042345 (best action=482)
#
# 0118-th step: f(x) = 2.796477 (action=412)
#    current best f(x) = 4.042345 (best action=482)
#
# 0119-th step: f(x) = 2.240289 (action=151)
#    current best f(x) = 4.042345 (best action=482)
#
# 0120-th step: f(x) = 3.356339 (action=55)
#    current best f(x) = 4.042345 (best action=482)
#
# 0121-th step: f(x) = 2.032710 (action=361)
#    current best f(x) = 4.042345 (best action=482)
#
# 0122-th step: f(x) = 2.072946 (action=147)
#    current best f(x) = 4.042345 (best action=482)
#
# 0123-th step: f(x) = 2.650736 (action=331)
#    current best f(x) = 4.042345 (best action=482)
#
# 0124-th step: f(x) = 2.517475 (action=15)
#    current best f(x) = 4.042345 (best action=482)
#
# 0125-th step: f(x) = 2.133533 (action=228)
#    current best f(x) = 4.042345 (best action=482)
#
# 0126-th step: f(x) = 4.706231 (action=73)
#    current best f(x) = 4.706231 (best action=73)
#
# 0127-th step: f(x) = 4.508599 (action=168)
#    current best f(x) = 4.706231 (best action=73)
#
# 0128-th step: f(x) = 3.047911 (action=252)
#    current best f(x) = 4.706231 (best action=73)
#
# 0129-th step: f(x) = 3.156001 (action=383)
#    current best f(x) = 4.706231 (best action=73)
#
# 0130-th step: f(x) = 4.015172 (action=471)
#    current best f(x) = 4.706231 (best action=73)
#
# 0131-th step: f(x) = 2.838673 (action=231)
#    current best f(x) = 4.706231 (best action=73)
#
# 0132-th step: f(x) = 4.527239 (action=316)
#    current best f(x) = 4.706231 (best action=73)
#
# 0133-th step: f(x) = 2.279116 (action=315)
#    current best f(x) = 4.706231 (best action=73)
#
# 0134-th step: f(x) = 3.359676 (action=24)
#    current best f(x) = 4.706231 (best action=73)
#
# 0135-th step: f(x) = 3.656655 (action=0)
#    current best f(x) = 4.706231 (best action=73)
#
# 0136-th step: f(x) = 2.433231 (action=128)
#    current best f(x) = 4.706231 (best action=73)
#
# 0137-th step: f(x) = 4.725240 (action=247)
#    current best f(x) = 4.725240 (best action=247)
#
# 0138-th step: f(x) = 4.682727 (action=479)
#    current best f(x) = 4.725240 (best action=247)
#
# 0139-th step: f(x) = 3.950354 (action=48)
#    current best f(x) = 4.725240 (best action=247)
#
# 0140-th step: f(x) = 3.761592 (action=36)
#    current best f(x) = 4.725240 (best action=247)
#
# 0141-th step: f(x) = 4.067988 (action=448)
#    current best f(x) = 4.725240 (best action=247)
#
# 0142-th step: f(x) = 3.264902 (action=355)
#    current best f(x) = 4.725240 (best action=247)
#
# 0143-th step: f(x) = 3.071644 (action=446)
#    current best f(x) = 4.725240 (best action=247)
#
# 0144-th step: f(x) = 3.408732 (action=120)
#    current best f(x) = 4.725240 (best action=247)
#
# 0145-th step: f(x) = 2.301847 (action=227)
#    current best f(x) = 4.725240 (best action=247)
#
# 0146-th step: f(x) = 2.305546 (action=398)
#    current best f(x) = 4.725240 (best action=247)
#
# 0147-th step: f(x) = 3.367598 (action=377)
#    current best f(x) = 4.725240 (best action=247)
#
# 0148-th step: f(x) = 3.009214 (action=129)
#    current best f(x) = 4.725240 (best action=247)
#
# 0149-th step: f(x) = 2.721873 (action=90)
#    current best f(x) = 4.725240 (best action=247)
#
# 0150-th step: f(x) = 3.979143 (action=107)
#    current best f(x) = 4.725240 (best action=247)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 101.05762763105314
# 50-th epoch, marginal likelihood 100.55994931022707
# 100-th epoch, marginal likelihood 100.26686094805999
# 150-th epoch, marginal likelihood 100.04255705454055
# 200-th epoch, marginal likelihood 99.83866754651491
# 250-th epoch, marginal likelihood 99.6554451156412
# 300-th epoch, marginal likelihood 99.57804370670637
# 350-th epoch, marginal likelihood 99.47809177427014
# 400-th epoch, marginal likelihood 99.3615301594439
# 450-th epoch, marginal likelihood 99.34283960396536
# 500-th epoch, marginal likelihood 99.21205447355914
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.14576997]
#  scale  =  0.24695671077568043
#  scale2 =  0.06098761699714308
#
#
# 0151-th step: f(x) = 3.298290 (action=372)
#    current best f(x) = 4.725240 (best action=247)
#
# 0152-th step: f(x) = 2.244324 (action=352)
#    current best f(x) = 4.725240 (best action=247)
#
# 0153-th step: f(x) = 2.326354 (action=400)
#    current best f(x) = 4.725240 (best action=247)
#
# 0154-th step: f(x) = 2.750888 (action=472)
#    current best f(x) = 4.725240 (best action=247)
#
# 0155-th step: f(x) = 4.107620 (action=223)
#    current best f(x) = 4.725240 (best action=247)
#
# 0156-th step: f(x) = 3.824264 (action=164)
#    current best f(x) = 4.725240 (best action=247)
#
# 0157-th step: f(x) = 3.901682 (action=462)
#    current best f(x) = 4.725240 (best action=247)
#
# 0158-th step: f(x) = 3.495000 (action=39)
#    current best f(x) = 4.725240 (best action=247)
#
# 0159-th step: f(x) = 3.909203 (action=338)
#    current best f(x) = 4.725240 (best action=247)
#
# 0160-th step: f(x) = 2.693562 (action=337)
#    current best f(x) = 4.725240 (best action=247)
#
# 0161-th step: f(x) = 2.148002 (action=403)
#    current best f(x) = 4.725240 (best action=247)
#
# 0162-th step: f(x) = 2.789102 (action=93)
#    current best f(x) = 4.725240 (best action=247)
#
# 0163-th step: f(x) = 2.489719 (action=171)
#    current best f(x) = 4.725240 (best action=247)
#
# 0164-th step: f(x) = 2.086169 (action=364)
#    current best f(x) = 4.725240 (best action=247)
#
# 0165-th step: f(x) = 2.166267 (action=387)
#    current best f(x) = 4.725240 (best action=247)
#
# 0166-th step: f(x) = 2.198917 (action=347)
#    current best f(x) = 4.725240 (best action=247)
#
# 0167-th step: f(x) = 2.530396 (action=196)
#    current best f(x) = 4.725240 (best action=247)
#
# 0168-th step: f(x) = 4.288360 (action=366)
#    current best f(x) = 4.725240 (best action=247)
#
# 0169-th step: f(x) = 3.603806 (action=493)
#    current best f(x) = 4.725240 (best action=247)
#
# 0170-th step: f(x) = 3.400929 (action=35)
#    current best f(x) = 4.725240 (best action=247)
#
# 0171-th step: f(x) = 4.270924 (action=426)
#    current best f(x) = 4.725240 (best action=247)
#
# 0172-th step: f(x) = 2.410179 (action=105)
#    current best f(x) = 4.725240 (best action=247)
#
# 0173-th step: f(x) = 2.731978 (action=176)
#    current best f(x) = 4.725240 (best action=247)
#
# 0174-th step: f(x) = 3.286670 (action=77)
#    current best f(x) = 4.725240 (best action=247)
#
# 0175-th step: f(x) = 2.847173 (action=444)
#    current best f(x) = 4.725240 (best action=247)
#
# 0176-th step: f(x) = 2.453982 (action=109)
#    current best f(x) = 4.725240 (best action=247)
#
# 0177-th step: f(x) = 4.190259 (action=218)
#    current best f(x) = 4.725240 (best action=247)
#
# 0178-th step: f(x) = 2.784103 (action=438)
#    current best f(x) = 4.725240 (best action=247)
#
# 0179-th step: f(x) = 2.637429 (action=13)
#    current best f(x) = 4.725240 (best action=247)
#
# 0180-th step: f(x) = 2.446035 (action=330)
#    current best f(x) = 4.725240 (best action=247)
#
# 0181-th step: f(x) = 5.057711 (action=250)
#    current best f(x) = 5.057711 (best action=250)
#
# 0182-th step: f(x) = 2.971935 (action=112)
#    current best f(x) = 5.057711 (best action=250)
#
# 0183-th step: f(x) = 2.143090 (action=288)
#    current best f(x) = 5.057711 (best action=250)
#
# 0184-th step: f(x) = 3.097235 (action=229)
#    current best f(x) = 5.057711 (best action=250)
#
# 0185-th step: f(x) = 1.927450 (action=255)
#    current best f(x) = 5.057711 (best action=250)
#
# 0186-th step: f(x) = 2.511968 (action=319)
#    current best f(x) = 5.057711 (best action=250)
#
# 0187-th step: f(x) = 2.830068 (action=189)
#    current best f(x) = 5.057711 (best action=250)
#
# 0188-th step: f(x) = 2.227650 (action=363)
#    current best f(x) = 5.057711 (best action=250)
#
# 0189-th step: f(x) = 2.521384 (action=495)
#    current best f(x) = 5.057711 (best action=250)
#
# 0190-th step: f(x) = 1.925328 (action=386)
#    current best f(x) = 5.057711 (best action=250)
#
# 0191-th step: f(x) = 3.170518 (action=40)
#    current best f(x) = 5.057711 (best action=250)
#
# 0192-th step: f(x) = 3.209805 (action=484)
#    current best f(x) = 5.057711 (best action=250)
#
# 0193-th step: f(x) = 2.683243 (action=336)
#    current best f(x) = 5.057711 (best action=250)
#
# 0194-th step: f(x) = 2.418407 (action=485)
#    current best f(x) = 5.057711 (best action=250)
#
# 0195-th step: f(x) = 2.304067 (action=111)
#    current best f(x) = 5.057711 (best action=250)
#
# 0196-th step: f(x) = 4.287449 (action=182)
#    current best f(x) = 5.057711 (best action=250)
#
# 0197-th step: f(x) = 3.886743 (action=253)
#    current best f(x) = 5.057711 (best action=250)
#
# 0198-th step: f(x) = 3.312010 (action=242)
#    current best f(x) = 5.057711 (best action=250)
#
# 0199-th step: f(x) = 2.680294 (action=357)
#    current best f(x) = 5.057711 (best action=250)
#
# 0200-th step: f(x) = 3.837505 (action=281)
#    current best f(x) = 5.057711 (best action=250)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 174.12062226870069
# 50-th epoch, marginal likelihood 171.74873624929057
# 100-th epoch, marginal likelihood 170.80103568034656
# 150-th epoch, marginal likelihood 170.09390469418082
# 200-th epoch, marginal likelihood 169.68218279750542
# 250-th epoch, marginal likelihood 169.44428329709996
# 300-th epoch, marginal likelihood 169.38120529577165
# 350-th epoch, marginal likelihood 169.24605321746418
# 400-th epoch, marginal likelihood 169.31829252125368
# 450-th epoch, marginal likelihood 169.17905207880216
# 500-th epoch, marginal likelihood 169.06407194119163
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [7.41185435]
#  scale  =  0.7911510002068821
#  scale2 =  0.6259199051283499
#
#
# 0201-th step: f(x) = 3.864941 (action=185)
#    current best f(x) = 5.057711 (best action=250)
#
# 0202-th step: f(x) = 1.978139 (action=498)
#    current best f(x) = 5.057711 (best action=250)
#
# 0203-th step: f(x) = 2.793633 (action=475)
#    current best f(x) = 5.057711 (best action=250)
#
# 0204-th step: f(x) = 1.958722 (action=167)
#    current best f(x) = 5.057711 (best action=250)
#
# 0205-th step: f(x) = 2.735916 (action=159)
#    current best f(x) = 5.057711 (best action=250)
#
# 0206-th step: f(x) = 2.514247 (action=44)
#    current best f(x) = 5.057711 (best action=250)
#
# 0207-th step: f(x) = 3.001148 (action=4)
#    current best f(x) = 5.057711 (best action=250)
#
# 0208-th step: f(x) = 2.160947 (action=374)
#    current best f(x) = 5.057711 (best action=250)
#
# 0209-th step: f(x) = 3.908885 (action=118)
#    current best f(x) = 5.057711 (best action=250)
#
# 0210-th step: f(x) = 3.559743 (action=323)
#    current best f(x) = 5.057711 (best action=250)
#
# 0211-th step: f(x) = 2.445585 (action=402)
#    current best f(x) = 5.057711 (best action=250)
#
# 0212-th step: f(x) = 3.515651 (action=289)
#    current best f(x) = 5.057711 (best action=250)
#
# 0213-th step: f(x) = 2.104538 (action=21)
#    current best f(x) = 5.057711 (best action=250)
#
# 0214-th step: f(x) = 2.109923 (action=58)
#    current best f(x) = 5.057711 (best action=250)
#
# 0215-th step: f(x) = 1.941175 (action=42)
#    current best f(x) = 5.057711 (best action=250)
#
# 0216-th step: f(x) = 2.383186 (action=395)
#    current best f(x) = 5.057711 (best action=250)
#
# 0217-th step: f(x) = 2.557924 (action=260)
#    current best f(x) = 5.057711 (best action=250)
#
# 0218-th step: f(x) = 1.982911 (action=320)
#    current best f(x) = 5.057711 (best action=250)
#
# 0219-th step: f(x) = 5.145519 (action=85)
#    current best f(x) = 5.145519 (best action=85)
#
# 0220-th step: f(x) = 2.218906 (action=262)
#    current best f(x) = 5.145519 (best action=85)
#
# 0221-th step: f(x) = 2.564279 (action=417)
#    current best f(x) = 5.145519 (best action=85)
#
# 0222-th step: f(x) = 2.710859 (action=179)
#    current best f(x) = 5.145519 (best action=85)
#
# 0223-th step: f(x) = 2.269876 (action=86)
#    current best f(x) = 5.145519 (best action=85)
#
# 0224-th step: f(x) = 3.095683 (action=130)
#    current best f(x) = 5.145519 (best action=85)
#
# 0225-th step: f(x) = 2.409400 (action=264)
#    current best f(x) = 5.145519 (best action=85)
#
# 0226-th step: f(x) = 2.015308 (action=283)
#    current best f(x) = 5.145519 (best action=85)
#
# 0227-th step: f(x) = 3.168273 (action=295)
#    current best f(x) = 5.145519 (best action=85)
#
# 0228-th step: f(x) = 2.616944 (action=122)
#    current best f(x) = 5.145519 (best action=85)
#
# 0229-th step: f(x) = 2.797378 (action=362)
#    current best f(x) = 5.145519 (best action=85)
#
# 0230-th step: f(x) = 3.112139 (action=311)
#    current best f(x) = 5.145519 (best action=85)
#
# 0231-th step: f(x) = 3.835379 (action=219)
#    current best f(x) = 5.145519 (best action=85)
#
# 0232-th step: f(x) = 3.822884 (action=303)
#    current best f(x) = 5.145519 (best action=85)
#
# 0233-th step: f(x) = 2.996586 (action=69)
#    current best f(x) = 5.145519 (best action=85)
#
# 0234-th step: f(x) = 2.352993 (action=210)
#    current best f(x) = 5.145519 (best action=85)
#
# 0235-th step: f(x) = 3.373301 (action=140)
#    current best f(x) = 5.145519 (best action=85)
#
# 0236-th step: f(x) = 2.991167 (action=139)
#    current best f(x) = 5.145519 (best action=85)
#
# 0237-th step: f(x) = 3.310716 (action=261)
#    current best f(x) = 5.145519 (best action=85)
#
# 0238-th step: f(x) = 2.943834 (action=265)
#    current best f(x) = 5.145519 (best action=85)
#
# 0239-th step: f(x) = 2.535317 (action=269)
#    current best f(x) = 5.145519 (best action=85)
#
# 0240-th step: f(x) = 2.023847 (action=435)
#    current best f(x) = 5.145519 (best action=85)
#
# 0241-th step: f(x) = 2.006214 (action=302)
#    current best f(x) = 5.145519 (best action=85)
#
# 0242-th step: f(x) = 2.269903 (action=106)
#    current best f(x) = 5.145519 (best action=85)
#
# 0243-th step: f(x) = 2.246948 (action=63)
#    current best f(x) = 5.145519 (best action=85)
#
# 0244-th step: f(x) = 2.047329 (action=401)
#    current best f(x) = 5.145519 (best action=85)
#
# 0245-th step: f(x) = 2.492086 (action=359)
#    current best f(x) = 5.145519 (best action=85)
#
# 0246-th step: f(x) = 2.359282 (action=428)
#    current best f(x) = 5.145519 (best action=85)
#
# 0247-th step: f(x) = 2.662879 (action=459)
#    current best f(x) = 5.145519 (best action=85)
#
# 0248-th step: f(x) = 2.785436 (action=28)
#    current best f(x) = 5.145519 (best action=85)
#
# 0249-th step: f(x) = 3.877561 (action=68)
#    current best f(x) = 5.145519 (best action=85)
#
# 0250-th step: f(x) = 2.543388 (action=350)
#    current best f(x) = 5.145519 (best action=85)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 233.1358550026587
# 50-th epoch, marginal likelihood 223.46576648694736
# 100-th epoch, marginal likelihood 222.44765693409437
# 150-th epoch, marginal likelihood 221.8992255746593
# 200-th epoch, marginal likelihood 221.5783178026594
# 250-th epoch, marginal likelihood 221.26420255613385
# 300-th epoch, marginal likelihood 221.08599998721382
# 350-th epoch, marginal likelihood 221.03092155793513
# 400-th epoch, marginal likelihood 220.91608738544798
# 450-th epoch, marginal likelihood 220.94759604692854
# 500-th epoch, marginal likelihood 221.19625993921778
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [7.25553221]
#  scale  =  0.8765856066378785
#  scale2 =  0.7684023257646976
#
#
# 0251-th step: f(x) = 2.399030 (action=351)
#    current best f(x) = 5.145519 (best action=85)
#
# 0252-th step: f(x) = 2.476858 (action=124)
#    current best f(x) = 5.145519 (best action=85)
#
# 0253-th step: f(x) = 1.922565 (action=3)
#    current best f(x) = 5.145519 (best action=85)
#
# 0254-th step: f(x) = 3.709738 (action=103)
#    current best f(x) = 5.145519 (best action=85)
#
# 0255-th step: f(x) = 3.170505 (action=169)
#    current best f(x) = 5.145519 (best action=85)
#
# 0256-th step: f(x) = 3.043263 (action=70)
#    current best f(x) = 5.145519 (best action=85)
#
# 0257-th step: f(x) = 2.543780 (action=243)
#    current best f(x) = 5.145519 (best action=85)
#
# 0258-th step: f(x) = 2.549730 (action=184)
#    current best f(x) = 5.145519 (best action=85)
#
# 0259-th step: f(x) = 1.999945 (action=480)
#    current best f(x) = 5.145519 (best action=85)
#
# 0260-th step: f(x) = 2.228637 (action=335)
#    current best f(x) = 5.145519 (best action=85)
#
# 0261-th step: f(x) = 4.315861 (action=81)
#    current best f(x) = 5.145519 (best action=85)
#
# 0262-th step: f(x) = 2.347726 (action=466)
#    current best f(x) = 5.145519 (best action=85)
#
# 0263-th step: f(x) = 2.755235 (action=102)
#    current best f(x) = 5.145519 (best action=85)
#
# 0264-th step: f(x) = 2.935765 (action=158)
#    current best f(x) = 5.145519 (best action=85)
#
# 0265-th step: f(x) = 2.705363 (action=312)
#    current best f(x) = 5.145519 (best action=85)
#
# 0266-th step: f(x) = 2.399007 (action=467)
#    current best f(x) = 5.145519 (best action=85)
#
# 0267-th step: f(x) = 3.541771 (action=47)
#    current best f(x) = 5.145519 (best action=85)
#
# 0268-th step: f(x) = 4.040700 (action=190)
#    current best f(x) = 5.145519 (best action=85)
#
# 0269-th step: f(x) = 3.061915 (action=405)
#    current best f(x) = 5.145519 (best action=85)
#
# 0270-th step: f(x) = 2.324978 (action=5)
#    current best f(x) = 5.145519 (best action=85)
#
# 0271-th step: f(x) = 2.711763 (action=436)
#    current best f(x) = 5.145519 (best action=85)
#
# 0272-th step: f(x) = 2.001193 (action=214)
#    current best f(x) = 5.145519 (best action=85)
#
# 0273-th step: f(x) = 1.981872 (action=322)
#    current best f(x) = 5.145519 (best action=85)
#
# 0274-th step: f(x) = 3.945998 (action=268)
#    current best f(x) = 5.145519 (best action=85)
#
# 0275-th step: f(x) = 3.548726 (action=97)
#    current best f(x) = 5.145519 (best action=85)
#
# 0276-th step: f(x) = 3.052043 (action=195)
#    current best f(x) = 5.145519 (best action=85)
#
# 0277-th step: f(x) = 2.390952 (action=381)
#    current best f(x) = 5.145519 (best action=85)
#
# 0278-th step: f(x) = 2.638413 (action=285)
#    current best f(x) = 5.145519 (best action=85)
#
# 0279-th step: f(x) = 2.680170 (action=461)
#    current best f(x) = 5.145519 (best action=85)
#
# 0280-th step: f(x) = 2.272421 (action=18)
#    current best f(x) = 5.145519 (best action=85)
#
# 0281-th step: f(x) = 1.986916 (action=94)
#    current best f(x) = 5.145519 (best action=85)
#
# 0282-th step: f(x) = 2.207274 (action=208)
#    current best f(x) = 5.145519 (best action=85)
#
# 0283-th step: f(x) = 3.571466 (action=117)
#    current best f(x) = 5.145519 (best action=85)
#
# 0284-th step: f(x) = 2.047624 (action=100)
#    current best f(x) = 5.145519 (best action=85)
#
# 0285-th step: f(x) = 2.484639 (action=80)
#    current best f(x) = 5.145519 (best action=85)
#
# 0286-th step: f(x) = 2.866999 (action=445)
#    current best f(x) = 5.145519 (best action=85)
#
# 0287-th step: f(x) = 2.454971 (action=74)
#    current best f(x) = 5.145519 (best action=85)
#
# 0288-th step: f(x) = 2.471051 (action=1)
#    current best f(x) = 5.145519 (best action=85)
#
# 0289-th step: f(x) = 3.300166 (action=180)
#    current best f(x) = 5.145519 (best action=85)
#
# 0290-th step: f(x) = 3.825027 (action=306)
#    current best f(x) = 5.145519 (best action=85)
#
# 0291-th step: f(x) = 2.143475 (action=96)
#    current best f(x) = 5.145519 (best action=85)
#
# 0292-th step: f(x) = 3.976796 (action=173)
#    current best f(x) = 5.145519 (best action=85)
#
# 0293-th step: f(x) = 2.090616 (action=465)
#    current best f(x) = 5.145519 (best action=85)
#
# 0294-th step: f(x) = 2.637765 (action=458)
#    current best f(x) = 5.145519 (best action=85)
#
# 0295-th step: f(x) = 3.222111 (action=393)
#    current best f(x) = 5.145519 (best action=85)
#
# 0296-th step: f(x) = 3.339624 (action=221)
#    current best f(x) = 5.145519 (best action=85)
#
# 0297-th step: f(x) = 2.788362 (action=270)
#    current best f(x) = 5.145519 (best action=85)
#
# 0298-th step: f(x) = 2.430162 (action=198)
#    current best f(x) = 5.145519 (best action=85)
#
# 0299-th step: f(x) = 2.812253 (action=491)
#    current best f(x) = 5.145519 (best action=85)
#
# 0300-th step: f(x) = 3.026150 (action=152)
#    current best f(x) = 5.145519 (best action=85)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 293.84602010408435
# 50-th epoch, marginal likelihood 275.7810192097015
# 100-th epoch, marginal likelihood 272.85772920700504
# 150-th epoch, marginal likelihood 271.3603501694955
# 200-th epoch, marginal likelihood 270.57467569473215
# 250-th epoch, marginal likelihood 270.42510436859425
# 300-th epoch, marginal likelihood 270.2699680100476
# 350-th epoch, marginal likelihood 270.4191614923252
# 400-th epoch, marginal likelihood 270.5714187390791
# 450-th epoch, marginal likelihood 270.54004940873483
# 500-th epoch, marginal likelihood 270.33718537392133
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.48701296]
#  scale  =  0.8563835254716043
#  scale2 =  0.733392742699174
#
#
# 0301-th step: f(x) = 2.230777 (action=212)
#    current best f(x) = 5.145519 (best action=85)
#
# 0302-th step: f(x) = 2.367384 (action=175)
#    current best f(x) = 5.145519 (best action=85)
#
# 0303-th step: f(x) = 2.030449 (action=278)
#    current best f(x) = 5.145519 (best action=85)
#
# 0304-th step: f(x) = 2.769902 (action=305)
#    current best f(x) = 5.145519 (best action=85)
#
# 0305-th step: f(x) = 2.583695 (action=376)
#    current best f(x) = 5.145519 (best action=85)
#
# 0306-th step: f(x) = 2.476953 (action=275)
#    current best f(x) = 5.145519 (best action=85)
#
# 0307-th step: f(x) = 2.723290 (action=89)
#    current best f(x) = 5.145519 (best action=85)
#
# 0308-th step: f(x) = 3.597137 (action=257)
#    current best f(x) = 5.145519 (best action=85)
#
# 0309-th step: f(x) = 2.572811 (action=310)
#    current best f(x) = 5.145519 (best action=85)
#
# 0310-th step: f(x) = 2.043189 (action=141)
#    current best f(x) = 5.145519 (best action=85)
#
# 0311-th step: f(x) = 2.604621 (action=248)
#    current best f(x) = 5.145519 (best action=85)
#
# 0312-th step: f(x) = 1.939002 (action=181)
#    current best f(x) = 5.145519 (best action=85)
#
# 0313-th step: f(x) = 2.730672 (action=427)
#    current best f(x) = 5.145519 (best action=85)
#
# 0314-th step: f(x) = 2.913231 (action=38)
#    current best f(x) = 5.145519 (best action=85)
#
# 0315-th step: f(x) = 2.047079 (action=174)
#    current best f(x) = 5.145519 (best action=85)
#
# 0316-th step: f(x) = 3.426586 (action=20)
#    current best f(x) = 5.145519 (best action=85)
#
# 0317-th step: f(x) = 2.576505 (action=32)
#    current best f(x) = 5.145519 (best action=85)
#
# 0318-th step: f(x) = 2.505775 (action=317)
#    current best f(x) = 5.145519 (best action=85)
#
# 0319-th step: f(x) = 3.945812 (action=369)
#    current best f(x) = 5.145519 (best action=85)
#
# 0320-th step: f(x) = 2.237687 (action=193)
#    current best f(x) = 5.145519 (best action=85)
#
# 0321-th step: f(x) = 2.317952 (action=10)
#    current best f(x) = 5.145519 (best action=85)
#
# 0322-th step: f(x) = 2.285828 (action=455)
#    current best f(x) = 5.145519 (best action=85)
#
# 0323-th step: f(x) = 2.377664 (action=453)
#    current best f(x) = 5.145519 (best action=85)
#
# 0324-th step: f(x) = 1.971275 (action=204)
#    current best f(x) = 5.145519 (best action=85)
#
# 0325-th step: f(x) = 2.608643 (action=454)
#    current best f(x) = 5.145519 (best action=85)
#
# 0326-th step: f(x) = 2.397857 (action=411)
#    current best f(x) = 5.145519 (best action=85)
#
# 0327-th step: f(x) = 2.382028 (action=414)
#    current best f(x) = 5.145519 (best action=85)
#
# 0328-th step: f(x) = 2.354839 (action=72)
#    current best f(x) = 5.145519 (best action=85)
#
# 0329-th step: f(x) = 2.091194 (action=349)
#    current best f(x) = 5.145519 (best action=85)
#
# 0330-th step: f(x) = 2.333648 (action=119)
#    current best f(x) = 5.145519 (best action=85)
#
# 0331-th step: f(x) = 2.370950 (action=43)
#    current best f(x) = 5.145519 (best action=85)
#
# 0332-th step: f(x) = 3.176120 (action=134)
#    current best f(x) = 5.145519 (best action=85)
#
# 0333-th step: f(x) = 2.344133 (action=136)
#    current best f(x) = 5.145519 (best action=85)
#
# 0334-th step: f(x) = 2.729645 (action=368)
#    current best f(x) = 5.145519 (best action=85)
#
# 0335-th step: f(x) = 2.434968 (action=449)
#    current best f(x) = 5.145519 (best action=85)
#
# 0336-th step: f(x) = 2.048103 (action=98)
#    current best f(x) = 5.145519 (best action=85)
#
# 0337-th step: f(x) = 2.317962 (action=460)
#    current best f(x) = 5.145519 (best action=85)
#
# 0338-th step: f(x) = 2.236429 (action=254)
#    current best f(x) = 5.145519 (best action=85)
#
# 0339-th step: f(x) = 2.293619 (action=53)
#    current best f(x) = 5.145519 (best action=85)
#
# 0340-th step: f(x) = 1.931224 (action=66)
#    current best f(x) = 5.145519 (best action=85)
#
# 0341-th step: f(x) = 2.130986 (action=12)
#    current best f(x) = 5.145519 (best action=85)
#
# 0342-th step: f(x) = 2.092953 (action=137)
#    current best f(x) = 5.145519 (best action=85)
#
# 0343-th step: f(x) = 3.027862 (action=11)
#    current best f(x) = 5.145519 (best action=85)
#
# 0344-th step: f(x) = 2.529742 (action=276)
#    current best f(x) = 5.145519 (best action=85)
#
# 0345-th step: f(x) = 2.215422 (action=399)
#    current best f(x) = 5.145519 (best action=85)
#
# 0346-th step: f(x) = 2.343225 (action=121)
#    current best f(x) = 5.145519 (best action=85)
#
# 0347-th step: f(x) = 2.963136 (action=277)
#    current best f(x) = 5.145519 (best action=85)
#
# 0348-th step: f(x) = 2.642557 (action=297)
#    current best f(x) = 5.145519 (best action=85)
#
# 0349-th step: f(x) = 2.104293 (action=280)
#    current best f(x) = 5.145519 (best action=85)
#
# 0350-th step: f(x) = 2.136561 (action=348)
#    current best f(x) = 5.145519 (best action=85)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 321.57553326386596
# 50-th epoch, marginal likelihood 301.3111485803154
# 100-th epoch, marginal likelihood 298.81276216992046
# 150-th epoch, marginal likelihood 297.8619301226421
# 200-th epoch, marginal likelihood 297.74797197997316
# 250-th epoch, marginal likelihood 298.4068136799459
# 300-th epoch, marginal likelihood 298.9662056611574
# 350-th epoch, marginal likelihood 299.0130468573432
# 400-th epoch, marginal likelihood 299.0170245733884
# 450-th epoch, marginal likelihood 298.8115250363661
# 500-th epoch, marginal likelihood 298.7554163758048
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [5.82598615]
#  scale  =  0.817060314210687
#  scale2 =  0.6675875570580666
#
#
# 0351-th step: f(x) = 2.180172 (action=456)
#    current best f(x) = 5.145519 (best action=85)
#
# 0352-th step: f(x) = 2.912351 (action=101)
#    current best f(x) = 5.145519 (best action=85)
#
# 0353-th step: f(x) = 2.592288 (action=41)
#    current best f(x) = 5.145519 (best action=85)
#
# 0354-th step: f(x) = 2.688538 (action=431)
#    current best f(x) = 5.145519 (best action=85)
#
# 0355-th step: f(x) = 1.977904 (action=451)
#    current best f(x) = 5.145519 (best action=85)
#
# 0356-th step: f(x) = 2.767693 (action=450)
#    current best f(x) = 5.145519 (best action=85)
#
# 0357-th step: f(x) = 2.507806 (action=153)
#    current best f(x) = 5.145519 (best action=85)
#
# 0358-th step: f(x) = 2.563363 (action=385)
#    current best f(x) = 5.145519 (best action=85)
#
# 0359-th step: f(x) = 2.086933 (action=327)
#    current best f(x) = 5.145519 (best action=85)
#
# 0360-th step: f(x) = 1.975747 (action=406)
#    current best f(x) = 5.145519 (best action=85)
#
# 0361-th step: f(x) = 2.843266 (action=478)
#    current best f(x) = 5.145519 (best action=85)
#
# 0362-th step: f(x) = 2.181766 (action=410)
#    current best f(x) = 5.145519 (best action=85)
#
# 0363-th step: f(x) = 2.307499 (action=439)
#    current best f(x) = 5.145519 (best action=85)
#
# 0364-th step: f(x) = 2.353441 (action=172)
#    current best f(x) = 5.145519 (best action=85)
#
# 0365-th step: f(x) = 2.129819 (action=394)
#    current best f(x) = 5.145519 (best action=85)
#
# 0366-th step: f(x) = 2.167062 (action=2)
#    current best f(x) = 5.145519 (best action=85)
#
# 0367-th step: f(x) = 2.205723 (action=233)
#    current best f(x) = 5.145519 (best action=85)
#
# 0368-th step: f(x) = 2.253737 (action=477)
#    current best f(x) = 5.145519 (best action=85)
#
# 0369-th step: f(x) = 2.595343 (action=135)
#    current best f(x) = 5.145519 (best action=85)
#
# 0370-th step: f(x) = 1.971005 (action=225)
#    current best f(x) = 5.145519 (best action=85)
#
# 0371-th step: f(x) = 2.645421 (action=434)
#    current best f(x) = 5.145519 (best action=85)
#
# 0372-th step: f(x) = 2.269370 (action=432)
#    current best f(x) = 5.145519 (best action=85)
#
# 0373-th step: f(x) = 2.605861 (action=430)
#    current best f(x) = 5.145519 (best action=85)
#
# 0374-th step: f(x) = 2.336159 (action=31)
#    current best f(x) = 5.145519 (best action=85)
#
# 0375-th step: f(x) = 2.152891 (action=304)
#    current best f(x) = 5.145519 (best action=85)
#
# 0376-th step: f(x) = 2.852417 (action=217)
#    current best f(x) = 5.145519 (best action=85)
#
# 0377-th step: f(x) = 2.567850 (action=110)
#    current best f(x) = 5.145519 (best action=85)
#
# 0378-th step: f(x) = 2.544343 (action=114)
#    current best f(x) = 5.145519 (best action=85)
#
# 0379-th step: f(x) = 3.160574 (action=422)
#    current best f(x) = 5.145519 (best action=85)
#
# 0380-th step: f(x) = 2.502291 (action=62)
#    current best f(x) = 5.145519 (best action=85)
#
# 0381-th step: f(x) = 2.542476 (action=37)
#    current best f(x) = 5.145519 (best action=85)
#
# 0382-th step: f(x) = 2.104863 (action=273)
#    current best f(x) = 5.145519 (best action=85)
#
# 0383-th step: f(x) = 2.666988 (action=433)
#    current best f(x) = 5.145519 (best action=85)
#
# 0384-th step: f(x) = 2.987134 (action=8)
#    current best f(x) = 5.145519 (best action=85)
#
# 0385-th step: f(x) = 2.759216 (action=473)
#    current best f(x) = 5.145519 (best action=85)
#
# 0386-th step: f(x) = 2.355067 (action=282)
#    current best f(x) = 5.145519 (best action=85)
#
# 0387-th step: f(x) = 2.527790 (action=440)
#    current best f(x) = 5.145519 (best action=85)
#
# 0388-th step: f(x) = 2.482478 (action=318)
#    current best f(x) = 5.145519 (best action=85)
#
# 0389-th step: f(x) = 2.749094 (action=202)
#    current best f(x) = 5.145519 (best action=85)
#
# 0390-th step: f(x) = 2.066790 (action=379)
#    current best f(x) = 5.145519 (best action=85)
#
# 0391-th step: f(x) = 2.488536 (action=142)
#    current best f(x) = 5.145519 (best action=85)
#
# 0392-th step: f(x) = 3.256902 (action=150)
#    current best f(x) = 5.145519 (best action=85)
#
# 0393-th step: f(x) = 2.412960 (action=421)
#    current best f(x) = 5.145519 (best action=85)
#
# 0394-th step: f(x) = 2.504622 (action=443)
#    current best f(x) = 5.145519 (best action=85)
#
# 0395-th step: f(x) = 3.555563 (action=183)
#    current best f(x) = 5.145519 (best action=85)
#
# 0396-th step: f(x) = 2.751306 (action=178)
#    current best f(x) = 5.145519 (best action=85)
#
# 0397-th step: f(x) = 2.555594 (action=429)
#    current best f(x) = 5.145519 (best action=85)
#
# 0398-th step: f(x) = 3.237144 (action=290)
#    current best f(x) = 5.145519 (best action=85)
#
# 0399-th step: f(x) = 2.187679 (action=321)
#    current best f(x) = 5.145519 (best action=85)
#
# 0400-th step: f(x) = 2.501522 (action=415)
#    current best f(x) = 5.145519 (best action=85)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 352.5980247185984
# 50-th epoch, marginal likelihood 329.29665478698416
# 100-th epoch, marginal likelihood 326.3272617476474
# 150-th epoch, marginal likelihood 325.70120089239657
# 200-th epoch, marginal likelihood 325.9256057169398
# 250-th epoch, marginal likelihood 326.3985941951683
# 300-th epoch, marginal likelihood 326.7039869851153
# 350-th epoch, marginal likelihood 326.5990517585967
# 400-th epoch, marginal likelihood 326.5874665491933
# 450-th epoch, marginal likelihood 326.8071999956046
# 500-th epoch, marginal likelihood 326.92423727055683
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [5.70364588]
#  scale  =  0.7866246429889877
#  scale2 =  0.6187783289575524
#
#
# 0401-th step: f(x) = 1.926639 (action=332)
#    current best f(x) = 5.145519 (best action=85)
#
# 0402-th step: f(x) = 3.327093 (action=191)
#    current best f(x) = 5.145519 (best action=85)
#
# 0403-th step: f(x) = 2.253350 (action=447)
#    current best f(x) = 5.145519 (best action=85)
#
# 0404-th step: f(x) = 2.010560 (action=496)
#    current best f(x) = 5.145519 (best action=85)
#
# 0405-th step: f(x) = 2.155686 (action=344)
#    current best f(x) = 5.145519 (best action=85)
#
# 0406-th step: f(x) = 2.886025 (action=9)
#    current best f(x) = 5.145519 (best action=85)
#
# 0407-th step: f(x) = 2.150653 (action=222)
#    current best f(x) = 5.145519 (best action=85)
#
# 0408-th step: f(x) = 3.004177 (action=25)
#    current best f(x) = 5.145519 (best action=85)
#
# 0409-th step: f(x) = 2.433500 (action=339)
#    current best f(x) = 5.145519 (best action=85)
#
# 0410-th step: f(x) = 3.570696 (action=82)
#    current best f(x) = 5.145519 (best action=85)
#
# 0411-th step: f(x) = 2.164168 (action=211)
#    current best f(x) = 5.145519 (best action=85)
#
# 0412-th step: f(x) = 2.357116 (action=441)
#    current best f(x) = 5.145519 (best action=85)
#
# 0413-th step: f(x) = 2.417828 (action=494)
#    current best f(x) = 5.145519 (best action=85)
#
# 0414-th step: f(x) = 2.120682 (action=27)
#    current best f(x) = 5.145519 (best action=85)
#
# 0415-th step: f(x) = 2.428719 (action=206)
#    current best f(x) = 5.145519 (best action=85)
#
# 0416-th step: f(x) = 1.996939 (action=60)
#    current best f(x) = 5.145519 (best action=85)
#
# 0417-th step: f(x) = 2.029610 (action=391)
#    current best f(x) = 5.145519 (best action=85)
#
# 0418-th step: f(x) = 2.080482 (action=390)
#    current best f(x) = 5.145519 (best action=85)
#
# 0419-th step: f(x) = 1.925936 (action=23)
#    current best f(x) = 5.145519 (best action=85)
#
# 0420-th step: f(x) = 1.945712 (action=116)
#    current best f(x) = 5.145519 (best action=85)
#
# 0421-th step: f(x) = 2.358697 (action=263)
#    current best f(x) = 5.145519 (best action=85)
#
# 0422-th step: f(x) = 2.449975 (action=84)
#    current best f(x) = 5.145519 (best action=85)
#
# 0423-th step: f(x) = 2.092934 (action=163)
#    current best f(x) = 5.145519 (best action=85)
#
# 0424-th step: f(x) = 2.039610 (action=132)
#    current best f(x) = 5.145519 (best action=85)
#
# 0425-th step: f(x) = 3.281901 (action=309)
#    current best f(x) = 5.145519 (best action=85)
#
# 0426-th step: f(x) = 2.318994 (action=224)
#    current best f(x) = 5.145519 (best action=85)
#
# 0427-th step: f(x) = 3.936592 (action=148)
#    current best f(x) = 5.145519 (best action=85)
#
# 0428-th step: f(x) = 2.305563 (action=104)
#    current best f(x) = 5.145519 (best action=85)
#
# 0429-th step: f(x) = 1.975886 (action=113)
#    current best f(x) = 5.145519 (best action=85)
#
# 0430-th step: f(x) = 1.968002 (action=160)
#    current best f(x) = 5.145519 (best action=85)
#
# 0431-th step: f(x) = 3.809868 (action=71)
#    current best f(x) = 5.145519 (best action=85)
#
# 0432-th step: f(x) = 2.125666 (action=50)
#    current best f(x) = 5.145519 (best action=85)
#
# 0433-th step: f(x) = 2.314462 (action=200)
#    current best f(x) = 5.145519 (best action=85)
#
# 0434-th step: f(x) = 2.570621 (action=14)
#    current best f(x) = 5.145519 (best action=85)
#
# 0435-th step: f(x) = 2.228130 (action=371)
#    current best f(x) = 5.145519 (best action=85)
#
# 0436-th step: f(x) = 2.526117 (action=149)
#    current best f(x) = 5.145519 (best action=85)
#
# 0437-th step: f(x) = 2.544702 (action=314)
#    current best f(x) = 5.145519 (best action=85)
#
# 0438-th step: f(x) = 2.262099 (action=416)
#    current best f(x) = 5.145519 (best action=85)
#
# 0439-th step: f(x) = 3.202611 (action=329)
#    current best f(x) = 5.145519 (best action=85)
#
# 0440-th step: f(x) = 2.604530 (action=341)
#    current best f(x) = 5.145519 (best action=85)
#
# 0441-th step: f(x) = 2.166818 (action=126)
#    current best f(x) = 5.145519 (best action=85)
#
# 0442-th step: f(x) = 2.663614 (action=52)
#    current best f(x) = 5.145519 (best action=85)
#
# 0443-th step: f(x) = 2.100603 (action=353)
#    current best f(x) = 5.145519 (best action=85)
#
# 0444-th step: f(x) = 2.238520 (action=266)
#    current best f(x) = 5.145519 (best action=85)
#
# 0445-th step: f(x) = 2.005578 (action=87)
#    current best f(x) = 5.145519 (best action=85)
#
# 0446-th step: f(x) = 2.914363 (action=145)
#    current best f(x) = 5.145519 (best action=85)
#
# 0447-th step: f(x) = 1.988187 (action=365)
#    current best f(x) = 5.145519 (best action=85)
#
# 0448-th step: f(x) = 2.753838 (action=235)
#    current best f(x) = 5.145519 (best action=85)
#
# 0449-th step: f(x) = 2.338854 (action=61)
#    current best f(x) = 5.145519 (best action=85)
#
# 0450-th step: f(x) = 2.482699 (action=234)
#    current best f(x) = 5.145519 (best action=85)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 409.4762546396574
# 50-th epoch, marginal likelihood 373.55983064418905
# 100-th epoch, marginal likelihood 368.28728035603353
# 150-th epoch, marginal likelihood 367.310785005473
# 200-th epoch, marginal likelihood 367.6637675224098
# 250-th epoch, marginal likelihood 368.1443499845447
# 300-th epoch, marginal likelihood 368.40712682512935
# 350-th epoch, marginal likelihood 368.3363221570163
# 400-th epoch, marginal likelihood 368.01524340971923
# 450-th epoch, marginal likelihood 367.96169167404963
# 500-th epoch, marginal likelihood 368.2289044229195
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [5.52693381]
#  scale  =  0.7521826531152123
#  scale2 =  0.5657787436474397
#
#
# 0451-th step: f(x) = 2.250752 (action=251)
#    current best f(x) = 5.145519 (best action=85)
#
# 0452-th step: f(x) = 2.511826 (action=92)
#    current best f(x) = 5.145519 (best action=85)
#
# 0453-th step: f(x) = 2.212961 (action=76)
#    current best f(x) = 5.145519 (best action=85)
#
# 0454-th step: f(x) = 2.315783 (action=54)
#    current best f(x) = 5.145519 (best action=85)
#
# 0455-th step: f(x) = 2.004677 (action=396)
#    current best f(x) = 5.145519 (best action=85)
#
# 0456-th step: f(x) = 3.956854 (action=49)
#    current best f(x) = 5.145519 (best action=85)
#
# 0457-th step: f(x) = 2.048927 (action=186)
#    current best f(x) = 5.145519 (best action=85)
#
# 0458-th step: f(x) = 2.006099 (action=483)
#    current best f(x) = 5.145519 (best action=85)
#
# 0459-th step: f(x) = 2.797998 (action=108)
#    current best f(x) = 5.145519 (best action=85)
#
# 0460-th step: f(x) = 2.741011 (action=468)
#    current best f(x) = 5.145519 (best action=85)
#
# 0461-th step: f(x) = 2.338626 (action=78)
#    current best f(x) = 5.145519 (best action=85)
#
# 0462-th step: f(x) = 2.277437 (action=146)
#    current best f(x) = 5.145519 (best action=85)
#
# 0463-th step: f(x) = 1.981223 (action=354)
#    current best f(x) = 5.145519 (best action=85)
#
# 0464-th step: f(x) = 1.981919 (action=75)
#    current best f(x) = 5.145519 (best action=85)
#
# 0465-th step: f(x) = 2.038031 (action=299)
#    current best f(x) = 5.145519 (best action=85)
#
# 0466-th step: f(x) = 1.971833 (action=356)
#    current best f(x) = 5.145519 (best action=85)
#
# 0467-th step: f(x) = 1.990225 (action=91)
#    current best f(x) = 5.145519 (best action=85)
#
# 0468-th step: f(x) = 1.960779 (action=19)
#    current best f(x) = 5.145519 (best action=85)
#
# 0469-th step: f(x) = 2.429008 (action=88)
#    current best f(x) = 5.145519 (best action=85)
#
# 0470-th step: f(x) = 2.093679 (action=384)
#    current best f(x) = 5.145519 (best action=85)
#
# 0471-th step: f(x) = 2.341118 (action=373)
#    current best f(x) = 5.145519 (best action=85)
#
# 0472-th step: f(x) = 2.468714 (action=423)
#    current best f(x) = 5.145519 (best action=85)
#
# 0473-th step: f(x) = 2.617578 (action=397)
#    current best f(x) = 5.145519 (best action=85)
#
# 0474-th step: f(x) = 1.922734 (action=215)
#    current best f(x) = 5.145519 (best action=85)
#
# 0475-th step: f(x) = 2.133326 (action=30)
#    current best f(x) = 5.145519 (best action=85)
#
# 0476-th step: f(x) = 2.353872 (action=392)
#    current best f(x) = 5.145519 (best action=85)
#
# 0477-th step: f(x) = 1.978480 (action=237)
#    current best f(x) = 5.145519 (best action=85)
#
# 0478-th step: f(x) = 2.549729 (action=7)
#    current best f(x) = 5.145519 (best action=85)
#
# 0479-th step: f(x) = 2.153066 (action=56)
#    current best f(x) = 5.145519 (best action=85)
#
# 0480-th step: f(x) = 2.676548 (action=95)
#    current best f(x) = 5.145519 (best action=85)
#
# 0481-th step: f(x) = 2.157175 (action=192)
#    current best f(x) = 5.145519 (best action=85)
#
# 0482-th step: f(x) = 2.196917 (action=166)
#    current best f(x) = 5.145519 (best action=85)
#
# 0483-th step: f(x) = 2.247411 (action=325)
#    current best f(x) = 5.145519 (best action=85)
#
# 0484-th step: f(x) = 2.338016 (action=170)
#    current best f(x) = 5.145519 (best action=85)
#
# 0485-th step: f(x) = 1.996575 (action=291)
#    current best f(x) = 5.145519 (best action=85)
#
# 0486-th step: f(x) = 1.980514 (action=249)
#    current best f(x) = 5.145519 (best action=85)
#
# 0487-th step: f(x) = 1.984781 (action=404)
#    current best f(x) = 5.145519 (best action=85)
#
# 0488-th step: f(x) = 2.176872 (action=487)
#    current best f(x) = 5.145519 (best action=85)
#
# 0489-th step: f(x) = 2.033832 (action=144)
#    current best f(x) = 5.145519 (best action=85)
#
# 0490-th step: f(x) = 2.237073 (action=143)
#    current best f(x) = 5.145519 (best action=85)
#
# 0491-th step: f(x) = 2.039260 (action=389)
#    current best f(x) = 5.145519 (best action=85)
#
# 0492-th step: f(x) = 2.035394 (action=125)
#    current best f(x) = 5.145519 (best action=85)
#
# 0493-th step: f(x) = 2.500998 (action=360)
#    current best f(x) = 5.145519 (best action=85)
#
# 0494-th step: f(x) = 2.462729 (action=46)
#    current best f(x) = 5.145519 (best action=85)
#
# 0495-th step: f(x) = 2.651898 (action=457)
#    current best f(x) = 5.145519 (best action=85)
#
# 0496-th step: f(x) = 2.495852 (action=238)
#    current best f(x) = 5.145519 (best action=85)
#
# 0497-th step: f(x) = 2.457504 (action=258)
#    current best f(x) = 5.145519 (best action=85)
#
# 0498-th step: f(x) = 2.420364 (action=380)
#    current best f(x) = 5.145519 (best action=85)
#
# 0499-th step: f(x) = 2.091224 (action=497)
#    current best f(x) = 5.145519 (best action=85)
#
# 0500-th step: f(x) = 1.987644 (action=16)
#    current best f(x) = 5.145519 (best action=85)

# %%
COMBO_EI_Working_Capacity_unrelevant = COMBO(Data_unrelevant_features_Working_Capacity, 'EI')
# Out:
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 22.534308025707205
# 50-th epoch, marginal likelihood 6.161990523603947
# 100-th epoch, marginal likelihood -4.228448474831822
# 150-th epoch, marginal likelihood -11.032258789281855
# 200-th epoch, marginal likelihood -15.334852184358866
# 250-th epoch, marginal likelihood -17.860712897755818
# 300-th epoch, marginal likelihood -19.568793473947593
# 350-th epoch, marginal likelihood -20.90735978059798
# 400-th epoch, marginal likelihood -21.708358706694966
# 450-th epoch, marginal likelihood -22.26638217249598
# 500-th epoch, marginal likelihood -22.64482896230735
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.]
#  scale  =  1.0
#  scale2 =  1.0
#
#
# 0101-th step: f(x) = 3.222779 (action=197)
#    current best f(x) = 3.222779 (best action=197)
#
# 0102-th step: f(x) = 4.107620 (action=223)
#    current best f(x) = 4.107620 (best action=223)
#
# 0103-th step: f(x) = 2.750888 (action=472)
#    current best f(x) = 4.107620 (best action=223)
#
# 0104-th step: f(x) = 3.901682 (action=462)
#    current best f(x) = 4.107620 (best action=223)
#
# 0105-th step: f(x) = 3.495000 (action=39)
#    current best f(x) = 4.107620 (best action=223)
#
# 0106-th step: f(x) = 3.824264 (action=164)
#    current best f(x) = 4.107620 (best action=223)
#
# 0107-th step: f(x) = 3.909203 (action=338)
#    current best f(x) = 4.107620 (best action=223)
#
# 0108-th step: f(x) = 2.693562 (action=337)
#    current best f(x) = 4.107620 (best action=223)
#
# 0109-th step: f(x) = 2.797378 (action=362)
#    current best f(x) = 4.107620 (best action=223)
#
# 0110-th step: f(x) = 2.148002 (action=403)
#    current best f(x) = 4.107620 (best action=223)
#
# 0111-th step: f(x) = 2.166267 (action=387)
#    current best f(x) = 4.107620 (best action=223)
#
# 0112-th step: f(x) = 2.789102 (action=93)
#    current best f(x) = 4.107620 (best action=223)
#
# 0113-th step: f(x) = 2.530396 (action=196)
#    current best f(x) = 4.107620 (best action=223)
#
# 0114-th step: f(x) = 1.927450 (action=255)
#    current best f(x) = 4.107620 (best action=223)
#
# 0115-th step: f(x) = 2.244324 (action=352)
#    current best f(x) = 4.107620 (best action=223)
#
# 0116-th step: f(x) = 3.298290 (action=372)
#    current best f(x) = 4.107620 (best action=223)
#
# 0117-th step: f(x) = 2.326354 (action=400)
#    current best f(x) = 4.107620 (best action=223)
#
# 0118-th step: f(x) = 2.705363 (action=312)
#    current best f(x) = 4.107620 (best action=223)
#
# 0119-th step: f(x) = 2.160947 (action=374)
#    current best f(x) = 4.107620 (best action=223)
#
# 0120-th step: f(x) = 2.198917 (action=347)
#    current best f(x) = 4.107620 (best action=223)
#
# 0121-th step: f(x) = 2.272024 (action=59)
#    current best f(x) = 4.107620 (best action=223)
#
# 0122-th step: f(x) = 2.650736 (action=331)
#    current best f(x) = 4.107620 (best action=223)
#
# 0123-th step: f(x) = 2.692199 (action=17)
#    current best f(x) = 4.107620 (best action=223)
#
# 0124-th step: f(x) = 2.116136 (action=205)
#    current best f(x) = 4.107620 (best action=223)
#
# 0125-th step: f(x) = 3.286539 (action=220)
#    current best f(x) = 4.107620 (best action=223)
#
# 0126-th step: f(x) = 3.292710 (action=492)
#    current best f(x) = 4.107620 (best action=223)
#
# 0127-th step: f(x) = 3.018996 (action=408)
#    current best f(x) = 4.107620 (best action=223)
#
# 0128-th step: f(x) = 2.822646 (action=370)
#    current best f(x) = 4.107620 (best action=223)
#
# 0129-th step: f(x) = 3.603806 (action=493)
#    current best f(x) = 4.107620 (best action=223)
#
# 0130-th step: f(x) = 5.057711 (action=250)
#    current best f(x) = 5.057711 (best action=250)
#
# 0131-th step: f(x) = 4.288360 (action=366)
#    current best f(x) = 5.057711 (best action=250)
#
# 0132-th step: f(x) = 3.400929 (action=35)
#    current best f(x) = 5.057711 (best action=250)
#
# 0133-th step: f(x) = 4.270924 (action=426)
#    current best f(x) = 5.057711 (best action=250)
#
# 0134-th step: f(x) = 2.971935 (action=112)
#    current best f(x) = 5.057711 (best action=250)
#
# 0135-th step: f(x) = 2.410179 (action=105)
#    current best f(x) = 5.057711 (best action=250)
#
# 0136-th step: f(x) = 4.725240 (action=247)
#    current best f(x) = 5.057711 (best action=250)
#
# 0137-th step: f(x) = 4.682727 (action=479)
#    current best f(x) = 5.057711 (best action=250)
#
# 0138-th step: f(x) = 3.761592 (action=36)
#    current best f(x) = 5.057711 (best action=250)
#
# 0139-th step: f(x) = 3.950354 (action=48)
#    current best f(x) = 5.057711 (best action=250)
#
# 0140-th step: f(x) = 4.067988 (action=448)
#    current best f(x) = 5.057711 (best action=250)
#
# 0141-th step: f(x) = 2.301847 (action=227)
#    current best f(x) = 5.057711 (best action=250)
#
# 0142-th step: f(x) = 2.991167 (action=139)
#    current best f(x) = 5.057711 (best action=250)
#
# 0143-th step: f(x) = 2.133533 (action=228)
#    current best f(x) = 5.057711 (best action=250)
#
# 0144-th step: f(x) = 2.433231 (action=128)
#    current best f(x) = 5.057711 (best action=250)
#
# 0145-th step: f(x) = 3.097235 (action=229)
#    current best f(x) = 5.057711 (best action=250)
#
# 0146-th step: f(x) = 2.446035 (action=330)
#    current best f(x) = 5.057711 (best action=250)
#
# 0147-th step: f(x) = 2.383186 (action=395)
#    current best f(x) = 5.057711 (best action=250)
#
# 0148-th step: f(x) = 2.830068 (action=189)
#    current best f(x) = 5.057711 (best action=250)
#
# 0149-th step: f(x) = 3.356339 (action=55)
#    current best f(x) = 5.057711 (best action=250)
#
# 0150-th step: f(x) = 2.721873 (action=90)
#    current best f(x) = 5.057711 (best action=250)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 100.99061990306201
# 50-th epoch, marginal likelihood 100.4247028489306
# 100-th epoch, marginal likelihood 99.82493944640939
# 150-th epoch, marginal likelihood 99.49347240046387
# 200-th epoch, marginal likelihood 99.20319403421432
# 250-th epoch, marginal likelihood 98.93861818449842
# 300-th epoch, marginal likelihood 98.87941095265994
# 350-th epoch, marginal likelihood 98.62180605640688
# 400-th epoch, marginal likelihood 98.63800015946764
# 450-th epoch, marginal likelihood 98.58995903591503
# 500-th epoch, marginal likelihood 98.67829354277156
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.19859299]
#  scale  =  0.2486962461526285
#  scale2 =  0.06184982285040879
#
#
# 0151-th step: f(x) = 2.731978 (action=176)
#    current best f(x) = 5.057711 (best action=250)
#
# 0152-th step: f(x) = 2.086169 (action=364)
#    current best f(x) = 5.057711 (best action=250)
#
# 0153-th step: f(x) = 3.286670 (action=77)
#    current best f(x) = 5.057711 (best action=250)
#
# 0154-th step: f(x) = 2.521384 (action=495)
#    current best f(x) = 5.057711 (best action=250)
#
# 0155-th step: f(x) = 2.143090 (action=288)
#    current best f(x) = 5.057711 (best action=250)
#
# 0156-th step: f(x) = 2.511968 (action=319)
#    current best f(x) = 5.057711 (best action=250)
#
# 0157-th step: f(x) = 3.264902 (action=355)
#    current best f(x) = 5.057711 (best action=250)
#
# 0158-th step: f(x) = 3.170518 (action=40)
#    current best f(x) = 5.057711 (best action=250)
#
# 0159-th step: f(x) = 1.958722 (action=167)
#    current best f(x) = 5.057711 (best action=250)
#
# 0160-th step: f(x) = 2.847173 (action=444)
#    current best f(x) = 5.057711 (best action=250)
#
# 0161-th step: f(x) = 2.227650 (action=363)
#    current best f(x) = 5.057711 (best action=250)
#
# 0162-th step: f(x) = 4.706231 (action=73)
#    current best f(x) = 5.057711 (best action=250)
#
# 0163-th step: f(x) = 4.508599 (action=168)
#    current best f(x) = 5.057711 (best action=250)
#
# 0164-th step: f(x) = 3.047911 (action=252)
#    current best f(x) = 5.057711 (best action=250)
#
# 0165-th step: f(x) = 2.637429 (action=13)
#    current best f(x) = 5.057711 (best action=250)
#
# 0166-th step: f(x) = 2.279116 (action=315)
#    current best f(x) = 5.057711 (best action=250)
#
# 0167-th step: f(x) = 3.359676 (action=24)
#    current best f(x) = 5.057711 (best action=250)
#
# 0168-th step: f(x) = 4.015172 (action=471)
#    current best f(x) = 5.057711 (best action=250)
#
# 0169-th step: f(x) = 2.453982 (action=109)
#    current best f(x) = 5.057711 (best action=250)
#
# 0170-th step: f(x) = 2.304067 (action=111)
#    current best f(x) = 5.057711 (best action=250)
#
# 0171-th step: f(x) = 2.784103 (action=438)
#    current best f(x) = 5.057711 (best action=250)
#
# 0172-th step: f(x) = 1.925328 (action=386)
#    current best f(x) = 5.057711 (best action=250)
#
# 0173-th step: f(x) = 3.367598 (action=377)
#    current best f(x) = 5.057711 (best action=250)
#
# 0174-th step: f(x) = 3.408732 (action=120)
#    current best f(x) = 5.057711 (best action=250)
#
# 0175-th step: f(x) = 2.418407 (action=485)
#    current best f(x) = 5.057711 (best action=250)
#
# 0176-th step: f(x) = 4.190259 (action=218)
#    current best f(x) = 5.057711 (best action=250)
#
# 0177-th step: f(x) = 3.515651 (action=289)
#    current best f(x) = 5.057711 (best action=250)
#
# 0178-th step: f(x) = 3.001148 (action=4)
#    current best f(x) = 5.057711 (best action=250)
#
# 0179-th step: f(x) = 2.109923 (action=58)
#    current best f(x) = 5.057711 (best action=250)
#
# 0180-th step: f(x) = 3.656655 (action=0)
#    current best f(x) = 5.057711 (best action=250)
#
# 0181-th step: f(x) = 2.305546 (action=398)
#    current best f(x) = 5.057711 (best action=250)
#
# 0182-th step: f(x) = 3.009214 (action=129)
#    current best f(x) = 5.057711 (best action=250)
#
# 0183-th step: f(x) = 2.683243 (action=336)
#    current best f(x) = 5.057711 (best action=250)
#
# 0184-th step: f(x) = 2.680294 (action=357)
#    current best f(x) = 5.057711 (best action=250)
#
# 0185-th step: f(x) = 3.837505 (action=281)
#    current best f(x) = 5.057711 (best action=250)
#
# 0186-th step: f(x) = 3.864941 (action=185)
#    current best f(x) = 5.057711 (best action=250)
#
# 0187-th step: f(x) = 1.978139 (action=498)
#    current best f(x) = 5.057711 (best action=250)
#
# 0188-th step: f(x) = 3.312010 (action=242)
#    current best f(x) = 5.057711 (best action=250)
#
# 0189-th step: f(x) = 2.793633 (action=475)
#    current best f(x) = 5.057711 (best action=250)
#
# 0190-th step: f(x) = 2.104538 (action=21)
#    current best f(x) = 5.057711 (best action=250)
#
# 0191-th step: f(x) = 2.517475 (action=15)
#    current best f(x) = 5.057711 (best action=250)
#
# 0192-th step: f(x) = 2.514247 (action=44)
#    current best f(x) = 5.057711 (best action=250)
#
# 0193-th step: f(x) = 2.616944 (action=122)
#    current best f(x) = 5.057711 (best action=250)
#
# 0194-th step: f(x) = 2.735916 (action=159)
#    current best f(x) = 5.057711 (best action=250)
#
# 0195-th step: f(x) = 3.559743 (action=323)
#    current best f(x) = 5.057711 (best action=250)
#
# 0196-th step: f(x) = 3.908885 (action=118)
#    current best f(x) = 5.057711 (best action=250)
#
# 0197-th step: f(x) = 2.445585 (action=402)
#    current best f(x) = 5.057711 (best action=250)
#
# 0198-th step: f(x) = 3.373301 (action=140)
#    current best f(x) = 5.057711 (best action=250)
#
# 0199-th step: f(x) = 2.489719 (action=171)
#    current best f(x) = 5.057711 (best action=250)
#
# 0200-th step: f(x) = 3.209805 (action=484)
#    current best f(x) = 5.057711 (best action=250)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 197.54998571290983
# 50-th epoch, marginal likelihood 172.98485654142874
# 100-th epoch, marginal likelihood 170.17678273817862
# 150-th epoch, marginal likelihood 168.9171993631492
# 200-th epoch, marginal likelihood 167.86788533168212
# 250-th epoch, marginal likelihood 167.0420685916436
# 300-th epoch, marginal likelihood 166.41804081877103
# 350-th epoch, marginal likelihood 165.99185036914128
# 400-th epoch, marginal likelihood 165.7124802886613
# 450-th epoch, marginal likelihood 165.5629058883312
# 500-th epoch, marginal likelihood 165.48596735911818
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [8.46452017]
#  scale  =  0.8158775914757352
#  scale2 =  0.6656562442722467
#
#
# 0201-th step: f(x) = 3.156001 (action=383)
#    current best f(x) = 5.057711 (best action=250)
#
# 0202-th step: f(x) = 3.002695 (action=287)
#    current best f(x) = 5.057711 (best action=250)
#
# 0203-th step: f(x) = 1.982911 (action=320)
#    current best f(x) = 5.057711 (best action=250)
#
# 0204-th step: f(x) = 2.838673 (action=231)
#    current best f(x) = 5.057711 (best action=250)
#
# 0205-th step: f(x) = 4.527239 (action=316)
#    current best f(x) = 5.057711 (best action=250)
#
# 0206-th step: f(x) = 1.941175 (action=42)
#    current best f(x) = 5.057711 (best action=250)
#
# 0207-th step: f(x) = 3.671379 (action=425)
#    current best f(x) = 5.057711 (best action=250)
#
# 0208-th step: f(x) = 2.032710 (action=361)
#    current best f(x) = 5.057711 (best action=250)
#
# 0209-th step: f(x) = 2.557924 (action=260)
#    current best f(x) = 5.057711 (best action=250)
#
# 0210-th step: f(x) = 3.665991 (action=328)
#    current best f(x) = 5.057711 (best action=250)
#
# 0211-th step: f(x) = 3.979143 (action=107)
#    current best f(x) = 5.057711 (best action=250)
#
# 0212-th step: f(x) = 3.095683 (action=130)
#    current best f(x) = 5.057711 (best action=250)
#
# 0213-th step: f(x) = 2.015308 (action=283)
#    current best f(x) = 5.057711 (best action=250)
#
# 0214-th step: f(x) = 2.710859 (action=179)
#    current best f(x) = 5.057711 (best action=250)
#
# 0215-th step: f(x) = 2.996586 (action=69)
#    current best f(x) = 5.057711 (best action=250)
#
# 0216-th step: f(x) = 3.709738 (action=103)
#    current best f(x) = 5.057711 (best action=250)
#
# 0217-th step: f(x) = 2.047329 (action=401)
#    current best f(x) = 5.057711 (best action=250)
#
# 0218-th step: f(x) = 3.168273 (action=295)
#    current best f(x) = 5.057711 (best action=250)
#
# 0219-th step: f(x) = 3.112139 (action=311)
#    current best f(x) = 5.057711 (best action=250)
#
# 0220-th step: f(x) = 2.072946 (action=147)
#    current best f(x) = 5.057711 (best action=250)
#
# 0221-th step: f(x) = 4.287449 (action=182)
#    current best f(x) = 5.057711 (best action=250)
#
# 0222-th step: f(x) = 5.145519 (action=85)
#    current best f(x) = 5.145519 (best action=85)
#
# 0223-th step: f(x) = 2.218906 (action=262)
#    current best f(x) = 5.145519 (best action=85)
#
# 0224-th step: f(x) = 2.564279 (action=417)
#    current best f(x) = 5.145519 (best action=85)
#
# 0225-th step: f(x) = 2.409400 (action=264)
#    current best f(x) = 5.145519 (best action=85)
#
# 0226-th step: f(x) = 4.042345 (action=482)
#    current best f(x) = 5.145519 (best action=85)
#
# 0227-th step: f(x) = 2.796477 (action=412)
#    current best f(x) = 5.145519 (best action=85)
#
# 0228-th step: f(x) = 3.071644 (action=446)
#    current best f(x) = 5.145519 (best action=85)
#
# 0229-th step: f(x) = 2.269876 (action=86)
#    current best f(x) = 5.145519 (best action=85)
#
# 0230-th step: f(x) = 3.886743 (action=253)
#    current best f(x) = 5.145519 (best action=85)
#
# 0231-th step: f(x) = 2.943834 (action=265)
#    current best f(x) = 5.145519 (best action=85)
#
# 0232-th step: f(x) = 3.310716 (action=261)
#    current best f(x) = 5.145519 (best action=85)
#
# 0233-th step: f(x) = 2.269903 (action=106)
#    current best f(x) = 5.145519 (best action=85)
#
# 0234-th step: f(x) = 2.023847 (action=435)
#    current best f(x) = 5.145519 (best action=85)
#
# 0235-th step: f(x) = 2.240289 (action=151)
#    current best f(x) = 5.145519 (best action=85)
#
# 0236-th step: f(x) = 3.835379 (action=219)
#    current best f(x) = 5.145519 (best action=85)
#
# 0237-th step: f(x) = 3.822884 (action=303)
#    current best f(x) = 5.145519 (best action=85)
#
# 0238-th step: f(x) = 2.543388 (action=350)
#    current best f(x) = 5.145519 (best action=85)
#
# 0239-th step: f(x) = 2.006214 (action=302)
#    current best f(x) = 5.145519 (best action=85)
#
# 0240-th step: f(x) = 2.476858 (action=124)
#    current best f(x) = 5.145519 (best action=85)
#
# 0241-th step: f(x) = 2.001193 (action=214)
#    current best f(x) = 5.145519 (best action=85)
#
# 0242-th step: f(x) = 2.352993 (action=210)
#    current best f(x) = 5.145519 (best action=85)
#
# 0243-th step: f(x) = 2.359282 (action=428)
#    current best f(x) = 5.145519 (best action=85)
#
# 0244-th step: f(x) = 2.246948 (action=63)
#    current best f(x) = 5.145519 (best action=85)
#
# 0245-th step: f(x) = 2.399030 (action=351)
#    current best f(x) = 5.145519 (best action=85)
#
# 0246-th step: f(x) = 2.662879 (action=459)
#    current best f(x) = 5.145519 (best action=85)
#
# 0247-th step: f(x) = 2.680170 (action=461)
#    current best f(x) = 5.145519 (best action=85)
#
# 0248-th step: f(x) = 3.043263 (action=70)
#    current best f(x) = 5.145519 (best action=85)
#
# 0249-th step: f(x) = 2.347726 (action=466)
#    current best f(x) = 5.145519 (best action=85)
#
# 0250-th step: f(x) = 2.535317 (action=269)
#    current best f(x) = 5.145519 (best action=85)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 231.94581743606545
# 50-th epoch, marginal likelihood 223.02086583667312
# 100-th epoch, marginal likelihood 222.25883214013908
# 150-th epoch, marginal likelihood 221.49984908409436
# 200-th epoch, marginal likelihood 221.36006143383173
# 250-th epoch, marginal likelihood 221.30031887575964
# 300-th epoch, marginal likelihood 221.00582108729589
# 350-th epoch, marginal likelihood 221.018243995606
# 400-th epoch, marginal likelihood 221.3596502305457
# 450-th epoch, marginal likelihood 221.4270408353106
# 500-th epoch, marginal likelihood 221.66064422132752
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [7.56187616]
#  scale  =  0.8746575531012298
#  scale2 =  0.7650258351970307
#
#
# 0251-th step: f(x) = 3.026150 (action=152)
#    current best f(x) = 5.145519 (best action=85)
#
# 0252-th step: f(x) = 3.122676 (action=213)
#    current best f(x) = 5.145519 (best action=85)
#
# 0253-th step: f(x) = 1.922565 (action=3)
#    current best f(x) = 5.145519 (best action=85)
#
# 0254-th step: f(x) = 2.549730 (action=184)
#    current best f(x) = 5.145519 (best action=85)
#
# 0255-th step: f(x) = 2.228637 (action=335)
#    current best f(x) = 5.145519 (best action=85)
#
# 0256-th step: f(x) = 2.785436 (action=28)
#    current best f(x) = 5.145519 (best action=85)
#
# 0257-th step: f(x) = 3.877561 (action=68)
#    current best f(x) = 5.145519 (best action=85)
#
# 0258-th step: f(x) = 1.999945 (action=480)
#    current best f(x) = 5.145519 (best action=85)
#
# 0259-th step: f(x) = 2.047624 (action=100)
#    current best f(x) = 5.145519 (best action=85)
#
# 0260-th step: f(x) = 2.755235 (action=102)
#    current best f(x) = 5.145519 (best action=85)
#
# 0261-th step: f(x) = 4.040700 (action=190)
#    current best f(x) = 5.145519 (best action=85)
#
# 0262-th step: f(x) = 3.170505 (action=169)
#    current best f(x) = 5.145519 (best action=85)
#
# 0263-th step: f(x) = 3.541771 (action=47)
#    current best f(x) = 5.145519 (best action=85)
#
# 0264-th step: f(x) = 2.866999 (action=445)
#    current best f(x) = 5.145519 (best action=85)
#
# 0265-th step: f(x) = 2.935765 (action=158)
#    current best f(x) = 5.145519 (best action=85)
#
# 0266-th step: f(x) = 2.638413 (action=285)
#    current best f(x) = 5.145519 (best action=85)
#
# 0267-th step: f(x) = 3.945998 (action=268)
#    current best f(x) = 5.145519 (best action=85)
#
# 0268-th step: f(x) = 3.548726 (action=97)
#    current best f(x) = 5.145519 (best action=85)
#
# 0269-th step: f(x) = 3.052043 (action=195)
#    current best f(x) = 5.145519 (best action=85)
#
# 0270-th step: f(x) = 2.711763 (action=436)
#    current best f(x) = 5.145519 (best action=85)
#
# 0271-th step: f(x) = 2.272421 (action=18)
#    current best f(x) = 5.145519 (best action=85)
#
# 0272-th step: f(x) = 2.324978 (action=5)
#    current best f(x) = 5.145519 (best action=85)
#
# 0273-th step: f(x) = 2.145624 (action=115)
#    current best f(x) = 5.145519 (best action=85)
#
# 0274-th step: f(x) = 2.454971 (action=74)
#    current best f(x) = 5.145519 (best action=85)
#
# 0275-th step: f(x) = 2.399007 (action=467)
#    current best f(x) = 5.145519 (best action=85)
#
# 0276-th step: f(x) = 2.492086 (action=359)
#    current best f(x) = 5.145519 (best action=85)
#
# 0277-th step: f(x) = 3.339624 (action=221)
#    current best f(x) = 5.145519 (best action=85)
#
# 0278-th step: f(x) = 1.981872 (action=322)
#    current best f(x) = 5.145519 (best action=85)
#
# 0279-th step: f(x) = 3.300166 (action=180)
#    current best f(x) = 5.145519 (best action=85)
#
# 0280-th step: f(x) = 3.825027 (action=306)
#    current best f(x) = 5.145519 (best action=85)
#
# 0281-th step: f(x) = 2.143475 (action=96)
#    current best f(x) = 5.145519 (best action=85)
#
# 0282-th step: f(x) = 3.061915 (action=405)
#    current best f(x) = 5.145519 (best action=85)
#
# 0283-th step: f(x) = 1.986916 (action=94)
#    current best f(x) = 5.145519 (best action=85)
#
# 0284-th step: f(x) = 3.571466 (action=117)
#    current best f(x) = 5.145519 (best action=85)
#
# 0285-th step: f(x) = 2.390952 (action=381)
#    current best f(x) = 5.145519 (best action=85)
#
# 0286-th step: f(x) = 2.090616 (action=465)
#    current best f(x) = 5.145519 (best action=85)
#
# 0287-th step: f(x) = 2.230777 (action=212)
#    current best f(x) = 5.145519 (best action=85)
#
# 0288-th step: f(x) = 2.637765 (action=458)
#    current best f(x) = 5.145519 (best action=85)
#
# 0289-th step: f(x) = 2.207274 (action=208)
#    current best f(x) = 5.145519 (best action=85)
#
# 0290-th step: f(x) = 3.976796 (action=173)
#    current best f(x) = 5.145519 (best action=85)
#
# 0291-th step: f(x) = 3.222111 (action=393)
#    current best f(x) = 5.145519 (best action=85)
#
# 0292-th step: f(x) = 2.812253 (action=491)
#    current best f(x) = 5.145519 (best action=85)
#
# 0293-th step: f(x) = 2.430162 (action=198)
#    current best f(x) = 5.145519 (best action=85)
#
# 0294-th step: f(x) = 2.788362 (action=270)
#    current best f(x) = 5.145519 (best action=85)
#
# 0295-th step: f(x) = 2.572811 (action=310)
#    current best f(x) = 5.145519 (best action=85)
#
# 0296-th step: f(x) = 2.471051 (action=1)
#    current best f(x) = 5.145519 (best action=85)
#
# 0297-th step: f(x) = 2.367384 (action=175)
#    current best f(x) = 5.145519 (best action=85)
#
# 0298-th step: f(x) = 2.030449 (action=278)
#    current best f(x) = 5.145519 (best action=85)
#
# 0299-th step: f(x) = 3.597137 (action=257)
#    current best f(x) = 5.145519 (best action=85)
#
# 0300-th step: f(x) = 2.723290 (action=89)
#    current best f(x) = 5.145519 (best action=85)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 286.9577238412891
# 50-th epoch, marginal likelihood 271.32498496765527
# 100-th epoch, marginal likelihood 269.41227251059155
# 150-th epoch, marginal likelihood 268.50037829792024
# 200-th epoch, marginal likelihood 268.35687274004675
# 250-th epoch, marginal likelihood 268.2740402400847
# 300-th epoch, marginal likelihood 268.7391894375687
# 350-th epoch, marginal likelihood 268.82158201488164
# 400-th epoch, marginal likelihood 269.06941799539004
# 450-th epoch, marginal likelihood 269.3752308626607
# 500-th epoch, marginal likelihood 269.9468192443721
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.4369062]
#  scale  =  0.8523692145411194
#  scale2 =  0.7265332778974447
#
#
# 0301-th step: f(x) = 2.047079 (action=174)
#    current best f(x) = 5.145519 (best action=85)
#
# 0302-th step: f(x) = 2.043189 (action=141)
#    current best f(x) = 5.145519 (best action=85)
#
# 0303-th step: f(x) = 2.604621 (action=248)
#    current best f(x) = 5.145519 (best action=85)
#
# 0304-th step: f(x) = 2.769902 (action=305)
#    current best f(x) = 5.145519 (best action=85)
#
# 0305-th step: f(x) = 1.939002 (action=181)
#    current best f(x) = 5.145519 (best action=85)
#
# 0306-th step: f(x) = 4.315861 (action=81)
#    current best f(x) = 5.145519 (best action=85)
#
# 0307-th step: f(x) = 3.426586 (action=20)
#    current best f(x) = 5.145519 (best action=85)
#
# 0308-th step: f(x) = 2.583695 (action=376)
#    current best f(x) = 5.145519 (best action=85)
#
# 0309-th step: f(x) = 2.091194 (action=349)
#    current best f(x) = 5.145519 (best action=85)
#
# 0310-th step: f(x) = 2.317952 (action=10)
#    current best f(x) = 5.145519 (best action=85)
#
# 0311-th step: f(x) = 2.505775 (action=317)
#    current best f(x) = 5.145519 (best action=85)
#
# 0312-th step: f(x) = 2.476953 (action=275)
#    current best f(x) = 5.145519 (best action=85)
#
# 0313-th step: f(x) = 2.913231 (action=38)
#    current best f(x) = 5.145519 (best action=85)
#
# 0314-th step: f(x) = 2.576505 (action=32)
#    current best f(x) = 5.145519 (best action=85)
#
# 0315-th step: f(x) = 2.484639 (action=80)
#    current best f(x) = 5.145519 (best action=85)
#
# 0316-th step: f(x) = 2.608643 (action=454)
#    current best f(x) = 5.145519 (best action=85)
#
# 0317-th step: f(x) = 1.971275 (action=204)
#    current best f(x) = 5.145519 (best action=85)
#
# 0318-th step: f(x) = 2.377664 (action=453)
#    current best f(x) = 5.145519 (best action=85)
#
# 0319-th step: f(x) = 3.945812 (action=369)
#    current best f(x) = 5.145519 (best action=85)
#
# 0320-th step: f(x) = 2.237687 (action=193)
#    current best f(x) = 5.145519 (best action=85)
#
# 0321-th step: f(x) = 2.730672 (action=427)
#    current best f(x) = 5.145519 (best action=85)
#
# 0322-th step: f(x) = 2.285828 (action=455)
#    current best f(x) = 5.145519 (best action=85)
#
# 0323-th step: f(x) = 2.397857 (action=411)
#    current best f(x) = 5.145519 (best action=85)
#
# 0324-th step: f(x) = 2.382028 (action=414)
#    current best f(x) = 5.145519 (best action=85)
#
# 0325-th step: f(x) = 2.354839 (action=72)
#    current best f(x) = 5.145519 (best action=85)
#
# 0326-th step: f(x) = 2.333648 (action=119)
#    current best f(x) = 5.145519 (best action=85)
#
# 0327-th step: f(x) = 2.370950 (action=43)
#    current best f(x) = 5.145519 (best action=85)
#
# 0328-th step: f(x) = 2.236429 (action=254)
#    current best f(x) = 5.145519 (best action=85)
#
# 0329-th step: f(x) = 2.317962 (action=460)
#    current best f(x) = 5.145519 (best action=85)
#
# 0330-th step: f(x) = 2.293619 (action=53)
#    current best f(x) = 5.145519 (best action=85)
#
# 0331-th step: f(x) = 2.130986 (action=12)
#    current best f(x) = 5.145519 (best action=85)
#
# 0332-th step: f(x) = 2.434968 (action=449)
#    current best f(x) = 5.145519 (best action=85)
#
# 0333-th step: f(x) = 3.654313 (action=293)
#    current best f(x) = 5.145519 (best action=85)
#
# 0334-th step: f(x) = 3.176120 (action=134)
#    current best f(x) = 5.145519 (best action=85)
#
# 0335-th step: f(x) = 2.729645 (action=368)
#    current best f(x) = 5.145519 (best action=85)
#
# 0336-th step: f(x) = 2.344133 (action=136)
#    current best f(x) = 5.145519 (best action=85)
#
# 0337-th step: f(x) = 3.027862 (action=11)
#    current best f(x) = 5.145519 (best action=85)
#
# 0338-th step: f(x) = 2.543780 (action=243)
#    current best f(x) = 5.145519 (best action=85)
#
# 0339-th step: f(x) = 1.931224 (action=66)
#    current best f(x) = 5.145519 (best action=85)
#
# 0340-th step: f(x) = 2.048103 (action=98)
#    current best f(x) = 5.145519 (best action=85)
#
# 0341-th step: f(x) = 2.092953 (action=137)
#    current best f(x) = 5.145519 (best action=85)
#
# 0342-th step: f(x) = 2.215422 (action=399)
#    current best f(x) = 5.145519 (best action=85)
#
# 0343-th step: f(x) = 2.343225 (action=121)
#    current best f(x) = 5.145519 (best action=85)
#
# 0344-th step: f(x) = 2.963136 (action=277)
#    current best f(x) = 5.145519 (best action=85)
#
# 0345-th step: f(x) = 2.642557 (action=297)
#    current best f(x) = 5.145519 (best action=85)
#
# 0346-th step: f(x) = 2.104293 (action=280)
#    current best f(x) = 5.145519 (best action=85)
#
# 0347-th step: f(x) = 2.529742 (action=276)
#    current best f(x) = 5.145519 (best action=85)
#
# 0348-th step: f(x) = 2.136561 (action=348)
#    current best f(x) = 5.145519 (best action=85)
#
# 0349-th step: f(x) = 2.688538 (action=431)
#    current best f(x) = 5.145519 (best action=85)
#
# 0350-th step: f(x) = 2.912351 (action=101)
#    current best f(x) = 5.145519 (best action=85)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 321.8781748298177
# 50-th epoch, marginal likelihood 302.44680195007186
# 100-th epoch, marginal likelihood 299.9560406284612
# 150-th epoch, marginal likelihood 299.00396096529875
# 200-th epoch, marginal likelihood 299.02352204498004
# 250-th epoch, marginal likelihood 299.76256019278765
# 300-th epoch, marginal likelihood 300.0181249498067
# 350-th epoch, marginal likelihood 299.78153434504213
# 400-th epoch, marginal likelihood 300.3229101957701
# 450-th epoch, marginal likelihood 300.4347601866809
# 500-th epoch, marginal likelihood 300.1036834554848
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [5.81841684]
#  scale  =  0.8217890550547678
#  scale2 =  0.6753372510078083
#
#
# 0351-th step: f(x) = 2.592288 (action=41)
#    current best f(x) = 5.145519 (best action=85)
#
# 0352-th step: f(x) = 2.180172 (action=456)
#    current best f(x) = 5.145519 (best action=85)
#
# 0353-th step: f(x) = 1.977904 (action=451)
#    current best f(x) = 5.145519 (best action=85)
#
# 0354-th step: f(x) = 2.767693 (action=450)
#    current best f(x) = 5.145519 (best action=85)
#
# 0355-th step: f(x) = 2.507806 (action=153)
#    current best f(x) = 5.145519 (best action=85)
#
# 0356-th step: f(x) = 2.563363 (action=385)
#    current best f(x) = 5.145519 (best action=85)
#
# 0357-th step: f(x) = 2.086933 (action=327)
#    current best f(x) = 5.145519 (best action=85)
#
# 0358-th step: f(x) = 1.975747 (action=406)
#    current best f(x) = 5.145519 (best action=85)
#
# 0359-th step: f(x) = 2.181766 (action=410)
#    current best f(x) = 5.145519 (best action=85)
#
# 0360-th step: f(x) = 2.843266 (action=478)
#    current best f(x) = 5.145519 (best action=85)
#
# 0361-th step: f(x) = 2.129819 (action=394)
#    current best f(x) = 5.145519 (best action=85)
#
# 0362-th step: f(x) = 2.353441 (action=172)
#    current best f(x) = 5.145519 (best action=85)
#
# 0363-th step: f(x) = 2.205723 (action=233)
#    current best f(x) = 5.145519 (best action=85)
#
# 0364-th step: f(x) = 2.253737 (action=477)
#    current best f(x) = 5.145519 (best action=85)
#
# 0365-th step: f(x) = 2.167062 (action=2)
#    current best f(x) = 5.145519 (best action=85)
#
# 0366-th step: f(x) = 2.307499 (action=439)
#    current best f(x) = 5.145519 (best action=85)
#
# 0367-th step: f(x) = 1.971005 (action=225)
#    current best f(x) = 5.145519 (best action=85)
#
# 0368-th step: f(x) = 2.595343 (action=135)
#    current best f(x) = 5.145519 (best action=85)
#
# 0369-th step: f(x) = 2.645421 (action=434)
#    current best f(x) = 5.145519 (best action=85)
#
# 0370-th step: f(x) = 2.269370 (action=432)
#    current best f(x) = 5.145519 (best action=85)
#
# 0371-th step: f(x) = 2.336159 (action=31)
#    current best f(x) = 5.145519 (best action=85)
#
# 0372-th step: f(x) = 2.152891 (action=304)
#    current best f(x) = 5.145519 (best action=85)
#
# 0373-th step: f(x) = 2.605861 (action=430)
#    current best f(x) = 5.145519 (best action=85)
#
# 0374-th step: f(x) = 2.544343 (action=114)
#    current best f(x) = 5.145519 (best action=85)
#
# 0375-th step: f(x) = 2.567850 (action=110)
#    current best f(x) = 5.145519 (best action=85)
#
# 0376-th step: f(x) = 2.852417 (action=217)
#    current best f(x) = 5.145519 (best action=85)
#
# 0377-th step: f(x) = 2.987134 (action=8)
#    current best f(x) = 5.145519 (best action=85)
#
# 0378-th step: f(x) = 3.160574 (action=422)
#    current best f(x) = 5.145519 (best action=85)
#
# 0379-th step: f(x) = 2.502291 (action=62)
#    current best f(x) = 5.145519 (best action=85)
#
# 0380-th step: f(x) = 2.104863 (action=273)
#    current best f(x) = 5.145519 (best action=85)
#
# 0381-th step: f(x) = 2.666988 (action=433)
#    current best f(x) = 5.145519 (best action=85)
#
# 0382-th step: f(x) = 2.542476 (action=37)
#    current best f(x) = 5.145519 (best action=85)
#
# 0383-th step: f(x) = 2.759216 (action=473)
#    current best f(x) = 5.145519 (best action=85)
#
# 0384-th step: f(x) = 2.355067 (action=282)
#    current best f(x) = 5.145519 (best action=85)
#
# 0385-th step: f(x) = 2.555594 (action=429)
#    current best f(x) = 5.145519 (best action=85)
#
# 0386-th step: f(x) = 2.527790 (action=440)
#    current best f(x) = 5.145519 (best action=85)
#
# 0387-th step: f(x) = 2.482478 (action=318)
#    current best f(x) = 5.145519 (best action=85)
#
# 0388-th step: f(x) = 2.066790 (action=379)
#    current best f(x) = 5.145519 (best action=85)
#
# 0389-th step: f(x) = 2.749094 (action=202)
#    current best f(x) = 5.145519 (best action=85)
#
# 0390-th step: f(x) = 2.488536 (action=142)
#    current best f(x) = 5.145519 (best action=85)
#
# 0391-th step: f(x) = 3.555563 (action=183)
#    current best f(x) = 5.145519 (best action=85)
#
# 0392-th step: f(x) = 2.751306 (action=178)
#    current best f(x) = 5.145519 (best action=85)
#
# 0393-th step: f(x) = 2.412960 (action=421)
#    current best f(x) = 5.145519 (best action=85)
#
# 0394-th step: f(x) = 3.256902 (action=150)
#    current best f(x) = 5.145519 (best action=85)
#
# 0395-th step: f(x) = 2.504622 (action=443)
#    current best f(x) = 5.145519 (best action=85)
#
# 0396-th step: f(x) = 1.926639 (action=332)
#    current best f(x) = 5.145519 (best action=85)
#
# 0397-th step: f(x) = 3.237144 (action=290)
#    current best f(x) = 5.145519 (best action=85)
#
# 0398-th step: f(x) = 2.187679 (action=321)
#    current best f(x) = 5.145519 (best action=85)
#
# 0399-th step: f(x) = 2.501522 (action=415)
#    current best f(x) = 5.145519 (best action=85)
#
# 0400-th step: f(x) = 2.155686 (action=344)
#    current best f(x) = 5.145519 (best action=85)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 349.0224378157636
# 50-th epoch, marginal likelihood 329.32938478076437
# 100-th epoch, marginal likelihood 326.6046816004639
# 150-th epoch, marginal likelihood 325.92597492206295
# 200-th epoch, marginal likelihood 326.327456881068
# 250-th epoch, marginal likelihood 326.28361850924625
# 300-th epoch, marginal likelihood 327.08442922556844
# 350-th epoch, marginal likelihood 327.66241006372394
# 400-th epoch, marginal likelihood 327.4491718189194
# 450-th epoch, marginal likelihood 327.1713054708008
# 500-th epoch, marginal likelihood 326.9826176013015
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [5.67191959]
#  scale  =  0.7857426130661922
#  scale2 =  0.6173914539880878
#
#
# 0401-th step: f(x) = 2.010560 (action=496)
#    current best f(x) = 5.145519 (best action=85)
#
# 0402-th step: f(x) = 2.150653 (action=222)
#    current best f(x) = 5.145519 (best action=85)
#
# 0403-th step: f(x) = 2.357116 (action=441)
#    current best f(x) = 5.145519 (best action=85)
#
# 0404-th step: f(x) = 2.428719 (action=206)
#    current best f(x) = 5.145519 (best action=85)
#
# 0405-th step: f(x) = 3.327093 (action=191)
#    current best f(x) = 5.145519 (best action=85)
#
# 0406-th step: f(x) = 2.253350 (action=447)
#    current best f(x) = 5.145519 (best action=85)
#
# 0407-th step: f(x) = 2.417828 (action=494)
#    current best f(x) = 5.145519 (best action=85)
#
# 0408-th step: f(x) = 3.004177 (action=25)
#    current best f(x) = 5.145519 (best action=85)
#
# 0409-th step: f(x) = 2.433500 (action=339)
#    current best f(x) = 5.145519 (best action=85)
#
# 0410-th step: f(x) = 2.886025 (action=9)
#    current best f(x) = 5.145519 (best action=85)
#
# 0411-th step: f(x) = 1.925936 (action=23)
#    current best f(x) = 5.145519 (best action=85)
#
# 0412-th step: f(x) = 2.120682 (action=27)
#    current best f(x) = 5.145519 (best action=85)
#
# 0413-th step: f(x) = 2.164168 (action=211)
#    current best f(x) = 5.145519 (best action=85)
#
# 0414-th step: f(x) = 1.996939 (action=60)
#    current best f(x) = 5.145519 (best action=85)
#
# 0415-th step: f(x) = 3.570696 (action=82)
#    current best f(x) = 5.145519 (best action=85)
#
# 0416-th step: f(x) = 2.080482 (action=390)
#    current best f(x) = 5.145519 (best action=85)
#
# 0417-th step: f(x) = 1.945712 (action=116)
#    current best f(x) = 5.145519 (best action=85)
#
# 0418-th step: f(x) = 2.029610 (action=391)
#    current best f(x) = 5.145519 (best action=85)
#
# 0419-th step: f(x) = 2.358697 (action=263)
#    current best f(x) = 5.145519 (best action=85)
#
# 0420-th step: f(x) = 2.449975 (action=84)
#    current best f(x) = 5.145519 (best action=85)
#
# 0421-th step: f(x) = 2.092934 (action=163)
#    current best f(x) = 5.145519 (best action=85)
#
# 0422-th step: f(x) = 2.125666 (action=50)
#    current best f(x) = 5.145519 (best action=85)
#
# 0423-th step: f(x) = 2.039610 (action=132)
#    current best f(x) = 5.145519 (best action=85)
#
# 0424-th step: f(x) = 3.281901 (action=309)
#    current best f(x) = 5.145519 (best action=85)
#
# 0425-th step: f(x) = 2.318994 (action=224)
#    current best f(x) = 5.145519 (best action=85)
#
# 0426-th step: f(x) = 3.936592 (action=148)
#    current best f(x) = 5.145519 (best action=85)
#
# 0427-th step: f(x) = 2.305563 (action=104)
#    current best f(x) = 5.145519 (best action=85)
#
# 0428-th step: f(x) = 1.975886 (action=113)
#    current best f(x) = 5.145519 (best action=85)
#
# 0429-th step: f(x) = 1.968002 (action=160)
#    current best f(x) = 5.145519 (best action=85)
#
# 0430-th step: f(x) = 3.809868 (action=71)
#    current best f(x) = 5.145519 (best action=85)
#
# 0431-th step: f(x) = 2.314462 (action=200)
#    current best f(x) = 5.145519 (best action=85)
#
# 0432-th step: f(x) = 2.570621 (action=14)
#    current best f(x) = 5.145519 (best action=85)
#
# 0433-th step: f(x) = 2.228130 (action=371)
#    current best f(x) = 5.145519 (best action=85)
#
# 0434-th step: f(x) = 2.262099 (action=416)
#    current best f(x) = 5.145519 (best action=85)
#
# 0435-th step: f(x) = 2.526117 (action=149)
#    current best f(x) = 5.145519 (best action=85)
#
# 0436-th step: f(x) = 2.544702 (action=314)
#    current best f(x) = 5.145519 (best action=85)
#
# 0437-th step: f(x) = 3.202611 (action=329)
#    current best f(x) = 5.145519 (best action=85)
#
# 0438-th step: f(x) = 2.604530 (action=341)
#    current best f(x) = 5.145519 (best action=85)
#
# 0439-th step: f(x) = 2.166818 (action=126)
#    current best f(x) = 5.145519 (best action=85)
#
# 0440-th step: f(x) = 2.663614 (action=52)
#    current best f(x) = 5.145519 (best action=85)
#
# 0441-th step: f(x) = 2.100603 (action=353)
#    current best f(x) = 5.145519 (best action=85)
#
# 0442-th step: f(x) = 2.093679 (action=384)
#    current best f(x) = 5.145519 (best action=85)
#
# 0443-th step: f(x) = 2.238520 (action=266)
#    current best f(x) = 5.145519 (best action=85)
#
# 0444-th step: f(x) = 2.005578 (action=87)
#    current best f(x) = 5.145519 (best action=85)
#
# 0445-th step: f(x) = 2.914363 (action=145)
#    current best f(x) = 5.145519 (best action=85)
#
# 0446-th step: f(x) = 1.988187 (action=365)
#    current best f(x) = 5.145519 (best action=85)
#
# 0447-th step: f(x) = 2.753838 (action=235)
#    current best f(x) = 5.145519 (best action=85)
#
# 0448-th step: f(x) = 2.338854 (action=61)
#    current best f(x) = 5.145519 (best action=85)
#
# 0449-th step: f(x) = 2.482699 (action=234)
#    current best f(x) = 5.145519 (best action=85)
#
# 0450-th step: f(x) = 2.511826 (action=92)
#    current best f(x) = 5.145519 (best action=85)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 410.22001821968456
# 50-th epoch, marginal likelihood 374.20212768565784
# 100-th epoch, marginal likelihood 369.1616431734325
# 150-th epoch, marginal likelihood 367.9006090903572
# 200-th epoch, marginal likelihood 368.15227822947463
# 250-th epoch, marginal likelihood 368.58009713732395
# 300-th epoch, marginal likelihood 368.8089237919339
# 350-th epoch, marginal likelihood 368.5652029599503
# 400-th epoch, marginal likelihood 368.9894604727125
# 450-th epoch, marginal likelihood 368.96407103345916
# 500-th epoch, marginal likelihood 368.9102484962159
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [5.56277236]
#  scale  =  0.7534601912592839
#  scale2 =  0.5677022598124767
#
#
# 0451-th step: f(x) = 2.250752 (action=251)
#    current best f(x) = 5.145519 (best action=85)
#
# 0452-th step: f(x) = 2.212961 (action=76)
#    current best f(x) = 5.145519 (best action=85)
#
# 0453-th step: f(x) = 2.004677 (action=396)
#    current best f(x) = 5.145519 (best action=85)
#
# 0454-th step: f(x) = 3.956854 (action=49)
#    current best f(x) = 5.145519 (best action=85)
#
# 0455-th step: f(x) = 2.048927 (action=186)
#    current best f(x) = 5.145519 (best action=85)
#
# 0456-th step: f(x) = 2.006099 (action=483)
#    current best f(x) = 5.145519 (best action=85)
#
# 0457-th step: f(x) = 2.797998 (action=108)
#    current best f(x) = 5.145519 (best action=85)
#
# 0458-th step: f(x) = 2.741011 (action=468)
#    current best f(x) = 5.145519 (best action=85)
#
# 0459-th step: f(x) = 2.338626 (action=78)
#    current best f(x) = 5.145519 (best action=85)
#
# 0460-th step: f(x) = 2.277437 (action=146)
#    current best f(x) = 5.145519 (best action=85)
#
# 0461-th step: f(x) = 1.981919 (action=75)
#    current best f(x) = 5.145519 (best action=85)
#
# 0462-th step: f(x) = 2.038031 (action=299)
#    current best f(x) = 5.145519 (best action=85)
#
# 0463-th step: f(x) = 1.971833 (action=356)
#    current best f(x) = 5.145519 (best action=85)
#
# 0464-th step: f(x) = 1.981223 (action=354)
#    current best f(x) = 5.145519 (best action=85)
#
# 0465-th step: f(x) = 1.990225 (action=91)
#    current best f(x) = 5.145519 (best action=85)
#
# 0466-th step: f(x) = 1.960779 (action=19)
#    current best f(x) = 5.145519 (best action=85)
#
# 0467-th step: f(x) = 2.429008 (action=88)
#    current best f(x) = 5.145519 (best action=85)
#
# 0468-th step: f(x) = 2.315783 (action=54)
#    current best f(x) = 5.145519 (best action=85)
#
# 0469-th step: f(x) = 2.341118 (action=373)
#    current best f(x) = 5.145519 (best action=85)
#
# 0470-th step: f(x) = 2.468714 (action=423)
#    current best f(x) = 5.145519 (best action=85)
#
# 0471-th step: f(x) = 2.617578 (action=397)
#    current best f(x) = 5.145519 (best action=85)
#
# 0472-th step: f(x) = 1.922734 (action=215)
#    current best f(x) = 5.145519 (best action=85)
#
# 0473-th step: f(x) = 1.978480 (action=237)
#    current best f(x) = 5.145519 (best action=85)
#
# 0474-th step: f(x) = 1.954579 (action=267)
#    current best f(x) = 5.145519 (best action=85)
#
# 0475-th step: f(x) = 2.133326 (action=30)
#    current best f(x) = 5.145519 (best action=85)
#
# 0476-th step: f(x) = 2.353872 (action=392)
#    current best f(x) = 5.145519 (best action=85)
#
# 0477-th step: f(x) = 2.549729 (action=7)
#    current best f(x) = 5.145519 (best action=85)
#
# 0478-th step: f(x) = 2.676548 (action=95)
#    current best f(x) = 5.145519 (best action=85)
#
# 0479-th step: f(x) = 2.153066 (action=56)
#    current best f(x) = 5.145519 (best action=85)
#
# 0480-th step: f(x) = 2.157175 (action=192)
#    current best f(x) = 5.145519 (best action=85)
#
# 0481-th step: f(x) = 2.196917 (action=166)
#    current best f(x) = 5.145519 (best action=85)
#
# 0482-th step: f(x) = 2.247411 (action=325)
#    current best f(x) = 5.145519 (best action=85)
#
# 0483-th step: f(x) = 2.338016 (action=170)
#    current best f(x) = 5.145519 (best action=85)
#
# 0484-th step: f(x) = 1.996575 (action=291)
#    current best f(x) = 5.145519 (best action=85)
#
# 0485-th step: f(x) = 1.980514 (action=249)
#    current best f(x) = 5.145519 (best action=85)
#
# 0486-th step: f(x) = 1.984781 (action=404)
#    current best f(x) = 5.145519 (best action=85)
#
# 0487-th step: f(x) = 2.033832 (action=144)
#    current best f(x) = 5.145519 (best action=85)
#
# 0488-th step: f(x) = 2.176872 (action=487)
#    current best f(x) = 5.145519 (best action=85)
#
# 0489-th step: f(x) = 2.237073 (action=143)
#    current best f(x) = 5.145519 (best action=85)
#
# 0490-th step: f(x) = 2.039260 (action=389)
#    current best f(x) = 5.145519 (best action=85)
#
# 0491-th step: f(x) = 2.035394 (action=125)
#    current best f(x) = 5.145519 (best action=85)
#
# 0492-th step: f(x) = 2.500998 (action=360)
#    current best f(x) = 5.145519 (best action=85)
#
# 0493-th step: f(x) = 2.462729 (action=46)
#    current best f(x) = 5.145519 (best action=85)
#
# 0494-th step: f(x) = 2.651898 (action=457)
#    current best f(x) = 5.145519 (best action=85)
#
# 0495-th step: f(x) = 2.495852 (action=238)
#    current best f(x) = 5.145519 (best action=85)
#
# 0496-th step: f(x) = 2.457504 (action=258)
#    current best f(x) = 5.145519 (best action=85)
#
# 0497-th step: f(x) = 2.420364 (action=380)
#    current best f(x) = 5.145519 (best action=85)
#
# 0498-th step: f(x) = 2.091224 (action=497)
#    current best f(x) = 5.145519 (best action=85)
#
# 0499-th step: f(x) = 2.244285 (action=286)
#    current best f(x) = 5.145519 (best action=85)
#
# 0500-th step: f(x) = 1.987644 (action=16)
#    current best f(x) = 5.145519 (best action=85)

# %%
index_Working_Capacity_unrelevant = np.argmax(Data_unrelevant_features_Working_Capacity.iloc[:, -1].values)
import numpy as np
from sklearn.manifold import TSNE

X_embedded = TSNE(n_components=2).fit_transform(Data_relevant_features_Henry_CO2.iloc[:, :-1].values)
X_embedded.shape

SC1 = np.transpose(X_embedded)[0]
SC2 = np.transpose(X_embedded)[1]

fig, ax = plt.subplots(figsize=(3,3), dpi=150)
ax.scatter(SC1, SC2, c='tab:blue', alpha=0.3)
initial_set = ax.scatter(SC1[minima], SC2[minima], c='gold', label = 'Initial set', alpha = 0.5)
optimum = ax.scatter(SC1[index_Working_Capacity_unrelevant], SC2[index_Working_Capacity_unrelevant], c='red', label = 'Optimum')

ax.legend([initial_set, optimum], ['Initial set', 'Optimum'], loc = 'best')
#labels = ['Initial set', 'Optimum']
#ax.legend(labels)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
plt.show()

# %% [markdown]
# ## Henry H2O

# %% [markdown]
# #### Relevant features

# %%
MEI_index_Henry_H2O_relevant = MEI(Data_relevant_features_Henry_H2O.iloc[:, :-1].values, Data_relevant_features_Henry_H2O.iloc[:, -1].values, 400, 100)
# Out:
#  36%|███▋      | 145/400 [1:06:14<1:56:30, 27.41s/it]

# %%
MLI_index_Henry_H2O_relevant = MLI(Data_relevant_features_Henry_H2O.iloc[:, :-1].values, Data_relevant_features_Henry_H2O.iloc[:, -1].values, 400, 100)
# Out:
#  15%|█▌        | 60/400 [18:29<1:44:44, 18.48s/it]

# %%
MU_index_Henry_H2O_relevant = MU(Data_relevant_features_Henry_H2O.iloc[:, :-1].values, Data_relevant_features_Henry_H2O.iloc[:, -1].values, 400, 100)
# Out:
#  46%|████▋     | 186/400 [1:53:43<2:10:50, 36.68s/it]

# %%
COMBO_PI_Henry_H2O_relevant = COMBO(Data_relevant_features_Henry_H2O, 'PI')
# Out:
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 420.57446795216663
# 50-th epoch, marginal likelihood 337.04118124318495
# 100-th epoch, marginal likelihood 279.20001945068645
# 150-th epoch, marginal likelihood 236.65148469546477
# 200-th epoch, marginal likelihood 204.39182930446677
# 250-th epoch, marginal likelihood 178.9697258179508
# 300-th epoch, marginal likelihood 160.8991206421631
# 350-th epoch, marginal likelihood 146.97395234742189
# 400-th epoch, marginal likelihood 135.75541725039443
# 450-th epoch, marginal likelihood 127.34189085032844
# 500-th epoch, marginal likelihood 120.54120578452829
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.]
#  scale  =  1.0
#  scale2 =  1.0
#
#
# 0101-th step: f(x) = 9.631272 (action=449)
#    current best f(x) = 9.631272 (best action=449)
#
# 0102-th step: f(x) = 10.696403 (action=234)
#    current best f(x) = 10.696403 (best action=234)
#
# 0103-th step: f(x) = 10.066571 (action=367)
#    current best f(x) = 10.696403 (best action=234)
#
# 0104-th step: f(x) = 14.548176 (action=423)
#    current best f(x) = 14.548176 (best action=423)
#
# 0105-th step: f(x) = 14.816282 (action=74)
#    current best f(x) = 14.816282 (best action=74)
#
# 0106-th step: f(x) = 12.981825 (action=393)
#    current best f(x) = 14.816282 (best action=74)
#
# 0107-th step: f(x) = 9.836070 (action=381)
#    current best f(x) = 14.816282 (best action=74)
#
# 0108-th step: f(x) = 11.950303 (action=153)
#    current best f(x) = 14.816282 (best action=74)
#
# 0109-th step: f(x) = 15.329956 (action=0)
#    current best f(x) = 15.329956 (best action=0)
#
# 0110-th step: f(x) = 12.082989 (action=130)
#    current best f(x) = 15.329956 (best action=0)
#
# 0111-th step: f(x) = 10.737033 (action=468)
#    current best f(x) = 15.329956 (best action=0)
#
# 0112-th step: f(x) = 8.687422 (action=208)
#    current best f(x) = 15.329956 (best action=0)
#
# 0113-th step: f(x) = 13.575485 (action=274)
#    current best f(x) = 15.329956 (best action=0)
#
# 0114-th step: f(x) = 10.553975 (action=454)
#    current best f(x) = 15.329956 (best action=0)
#
# 0115-th step: f(x) = 13.161024 (action=63)
#    current best f(x) = 15.329956 (best action=0)
#
# 0116-th step: f(x) = 11.019247 (action=188)
#    current best f(x) = 15.329956 (best action=0)
#
# 0117-th step: f(x) = 13.536260 (action=220)
#    current best f(x) = 15.329956 (best action=0)
#
# 0118-th step: f(x) = 10.654156 (action=370)
#    current best f(x) = 15.329956 (best action=0)
#
# 0119-th step: f(x) = 9.872121 (action=269)
#    current best f(x) = 15.329956 (best action=0)
#
# 0120-th step: f(x) = 12.262703 (action=466)
#    current best f(x) = 15.329956 (best action=0)
#
# 0121-th step: f(x) = 13.215019 (action=491)
#    current best f(x) = 15.329956 (best action=0)
#
# 0122-th step: f(x) = 11.556895 (action=231)
#    current best f(x) = 15.329956 (best action=0)
#
# 0123-th step: f(x) = 11.324810 (action=433)
#    current best f(x) = 15.329956 (best action=0)
#
# 0124-th step: f(x) = 9.521568 (action=90)
#    current best f(x) = 15.329956 (best action=0)
#
# 0125-th step: f(x) = 11.201268 (action=181)
#    current best f(x) = 15.329956 (best action=0)
#
# 0126-th step: f(x) = 13.048880 (action=328)
#    current best f(x) = 15.329956 (best action=0)
#
# 0127-th step: f(x) = 14.000021 (action=107)
#    current best f(x) = 15.329956 (best action=0)
#
# 0128-th step: f(x) = 16.048959 (action=411)
#    current best f(x) = 16.048959 (best action=411)
#
# 0129-th step: f(x) = 8.229530 (action=109)
#    current best f(x) = 16.048959 (best action=411)
#
# 0130-th step: f(x) = 14.760148 (action=114)
#    current best f(x) = 16.048959 (best action=411)
#
# 0131-th step: f(x) = 9.998502 (action=159)
#    current best f(x) = 16.048959 (best action=411)
#
# 0132-th step: f(x) = 12.390168 (action=427)
#    current best f(x) = 16.048959 (best action=411)
#
# 0133-th step: f(x) = 10.176274 (action=12)
#    current best f(x) = 16.048959 (best action=411)
#
# 0134-th step: f(x) = 17.022443 (action=214)
#    current best f(x) = 17.022443 (best action=214)
#
# 0135-th step: f(x) = 12.102233 (action=24)
#    current best f(x) = 17.022443 (best action=214)
#
# 0136-th step: f(x) = 14.557415 (action=80)
#    current best f(x) = 17.022443 (best action=214)
#
# 0137-th step: f(x) = 16.032274 (action=229)
#    current best f(x) = 17.022443 (best action=214)
#
# 0138-th step: f(x) = 10.887112 (action=55)
#    current best f(x) = 17.022443 (best action=214)
#
# 0139-th step: f(x) = 13.124802 (action=280)
#    current best f(x) = 17.022443 (best action=214)
#
# 0140-th step: f(x) = 12.331550 (action=26)
#    current best f(x) = 17.022443 (best action=214)
#
# 0141-th step: f(x) = 10.867616 (action=420)
#    current best f(x) = 17.022443 (best action=214)
#
# 0142-th step: f(x) = 16.932531 (action=254)
#    current best f(x) = 17.022443 (best action=214)
#
# 0143-th step: f(x) = 13.712758 (action=327)
#    current best f(x) = 17.022443 (best action=214)
#
# 0144-th step: f(x) = 17.599405 (action=198)
#    current best f(x) = 17.599405 (best action=198)
#
# 0145-th step: f(x) = 15.516782 (action=317)
#    current best f(x) = 17.599405 (best action=198)
#
# 0146-th step: f(x) = 15.736654 (action=330)
#    current best f(x) = 17.599405 (best action=198)
#
# 0147-th step: f(x) = 12.162878 (action=86)
#    current best f(x) = 17.599405 (best action=198)
#
# 0148-th step: f(x) = 13.413145 (action=363)
#    current best f(x) = 17.599405 (best action=198)
#
# 0149-th step: f(x) = 10.485605 (action=379)
#    current best f(x) = 17.599405 (best action=198)
#
# 0150-th step: f(x) = 15.402149 (action=288)
#    current best f(x) = 17.599405 (best action=198)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 274.61038303600577
# 50-th epoch, marginal likelihood 271.64291013600274
# 100-th epoch, marginal likelihood 270.543122270821
# 150-th epoch, marginal likelihood 271.98849962995746
# 200-th epoch, marginal likelihood 271.9618770689851
# 250-th epoch, marginal likelihood 269.9304289830363
# 300-th epoch, marginal likelihood 269.11962566448454
# 350-th epoch, marginal likelihood 268.9740396518811
# 400-th epoch, marginal likelihood 269.6051116712472
# 450-th epoch, marginal likelihood 269.76074931891833
# 500-th epoch, marginal likelihood 270.39821192248564
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [1.69013688]
#  scale  =  0.6714840093578913
#  scale2 =  0.45089077482334866
#
#
# 0151-th step: f(x) = 10.696245 (action=111)
#    current best f(x) = 17.599405 (best action=198)
#
# 0152-th step: f(x) = 20.745086 (action=112)
#    current best f(x) = 20.745086 (best action=112)
#
# 0153-th step: f(x) = 23.417488 (action=372)
#    current best f(x) = 23.417488 (best action=372)
#
# 0154-th step: f(x) = 23.786587 (action=493)
#    current best f(x) = 23.786587 (best action=493)
#
# 0155-th step: f(x) = 23.321055 (action=250)
#    current best f(x) = 23.786587 (best action=493)
#
# 0156-th step: f(x) = 20.940093 (action=366)
#    current best f(x) = 23.786587 (best action=493)
#
# 0157-th step: f(x) = 19.112447 (action=35)
#    current best f(x) = 23.786587 (best action=493)
#
# 0158-th step: f(x) = 24.074734 (action=462)
#    current best f(x) = 24.074734 (best action=462)
#
# 0159-th step: f(x) = 19.219957 (action=39)
#    current best f(x) = 24.074734 (best action=462)
#
# 0160-th step: f(x) = 15.242032 (action=284)
#    current best f(x) = 24.074734 (best action=462)
#
# 0161-th step: f(x) = 10.098647 (action=209)
#    current best f(x) = 24.074734 (best action=462)
#
# 0162-th step: f(x) = 25.446139 (action=223)
#    current best f(x) = 25.446139 (best action=223)
#
# 0163-th step: f(x) = 17.234512 (action=472)
#    current best f(x) = 25.446139 (best action=223)
#
# 0164-th step: f(x) = 10.714462 (action=131)
#    current best f(x) = 25.446139 (best action=223)
#
# 0165-th step: f(x) = 19.961039 (action=164)
#    current best f(x) = 25.446139 (best action=223)
#
# 0166-th step: f(x) = 19.627496 (action=338)
#    current best f(x) = 25.446139 (best action=223)
#
# 0167-th step: f(x) = 20.178811 (action=426)
#    current best f(x) = 25.446139 (best action=223)
#
# 0168-th step: f(x) = 15.741864 (action=93)
#    current best f(x) = 25.446139 (best action=223)
#
# 0169-th step: f(x) = 8.549548 (action=435)
#    current best f(x) = 25.446139 (best action=223)
#
# 0170-th step: f(x) = 13.382275 (action=77)
#    current best f(x) = 25.446139 (best action=223)
#
# 0171-th step: f(x) = 15.506670 (action=44)
#    current best f(x) = 25.446139 (best action=223)
#
# 0172-th step: f(x) = 12.701915 (action=387)
#    current best f(x) = 25.446139 (best action=223)
#
# 0173-th step: f(x) = 20.785715 (action=357)
#    current best f(x) = 25.446139 (best action=223)
#
# 0174-th step: f(x) = 19.635584 (action=245)
#    current best f(x) = 25.446139 (best action=223)
#
# 0175-th step: f(x) = 20.162669 (action=117)
#    current best f(x) = 25.446139 (best action=223)
#
# 0176-th step: f(x) = 18.700761 (action=53)
#    current best f(x) = 25.446139 (best action=223)
#
# 0177-th step: f(x) = 24.460583 (action=8)
#    current best f(x) = 25.446139 (best action=223)
#
# 0178-th step: f(x) = 19.788790 (action=498)
#    current best f(x) = 25.446139 (best action=223)
#
# 0179-th step: f(x) = 18.367571 (action=118)
#    current best f(x) = 25.446139 (best action=223)
#
# 0180-th step: f(x) = 27.200952 (action=453)
#    current best f(x) = 27.200952 (best action=453)
#
# 0181-th step: f(x) = 22.669884 (action=463)
#    current best f(x) = 27.200952 (best action=453)
#
# 0182-th step: f(x) = 21.085091 (action=311)
#    current best f(x) = 27.200952 (best action=453)
#
# 0183-th step: f(x) = 24.230367 (action=177)
#    current best f(x) = 27.200952 (best action=453)
#
# 0184-th step: f(x) = 19.661390 (action=475)
#    current best f(x) = 27.200952 (best action=453)
#
# 0185-th step: f(x) = 19.121564 (action=323)
#    current best f(x) = 27.200952 (best action=453)
#
# 0186-th step: f(x) = 10.353763 (action=331)
#    current best f(x) = 27.200952 (best action=453)
#
# 0187-th step: f(x) = 9.149075 (action=64)
#    current best f(x) = 27.200952 (best action=453)
#
# 0188-th step: f(x) = 8.325543 (action=102)
#    current best f(x) = 27.200952 (best action=453)
#
# 0189-th step: f(x) = 12.722584 (action=436)
#    current best f(x) = 27.200952 (best action=453)
#
# 0190-th step: f(x) = 14.454270 (action=296)
#    current best f(x) = 27.200952 (best action=453)
#
# 0191-th step: f(x) = 25.615406 (action=359)
#    current best f(x) = 27.200952 (best action=453)
#
# 0192-th step: f(x) = 17.862973 (action=96)
#    current best f(x) = 27.200952 (best action=453)
#
# 0193-th step: f(x) = 11.758832 (action=201)
#    current best f(x) = 27.200952 (best action=453)
#
# 0194-th step: f(x) = 10.309692 (action=3)
#    current best f(x) = 27.200952 (best action=453)
#
# 0195-th step: f(x) = 24.073749 (action=342)
#    current best f(x) = 27.200952 (best action=453)
#
# 0196-th step: f(x) = 21.201857 (action=306)
#    current best f(x) = 27.200952 (best action=453)
#
# 0197-th step: f(x) = 19.087295 (action=144)
#    current best f(x) = 27.200952 (best action=453)
#
# 0198-th step: f(x) = 24.150111 (action=407)
#    current best f(x) = 27.200952 (best action=453)
#
# 0199-th step: f(x) = 22.410886 (action=488)
#    current best f(x) = 27.200952 (best action=453)
#
# 0200-th step: f(x) = 20.166710 (action=461)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 465.24609920915424
# 50-th epoch, marginal likelihood 465.0395279511223
# 100-th epoch, marginal likelihood 465.196073253526
# 150-th epoch, marginal likelihood 466.793104461677
# 200-th epoch, marginal likelihood 465.9380175536956
# 250-th epoch, marginal likelihood 466.1312757130977
# 300-th epoch, marginal likelihood 466.7880653008846
# 350-th epoch, marginal likelihood 467.105443326265
# 400-th epoch, marginal likelihood 466.9646109471619
# 450-th epoch, marginal likelihood 465.805660610807
# 500-th epoch, marginal likelihood 464.7029486045627
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [2.71596797]
#  scale  =  2.726974110849611
#  scale2 =  7.4363878012440265
#
#
# 0201-th step: f(x) = 20.617683 (action=51)
#    current best f(x) = 27.200952 (best action=453)
#
# 0202-th step: f(x) = 8.663025 (action=343)
#    current best f(x) = 27.200952 (best action=453)
#
# 0203-th step: f(x) = 11.039188 (action=140)
#    current best f(x) = 27.200952 (best action=453)
#
# 0204-th step: f(x) = 20.809906 (action=371)
#    current best f(x) = 27.200952 (best action=453)
#
# 0205-th step: f(x) = 11.791428 (action=438)
#    current best f(x) = 27.200952 (best action=453)
#
# 0206-th step: f(x) = 18.947412 (action=54)
#    current best f(x) = 27.200952 (best action=453)
#
# 0207-th step: f(x) = 13.537182 (action=189)
#    current best f(x) = 27.200952 (best action=453)
#
# 0208-th step: f(x) = 9.349041 (action=362)
#    current best f(x) = 27.200952 (best action=453)
#
# 0209-th step: f(x) = 20.592638 (action=394)
#    current best f(x) = 27.200952 (best action=453)
#
# 0210-th step: f(x) = 17.891501 (action=240)
#    current best f(x) = 27.200952 (best action=453)
#
# 0211-th step: f(x) = 20.044179 (action=176)
#    current best f(x) = 27.200952 (best action=453)
#
# 0212-th step: f(x) = 14.540598 (action=345)
#    current best f(x) = 27.200952 (best action=453)
#
# 0213-th step: f(x) = 8.764908 (action=232)
#    current best f(x) = 27.200952 (best action=453)
#
# 0214-th step: f(x) = 11.616195 (action=212)
#    current best f(x) = 27.200952 (best action=453)
#
# 0215-th step: f(x) = 10.125094 (action=444)
#    current best f(x) = 27.200952 (best action=453)
#
# 0216-th step: f(x) = 18.991240 (action=83)
#    current best f(x) = 27.200952 (best action=453)
#
# 0217-th step: f(x) = 11.303103 (action=67)
#    current best f(x) = 27.200952 (best action=453)
#
# 0218-th step: f(x) = 9.774005 (action=196)
#    current best f(x) = 27.200952 (best action=453)
#
# 0219-th step: f(x) = 12.806394 (action=62)
#    current best f(x) = 27.200952 (best action=453)
#
# 0220-th step: f(x) = 9.459370 (action=319)
#    current best f(x) = 27.200952 (best action=453)
#
# 0221-th step: f(x) = 10.921497 (action=320)
#    current best f(x) = 27.200952 (best action=453)
#
# 0222-th step: f(x) = 8.308253 (action=29)
#    current best f(x) = 27.200952 (best action=453)
#
# 0223-th step: f(x) = 11.784874 (action=278)
#    current best f(x) = 27.200952 (best action=453)
#
# 0224-th step: f(x) = 9.011190 (action=360)
#    current best f(x) = 27.200952 (best action=453)
#
# 0225-th step: f(x) = 10.619391 (action=124)
#    current best f(x) = 27.200952 (best action=453)
#
# 0226-th step: f(x) = 25.032813 (action=413)
#    current best f(x) = 27.200952 (best action=453)
#
# 0227-th step: f(x) = 17.797239 (action=283)
#    current best f(x) = 27.200952 (best action=453)
#
# 0228-th step: f(x) = 9.689279 (action=260)
#    current best f(x) = 27.200952 (best action=453)
#
# 0229-th step: f(x) = 13.191300 (action=265)
#    current best f(x) = 27.200952 (best action=453)
#
# 0230-th step: f(x) = 19.434830 (action=281)
#    current best f(x) = 27.200952 (best action=453)
#
# 0231-th step: f(x) = 8.940435 (action=119)
#    current best f(x) = 27.200952 (best action=453)
#
# 0232-th step: f(x) = 11.286286 (action=401)
#    current best f(x) = 27.200952 (best action=453)
#
# 0233-th step: f(x) = 10.040245 (action=442)
#    current best f(x) = 27.200952 (best action=453)
#
# 0234-th step: f(x) = 18.368629 (action=84)
#    current best f(x) = 27.200952 (best action=453)
#
# 0235-th step: f(x) = 23.648870 (action=95)
#    current best f(x) = 27.200952 (best action=453)
#
# 0236-th step: f(x) = 9.912928 (action=203)
#    current best f(x) = 27.200952 (best action=453)
#
# 0237-th step: f(x) = 16.795142 (action=238)
#    current best f(x) = 27.200952 (best action=453)
#
# 0238-th step: f(x) = 9.027180 (action=94)
#    current best f(x) = 27.200952 (best action=453)
#
# 0239-th step: f(x) = 24.720306 (action=219)
#    current best f(x) = 27.200952 (best action=453)
#
# 0240-th step: f(x) = 10.681088 (action=70)
#    current best f(x) = 27.200952 (best action=453)
#
# 0241-th step: f(x) = 10.001095 (action=66)
#    current best f(x) = 27.200952 (best action=453)
#
# 0242-th step: f(x) = 12.995970 (action=246)
#    current best f(x) = 27.200952 (best action=453)
#
# 0243-th step: f(x) = 10.155557 (action=315)
#    current best f(x) = 27.200952 (best action=453)
#
# 0244-th step: f(x) = 19.565801 (action=344)
#    current best f(x) = 27.200952 (best action=453)
#
# 0245-th step: f(x) = 26.956130 (action=440)
#    current best f(x) = 27.200952 (best action=453)
#
# 0246-th step: f(x) = 19.127824 (action=47)
#    current best f(x) = 27.200952 (best action=453)
#
# 0247-th step: f(x) = 8.723741 (action=346)
#    current best f(x) = 27.200952 (best action=453)
#
# 0248-th step: f(x) = 9.474695 (action=277)
#    current best f(x) = 27.200952 (best action=453)
#
# 0249-th step: f(x) = 10.562600 (action=139)
#    current best f(x) = 27.200952 (best action=453)
#
# 0250-th step: f(x) = 12.133077 (action=297)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 611.2787904378406
# 50-th epoch, marginal likelihood 604.2553214321485
# 100-th epoch, marginal likelihood 601.0099372320742
# 150-th epoch, marginal likelihood 599.300244299925
# 200-th epoch, marginal likelihood 597.3293926782591
# 250-th epoch, marginal likelihood 595.9765426070192
# 300-th epoch, marginal likelihood 594.8040029842056
# 350-th epoch, marginal likelihood 593.4090245422343
# 400-th epoch, marginal likelihood 592.6029740786335
# 450-th epoch, marginal likelihood 591.7776324049498
# 500-th epoch, marginal likelihood 590.6649828300467
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.4087224]
#  scale  =  6.23356213411307
#  scale2 =  38.85729687984829
#
#
# 0251-th step: f(x) = 22.536448 (action=180)
#    current best f(x) = 27.200952 (best action=453)
#
# 0252-th step: f(x) = 17.679511 (action=384)
#    current best f(x) = 27.200952 (best action=453)
#
# 0253-th step: f(x) = 24.325384 (action=303)
#    current best f(x) = 27.200952 (best action=453)
#
# 0254-th step: f(x) = 20.552601 (action=318)
#    current best f(x) = 27.200952 (best action=453)
#
# 0255-th step: f(x) = 13.103882 (action=78)
#    current best f(x) = 27.200952 (best action=453)
#
# 0256-th step: f(x) = 11.521340 (action=399)
#    current best f(x) = 27.200952 (best action=453)
#
# 0257-th step: f(x) = 9.939516 (action=184)
#    current best f(x) = 27.200952 (best action=453)
#
# 0258-th step: f(x) = 10.312649 (action=72)
#    current best f(x) = 27.200952 (best action=453)
#
# 0259-th step: f(x) = 9.231417 (action=18)
#    current best f(x) = 27.200952 (best action=453)
#
# 0260-th step: f(x) = 8.604392 (action=395)
#    current best f(x) = 27.200952 (best action=453)
#
# 0261-th step: f(x) = 11.785598 (action=195)
#    current best f(x) = 27.200952 (best action=453)
#
# 0262-th step: f(x) = 10.031485 (action=294)
#    current best f(x) = 27.200952 (best action=453)
#
# 0263-th step: f(x) = 11.549103 (action=271)
#    current best f(x) = 27.200952 (best action=453)
#
# 0264-th step: f(x) = 10.746670 (action=309)
#    current best f(x) = 27.200952 (best action=453)
#
# 0265-th step: f(x) = 19.065142 (action=439)
#    current best f(x) = 27.200952 (best action=453)
#
# 0266-th step: f(x) = 19.575174 (action=6)
#    current best f(x) = 27.200952 (best action=453)
#
# 0267-th step: f(x) = 12.159280 (action=480)
#    current best f(x) = 27.200952 (best action=453)
#
# 0268-th step: f(x) = 8.175553 (action=5)
#    current best f(x) = 27.200952 (best action=453)
#
# 0269-th step: f(x) = 11.208855 (action=443)
#    current best f(x) = 27.200952 (best action=453)
#
# 0270-th step: f(x) = 9.538002 (action=239)
#    current best f(x) = 27.200952 (best action=453)
#
# 0271-th step: f(x) = 17.019654 (action=310)
#    current best f(x) = 27.200952 (best action=453)
#
# 0272-th step: f(x) = 8.518273 (action=100)
#    current best f(x) = 27.200952 (best action=453)
#
# 0273-th step: f(x) = 8.410939 (action=376)
#    current best f(x) = 27.200952 (best action=453)
#
# 0274-th step: f(x) = 8.224445 (action=485)
#    current best f(x) = 27.200952 (best action=453)
#
# 0275-th step: f(x) = 8.192244 (action=403)
#    current best f(x) = 27.200952 (best action=453)
#
# 0276-th step: f(x) = 10.906387 (action=252)
#    current best f(x) = 27.200952 (best action=453)
#
# 0277-th step: f(x) = 9.303758 (action=417)
#    current best f(x) = 27.200952 (best action=453)
#
# 0278-th step: f(x) = 8.649175 (action=459)
#    current best f(x) = 27.200952 (best action=453)
#
# 0279-th step: f(x) = 10.646867 (action=308)
#    current best f(x) = 27.200952 (best action=453)
#
# 0280-th step: f(x) = 10.451722 (action=292)
#    current best f(x) = 27.200952 (best action=453)
#
# 0281-th step: f(x) = 11.060663 (action=368)
#    current best f(x) = 27.200952 (best action=453)
#
# 0282-th step: f(x) = 17.033093 (action=211)
#    current best f(x) = 27.200952 (best action=453)
#
# 0283-th step: f(x) = 10.549001 (action=471)
#    current best f(x) = 27.200952 (best action=453)
#
# 0284-th step: f(x) = 10.112508 (action=422)
#    current best f(x) = 27.200952 (best action=453)
#
# 0285-th step: f(x) = 10.578804 (action=279)
#    current best f(x) = 27.200952 (best action=453)
#
# 0286-th step: f(x) = 11.324984 (action=298)
#    current best f(x) = 27.200952 (best action=453)
#
# 0287-th step: f(x) = 9.614772 (action=122)
#    current best f(x) = 27.200952 (best action=453)
#
# 0288-th step: f(x) = 19.386560 (action=295)
#    current best f(x) = 27.200952 (best action=453)
#
# 0289-th step: f(x) = 10.314477 (action=197)
#    current best f(x) = 27.200952 (best action=453)
#
# 0290-th step: f(x) = 9.166123 (action=21)
#    current best f(x) = 27.200952 (best action=453)
#
# 0291-th step: f(x) = 20.385631 (action=242)
#    current best f(x) = 27.200952 (best action=453)
#
# 0292-th step: f(x) = 11.797766 (action=365)
#    current best f(x) = 27.200952 (best action=453)
#
# 0293-th step: f(x) = 12.872524 (action=408)
#    current best f(x) = 27.200952 (best action=453)
#
# 0294-th step: f(x) = 18.974373 (action=267)
#    current best f(x) = 27.200952 (best action=453)
#
# 0295-th step: f(x) = 8.752795 (action=202)
#    current best f(x) = 27.200952 (best action=453)
#
# 0296-th step: f(x) = 9.398884 (action=104)
#    current best f(x) = 27.200952 (best action=453)
#
# 0297-th step: f(x) = 12.036363 (action=261)
#    current best f(x) = 27.200952 (best action=453)
#
# 0298-th step: f(x) = 11.117079 (action=218)
#    current best f(x) = 27.200952 (best action=453)
#
# 0299-th step: f(x) = 17.255800 (action=457)
#    current best f(x) = 27.200952 (best action=453)
#
# 0300-th step: f(x) = 10.108549 (action=85)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 727.916745585002
# 50-th epoch, marginal likelihood 716.8095609559339
# 100-th epoch, marginal likelihood 710.243060495985
# 150-th epoch, marginal likelihood 706.7166413982895
# 200-th epoch, marginal likelihood 702.4369332133255
# 250-th epoch, marginal likelihood 698.2788641815379
# 300-th epoch, marginal likelihood 696.0406190886738
# 350-th epoch, marginal likelihood 693.6545404332975
# 400-th epoch, marginal likelihood 692.104377306157
# 450-th epoch, marginal likelihood 690.7191700655678
# 500-th epoch, marginal likelihood 689.7490646033446
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.07923859]
#  scale  =  5.4144438717421215
#  scale2 =  29.316202440245814
#
#
# 0301-th step: f(x) = 18.574627 (action=9)
#    current best f(x) = 27.200952 (best action=453)
#
# 0302-th step: f(x) = 19.124220 (action=185)
#    current best f(x) = 27.200952 (best action=453)
#
# 0303-th step: f(x) = 18.494091 (action=37)
#    current best f(x) = 27.200952 (best action=453)
#
# 0304-th step: f(x) = 14.481328 (action=28)
#    current best f(x) = 27.200952 (best action=453)
#
# 0305-th step: f(x) = 9.745295 (action=307)
#    current best f(x) = 27.200952 (best action=453)
#
# 0306-th step: f(x) = 12.303462 (action=358)
#    current best f(x) = 27.200952 (best action=453)
#
# 0307-th step: f(x) = 10.006865 (action=391)
#    current best f(x) = 27.200952 (best action=453)
#
# 0308-th step: f(x) = 8.552751 (action=263)
#    current best f(x) = 27.200952 (best action=453)
#
# 0309-th step: f(x) = 11.106032 (action=38)
#    current best f(x) = 27.200952 (best action=453)
#
# 0310-th step: f(x) = 8.867940 (action=162)
#    current best f(x) = 27.200952 (best action=453)
#
# 0311-th step: f(x) = 10.865881 (action=11)
#    current best f(x) = 27.200952 (best action=453)
#
# 0312-th step: f(x) = 9.148296 (action=478)
#    current best f(x) = 27.200952 (best action=453)
#
# 0313-th step: f(x) = 10.167070 (action=23)
#    current best f(x) = 27.200952 (best action=453)
#
# 0314-th step: f(x) = 10.103281 (action=431)
#    current best f(x) = 27.200952 (best action=453)
#
# 0315-th step: f(x) = 9.597560 (action=61)
#    current best f(x) = 27.200952 (best action=453)
#
# 0316-th step: f(x) = 24.477783 (action=333)
#    current best f(x) = 27.200952 (best action=453)
#
# 0317-th step: f(x) = 20.806511 (action=416)
#    current best f(x) = 27.200952 (best action=453)
#
# 0318-th step: f(x) = 22.780712 (action=286)
#    current best f(x) = 27.200952 (best action=453)
#
# 0319-th step: f(x) = 18.179882 (action=404)
#    current best f(x) = 27.200952 (best action=453)
#
# 0320-th step: f(x) = 10.227301 (action=158)
#    current best f(x) = 27.200952 (best action=453)
#
# 0321-th step: f(x) = 9.593130 (action=251)
#    current best f(x) = 27.200952 (best action=453)
#
# 0322-th step: f(x) = 9.184536 (action=69)
#    current best f(x) = 27.200952 (best action=453)
#
# 0323-th step: f(x) = 18.436723 (action=82)
#    current best f(x) = 27.200952 (best action=453)
#
# 0324-th step: f(x) = 9.374820 (action=22)
#    current best f(x) = 27.200952 (best action=453)
#
# 0325-th step: f(x) = 9.482899 (action=31)
#    current best f(x) = 27.200952 (best action=453)
#
# 0326-th step: f(x) = 10.325013 (action=489)
#    current best f(x) = 27.200952 (best action=453)
#
# 0327-th step: f(x) = 10.802941 (action=13)
#    current best f(x) = 27.200952 (best action=453)
#
# 0328-th step: f(x) = 11.122735 (action=133)
#    current best f(x) = 27.200952 (best action=453)
#
# 0329-th step: f(x) = 12.016624 (action=71)
#    current best f(x) = 27.200952 (best action=453)
#
# 0330-th step: f(x) = 11.181507 (action=465)
#    current best f(x) = 27.200952 (best action=453)
#
# 0331-th step: f(x) = 11.857812 (action=190)
#    current best f(x) = 27.200952 (best action=453)
#
# 0332-th step: f(x) = 9.769790 (action=41)
#    current best f(x) = 27.200952 (best action=453)
#
# 0333-th step: f(x) = 17.765992 (action=206)
#    current best f(x) = 27.200952 (best action=453)
#
# 0334-th step: f(x) = 8.184408 (action=161)
#    current best f(x) = 27.200952 (best action=453)
#
# 0335-th step: f(x) = 12.301324 (action=425)
#    current best f(x) = 27.200952 (best action=453)
#
# 0336-th step: f(x) = 9.807213 (action=40)
#    current best f(x) = 27.200952 (best action=453)
#
# 0337-th step: f(x) = 10.849139 (action=272)
#    current best f(x) = 27.200952 (best action=453)
#
# 0338-th step: f(x) = 8.743393 (action=418)
#    current best f(x) = 27.200952 (best action=453)
#
# 0339-th step: f(x) = 8.388450 (action=106)
#    current best f(x) = 27.200952 (best action=453)
#
# 0340-th step: f(x) = 10.346104 (action=350)
#    current best f(x) = 27.200952 (best action=453)
#
# 0341-th step: f(x) = 10.819696 (action=52)
#    current best f(x) = 27.200952 (best action=453)
#
# 0342-th step: f(x) = 11.245583 (action=492)
#    current best f(x) = 27.200952 (best action=453)
#
# 0343-th step: f(x) = 9.298012 (action=484)
#    current best f(x) = 27.200952 (best action=453)
#
# 0344-th step: f(x) = 9.837844 (action=313)
#    current best f(x) = 27.200952 (best action=453)
#
# 0345-th step: f(x) = 12.965340 (action=482)
#    current best f(x) = 27.200952 (best action=453)
#
# 0346-th step: f(x) = 11.389134 (action=154)
#    current best f(x) = 27.200952 (best action=453)
#
# 0347-th step: f(x) = 9.501531 (action=10)
#    current best f(x) = 27.200952 (best action=453)
#
# 0348-th step: f(x) = 8.592269 (action=336)
#    current best f(x) = 27.200952 (best action=453)
#
# 0349-th step: f(x) = 12.753520 (action=467)
#    current best f(x) = 27.200952 (best action=453)
#
# 0350-th step: f(x) = 10.764082 (action=460)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 862.8543677365155
# 50-th epoch, marginal likelihood 841.9490924870031
# 100-th epoch, marginal likelihood 830.5506556844227
# 150-th epoch, marginal likelihood 816.5706108813954
# 200-th epoch, marginal likelihood 807.5358605801223
# 250-th epoch, marginal likelihood 799.4635179503139
# 300-th epoch, marginal likelihood 794.2987947834107
# 350-th epoch, marginal likelihood 790.7269529690238
# 400-th epoch, marginal likelihood 788.2649564905466
# 450-th epoch, marginal likelihood 786.460304927112
# 500-th epoch, marginal likelihood 785.3360403392737
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.06990818]
#  scale  =  5.0997324975792715
#  scale2 =  26.007271546866114
#
#
# 0351-th step: f(x) = 9.150378 (action=228)
#    current best f(x) = 27.200952 (best action=453)
#
# 0352-th step: f(x) = 8.879206 (action=302)
#    current best f(x) = 27.200952 (best action=453)
#
# 0353-th step: f(x) = 11.569069 (action=316)
#    current best f(x) = 27.200952 (best action=453)
#
# 0354-th step: f(x) = 10.798158 (action=155)
#    current best f(x) = 27.200952 (best action=453)
#
# 0355-th step: f(x) = 8.413187 (action=135)
#    current best f(x) = 27.200952 (best action=453)
#
# 0356-th step: f(x) = 10.886919 (action=305)
#    current best f(x) = 27.200952 (best action=453)
#
# 0357-th step: f(x) = 10.020662 (action=187)
#    current best f(x) = 27.200952 (best action=453)
#
# 0358-th step: f(x) = 10.994084 (action=116)
#    current best f(x) = 27.200952 (best action=453)
#
# 0359-th step: f(x) = 8.459634 (action=437)
#    current best f(x) = 27.200952 (best action=453)
#
# 0360-th step: f(x) = 10.176659 (action=486)
#    current best f(x) = 27.200952 (best action=453)
#
# 0361-th step: f(x) = 8.305630 (action=172)
#    current best f(x) = 27.200952 (best action=453)
#
# 0362-th step: f(x) = 10.462989 (action=101)
#    current best f(x) = 27.200952 (best action=453)
#
# 0363-th step: f(x) = 11.376817 (action=434)
#    current best f(x) = 27.200952 (best action=453)
#
# 0364-th step: f(x) = 8.577983 (action=57)
#    current best f(x) = 27.200952 (best action=453)
#
# 0365-th step: f(x) = 8.072595 (action=337)
#    current best f(x) = 27.200952 (best action=453)
#
# 0366-th step: f(x) = 9.473358 (action=65)
#    current best f(x) = 27.200952 (best action=453)
#
# 0367-th step: f(x) = 9.779923 (action=151)
#    current best f(x) = 27.200952 (best action=453)
#
# 0368-th step: f(x) = 8.764844 (action=105)
#    current best f(x) = 27.200952 (best action=453)
#
# 0369-th step: f(x) = 10.361846 (action=48)
#    current best f(x) = 27.200952 (best action=453)
#
# 0370-th step: f(x) = 9.546641 (action=445)
#    current best f(x) = 27.200952 (best action=453)
#
# 0371-th step: f(x) = 7.317166 (action=352)
#    current best f(x) = 27.200952 (best action=453)
#
# 0372-th step: f(x) = 9.300565 (action=390)
#    current best f(x) = 27.200952 (best action=453)
#
# 0373-th step: f(x) = 10.092387 (action=128)
#    current best f(x) = 27.200952 (best action=453)
#
# 0374-th step: f(x) = 8.775160 (action=127)
#    current best f(x) = 27.200952 (best action=453)
#
# 0375-th step: f(x) = 8.472652 (action=432)
#    current best f(x) = 27.200952 (best action=453)
#
# 0376-th step: f(x) = 8.409145 (action=474)
#    current best f(x) = 27.200952 (best action=453)
#
# 0377-th step: f(x) = 9.672967 (action=446)
#    current best f(x) = 27.200952 (best action=453)
#
# 0378-th step: f(x) = 12.186645 (action=146)
#    current best f(x) = 27.200952 (best action=453)
#
# 0379-th step: f(x) = 10.232971 (action=483)
#    current best f(x) = 27.200952 (best action=453)
#
# 0380-th step: f(x) = 6.968690 (action=400)
#    current best f(x) = 27.200952 (best action=453)
#
# 0381-th step: f(x) = 8.485168 (action=60)
#    current best f(x) = 27.200952 (best action=453)
#
# 0382-th step: f(x) = 7.657826 (action=42)
#    current best f(x) = 27.200952 (best action=453)
#
# 0383-th step: f(x) = 9.947423 (action=179)
#    current best f(x) = 27.200952 (best action=453)
#
# 0384-th step: f(x) = 7.992556 (action=1)
#    current best f(x) = 27.200952 (best action=453)
#
# 0385-th step: f(x) = 8.214925 (action=262)
#    current best f(x) = 27.200952 (best action=453)
#
# 0386-th step: f(x) = 7.401463 (action=207)
#    current best f(x) = 27.200952 (best action=453)
#
# 0387-th step: f(x) = 7.470817 (action=255)
#    current best f(x) = 27.200952 (best action=453)
#
# 0388-th step: f(x) = 6.012032 (action=402)
#    current best f(x) = 27.200952 (best action=453)
#
# 0389-th step: f(x) = 11.007414 (action=92)
#    current best f(x) = 27.200952 (best action=453)
#
# 0390-th step: f(x) = 11.159947 (action=43)
#    current best f(x) = 27.200952 (best action=453)
#
# 0391-th step: f(x) = 7.120582 (action=499)
#    current best f(x) = 27.200952 (best action=453)
#
# 0392-th step: f(x) = 7.620641 (action=264)
#    current best f(x) = 27.200952 (best action=453)
#
# 0393-th step: f(x) = 9.204538 (action=129)
#    current best f(x) = 27.200952 (best action=453)
#
# 0394-th step: f(x) = 8.257007 (action=496)
#    current best f(x) = 27.200952 (best action=453)
#
# 0395-th step: f(x) = 12.216533 (action=4)
#    current best f(x) = 27.200952 (best action=453)
#
# 0396-th step: f(x) = 9.597451 (action=166)
#    current best f(x) = 27.200952 (best action=453)
#
# 0397-th step: f(x) = 7.880260 (action=174)
#    current best f(x) = 27.200952 (best action=453)
#
# 0398-th step: f(x) = 9.264374 (action=415)
#    current best f(x) = 27.200952 (best action=453)
#
# 0399-th step: f(x) = 8.553799 (action=150)
#    current best f(x) = 27.200952 (best action=453)
#
# 0400-th step: f(x) = 9.871811 (action=477)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 962.8326876017418
# 50-th epoch, marginal likelihood 937.86490743261
# 100-th epoch, marginal likelihood 922.90544258076
# 150-th epoch, marginal likelihood 908.450044812987
# 200-th epoch, marginal likelihood 897.5403890409021
# 250-th epoch, marginal likelihood 891.7050279300497
# 300-th epoch, marginal likelihood 886.9157718221438
# 350-th epoch, marginal likelihood 881.7542411019261
# 400-th epoch, marginal likelihood 878.6860499737307
# 450-th epoch, marginal likelihood 877.9268911043073
# 500-th epoch, marginal likelihood 876.4846068007423
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.07450378]
#  scale  =  4.936371631368972
#  scale2 =  24.36776488298436
#
#
# 0401-th step: f(x) = 7.959727 (action=385)
#    current best f(x) = 27.200952 (best action=453)
#
# 0402-th step: f(x) = 8.648269 (action=99)
#    current best f(x) = 27.200952 (best action=453)
#
# 0403-th step: f(x) = 12.510394 (action=168)
#    current best f(x) = 27.200952 (best action=453)
#
# 0404-th step: f(x) = 7.279636 (action=113)
#    current best f(x) = 27.200952 (best action=453)
#
# 0405-th step: f(x) = 10.323454 (action=87)
#    current best f(x) = 27.200952 (best action=453)
#
# 0406-th step: f(x) = 11.709692 (action=259)
#    current best f(x) = 27.200952 (best action=453)
#
# 0407-th step: f(x) = 8.621496 (action=470)
#    current best f(x) = 27.200952 (best action=453)
#
# 0408-th step: f(x) = 11.472193 (action=293)
#    current best f(x) = 27.200952 (best action=453)
#
# 0409-th step: f(x) = 11.181464 (action=97)
#    current best f(x) = 27.200952 (best action=453)
#
# 0410-th step: f(x) = 10.058481 (action=186)
#    current best f(x) = 27.200952 (best action=453)
#
# 0411-th step: f(x) = 6.754841 (action=335)
#    current best f(x) = 27.200952 (best action=453)
#
# 0412-th step: f(x) = 10.202543 (action=275)
#    current best f(x) = 27.200952 (best action=453)
#
# 0413-th step: f(x) = 7.430411 (action=312)
#    current best f(x) = 27.200952 (best action=453)
#
# 0414-th step: f(x) = 12.349684 (action=455)
#    current best f(x) = 27.200952 (best action=453)
#
# 0415-th step: f(x) = 11.323582 (action=361)
#    current best f(x) = 27.200952 (best action=453)
#
# 0416-th step: f(x) = 10.277968 (action=173)
#    current best f(x) = 27.200952 (best action=453)
#
# 0417-th step: f(x) = 8.136360 (action=227)
#    current best f(x) = 27.200952 (best action=453)
#
# 0418-th step: f(x) = 7.766129 (action=224)
#    current best f(x) = 27.200952 (best action=453)
#
# 0419-th step: f(x) = 7.980841 (action=349)
#    current best f(x) = 27.200952 (best action=453)
#
# 0420-th step: f(x) = 8.547200 (action=377)
#    current best f(x) = 27.200952 (best action=453)
#
# 0421-th step: f(x) = 10.755536 (action=16)
#    current best f(x) = 27.200952 (best action=453)
#
# 0422-th step: f(x) = 7.351364 (action=347)
#    current best f(x) = 27.200952 (best action=453)
#
# 0423-th step: f(x) = 9.093463 (action=494)
#    current best f(x) = 27.200952 (best action=453)
#
# 0424-th step: f(x) = 7.791767 (action=273)
#    current best f(x) = 27.200952 (best action=453)
#
# 0425-th step: f(x) = 11.342833 (action=216)
#    current best f(x) = 27.200952 (best action=453)
#
# 0426-th step: f(x) = 7.957569 (action=441)
#    current best f(x) = 27.200952 (best action=453)
#
# 0427-th step: f(x) = 7.818479 (action=34)
#    current best f(x) = 27.200952 (best action=453)
#
# 0428-th step: f(x) = 9.275903 (action=332)
#    current best f(x) = 27.200952 (best action=453)
#
# 0429-th step: f(x) = 9.812435 (action=299)
#    current best f(x) = 27.200952 (best action=453)
#
# 0430-th step: f(x) = 8.675277 (action=17)
#    current best f(x) = 27.200952 (best action=453)
#
# 0431-th step: f(x) = 7.539931 (action=490)
#    current best f(x) = 27.200952 (best action=453)
#
# 0432-th step: f(x) = 9.912229 (action=15)
#    current best f(x) = 27.200952 (best action=453)
#
# 0433-th step: f(x) = 10.005417 (action=169)
#    current best f(x) = 27.200952 (best action=453)
#
# 0434-th step: f(x) = 7.374504 (action=414)
#    current best f(x) = 27.200952 (best action=453)
#
# 0435-th step: f(x) = 7.168218 (action=59)
#    current best f(x) = 27.200952 (best action=453)
#
# 0436-th step: f(x) = 7.182155 (action=2)
#    current best f(x) = 27.200952 (best action=453)
#
# 0437-th step: f(x) = 8.937088 (action=341)
#    current best f(x) = 27.200952 (best action=453)
#
# 0438-th step: f(x) = 7.775188 (action=428)
#    current best f(x) = 27.200952 (best action=453)
#
# 0439-th step: f(x) = 11.788995 (action=221)
#    current best f(x) = 27.200952 (best action=453)
#
# 0440-th step: f(x) = 10.154133 (action=50)
#    current best f(x) = 27.200952 (best action=453)
#
# 0441-th step: f(x) = 11.288276 (action=237)
#    current best f(x) = 27.200952 (best action=453)
#
# 0442-th step: f(x) = 8.795967 (action=354)
#    current best f(x) = 27.200952 (best action=453)
#
# 0443-th step: f(x) = 8.731186 (action=30)
#    current best f(x) = 27.200952 (best action=453)
#
# 0444-th step: f(x) = 11.111703 (action=424)
#    current best f(x) = 27.200952 (best action=453)
#
# 0445-th step: f(x) = 9.504382 (action=322)
#    current best f(x) = 27.200952 (best action=453)
#
# 0446-th step: f(x) = 6.628524 (action=156)
#    current best f(x) = 27.200952 (best action=453)
#
# 0447-th step: f(x) = 7.934130 (action=452)
#    current best f(x) = 27.200952 (best action=453)
#
# 0448-th step: f(x) = 11.993764 (action=448)
#    current best f(x) = 27.200952 (best action=453)
#
# 0449-th step: f(x) = 7.833366 (action=137)
#    current best f(x) = 27.200952 (best action=453)
#
# 0450-th step: f(x) = 10.475035 (action=145)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 1054.519889350473
# 50-th epoch, marginal likelihood 1032.254983654735
# 100-th epoch, marginal likelihood 1014.8088327066686
# 150-th epoch, marginal likelihood 994.3612248632196
# 200-th epoch, marginal likelihood 985.4175802547651
# 250-th epoch, marginal likelihood 978.0486891853807
# 300-th epoch, marginal likelihood 971.7583344513309
# 350-th epoch, marginal likelihood 969.0885443794091
# 400-th epoch, marginal likelihood 967.4209903687097
# 450-th epoch, marginal likelihood 965.5663055478004
# 500-th epoch, marginal likelihood 964.1625120519802
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.04832645]
#  scale  =  4.872564906365311
#  scale2 =  23.741888766742797
#
#
# 0451-th step: f(x) = 8.651240 (action=324)
#    current best f(x) = 27.200952 (best action=453)
#
# 0452-th step: f(x) = 11.093591 (action=194)
#    current best f(x) = 27.200952 (best action=453)
#
# 0453-th step: f(x) = 8.989613 (action=405)
#    current best f(x) = 27.200952 (best action=453)
#
# 0454-th step: f(x) = 11.381385 (action=68)
#    current best f(x) = 27.200952 (best action=453)
#
# 0455-th step: f(x) = 10.768150 (action=134)
#    current best f(x) = 27.200952 (best action=453)
#
# 0456-th step: f(x) = 10.813239 (action=458)
#    current best f(x) = 27.200952 (best action=453)
#
# 0457-th step: f(x) = 9.048077 (action=152)
#    current best f(x) = 27.200952 (best action=453)
#
# 0458-th step: f(x) = 10.990948 (action=495)
#    current best f(x) = 27.200952 (best action=453)
#
# 0459-th step: f(x) = 8.813346 (action=409)
#    current best f(x) = 27.200952 (best action=453)
#
# 0460-th step: f(x) = 7.061866 (action=374)
#    current best f(x) = 27.200952 (best action=453)
#
# 0461-th step: f(x) = 12.072616 (action=213)
#    current best f(x) = 27.200952 (best action=453)
#
# 0462-th step: f(x) = 7.418187 (action=304)
#    current best f(x) = 27.200952 (best action=453)
#
# 0463-th step: f(x) = 8.476657 (action=285)
#    current best f(x) = 27.200952 (best action=453)
#
# 0464-th step: f(x) = 12.638871 (action=76)
#    current best f(x) = 27.200952 (best action=453)
#
# 0465-th step: f(x) = 9.629406 (action=473)
#    current best f(x) = 27.200952 (best action=453)
#
# 0466-th step: f(x) = 10.293233 (action=430)
#    current best f(x) = 27.200952 (best action=453)
#
# 0467-th step: f(x) = 9.914487 (action=450)
#    current best f(x) = 27.200952 (best action=453)
#
# 0468-th step: f(x) = 7.343724 (action=165)
#    current best f(x) = 27.200952 (best action=453)
#
# 0469-th step: f(x) = 10.557070 (action=412)
#    current best f(x) = 27.200952 (best action=453)
#
# 0470-th step: f(x) = 10.122503 (action=314)
#    current best f(x) = 27.200952 (best action=453)
#
# 0471-th step: f(x) = 8.927517 (action=123)
#    current best f(x) = 27.200952 (best action=453)
#
# 0472-th step: f(x) = 8.043984 (action=356)
#    current best f(x) = 27.200952 (best action=453)
#
# 0473-th step: f(x) = 7.310182 (action=419)
#    current best f(x) = 27.200952 (best action=453)
#
# 0474-th step: f(x) = 8.646613 (action=421)
#    current best f(x) = 27.200952 (best action=453)
#
# 0475-th step: f(x) = 7.959454 (action=210)
#    current best f(x) = 27.200952 (best action=453)
#
# 0476-th step: f(x) = 7.968659 (action=193)
#    current best f(x) = 27.200952 (best action=453)
#
# 0477-th step: f(x) = 8.350529 (action=340)
#    current best f(x) = 27.200952 (best action=453)
#
# 0478-th step: f(x) = 11.497698 (action=398)
#    current best f(x) = 27.200952 (best action=453)
#
# 0479-th step: f(x) = 7.445096 (action=79)
#    current best f(x) = 27.200952 (best action=453)
#
# 0480-th step: f(x) = 10.157350 (action=98)
#    current best f(x) = 27.200952 (best action=453)
#
# 0481-th step: f(x) = 10.307702 (action=235)
#    current best f(x) = 27.200952 (best action=453)
#
# 0482-th step: f(x) = 8.701103 (action=120)
#    current best f(x) = 27.200952 (best action=453)
#
# 0483-th step: f(x) = 6.943171 (action=58)
#    current best f(x) = 27.200952 (best action=453)
#
# 0484-th step: f(x) = 8.484439 (action=447)
#    current best f(x) = 27.200952 (best action=453)
#
# 0485-th step: f(x) = 8.466462 (action=56)
#    current best f(x) = 27.200952 (best action=453)
#
# 0486-th step: f(x) = 7.286233 (action=389)
#    current best f(x) = 27.200952 (best action=453)
#
# 0487-th step: f(x) = 6.690932 (action=167)
#    current best f(x) = 27.200952 (best action=453)
#
# 0488-th step: f(x) = 7.929785 (action=429)
#    current best f(x) = 27.200952 (best action=453)
#
# 0489-th step: f(x) = 7.216754 (action=14)
#    current best f(x) = 27.200952 (best action=453)
#
# 0490-th step: f(x) = 7.917562 (action=143)
#    current best f(x) = 27.200952 (best action=453)
#
# 0491-th step: f(x) = 6.479199 (action=91)
#    current best f(x) = 27.200952 (best action=453)
#
# 0492-th step: f(x) = 7.974901 (action=147)
#    current best f(x) = 27.200952 (best action=453)
#
# 0493-th step: f(x) = 6.967438 (action=115)
#    current best f(x) = 27.200952 (best action=453)
#
# 0494-th step: f(x) = 7.295925 (action=386)
#    current best f(x) = 27.200952 (best action=453)
#
# 0495-th step: f(x) = 7.872840 (action=373)
#    current best f(x) = 27.200952 (best action=453)
#
# 0496-th step: f(x) = 7.546737 (action=110)
#    current best f(x) = 27.200952 (best action=453)
#
# 0497-th step: f(x) = 7.379850 (action=244)
#    current best f(x) = 27.200952 (best action=453)
#
# 0498-th step: f(x) = 11.512751 (action=456)
#    current best f(x) = 27.200952 (best action=453)
#
# 0499-th step: f(x) = 10.412183 (action=247)
#    current best f(x) = 27.200952 (best action=453)
#
# 0500-th step: f(x) = 8.994670 (action=170)
#    current best f(x) = 27.200952 (best action=453)

# %%
COMBO_EI_Henry_H2O_relevant = COMBO(Data_relevant_features_Henry_H2O, 'EI')
# Out:
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 401.3852109666326
# 50-th epoch, marginal likelihood 322.27581227420285
# 100-th epoch, marginal likelihood 265.99044441426156
# 150-th epoch, marginal likelihood 224.94775209966633
# 200-th epoch, marginal likelihood 193.9614850436858
# 250-th epoch, marginal likelihood 172.1940030092809
# 300-th epoch, marginal likelihood 154.78123028236752
# 350-th epoch, marginal likelihood 142.08380163051442
# 400-th epoch, marginal likelihood 131.17126628102682
# 450-th epoch, marginal likelihood 122.7125951496197
# 500-th epoch, marginal likelihood 116.22044053085146
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.]
#  scale  =  1.0
#  scale2 =  1.0
#
#
# 0101-th step: f(x) = 9.631272 (action=449)
#    current best f(x) = 9.631272 (best action=449)
#
# 0102-th step: f(x) = 10.696403 (action=234)
#    current best f(x) = 10.696403 (best action=234)
#
# 0103-th step: f(x) = 10.066571 (action=367)
#    current best f(x) = 10.696403 (best action=234)
#
# 0104-th step: f(x) = 14.548176 (action=423)
#    current best f(x) = 14.548176 (best action=423)
#
# 0105-th step: f(x) = 14.816282 (action=74)
#    current best f(x) = 14.816282 (best action=74)
#
# 0106-th step: f(x) = 12.981825 (action=393)
#    current best f(x) = 14.816282 (best action=74)
#
# 0107-th step: f(x) = 9.836070 (action=381)
#    current best f(x) = 14.816282 (best action=74)
#
# 0108-th step: f(x) = 11.950303 (action=153)
#    current best f(x) = 14.816282 (best action=74)
#
# 0109-th step: f(x) = 10.737033 (action=468)
#    current best f(x) = 14.816282 (best action=74)
#
# 0110-th step: f(x) = 15.329956 (action=0)
#    current best f(x) = 15.329956 (best action=0)
#
# 0111-th step: f(x) = 12.082989 (action=130)
#    current best f(x) = 15.329956 (best action=0)
#
# 0112-th step: f(x) = 8.687422 (action=208)
#    current best f(x) = 15.329956 (best action=0)
#
# 0113-th step: f(x) = 13.575485 (action=274)
#    current best f(x) = 15.329956 (best action=0)
#
# 0114-th step: f(x) = 10.553975 (action=454)
#    current best f(x) = 15.329956 (best action=0)
#
# 0115-th step: f(x) = 13.161024 (action=63)
#    current best f(x) = 15.329956 (best action=0)
#
# 0116-th step: f(x) = 11.019247 (action=188)
#    current best f(x) = 15.329956 (best action=0)
#
# 0117-th step: f(x) = 14.000021 (action=107)
#    current best f(x) = 15.329956 (best action=0)
#
# 0118-th step: f(x) = 16.048959 (action=411)
#    current best f(x) = 16.048959 (best action=411)
#
# 0119-th step: f(x) = 8.229530 (action=109)
#    current best f(x) = 16.048959 (best action=411)
#
# 0120-th step: f(x) = 14.760148 (action=114)
#    current best f(x) = 16.048959 (best action=411)
#
# 0121-th step: f(x) = 9.998502 (action=159)
#    current best f(x) = 16.048959 (best action=411)
#
# 0122-th step: f(x) = 12.390168 (action=427)
#    current best f(x) = 16.048959 (best action=411)
#
# 0123-th step: f(x) = 9.521568 (action=90)
#    current best f(x) = 16.048959 (best action=411)
#
# 0124-th step: f(x) = 13.536260 (action=220)
#    current best f(x) = 16.048959 (best action=411)
#
# 0125-th step: f(x) = 10.654156 (action=370)
#    current best f(x) = 16.048959 (best action=411)
#
# 0126-th step: f(x) = 9.872121 (action=269)
#    current best f(x) = 16.048959 (best action=411)
#
# 0127-th step: f(x) = 12.262703 (action=466)
#    current best f(x) = 16.048959 (best action=411)
#
# 0128-th step: f(x) = 13.215019 (action=491)
#    current best f(x) = 16.048959 (best action=411)
#
# 0129-th step: f(x) = 11.556895 (action=231)
#    current best f(x) = 16.048959 (best action=411)
#
# 0130-th step: f(x) = 11.324810 (action=433)
#    current best f(x) = 16.048959 (best action=411)
#
# 0131-th step: f(x) = 13.048880 (action=328)
#    current best f(x) = 16.048959 (best action=411)
#
# 0132-th step: f(x) = 11.201268 (action=181)
#    current best f(x) = 16.048959 (best action=411)
#
# 0133-th step: f(x) = 10.176274 (action=12)
#    current best f(x) = 16.048959 (best action=411)
#
# 0134-th step: f(x) = 17.022443 (action=214)
#    current best f(x) = 17.022443 (best action=214)
#
# 0135-th step: f(x) = 12.102233 (action=24)
#    current best f(x) = 17.022443 (best action=214)
#
# 0136-th step: f(x) = 14.557415 (action=80)
#    current best f(x) = 17.022443 (best action=214)
#
# 0137-th step: f(x) = 16.032274 (action=229)
#    current best f(x) = 17.022443 (best action=214)
#
# 0138-th step: f(x) = 10.887112 (action=55)
#    current best f(x) = 17.022443 (best action=214)
#
# 0139-th step: f(x) = 13.124802 (action=280)
#    current best f(x) = 17.022443 (best action=214)
#
# 0140-th step: f(x) = 12.331550 (action=26)
#    current best f(x) = 17.022443 (best action=214)
#
# 0141-th step: f(x) = 10.867616 (action=420)
#    current best f(x) = 17.022443 (best action=214)
#
# 0142-th step: f(x) = 16.932531 (action=254)
#    current best f(x) = 17.022443 (best action=214)
#
# 0143-th step: f(x) = 13.712758 (action=327)
#    current best f(x) = 17.022443 (best action=214)
#
# 0144-th step: f(x) = 17.599405 (action=198)
#    current best f(x) = 17.599405 (best action=198)
#
# 0145-th step: f(x) = 15.516782 (action=317)
#    current best f(x) = 17.599405 (best action=198)
#
# 0146-th step: f(x) = 15.736654 (action=330)
#    current best f(x) = 17.599405 (best action=198)
#
# 0147-th step: f(x) = 12.162878 (action=86)
#    current best f(x) = 17.599405 (best action=198)
#
# 0148-th step: f(x) = 13.413145 (action=363)
#    current best f(x) = 17.599405 (best action=198)
#
# 0149-th step: f(x) = 10.485605 (action=379)
#    current best f(x) = 17.599405 (best action=198)
#
# 0150-th step: f(x) = 12.995970 (action=246)
#    current best f(x) = 17.599405 (best action=198)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 270.40024604657606
# 50-th epoch, marginal likelihood 269.1746572677588
# 100-th epoch, marginal likelihood 267.4097283720391
# 150-th epoch, marginal likelihood 268.13847504051625
# 200-th epoch, marginal likelihood 267.76242395636615
# 250-th epoch, marginal likelihood 267.55572297495985
# 300-th epoch, marginal likelihood 267.5200055950319
# 350-th epoch, marginal likelihood 267.7487680752685
# 400-th epoch, marginal likelihood 267.2498205418232
# 450-th epoch, marginal likelihood 267.16909204839607
# 500-th epoch, marginal likelihood 266.6648460491387
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [1.65781029]
#  scale  =  0.669824181261729
#  scale2 =  0.44866443380294563
#
#
# 0151-th step: f(x) = 10.696245 (action=111)
#    current best f(x) = 17.599405 (best action=198)
#
# 0152-th step: f(x) = 15.402149 (action=288)
#    current best f(x) = 17.599405 (best action=198)
#
# 0153-th step: f(x) = 20.745086 (action=112)
#    current best f(x) = 20.745086 (best action=112)
#
# 0154-th step: f(x) = 23.417488 (action=372)
#    current best f(x) = 23.417488 (best action=372)
#
# 0155-th step: f(x) = 23.786587 (action=493)
#    current best f(x) = 23.786587 (best action=493)
#
# 0156-th step: f(x) = 23.321055 (action=250)
#    current best f(x) = 23.786587 (best action=493)
#
# 0157-th step: f(x) = 20.940093 (action=366)
#    current best f(x) = 23.786587 (best action=493)
#
# 0158-th step: f(x) = 19.112447 (action=35)
#    current best f(x) = 23.786587 (best action=493)
#
# 0159-th step: f(x) = 24.074734 (action=462)
#    current best f(x) = 24.074734 (best action=462)
#
# 0160-th step: f(x) = 19.219957 (action=39)
#    current best f(x) = 24.074734 (best action=462)
#
# 0161-th step: f(x) = 15.242032 (action=284)
#    current best f(x) = 24.074734 (best action=462)
#
# 0162-th step: f(x) = 10.098647 (action=209)
#    current best f(x) = 24.074734 (best action=462)
#
# 0163-th step: f(x) = 25.446139 (action=223)
#    current best f(x) = 25.446139 (best action=223)
#
# 0164-th step: f(x) = 17.234512 (action=472)
#    current best f(x) = 25.446139 (best action=223)
#
# 0165-th step: f(x) = 10.714462 (action=131)
#    current best f(x) = 25.446139 (best action=223)
#
# 0166-th step: f(x) = 19.961039 (action=164)
#    current best f(x) = 25.446139 (best action=223)
#
# 0167-th step: f(x) = 19.627496 (action=338)
#    current best f(x) = 25.446139 (best action=223)
#
# 0168-th step: f(x) = 20.178811 (action=426)
#    current best f(x) = 25.446139 (best action=223)
#
# 0169-th step: f(x) = 15.741864 (action=93)
#    current best f(x) = 25.446139 (best action=223)
#
# 0170-th step: f(x) = 8.549548 (action=435)
#    current best f(x) = 25.446139 (best action=223)
#
# 0171-th step: f(x) = 13.382275 (action=77)
#    current best f(x) = 25.446139 (best action=223)
#
# 0172-th step: f(x) = 15.506670 (action=44)
#    current best f(x) = 25.446139 (best action=223)
#
# 0173-th step: f(x) = 12.701915 (action=387)
#    current best f(x) = 25.446139 (best action=223)
#
# 0174-th step: f(x) = 20.785715 (action=357)
#    current best f(x) = 25.446139 (best action=223)
#
# 0175-th step: f(x) = 19.635584 (action=245)
#    current best f(x) = 25.446139 (best action=223)
#
# 0176-th step: f(x) = 20.162669 (action=117)
#    current best f(x) = 25.446139 (best action=223)
#
# 0177-th step: f(x) = 18.700761 (action=53)
#    current best f(x) = 25.446139 (best action=223)
#
# 0178-th step: f(x) = 24.460583 (action=8)
#    current best f(x) = 25.446139 (best action=223)
#
# 0179-th step: f(x) = 19.788790 (action=498)
#    current best f(x) = 25.446139 (best action=223)
#
# 0180-th step: f(x) = 18.367571 (action=118)
#    current best f(x) = 25.446139 (best action=223)
#
# 0181-th step: f(x) = 27.200952 (action=453)
#    current best f(x) = 27.200952 (best action=453)
#
# 0182-th step: f(x) = 22.669884 (action=463)
#    current best f(x) = 27.200952 (best action=453)
#
# 0183-th step: f(x) = 21.085091 (action=311)
#    current best f(x) = 27.200952 (best action=453)
#
# 0184-th step: f(x) = 24.230367 (action=177)
#    current best f(x) = 27.200952 (best action=453)
#
# 0185-th step: f(x) = 19.661390 (action=475)
#    current best f(x) = 27.200952 (best action=453)
#
# 0186-th step: f(x) = 19.121564 (action=323)
#    current best f(x) = 27.200952 (best action=453)
#
# 0187-th step: f(x) = 10.353763 (action=331)
#    current best f(x) = 27.200952 (best action=453)
#
# 0188-th step: f(x) = 9.149075 (action=64)
#    current best f(x) = 27.200952 (best action=453)
#
# 0189-th step: f(x) = 12.722584 (action=436)
#    current best f(x) = 27.200952 (best action=453)
#
# 0190-th step: f(x) = 8.325543 (action=102)
#    current best f(x) = 27.200952 (best action=453)
#
# 0191-th step: f(x) = 25.615406 (action=359)
#    current best f(x) = 27.200952 (best action=453)
#
# 0192-th step: f(x) = 17.862973 (action=96)
#    current best f(x) = 27.200952 (best action=453)
#
# 0193-th step: f(x) = 10.309692 (action=3)
#    current best f(x) = 27.200952 (best action=453)
#
# 0194-th step: f(x) = 11.758832 (action=201)
#    current best f(x) = 27.200952 (best action=453)
#
# 0195-th step: f(x) = 24.073749 (action=342)
#    current best f(x) = 27.200952 (best action=453)
#
# 0196-th step: f(x) = 21.201857 (action=306)
#    current best f(x) = 27.200952 (best action=453)
#
# 0197-th step: f(x) = 19.087295 (action=144)
#    current best f(x) = 27.200952 (best action=453)
#
# 0198-th step: f(x) = 24.150111 (action=407)
#    current best f(x) = 27.200952 (best action=453)
#
# 0199-th step: f(x) = 22.410886 (action=488)
#    current best f(x) = 27.200952 (best action=453)
#
# 0200-th step: f(x) = 20.166710 (action=461)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 463.6902404527525
# 50-th epoch, marginal likelihood 463.9530684134012
# 100-th epoch, marginal likelihood 464.30567227066916
# 150-th epoch, marginal likelihood 464.3339771706453
# 200-th epoch, marginal likelihood 465.57757319428515
# 250-th epoch, marginal likelihood 465.34162553469884
# 300-th epoch, marginal likelihood 464.6815120490709
# 350-th epoch, marginal likelihood 465.74957751486454
# 400-th epoch, marginal likelihood 464.0694552133655
# 450-th epoch, marginal likelihood 465.0319622118089
# 500-th epoch, marginal likelihood 464.70523503987994
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [2.67021609]
#  scale  =  2.6986935607410434
#  scale2 =  7.282946934785172
#
#
# 0201-th step: f(x) = 20.617683 (action=51)
#    current best f(x) = 27.200952 (best action=453)
#
# 0202-th step: f(x) = 8.663025 (action=343)
#    current best f(x) = 27.200952 (best action=453)
#
# 0203-th step: f(x) = 11.039188 (action=140)
#    current best f(x) = 27.200952 (best action=453)
#
# 0204-th step: f(x) = 11.791428 (action=438)
#    current best f(x) = 27.200952 (best action=453)
#
# 0205-th step: f(x) = 20.809906 (action=371)
#    current best f(x) = 27.200952 (best action=453)
#
# 0206-th step: f(x) = 13.537182 (action=189)
#    current best f(x) = 27.200952 (best action=453)
#
# 0207-th step: f(x) = 9.349041 (action=362)
#    current best f(x) = 27.200952 (best action=453)
#
# 0208-th step: f(x) = 18.947412 (action=54)
#    current best f(x) = 27.200952 (best action=453)
#
# 0209-th step: f(x) = 20.592638 (action=394)
#    current best f(x) = 27.200952 (best action=453)
#
# 0210-th step: f(x) = 17.891501 (action=240)
#    current best f(x) = 27.200952 (best action=453)
#
# 0211-th step: f(x) = 14.540598 (action=345)
#    current best f(x) = 27.200952 (best action=453)
#
# 0212-th step: f(x) = 20.044179 (action=176)
#    current best f(x) = 27.200952 (best action=453)
#
# 0213-th step: f(x) = 8.764908 (action=232)
#    current best f(x) = 27.200952 (best action=453)
#
# 0214-th step: f(x) = 14.454270 (action=296)
#    current best f(x) = 27.200952 (best action=453)
#
# 0215-th step: f(x) = 11.616195 (action=212)
#    current best f(x) = 27.200952 (best action=453)
#
# 0216-th step: f(x) = 10.125094 (action=444)
#    current best f(x) = 27.200952 (best action=453)
#
# 0217-th step: f(x) = 18.991240 (action=83)
#    current best f(x) = 27.200952 (best action=453)
#
# 0218-th step: f(x) = 9.774005 (action=196)
#    current best f(x) = 27.200952 (best action=453)
#
# 0219-th step: f(x) = 12.806394 (action=62)
#    current best f(x) = 27.200952 (best action=453)
#
# 0220-th step: f(x) = 9.459370 (action=319)
#    current best f(x) = 27.200952 (best action=453)
#
# 0221-th step: f(x) = 10.921497 (action=320)
#    current best f(x) = 27.200952 (best action=453)
#
# 0222-th step: f(x) = 8.308253 (action=29)
#    current best f(x) = 27.200952 (best action=453)
#
# 0223-th step: f(x) = 11.303103 (action=67)
#    current best f(x) = 27.200952 (best action=453)
#
# 0224-th step: f(x) = 9.011190 (action=360)
#    current best f(x) = 27.200952 (best action=453)
#
# 0225-th step: f(x) = 11.784874 (action=278)
#    current best f(x) = 27.200952 (best action=453)
#
# 0226-th step: f(x) = 10.619391 (action=124)
#    current best f(x) = 27.200952 (best action=453)
#
# 0227-th step: f(x) = 9.689279 (action=260)
#    current best f(x) = 27.200952 (best action=453)
#
# 0228-th step: f(x) = 25.032813 (action=413)
#    current best f(x) = 27.200952 (best action=453)
#
# 0229-th step: f(x) = 17.797239 (action=283)
#    current best f(x) = 27.200952 (best action=453)
#
# 0230-th step: f(x) = 8.940435 (action=119)
#    current best f(x) = 27.200952 (best action=453)
#
# 0231-th step: f(x) = 13.191300 (action=265)
#    current best f(x) = 27.200952 (best action=453)
#
# 0232-th step: f(x) = 19.434830 (action=281)
#    current best f(x) = 27.200952 (best action=453)
#
# 0233-th step: f(x) = 11.286286 (action=401)
#    current best f(x) = 27.200952 (best action=453)
#
# 0234-th step: f(x) = 10.040245 (action=442)
#    current best f(x) = 27.200952 (best action=453)
#
# 0235-th step: f(x) = 18.368629 (action=84)
#    current best f(x) = 27.200952 (best action=453)
#
# 0236-th step: f(x) = 23.648870 (action=95)
#    current best f(x) = 27.200952 (best action=453)
#
# 0237-th step: f(x) = 9.912928 (action=203)
#    current best f(x) = 27.200952 (best action=453)
#
# 0238-th step: f(x) = 16.795142 (action=238)
#    current best f(x) = 27.200952 (best action=453)
#
# 0239-th step: f(x) = 9.027180 (action=94)
#    current best f(x) = 27.200952 (best action=453)
#
# 0240-th step: f(x) = 24.720306 (action=219)
#    current best f(x) = 27.200952 (best action=453)
#
# 0241-th step: f(x) = 10.681088 (action=70)
#    current best f(x) = 27.200952 (best action=453)
#
# 0242-th step: f(x) = 10.001095 (action=66)
#    current best f(x) = 27.200952 (best action=453)
#
# 0243-th step: f(x) = 10.155557 (action=315)
#    current best f(x) = 27.200952 (best action=453)
#
# 0244-th step: f(x) = 19.565801 (action=344)
#    current best f(x) = 27.200952 (best action=453)
#
# 0245-th step: f(x) = 26.956130 (action=440)
#    current best f(x) = 27.200952 (best action=453)
#
# 0246-th step: f(x) = 19.127824 (action=47)
#    current best f(x) = 27.200952 (best action=453)
#
# 0247-th step: f(x) = 8.723741 (action=346)
#    current best f(x) = 27.200952 (best action=453)
#
# 0248-th step: f(x) = 9.474695 (action=277)
#    current best f(x) = 27.200952 (best action=453)
#
# 0249-th step: f(x) = 10.562600 (action=139)
#    current best f(x) = 27.200952 (best action=453)
#
# 0250-th step: f(x) = 12.133077 (action=297)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 610.3365329093672
# 50-th epoch, marginal likelihood 605.0762323057661
# 100-th epoch, marginal likelihood 602.5934434271369
# 150-th epoch, marginal likelihood 600.3324614769309
# 200-th epoch, marginal likelihood 598.8826254628264
# 250-th epoch, marginal likelihood 596.988543392514
# 300-th epoch, marginal likelihood 595.3659039596756
# 350-th epoch, marginal likelihood 594.1358723252424
# 400-th epoch, marginal likelihood 592.7296387543674
# 450-th epoch, marginal likelihood 591.6062467569454
# 500-th epoch, marginal likelihood 590.9709575809188
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.45903554]
#  scale  =  6.207549710511475
#  scale2 =  38.533673408471095
#
#
# 0251-th step: f(x) = 22.536448 (action=180)
#    current best f(x) = 27.200952 (best action=453)
#
# 0252-th step: f(x) = 17.679511 (action=384)
#    current best f(x) = 27.200952 (best action=453)
#
# 0253-th step: f(x) = 24.325384 (action=303)
#    current best f(x) = 27.200952 (best action=453)
#
# 0254-th step: f(x) = 20.552601 (action=318)
#    current best f(x) = 27.200952 (best action=453)
#
# 0255-th step: f(x) = 13.103882 (action=78)
#    current best f(x) = 27.200952 (best action=453)
#
# 0256-th step: f(x) = 11.521340 (action=399)
#    current best f(x) = 27.200952 (best action=453)
#
# 0257-th step: f(x) = 9.939516 (action=184)
#    current best f(x) = 27.200952 (best action=453)
#
# 0258-th step: f(x) = 10.312649 (action=72)
#    current best f(x) = 27.200952 (best action=453)
#
# 0259-th step: f(x) = 9.231417 (action=18)
#    current best f(x) = 27.200952 (best action=453)
#
# 0260-th step: f(x) = 8.604392 (action=395)
#    current best f(x) = 27.200952 (best action=453)
#
# 0261-th step: f(x) = 11.785598 (action=195)
#    current best f(x) = 27.200952 (best action=453)
#
# 0262-th step: f(x) = 11.549103 (action=271)
#    current best f(x) = 27.200952 (best action=453)
#
# 0263-th step: f(x) = 10.031485 (action=294)
#    current best f(x) = 27.200952 (best action=453)
#
# 0264-th step: f(x) = 10.746670 (action=309)
#    current best f(x) = 27.200952 (best action=453)
#
# 0265-th step: f(x) = 19.065142 (action=439)
#    current best f(x) = 27.200952 (best action=453)
#
# 0266-th step: f(x) = 8.175553 (action=5)
#    current best f(x) = 27.200952 (best action=453)
#
# 0267-th step: f(x) = 12.159280 (action=480)
#    current best f(x) = 27.200952 (best action=453)
#
# 0268-th step: f(x) = 19.575174 (action=6)
#    current best f(x) = 27.200952 (best action=453)
#
# 0269-th step: f(x) = 11.208855 (action=443)
#    current best f(x) = 27.200952 (best action=453)
#
# 0270-th step: f(x) = 9.538002 (action=239)
#    current best f(x) = 27.200952 (best action=453)
#
# 0271-th step: f(x) = 17.019654 (action=310)
#    current best f(x) = 27.200952 (best action=453)
#
# 0272-th step: f(x) = 8.518273 (action=100)
#    current best f(x) = 27.200952 (best action=453)
#
# 0273-th step: f(x) = 8.410939 (action=376)
#    current best f(x) = 27.200952 (best action=453)
#
# 0274-th step: f(x) = 8.224445 (action=485)
#    current best f(x) = 27.200952 (best action=453)
#
# 0275-th step: f(x) = 8.192244 (action=403)
#    current best f(x) = 27.200952 (best action=453)
#
# 0276-th step: f(x) = 10.906387 (action=252)
#    current best f(x) = 27.200952 (best action=453)
#
# 0277-th step: f(x) = 9.303758 (action=417)
#    current best f(x) = 27.200952 (best action=453)
#
# 0278-th step: f(x) = 8.649175 (action=459)
#    current best f(x) = 27.200952 (best action=453)
#
# 0279-th step: f(x) = 10.646867 (action=308)
#    current best f(x) = 27.200952 (best action=453)
#
# 0280-th step: f(x) = 10.451722 (action=292)
#    current best f(x) = 27.200952 (best action=453)
#
# 0281-th step: f(x) = 11.060663 (action=368)
#    current best f(x) = 27.200952 (best action=453)
#
# 0282-th step: f(x) = 10.549001 (action=471)
#    current best f(x) = 27.200952 (best action=453)
#
# 0283-th step: f(x) = 10.112508 (action=422)
#    current best f(x) = 27.200952 (best action=453)
#
# 0284-th step: f(x) = 10.578804 (action=279)
#    current best f(x) = 27.200952 (best action=453)
#
# 0285-th step: f(x) = 11.324984 (action=298)
#    current best f(x) = 27.200952 (best action=453)
#
# 0286-th step: f(x) = 17.033093 (action=211)
#    current best f(x) = 27.200952 (best action=453)
#
# 0287-th step: f(x) = 9.614772 (action=122)
#    current best f(x) = 27.200952 (best action=453)
#
# 0288-th step: f(x) = 19.386560 (action=295)
#    current best f(x) = 27.200952 (best action=453)
#
# 0289-th step: f(x) = 10.314477 (action=197)
#    current best f(x) = 27.200952 (best action=453)
#
# 0290-th step: f(x) = 9.166123 (action=21)
#    current best f(x) = 27.200952 (best action=453)
#
# 0291-th step: f(x) = 20.385631 (action=242)
#    current best f(x) = 27.200952 (best action=453)
#
# 0292-th step: f(x) = 11.797766 (action=365)
#    current best f(x) = 27.200952 (best action=453)
#
# 0293-th step: f(x) = 12.872524 (action=408)
#    current best f(x) = 27.200952 (best action=453)
#
# 0294-th step: f(x) = 18.974373 (action=267)
#    current best f(x) = 27.200952 (best action=453)
#
# 0295-th step: f(x) = 8.752795 (action=202)
#    current best f(x) = 27.200952 (best action=453)
#
# 0296-th step: f(x) = 9.398884 (action=104)
#    current best f(x) = 27.200952 (best action=453)
#
# 0297-th step: f(x) = 12.036363 (action=261)
#    current best f(x) = 27.200952 (best action=453)
#
# 0298-th step: f(x) = 11.117079 (action=218)
#    current best f(x) = 27.200952 (best action=453)
#
# 0299-th step: f(x) = 17.255800 (action=457)
#    current best f(x) = 27.200952 (best action=453)
#
# 0300-th step: f(x) = 10.108549 (action=85)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 728.7465764977312
# 50-th epoch, marginal likelihood 717.2374097097179
# 100-th epoch, marginal likelihood 711.5211816067992
# 150-th epoch, marginal likelihood 707.258380208059
# 200-th epoch, marginal likelihood 703.2626437694375
# 250-th epoch, marginal likelihood 700.366883103322
# 300-th epoch, marginal likelihood 698.4217460843969
# 350-th epoch, marginal likelihood 695.639339727948
# 400-th epoch, marginal likelihood 693.3744819177829
# 450-th epoch, marginal likelihood 691.9821122580045
# 500-th epoch, marginal likelihood 690.4776791024843
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.08680924]
#  scale  =  5.335807122407929
#  scale2 =  28.470837647539184
#
#
# 0301-th step: f(x) = 18.574627 (action=9)
#    current best f(x) = 27.200952 (best action=453)
#
# 0302-th step: f(x) = 19.124220 (action=185)
#    current best f(x) = 27.200952 (best action=453)
#
# 0303-th step: f(x) = 18.494091 (action=37)
#    current best f(x) = 27.200952 (best action=453)
#
# 0304-th step: f(x) = 14.481328 (action=28)
#    current best f(x) = 27.200952 (best action=453)
#
# 0305-th step: f(x) = 9.745295 (action=307)
#    current best f(x) = 27.200952 (best action=453)
#
# 0306-th step: f(x) = 12.303462 (action=358)
#    current best f(x) = 27.200952 (best action=453)
#
# 0307-th step: f(x) = 8.552751 (action=263)
#    current best f(x) = 27.200952 (best action=453)
#
# 0308-th step: f(x) = 10.006865 (action=391)
#    current best f(x) = 27.200952 (best action=453)
#
# 0309-th step: f(x) = 11.106032 (action=38)
#    current best f(x) = 27.200952 (best action=453)
#
# 0310-th step: f(x) = 8.867940 (action=162)
#    current best f(x) = 27.200952 (best action=453)
#
# 0311-th step: f(x) = 10.865881 (action=11)
#    current best f(x) = 27.200952 (best action=453)
#
# 0312-th step: f(x) = 9.148296 (action=478)
#    current best f(x) = 27.200952 (best action=453)
#
# 0313-th step: f(x) = 10.167070 (action=23)
#    current best f(x) = 27.200952 (best action=453)
#
# 0314-th step: f(x) = 10.103281 (action=431)
#    current best f(x) = 27.200952 (best action=453)
#
# 0315-th step: f(x) = 9.597560 (action=61)
#    current best f(x) = 27.200952 (best action=453)
#
# 0316-th step: f(x) = 10.227301 (action=158)
#    current best f(x) = 27.200952 (best action=453)
#
# 0317-th step: f(x) = 9.593130 (action=251)
#    current best f(x) = 27.200952 (best action=453)
#
# 0318-th step: f(x) = 24.477783 (action=333)
#    current best f(x) = 27.200952 (best action=453)
#
# 0319-th step: f(x) = 20.806511 (action=416)
#    current best f(x) = 27.200952 (best action=453)
#
# 0320-th step: f(x) = 22.780712 (action=286)
#    current best f(x) = 27.200952 (best action=453)
#
# 0321-th step: f(x) = 18.179882 (action=404)
#    current best f(x) = 27.200952 (best action=453)
#
# 0322-th step: f(x) = 9.184536 (action=69)
#    current best f(x) = 27.200952 (best action=453)
#
# 0323-th step: f(x) = 9.374820 (action=22)
#    current best f(x) = 27.200952 (best action=453)
#
# 0324-th step: f(x) = 18.436723 (action=82)
#    current best f(x) = 27.200952 (best action=453)
#
# 0325-th step: f(x) = 9.482899 (action=31)
#    current best f(x) = 27.200952 (best action=453)
#
# 0326-th step: f(x) = 10.325013 (action=489)
#    current best f(x) = 27.200952 (best action=453)
#
# 0327-th step: f(x) = 10.802941 (action=13)
#    current best f(x) = 27.200952 (best action=453)
#
# 0328-th step: f(x) = 11.122735 (action=133)
#    current best f(x) = 27.200952 (best action=453)
#
# 0329-th step: f(x) = 12.016624 (action=71)
#    current best f(x) = 27.200952 (best action=453)
#
# 0330-th step: f(x) = 11.181507 (action=465)
#    current best f(x) = 27.200952 (best action=453)
#
# 0331-th step: f(x) = 11.857812 (action=190)
#    current best f(x) = 27.200952 (best action=453)
#
# 0332-th step: f(x) = 9.769790 (action=41)
#    current best f(x) = 27.200952 (best action=453)
#
# 0333-th step: f(x) = 8.184408 (action=161)
#    current best f(x) = 27.200952 (best action=453)
#
# 0334-th step: f(x) = 12.301324 (action=425)
#    current best f(x) = 27.200952 (best action=453)
#
# 0335-th step: f(x) = 17.765992 (action=206)
#    current best f(x) = 27.200952 (best action=453)
#
# 0336-th step: f(x) = 9.807213 (action=40)
#    current best f(x) = 27.200952 (best action=453)
#
# 0337-th step: f(x) = 10.849139 (action=272)
#    current best f(x) = 27.200952 (best action=453)
#
# 0338-th step: f(x) = 8.743393 (action=418)
#    current best f(x) = 27.200952 (best action=453)
#
# 0339-th step: f(x) = 8.388450 (action=106)
#    current best f(x) = 27.200952 (best action=453)
#
# 0340-th step: f(x) = 10.346104 (action=350)
#    current best f(x) = 27.200952 (best action=453)
#
# 0341-th step: f(x) = 10.819696 (action=52)
#    current best f(x) = 27.200952 (best action=453)
#
# 0342-th step: f(x) = 12.965340 (action=482)
#    current best f(x) = 27.200952 (best action=453)
#
# 0343-th step: f(x) = 11.245583 (action=492)
#    current best f(x) = 27.200952 (best action=453)
#
# 0344-th step: f(x) = 9.298012 (action=484)
#    current best f(x) = 27.200952 (best action=453)
#
# 0345-th step: f(x) = 9.837844 (action=313)
#    current best f(x) = 27.200952 (best action=453)
#
# 0346-th step: f(x) = 11.389134 (action=154)
#    current best f(x) = 27.200952 (best action=453)
#
# 0347-th step: f(x) = 9.501531 (action=10)
#    current best f(x) = 27.200952 (best action=453)
#
# 0348-th step: f(x) = 8.592269 (action=336)
#    current best f(x) = 27.200952 (best action=453)
#
# 0349-th step: f(x) = 12.753520 (action=467)
#    current best f(x) = 27.200952 (best action=453)
#
# 0350-th step: f(x) = 10.764082 (action=460)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 859.9785419646005
# 50-th epoch, marginal likelihood 841.2305383117002
# 100-th epoch, marginal likelihood 827.0449738078106
# 150-th epoch, marginal likelihood 815.9504671270573
# 200-th epoch, marginal likelihood 806.4705294288016
# 250-th epoch, marginal likelihood 799.026383252463
# 300-th epoch, marginal likelihood 794.6530697498863
# 350-th epoch, marginal likelihood 791.5089235783992
# 400-th epoch, marginal likelihood 789.4167481154843
# 450-th epoch, marginal likelihood 787.259710339792
# 500-th epoch, marginal likelihood 785.1717248330498
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.06415769]
#  scale  =  5.040868977905904
#  scale2 =  25.410360052414116
#
#
# 0351-th step: f(x) = 9.150378 (action=228)
#    current best f(x) = 27.200952 (best action=453)
#
# 0352-th step: f(x) = 8.879206 (action=302)
#    current best f(x) = 27.200952 (best action=453)
#
# 0353-th step: f(x) = 11.569069 (action=316)
#    current best f(x) = 27.200952 (best action=453)
#
# 0354-th step: f(x) = 10.798158 (action=155)
#    current best f(x) = 27.200952 (best action=453)
#
# 0355-th step: f(x) = 8.413187 (action=135)
#    current best f(x) = 27.200952 (best action=453)
#
# 0356-th step: f(x) = 10.886919 (action=305)
#    current best f(x) = 27.200952 (best action=453)
#
# 0357-th step: f(x) = 10.020662 (action=187)
#    current best f(x) = 27.200952 (best action=453)
#
# 0358-th step: f(x) = 10.994084 (action=116)
#    current best f(x) = 27.200952 (best action=453)
#
# 0359-th step: f(x) = 10.176659 (action=486)
#    current best f(x) = 27.200952 (best action=453)
#
# 0360-th step: f(x) = 8.459634 (action=437)
#    current best f(x) = 27.200952 (best action=453)
#
# 0361-th step: f(x) = 8.072595 (action=337)
#    current best f(x) = 27.200952 (best action=453)
#
# 0362-th step: f(x) = 8.305630 (action=172)
#    current best f(x) = 27.200952 (best action=453)
#
# 0363-th step: f(x) = 10.462989 (action=101)
#    current best f(x) = 27.200952 (best action=453)
#
# 0364-th step: f(x) = 11.376817 (action=434)
#    current best f(x) = 27.200952 (best action=453)
#
# 0365-th step: f(x) = 8.577983 (action=57)
#    current best f(x) = 27.200952 (best action=453)
#
# 0366-th step: f(x) = 9.473358 (action=65)
#    current best f(x) = 27.200952 (best action=453)
#
# 0367-th step: f(x) = 8.764844 (action=105)
#    current best f(x) = 27.200952 (best action=453)
#
# 0368-th step: f(x) = 9.779923 (action=151)
#    current best f(x) = 27.200952 (best action=453)
#
# 0369-th step: f(x) = 10.361846 (action=48)
#    current best f(x) = 27.200952 (best action=453)
#
# 0370-th step: f(x) = 9.546641 (action=445)
#    current best f(x) = 27.200952 (best action=453)
#
# 0371-th step: f(x) = 7.317166 (action=352)
#    current best f(x) = 27.200952 (best action=453)
#
# 0372-th step: f(x) = 10.232971 (action=483)
#    current best f(x) = 27.200952 (best action=453)
#
# 0373-th step: f(x) = 9.300565 (action=390)
#    current best f(x) = 27.200952 (best action=453)
#
# 0374-th step: f(x) = 12.186645 (action=146)
#    current best f(x) = 27.200952 (best action=453)
#
# 0375-th step: f(x) = 8.775160 (action=127)
#    current best f(x) = 27.200952 (best action=453)
#
# 0376-th step: f(x) = 8.409145 (action=474)
#    current best f(x) = 27.200952 (best action=453)
#
# 0377-th step: f(x) = 9.672967 (action=446)
#    current best f(x) = 27.200952 (best action=453)
#
# 0378-th step: f(x) = 10.092387 (action=128)
#    current best f(x) = 27.200952 (best action=453)
#
# 0379-th step: f(x) = 6.968690 (action=400)
#    current best f(x) = 27.200952 (best action=453)
#
# 0380-th step: f(x) = 8.472652 (action=432)
#    current best f(x) = 27.200952 (best action=453)
#
# 0381-th step: f(x) = 7.657826 (action=42)
#    current best f(x) = 27.200952 (best action=453)
#
# 0382-th step: f(x) = 8.485168 (action=60)
#    current best f(x) = 27.200952 (best action=453)
#
# 0383-th step: f(x) = 9.947423 (action=179)
#    current best f(x) = 27.200952 (best action=453)
#
# 0384-th step: f(x) = 7.992556 (action=1)
#    current best f(x) = 27.200952 (best action=453)
#
# 0385-th step: f(x) = 7.401463 (action=207)
#    current best f(x) = 27.200952 (best action=453)
#
# 0386-th step: f(x) = 8.214925 (action=262)
#    current best f(x) = 27.200952 (best action=453)
#
# 0387-th step: f(x) = 7.470817 (action=255)
#    current best f(x) = 27.200952 (best action=453)
#
# 0388-th step: f(x) = 6.012032 (action=402)
#    current best f(x) = 27.200952 (best action=453)
#
# 0389-th step: f(x) = 7.120582 (action=499)
#    current best f(x) = 27.200952 (best action=453)
#
# 0390-th step: f(x) = 11.007414 (action=92)
#    current best f(x) = 27.200952 (best action=453)
#
# 0391-th step: f(x) = 7.620641 (action=264)
#    current best f(x) = 27.200952 (best action=453)
#
# 0392-th step: f(x) = 11.159947 (action=43)
#    current best f(x) = 27.200952 (best action=453)
#
# 0393-th step: f(x) = 9.204538 (action=129)
#    current best f(x) = 27.200952 (best action=453)
#
# 0394-th step: f(x) = 8.257007 (action=496)
#    current best f(x) = 27.200952 (best action=453)
#
# 0395-th step: f(x) = 12.216533 (action=4)
#    current best f(x) = 27.200952 (best action=453)
#
# 0396-th step: f(x) = 7.880260 (action=174)
#    current best f(x) = 27.200952 (best action=453)
#
# 0397-th step: f(x) = 7.959727 (action=385)
#    current best f(x) = 27.200952 (best action=453)
#
# 0398-th step: f(x) = 9.597451 (action=166)
#    current best f(x) = 27.200952 (best action=453)
#
# 0399-th step: f(x) = 9.264374 (action=415)
#    current best f(x) = 27.200952 (best action=453)
#
# 0400-th step: f(x) = 8.553799 (action=150)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 962.0117020134333
# 50-th epoch, marginal likelihood 937.6116444592183
# 100-th epoch, marginal likelihood 919.742975511328
# 150-th epoch, marginal likelihood 907.6739243715141
# 200-th epoch, marginal likelihood 898.8844719309694
# 250-th epoch, marginal likelihood 890.0595296890375
# 300-th epoch, marginal likelihood 884.4453385468878
# 350-th epoch, marginal likelihood 881.3085200856024
# 400-th epoch, marginal likelihood 877.5686507409457
# 450-th epoch, marginal likelihood 875.3561315144483
# 500-th epoch, marginal likelihood 874.864380939754
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.09722891]
#  scale  =  4.910823650981158
#  scale2 =  24.116188931035907
#
#
# 0401-th step: f(x) = 9.871811 (action=477)
#    current best f(x) = 27.200952 (best action=453)
#
# 0402-th step: f(x) = 8.648269 (action=99)
#    current best f(x) = 27.200952 (best action=453)
#
# 0403-th step: f(x) = 12.510394 (action=168)
#    current best f(x) = 27.200952 (best action=453)
#
# 0404-th step: f(x) = 7.279636 (action=113)
#    current best f(x) = 27.200952 (best action=453)
#
# 0405-th step: f(x) = 10.323454 (action=87)
#    current best f(x) = 27.200952 (best action=453)
#
# 0406-th step: f(x) = 11.709692 (action=259)
#    current best f(x) = 27.200952 (best action=453)
#
# 0407-th step: f(x) = 8.621496 (action=470)
#    current best f(x) = 27.200952 (best action=453)
#
# 0408-th step: f(x) = 11.472193 (action=293)
#    current best f(x) = 27.200952 (best action=453)
#
# 0409-th step: f(x) = 11.181464 (action=97)
#    current best f(x) = 27.200952 (best action=453)
#
# 0410-th step: f(x) = 10.058481 (action=186)
#    current best f(x) = 27.200952 (best action=453)
#
# 0411-th step: f(x) = 6.754841 (action=335)
#    current best f(x) = 27.200952 (best action=453)
#
# 0412-th step: f(x) = 10.202543 (action=275)
#    current best f(x) = 27.200952 (best action=453)
#
# 0413-th step: f(x) = 7.430411 (action=312)
#    current best f(x) = 27.200952 (best action=453)
#
# 0414-th step: f(x) = 12.349684 (action=455)
#    current best f(x) = 27.200952 (best action=453)
#
# 0415-th step: f(x) = 11.323582 (action=361)
#    current best f(x) = 27.200952 (best action=453)
#
# 0416-th step: f(x) = 10.277968 (action=173)
#    current best f(x) = 27.200952 (best action=453)
#
# 0417-th step: f(x) = 8.136360 (action=227)
#    current best f(x) = 27.200952 (best action=453)
#
# 0418-th step: f(x) = 7.766129 (action=224)
#    current best f(x) = 27.200952 (best action=453)
#
# 0419-th step: f(x) = 7.980841 (action=349)
#    current best f(x) = 27.200952 (best action=453)
#
# 0420-th step: f(x) = 10.755536 (action=16)
#    current best f(x) = 27.200952 (best action=453)
#
# 0421-th step: f(x) = 9.093463 (action=494)
#    current best f(x) = 27.200952 (best action=453)
#
# 0422-th step: f(x) = 7.791767 (action=273)
#    current best f(x) = 27.200952 (best action=453)
#
# 0423-th step: f(x) = 7.351364 (action=347)
#    current best f(x) = 27.200952 (best action=453)
#
# 0424-th step: f(x) = 11.342833 (action=216)
#    current best f(x) = 27.200952 (best action=453)
#
# 0425-th step: f(x) = 7.957569 (action=441)
#    current best f(x) = 27.200952 (best action=453)
#
# 0426-th step: f(x) = 8.547200 (action=377)
#    current best f(x) = 27.200952 (best action=453)
#
# 0427-th step: f(x) = 7.818479 (action=34)
#    current best f(x) = 27.200952 (best action=453)
#
# 0428-th step: f(x) = 9.275903 (action=332)
#    current best f(x) = 27.200952 (best action=453)
#
# 0429-th step: f(x) = 9.812435 (action=299)
#    current best f(x) = 27.200952 (best action=453)
#
# 0430-th step: f(x) = 8.675277 (action=17)
#    current best f(x) = 27.200952 (best action=453)
#
# 0431-th step: f(x) = 7.539931 (action=490)
#    current best f(x) = 27.200952 (best action=453)
#
# 0432-th step: f(x) = 9.912229 (action=15)
#    current best f(x) = 27.200952 (best action=453)
#
# 0433-th step: f(x) = 10.005417 (action=169)
#    current best f(x) = 27.200952 (best action=453)
#
# 0434-th step: f(x) = 7.374504 (action=414)
#    current best f(x) = 27.200952 (best action=453)
#
# 0435-th step: f(x) = 7.168218 (action=59)
#    current best f(x) = 27.200952 (best action=453)
#
# 0436-th step: f(x) = 8.937088 (action=341)
#    current best f(x) = 27.200952 (best action=453)
#
# 0437-th step: f(x) = 7.182155 (action=2)
#    current best f(x) = 27.200952 (best action=453)
#
# 0438-th step: f(x) = 11.788995 (action=221)
#    current best f(x) = 27.200952 (best action=453)
#
# 0439-th step: f(x) = 7.775188 (action=428)
#    current best f(x) = 27.200952 (best action=453)
#
# 0440-th step: f(x) = 10.154133 (action=50)
#    current best f(x) = 27.200952 (best action=453)
#
# 0441-th step: f(x) = 11.288276 (action=237)
#    current best f(x) = 27.200952 (best action=453)
#
# 0442-th step: f(x) = 8.795967 (action=354)
#    current best f(x) = 27.200952 (best action=453)
#
# 0443-th step: f(x) = 8.731186 (action=30)
#    current best f(x) = 27.200952 (best action=453)
#
# 0444-th step: f(x) = 11.111703 (action=424)
#    current best f(x) = 27.200952 (best action=453)
#
# 0445-th step: f(x) = 9.504382 (action=322)
#    current best f(x) = 27.200952 (best action=453)
#
# 0446-th step: f(x) = 6.628524 (action=156)
#    current best f(x) = 27.200952 (best action=453)
#
# 0447-th step: f(x) = 7.934130 (action=452)
#    current best f(x) = 27.200952 (best action=453)
#
# 0448-th step: f(x) = 11.993764 (action=448)
#    current best f(x) = 27.200952 (best action=453)
#
# 0449-th step: f(x) = 10.475035 (action=145)
#    current best f(x) = 27.200952 (best action=453)
#
# 0450-th step: f(x) = 7.833366 (action=137)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 1055.8693381946855
# 50-th epoch, marginal likelihood 1032.2675833947355
# 100-th epoch, marginal likelihood 1014.1749727520685
# 150-th epoch, marginal likelihood 1000.6474027047542
# 200-th epoch, marginal likelihood 988.5352196606686
# 250-th epoch, marginal likelihood 978.8212573064966
# 300-th epoch, marginal likelihood 973.5052694203337
# 350-th epoch, marginal likelihood 967.2864883587155
# 400-th epoch, marginal likelihood 964.3209198828521
# 450-th epoch, marginal likelihood 962.9906066246317
# 500-th epoch, marginal likelihood 961.5106810713718
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.05143853]
#  scale  =  4.872369120913467
#  scale2 =  23.739980850431067
#
#
# 0451-th step: f(x) = 8.651240 (action=324)
#    current best f(x) = 27.200952 (best action=453)
#
# 0452-th step: f(x) = 11.093591 (action=194)
#    current best f(x) = 27.200952 (best action=453)
#
# 0453-th step: f(x) = 10.768150 (action=134)
#    current best f(x) = 27.200952 (best action=453)
#
# 0454-th step: f(x) = 9.048077 (action=152)
#    current best f(x) = 27.200952 (best action=453)
#
# 0455-th step: f(x) = 11.381385 (action=68)
#    current best f(x) = 27.200952 (best action=453)
#
# 0456-th step: f(x) = 7.061866 (action=374)
#    current best f(x) = 27.200952 (best action=453)
#
# 0457-th step: f(x) = 10.813239 (action=458)
#    current best f(x) = 27.200952 (best action=453)
#
# 0458-th step: f(x) = 7.418187 (action=304)
#    current best f(x) = 27.200952 (best action=453)
#
# 0459-th step: f(x) = 8.989613 (action=405)
#    current best f(x) = 27.200952 (best action=453)
#
# 0460-th step: f(x) = 12.072616 (action=213)
#    current best f(x) = 27.200952 (best action=453)
#
# 0461-th step: f(x) = 8.813346 (action=409)
#    current best f(x) = 27.200952 (best action=453)
#
# 0462-th step: f(x) = 7.343724 (action=165)
#    current best f(x) = 27.200952 (best action=453)
#
# 0463-th step: f(x) = 10.990948 (action=495)
#    current best f(x) = 27.200952 (best action=453)
#
# 0464-th step: f(x) = 7.959454 (action=210)
#    current best f(x) = 27.200952 (best action=453)
#
# 0465-th step: f(x) = 7.310182 (action=419)
#    current best f(x) = 27.200952 (best action=453)
#
# 0466-th step: f(x) = 9.914487 (action=450)
#    current best f(x) = 27.200952 (best action=453)
#
# 0467-th step: f(x) = 12.638871 (action=76)
#    current best f(x) = 27.200952 (best action=453)
#
# 0468-th step: f(x) = 9.629406 (action=473)
#    current best f(x) = 27.200952 (best action=453)
#
# 0469-th step: f(x) = 8.043984 (action=356)
#    current best f(x) = 27.200952 (best action=453)
#
# 0470-th step: f(x) = 7.968659 (action=193)
#    current best f(x) = 27.200952 (best action=453)
#
# 0471-th step: f(x) = 8.476657 (action=285)
#    current best f(x) = 27.200952 (best action=453)
#
# 0472-th step: f(x) = 10.293233 (action=430)
#    current best f(x) = 27.200952 (best action=453)
#
# 0473-th step: f(x) = 10.557070 (action=412)
#    current best f(x) = 27.200952 (best action=453)
#
# 0474-th step: f(x) = 10.122503 (action=314)
#    current best f(x) = 27.200952 (best action=453)
#
# 0475-th step: f(x) = 7.445096 (action=79)
#    current best f(x) = 27.200952 (best action=453)
#
# 0476-th step: f(x) = 11.497698 (action=398)
#    current best f(x) = 27.200952 (best action=453)
#
# 0477-th step: f(x) = 8.646613 (action=421)
#    current best f(x) = 27.200952 (best action=453)
#
# 0478-th step: f(x) = 8.927517 (action=123)
#    current best f(x) = 27.200952 (best action=453)
#
# 0479-th step: f(x) = 8.350529 (action=340)
#    current best f(x) = 27.200952 (best action=453)
#
# 0480-th step: f(x) = 10.307702 (action=235)
#    current best f(x) = 27.200952 (best action=453)
#
# 0481-th step: f(x) = 6.943171 (action=58)
#    current best f(x) = 27.200952 (best action=453)
#
# 0482-th step: f(x) = 10.157350 (action=98)
#    current best f(x) = 27.200952 (best action=453)
#
# 0483-th step: f(x) = 8.701103 (action=120)
#    current best f(x) = 27.200952 (best action=453)
#
# 0484-th step: f(x) = 7.295925 (action=386)
#    current best f(x) = 27.200952 (best action=453)
#
# 0485-th step: f(x) = 7.286233 (action=389)
#    current best f(x) = 27.200952 (best action=453)
#
# 0486-th step: f(x) = 6.690932 (action=167)
#    current best f(x) = 27.200952 (best action=453)
#
# 0487-th step: f(x) = 7.929785 (action=429)
#    current best f(x) = 27.200952 (best action=453)
#
# 0488-th step: f(x) = 6.479199 (action=91)
#    current best f(x) = 27.200952 (best action=453)
#
# 0489-th step: f(x) = 8.466462 (action=56)
#    current best f(x) = 27.200952 (best action=453)
#
# 0490-th step: f(x) = 7.216754 (action=14)
#    current best f(x) = 27.200952 (best action=453)
#
# 0491-th step: f(x) = 7.917562 (action=143)
#    current best f(x) = 27.200952 (best action=453)
#
# 0492-th step: f(x) = 7.974901 (action=147)
#    current best f(x) = 27.200952 (best action=453)
#
# 0493-th step: f(x) = 6.967438 (action=115)
#    current best f(x) = 27.200952 (best action=453)
#
# 0494-th step: f(x) = 7.872840 (action=373)
#    current best f(x) = 27.200952 (best action=453)
#
# 0495-th step: f(x) = 7.546737 (action=110)
#    current best f(x) = 27.200952 (best action=453)
#
# 0496-th step: f(x) = 7.379850 (action=244)
#    current best f(x) = 27.200952 (best action=453)
#
# 0497-th step: f(x) = 8.484439 (action=447)
#    current best f(x) = 27.200952 (best action=453)
#
# 0498-th step: f(x) = 6.281270 (action=33)
#    current best f(x) = 27.200952 (best action=453)
#
# 0499-th step: f(x) = 6.974918 (action=348)
#    current best f(x) = 27.200952 (best action=453)
#
# 0500-th step: f(x) = 10.412183 (action=247)
#    current best f(x) = 27.200952 (best action=453)

# %%
index_Henry_H2O_relevant = np.argmax(Data_relevant_features_Henry_H2O.iloc[:, -1].values)
import numpy as np
from sklearn.manifold import TSNE

X_embedded = TSNE(n_components=2).fit_transform(Data_relevant_features_Henry_CO2.iloc[:, :-1].values)
X_embedded.shape

SC1 = np.transpose(X_embedded)[0]
SC2 = np.transpose(X_embedded)[1]

fig, ax = plt.subplots(figsize=(3,3), dpi=150)
ax.scatter(SC1, SC2, c='tab:blue', alpha=0.3)
initial_set = ax.scatter(SC1[minima], SC2[minima], c='gold', label = 'Initial set', alpha = 0.5)
optimum = ax.scatter(SC1[index_Henry_H2O_relevant], SC2[index_Henry_H2O_relevant], c='red', label = 'Optimum')

ax.legend([initial_set, optimum], ['Initial set', 'Optimum'], loc = 'best')
#labels = ['Initial set', 'Optimum']
#ax.legend(labels)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
plt.show()

# %% [markdown]
# #### Unrelevant features

# %%
MEI_index_Henry_H2O_unrelevant = MEI(Data_unrelevant_features_Henry_H2O.iloc[:, :-1].values, Data_unrelevant_features_Henry_H2O.iloc[:, -1].values, 400, 100)
# Out:
#  32%|███▏      | 126/400 [3:56:34<8:34:27, 112.65s/it]

# %%
MLI_index_Henry_H2O_unrelevant = MLI(Data_unrelevant_features_Henry_H2O.iloc[:, :-1].values, Data_unrelevant_features_Henry_H2O.iloc[:, -1].values, 400, 100)
# Out:
#  11%|█▏        | 45/400 [47:30<6:14:46, 63.34s/it]

# %%
MU_index_Henry_H2O_unrelevant = MU(Data_unrelevant_features_Henry_H2O.iloc[:, :-1].values, Data_unrelevant_features_Henry_H2O.iloc[:, -1].values, 400, 100)
# Out:
#  36%|███▋      | 146/400 [5:47:38<10:04:48, 142.87s/it]

# %%
COMBO_PI_Henry_H2O_unrelevant = COMBO(Data_unrelevant_features_Henry_H2O, 'PI')
# Out:
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 130.23433735372925
# 50-th epoch, marginal likelihood 109.58697821701463
# 100-th epoch, marginal likelihood 96.2012237062626
# 150-th epoch, marginal likelihood 87.64336623074306
# 200-th epoch, marginal likelihood 81.91116964160187
# 250-th epoch, marginal likelihood 78.34120400801716
# 300-th epoch, marginal likelihood 75.67185153214187
# 350-th epoch, marginal likelihood 73.73369240724969
# 400-th epoch, marginal likelihood 72.23980862313533
# 450-th epoch, marginal likelihood 71.35416817002937
# 500-th epoch, marginal likelihood 70.49305096668175
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.]
#  scale  =  1.0
#  scale2 =  1.0
#
#
# 0101-th step: f(x) = 9.259340 (action=329)
#    current best f(x) = 9.259340 (best action=329)
#
# 0102-th step: f(x) = 8.646613 (action=421)
#    current best f(x) = 9.259340 (best action=329)
#
# 0103-th step: f(x) = 9.985689 (action=276)
#    current best f(x) = 9.985689 (best action=276)
#
# 0104-th step: f(x) = 9.672967 (action=446)
#    current best f(x) = 9.985689 (best action=276)
#
# 0105-th step: f(x) = 14.000021 (action=107)
#    current best f(x) = 14.000021 (best action=107)
#
# 0106-th step: f(x) = 10.654156 (action=370)
#    current best f(x) = 14.000021 (best action=107)
#
# 0107-th step: f(x) = 11.791428 (action=438)
#    current best f(x) = 14.000021 (best action=107)
#
# 0108-th step: f(x) = 10.125094 (action=444)
#    current best f(x) = 14.000021 (best action=107)
#
# 0109-th step: f(x) = 12.082989 (action=130)
#    current best f(x) = 14.000021 (best action=107)
#
# 0110-th step: f(x) = 12.036363 (action=261)
#    current best f(x) = 14.000021 (best action=107)
#
# 0111-th step: f(x) = 15.329956 (action=0)
#    current best f(x) = 15.329956 (best action=0)
#
# 0112-th step: f(x) = 12.390168 (action=427)
#    current best f(x) = 15.329956 (best action=0)
#
# 0113-th step: f(x) = 12.981825 (action=393)
#    current best f(x) = 15.329956 (best action=0)
#
# 0114-th step: f(x) = 13.382275 (action=77)
#    current best f(x) = 15.329956 (best action=0)
#
# 0115-th step: f(x) = 8.649175 (action=459)
#    current best f(x) = 15.329956 (best action=0)
#
# 0116-th step: f(x) = 14.760148 (action=114)
#    current best f(x) = 15.329956 (best action=0)
#
# 0117-th step: f(x) = 9.998502 (action=159)
#    current best f(x) = 15.329956 (best action=0)
#
# 0118-th step: f(x) = 13.161024 (action=63)
#    current best f(x) = 15.329956 (best action=0)
#
# 0119-th step: f(x) = 16.048959 (action=411)
#    current best f(x) = 16.048959 (best action=411)
#
# 0120-th step: f(x) = 8.229530 (action=109)
#    current best f(x) = 16.048959 (best action=411)
#
# 0121-th step: f(x) = 11.342833 (action=216)
#    current best f(x) = 16.048959 (best action=411)
#
# 0122-th step: f(x) = 20.178811 (action=426)
#    current best f(x) = 20.178811 (best action=426)
#
# 0123-th step: f(x) = 23.786587 (action=493)
#    current best f(x) = 23.786587 (best action=493)
#
# 0124-th step: f(x) = 19.112447 (action=35)
#    current best f(x) = 23.786587 (best action=493)
#
# 0125-th step: f(x) = 20.940093 (action=366)
#    current best f(x) = 23.786587 (best action=493)
#
# 0126-th step: f(x) = 23.321055 (action=250)
#    current best f(x) = 23.786587 (best action=493)
#
# 0127-th step: f(x) = 20.745086 (action=112)
#    current best f(x) = 23.786587 (best action=493)
#
# 0128-th step: f(x) = 23.417488 (action=372)
#    current best f(x) = 23.786587 (best action=493)
#
# 0129-th step: f(x) = 10.227301 (action=158)
#    current best f(x) = 23.786587 (best action=493)
#
# 0130-th step: f(x) = 17.891501 (action=240)
#    current best f(x) = 23.786587 (best action=493)
#
# 0131-th step: f(x) = 11.286286 (action=401)
#    current best f(x) = 23.786587 (best action=493)
#
# 0132-th step: f(x) = 12.872524 (action=408)
#    current best f(x) = 23.786587 (best action=493)
#
# 0133-th step: f(x) = 13.536260 (action=220)
#    current best f(x) = 23.786587 (best action=493)
#
# 0134-th step: f(x) = 10.412183 (action=247)
#    current best f(x) = 23.786587 (best action=493)
#
# 0135-th step: f(x) = 19.219957 (action=39)
#    current best f(x) = 23.786587 (best action=493)
#
# 0136-th step: f(x) = 24.074734 (action=462)
#    current best f(x) = 24.074734 (best action=462)
#
# 0137-th step: f(x) = 15.242032 (action=284)
#    current best f(x) = 24.074734 (best action=462)
#
# 0138-th step: f(x) = 19.961039 (action=164)
#    current best f(x) = 24.074734 (best action=462)
#
# 0139-th step: f(x) = 19.627496 (action=338)
#    current best f(x) = 24.074734 (best action=462)
#
# 0140-th step: f(x) = 25.446139 (action=223)
#    current best f(x) = 25.446139 (best action=223)
#
# 0141-th step: f(x) = 17.234512 (action=472)
#    current best f(x) = 25.446139 (best action=223)
#
# 0142-th step: f(x) = 10.098647 (action=209)
#    current best f(x) = 25.446139 (best action=223)
#
# 0143-th step: f(x) = 15.741864 (action=93)
#    current best f(x) = 25.446139 (best action=223)
#
# 0144-th step: f(x) = 12.701915 (action=387)
#    current best f(x) = 25.446139 (best action=223)
#
# 0145-th step: f(x) = 9.149075 (action=64)
#    current best f(x) = 25.446139 (best action=223)
#
# 0146-th step: f(x) = 9.349041 (action=362)
#    current best f(x) = 25.446139 (best action=223)
#
# 0147-th step: f(x) = 10.714462 (action=131)
#    current best f(x) = 25.446139 (best action=223)
#
# 0148-th step: f(x) = 8.663025 (action=343)
#    current best f(x) = 25.446139 (best action=223)
#
# 0149-th step: f(x) = 16.032274 (action=229)
#    current best f(x) = 25.446139 (best action=223)
#
# 0150-th step: f(x) = 16.932531 (action=254)
#    current best f(x) = 25.446139 (best action=223)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 324.3815754974573
# 50-th epoch, marginal likelihood 324.0863621972276
# 100-th epoch, marginal likelihood 323.90943718900917
# 150-th epoch, marginal likelihood 324.1830745064065
# 200-th epoch, marginal likelihood 324.3311681474227
# 250-th epoch, marginal likelihood 324.3023338774056
# 300-th epoch, marginal likelihood 324.41115487667605
# 350-th epoch, marginal likelihood 324.3530247174831
# 400-th epoch, marginal likelihood 325.30865850888335
# 450-th epoch, marginal likelihood 324.6401802791949
# 500-th epoch, marginal likelihood 324.5769661847371
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.2575741]
#  scale  =  0.6187499234296404
#  scale2 =  0.3828514677441859
#
#
# 0151-th step: f(x) = 13.413145 (action=363)
#    current best f(x) = 25.446139 (best action=223)
#
# 0152-th step: f(x) = 15.736654 (action=330)
#    current best f(x) = 25.446139 (best action=223)
#
# 0153-th step: f(x) = 20.044179 (action=176)
#    current best f(x) = 25.446139 (best action=223)
#
# 0154-th step: f(x) = 20.785715 (action=357)
#    current best f(x) = 25.446139 (best action=223)
#
# 0155-th step: f(x) = 19.788790 (action=498)
#    current best f(x) = 25.446139 (best action=223)
#
# 0156-th step: f(x) = 19.386560 (action=295)
#    current best f(x) = 25.446139 (best action=223)
#
# 0157-th step: f(x) = 19.434830 (action=281)
#    current best f(x) = 25.446139 (best action=223)
#
# 0158-th step: f(x) = 19.635584 (action=245)
#    current best f(x) = 25.446139 (best action=223)
#
# 0159-th step: f(x) = 18.367571 (action=118)
#    current best f(x) = 25.446139 (best action=223)
#
# 0160-th step: f(x) = 20.385631 (action=242)
#    current best f(x) = 25.446139 (best action=223)
#
# 0161-th step: f(x) = 19.661390 (action=475)
#    current best f(x) = 25.446139 (best action=223)
#
# 0162-th step: f(x) = 18.700761 (action=53)
#    current best f(x) = 25.446139 (best action=223)
#
# 0163-th step: f(x) = 25.615406 (action=359)
#    current best f(x) = 25.615406 (best action=359)
#
# 0164-th step: f(x) = 12.162878 (action=86)
#    current best f(x) = 25.615406 (best action=359)
#
# 0165-th step: f(x) = 24.230367 (action=177)
#    current best f(x) = 25.615406 (best action=359)
#
# 0166-th step: f(x) = 24.720306 (action=219)
#    current best f(x) = 25.615406 (best action=359)
#
# 0167-th step: f(x) = 19.121564 (action=323)
#    current best f(x) = 25.615406 (best action=359)
#
# 0168-th step: f(x) = 22.669884 (action=463)
#    current best f(x) = 25.615406 (best action=359)
#
# 0169-th step: f(x) = 20.806511 (action=416)
#    current best f(x) = 25.615406 (best action=359)
#
# 0170-th step: f(x) = 19.065142 (action=439)
#    current best f(x) = 25.615406 (best action=359)
#
# 0171-th step: f(x) = 19.127824 (action=47)
#    current best f(x) = 25.615406 (best action=359)
#
# 0172-th step: f(x) = 20.617683 (action=51)
#    current best f(x) = 25.615406 (best action=359)
#
# 0173-th step: f(x) = 21.085091 (action=311)
#    current best f(x) = 25.615406 (best action=359)
#
# 0174-th step: f(x) = 18.991240 (action=83)
#    current best f(x) = 25.615406 (best action=359)
#
# 0175-th step: f(x) = 17.862973 (action=96)
#    current best f(x) = 25.615406 (best action=359)
#
# 0176-th step: f(x) = 15.402149 (action=288)
#    current best f(x) = 25.615406 (best action=359)
#
# 0177-th step: f(x) = 27.200952 (action=453)
#    current best f(x) = 27.200952 (best action=453)
#
# 0178-th step: f(x) = 26.956130 (action=440)
#    current best f(x) = 27.200952 (best action=453)
#
# 0179-th step: f(x) = 10.696245 (action=111)
#    current best f(x) = 27.200952 (best action=453)
#
# 0180-th step: f(x) = 18.368629 (action=84)
#    current best f(x) = 27.200952 (best action=453)
#
# 0181-th step: f(x) = 15.506670 (action=44)
#    current best f(x) = 27.200952 (best action=453)
#
# 0182-th step: f(x) = 21.201857 (action=306)
#    current best f(x) = 27.200952 (best action=453)
#
# 0183-th step: f(x) = 24.460583 (action=8)
#    current best f(x) = 27.200952 (best action=453)
#
# 0184-th step: f(x) = 20.166710 (action=461)
#    current best f(x) = 27.200952 (best action=453)
#
# 0185-th step: f(x) = 10.314477 (action=197)
#    current best f(x) = 27.200952 (best action=453)
#
# 0186-th step: f(x) = 20.809906 (action=371)
#    current best f(x) = 27.200952 (best action=453)
#
# 0187-th step: f(x) = 17.765992 (action=206)
#    current best f(x) = 27.200952 (best action=453)
#
# 0188-th step: f(x) = 22.536448 (action=180)
#    current best f(x) = 27.200952 (best action=453)
#
# 0189-th step: f(x) = 13.215019 (action=491)
#    current best f(x) = 27.200952 (best action=453)
#
# 0190-th step: f(x) = 10.921497 (action=320)
#    current best f(x) = 27.200952 (best action=453)
#
# 0191-th step: f(x) = 9.774005 (action=196)
#    current best f(x) = 27.200952 (best action=453)
#
# 0192-th step: f(x) = 20.552601 (action=318)
#    current best f(x) = 27.200952 (best action=453)
#
# 0193-th step: f(x) = 10.092387 (action=128)
#    current best f(x) = 27.200952 (best action=453)
#
# 0194-th step: f(x) = 9.459370 (action=319)
#    current best f(x) = 27.200952 (best action=453)
#
# 0195-th step: f(x) = 17.033093 (action=211)
#    current best f(x) = 27.200952 (best action=453)
#
# 0196-th step: f(x) = 13.537182 (action=189)
#    current best f(x) = 27.200952 (best action=453)
#
# 0197-th step: f(x) = 10.990948 (action=495)
#    current best f(x) = 27.200952 (best action=453)
#
# 0198-th step: f(x) = 20.592638 (action=394)
#    current best f(x) = 27.200952 (best action=453)
#
# 0199-th step: f(x) = 24.073749 (action=342)
#    current best f(x) = 27.200952 (best action=453)
#
# 0200-th step: f(x) = 24.150111 (action=407)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 493.45307839251143
# 50-th epoch, marginal likelihood 493.38605873212737
# 100-th epoch, marginal likelihood 493.29036346717635
# 150-th epoch, marginal likelihood 493.2733422012518
# 200-th epoch, marginal likelihood 493.2889939251492
# 250-th epoch, marginal likelihood 493.3095026323219
# 300-th epoch, marginal likelihood 493.21353723107455
# 350-th epoch, marginal likelihood 493.17006253962387
# 400-th epoch, marginal likelihood 493.10135148502917
# 450-th epoch, marginal likelihood 493.0758676516593
# 500-th epoch, marginal likelihood 492.93754413818226
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [13.28137294]
#  scale  =  5.6926135610106225
#  scale2 =  32.40584915500204
#
#
# 0201-th step: f(x) = 24.477783 (action=333)
#    current best f(x) = 27.200952 (best action=453)
#
# 0202-th step: f(x) = 19.575174 (action=6)
#    current best f(x) = 27.200952 (best action=453)
#
# 0203-th step: f(x) = 22.410886 (action=488)
#    current best f(x) = 27.200952 (best action=453)
#
# 0204-th step: f(x) = 18.974373 (action=267)
#    current best f(x) = 27.200952 (best action=453)
#
# 0205-th step: f(x) = 17.255800 (action=457)
#    current best f(x) = 27.200952 (best action=453)
#
# 0206-th step: f(x) = 18.947412 (action=54)
#    current best f(x) = 27.200952 (best action=453)
#
# 0207-th step: f(x) = 11.758832 (action=201)
#    current best f(x) = 27.200952 (best action=453)
#
# 0208-th step: f(x) = 14.540598 (action=345)
#    current best f(x) = 27.200952 (best action=453)
#
# 0209-th step: f(x) = 17.797239 (action=283)
#    current best f(x) = 27.200952 (best action=453)
#
# 0210-th step: f(x) = 19.565801 (action=344)
#    current best f(x) = 27.200952 (best action=453)
#
# 0211-th step: f(x) = 17.599405 (action=198)
#    current best f(x) = 27.200952 (best action=453)
#
# 0212-th step: f(x) = 15.516782 (action=317)
#    current best f(x) = 27.200952 (best action=453)
#
# 0213-th step: f(x) = 10.867616 (action=420)
#    current best f(x) = 27.200952 (best action=453)
#
# 0214-th step: f(x) = 11.201268 (action=181)
#    current best f(x) = 27.200952 (best action=453)
#
# 0215-th step: f(x) = 10.849139 (action=272)
#    current best f(x) = 27.200952 (best action=453)
#
# 0216-th step: f(x) = 10.887112 (action=55)
#    current best f(x) = 27.200952 (best action=453)
#
# 0217-th step: f(x) = 16.795142 (action=238)
#    current best f(x) = 27.200952 (best action=453)
#
# 0218-th step: f(x) = 14.454270 (action=296)
#    current best f(x) = 27.200952 (best action=453)
#
# 0219-th step: f(x) = 11.117079 (action=218)
#    current best f(x) = 27.200952 (best action=453)
#
# 0220-th step: f(x) = 18.494091 (action=37)
#    current best f(x) = 27.200952 (best action=453)
#
# 0221-th step: f(x) = 8.549548 (action=435)
#    current best f(x) = 27.200952 (best action=453)
#
# 0222-th step: f(x) = 12.262703 (action=466)
#    current best f(x) = 27.200952 (best action=453)
#
# 0223-th step: f(x) = 9.150378 (action=228)
#    current best f(x) = 27.200952 (best action=453)
#
# 0224-th step: f(x) = 23.648870 (action=95)
#    current best f(x) = 27.200952 (best action=453)
#
# 0225-th step: f(x) = 11.616195 (action=212)
#    current best f(x) = 27.200952 (best action=453)
#
# 0226-th step: f(x) = 10.353763 (action=331)
#    current best f(x) = 27.200952 (best action=453)
#
# 0227-th step: f(x) = 8.518273 (action=100)
#    current best f(x) = 27.200952 (best action=453)
#
# 0228-th step: f(x) = 9.521568 (action=90)
#    current best f(x) = 27.200952 (best action=453)
#
# 0229-th step: f(x) = 12.722584 (action=436)
#    current best f(x) = 27.200952 (best action=453)
#
# 0230-th step: f(x) = 9.011190 (action=360)
#    current best f(x) = 27.200952 (best action=453)
#
# 0231-th step: f(x) = 13.712758 (action=327)
#    current best f(x) = 27.200952 (best action=453)
#
# 0232-th step: f(x) = 9.807213 (action=40)
#    current best f(x) = 27.200952 (best action=453)
#
# 0233-th step: f(x) = 10.346104 (action=350)
#    current best f(x) = 27.200952 (best action=453)
#
# 0234-th step: f(x) = 11.039188 (action=140)
#    current best f(x) = 27.200952 (best action=453)
#
# 0235-th step: f(x) = 24.325384 (action=303)
#    current best f(x) = 27.200952 (best action=453)
#
# 0236-th step: f(x) = 8.723741 (action=346)
#    current best f(x) = 27.200952 (best action=453)
#
# 0237-th step: f(x) = 9.745295 (action=307)
#    current best f(x) = 27.200952 (best action=453)
#
# 0238-th step: f(x) = 8.192244 (action=403)
#    current best f(x) = 27.200952 (best action=453)
#
# 0239-th step: f(x) = 9.947423 (action=179)
#    current best f(x) = 27.200952 (best action=453)
#
# 0240-th step: f(x) = 8.214925 (action=262)
#    current best f(x) = 27.200952 (best action=453)
#
# 0241-th step: f(x) = 11.784874 (action=278)
#    current best f(x) = 27.200952 (best action=453)
#
# 0242-th step: f(x) = 10.553975 (action=454)
#    current best f(x) = 27.200952 (best action=453)
#
# 0243-th step: f(x) = 10.031485 (action=294)
#    current best f(x) = 27.200952 (best action=453)
#
# 0244-th step: f(x) = 8.184408 (action=161)
#    current best f(x) = 27.200952 (best action=453)
#
# 0245-th step: f(x) = 8.675277 (action=17)
#    current best f(x) = 27.200952 (best action=453)
#
# 0246-th step: f(x) = 11.303103 (action=67)
#    current best f(x) = 27.200952 (best action=453)
#
# 0247-th step: f(x) = 20.162669 (action=117)
#    current best f(x) = 27.200952 (best action=453)
#
# 0248-th step: f(x) = 9.912229 (action=15)
#    current best f(x) = 27.200952 (best action=453)
#
# 0249-th step: f(x) = 18.179882 (action=404)
#    current best f(x) = 27.200952 (best action=453)
#
# 0250-th step: f(x) = 25.032813 (action=413)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 624.2735404518502
# 50-th epoch, marginal likelihood 624.2834107769349
# 100-th epoch, marginal likelihood 624.2068150105888
# 150-th epoch, marginal likelihood 624.1798460503412
# 200-th epoch, marginal likelihood 624.1629830679857
# 250-th epoch, marginal likelihood 624.0591884869492
# 300-th epoch, marginal likelihood 624.0246906633447
# 350-th epoch, marginal likelihood 623.892585371738
# 400-th epoch, marginal likelihood 623.9431145413832
# 450-th epoch, marginal likelihood 623.7226724354541
# 500-th epoch, marginal likelihood 623.6095601183512
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [10.74507268]
#  scale  =  6.709046263799932
#  scale2 =  45.01130176980783
#
#
# 0251-th step: f(x) = 22.780712 (action=286)
#    current best f(x) = 27.200952 (best action=453)
#
# 0252-th step: f(x) = 19.087295 (action=144)
#    current best f(x) = 27.200952 (best action=453)
#
# 0253-th step: f(x) = 12.753520 (action=467)
#    current best f(x) = 27.200952 (best action=453)
#
# 0254-th step: f(x) = 19.124220 (action=185)
#    current best f(x) = 27.200952 (best action=453)
#
# 0255-th step: f(x) = 18.574627 (action=9)
#    current best f(x) = 27.200952 (best action=453)
#
# 0256-th step: f(x) = 10.040245 (action=442)
#    current best f(x) = 27.200952 (best action=453)
#
# 0257-th step: f(x) = 17.679511 (action=384)
#    current best f(x) = 27.200952 (best action=453)
#
# 0258-th step: f(x) = 10.886919 (action=305)
#    current best f(x) = 27.200952 (best action=453)
#
# 0259-th step: f(x) = 12.995970 (action=246)
#    current best f(x) = 27.200952 (best action=453)
#
# 0260-th step: f(x) = 12.102233 (action=24)
#    current best f(x) = 27.200952 (best action=453)
#
# 0261-th step: f(x) = 10.155557 (action=315)
#    current best f(x) = 27.200952 (best action=453)
#
# 0262-th step: f(x) = 9.836070 (action=381)
#    current best f(x) = 27.200952 (best action=453)
#
# 0263-th step: f(x) = 9.027180 (action=94)
#    current best f(x) = 27.200952 (best action=453)
#
# 0264-th step: f(x) = 11.019247 (action=188)
#    current best f(x) = 27.200952 (best action=453)
#
# 0265-th step: f(x) = 10.562600 (action=139)
#    current best f(x) = 27.200952 (best action=453)
#
# 0266-th step: f(x) = 8.604392 (action=395)
#    current best f(x) = 27.200952 (best action=453)
#
# 0267-th step: f(x) = 10.066571 (action=367)
#    current best f(x) = 27.200952 (best action=453)
#
# 0268-th step: f(x) = 10.802941 (action=13)
#    current best f(x) = 27.200952 (best action=453)
#
# 0269-th step: f(x) = 9.166123 (action=21)
#    current best f(x) = 27.200952 (best action=453)
#
# 0270-th step: f(x) = 10.325013 (action=489)
#    current best f(x) = 27.200952 (best action=453)
#
# 0271-th step: f(x) = 11.122735 (action=133)
#    current best f(x) = 27.200952 (best action=453)
#
# 0272-th step: f(x) = 13.124802 (action=280)
#    current best f(x) = 27.200952 (best action=453)
#
# 0273-th step: f(x) = 9.538002 (action=239)
#    current best f(x) = 27.200952 (best action=453)
#
# 0274-th step: f(x) = 10.906387 (action=252)
#    current best f(x) = 27.200952 (best action=453)
#
# 0275-th step: f(x) = 11.888701 (action=383)
#    current best f(x) = 27.200952 (best action=453)
#
# 0276-th step: f(x) = 8.764908 (action=232)
#    current best f(x) = 27.200952 (best action=453)
#
# 0277-th step: f(x) = 14.557415 (action=80)
#    current best f(x) = 27.200952 (best action=453)
#
# 0278-th step: f(x) = 11.323582 (action=361)
#    current best f(x) = 27.200952 (best action=453)
#
# 0279-th step: f(x) = 10.001095 (action=66)
#    current best f(x) = 27.200952 (best action=453)
#
# 0280-th step: f(x) = 10.619391 (action=124)
#    current best f(x) = 27.200952 (best action=453)
#
# 0281-th step: f(x) = 12.510394 (action=168)
#    current best f(x) = 27.200952 (best action=453)
#
# 0282-th step: f(x) = 8.213658 (action=287)
#    current best f(x) = 27.200952 (best action=453)
#
# 0283-th step: f(x) = 8.879206 (action=302)
#    current best f(x) = 27.200952 (best action=453)
#
# 0284-th step: f(x) = 12.303462 (action=358)
#    current best f(x) = 27.200952 (best action=453)
#
# 0285-th step: f(x) = 10.451722 (action=292)
#    current best f(x) = 27.200952 (best action=453)
#
# 0286-th step: f(x) = 9.614772 (action=122)
#    current best f(x) = 27.200952 (best action=453)
#
# 0287-th step: f(x) = 8.308253 (action=29)
#    current best f(x) = 27.200952 (best action=453)
#
# 0288-th step: f(x) = 8.687422 (action=208)
#    current best f(x) = 27.200952 (best action=453)
#
# 0289-th step: f(x) = 10.549001 (action=471)
#    current best f(x) = 27.200952 (best action=453)
#
# 0290-th step: f(x) = 8.701103 (action=120)
#    current best f(x) = 27.200952 (best action=453)
#
# 0291-th step: f(x) = 9.872121 (action=269)
#    current best f(x) = 27.200952 (best action=453)
#
# 0292-th step: f(x) = 14.481328 (action=28)
#    current best f(x) = 27.200952 (best action=453)
#
# 0293-th step: f(x) = 12.216533 (action=4)
#    current best f(x) = 27.200952 (best action=453)
#
# 0294-th step: f(x) = 18.436723 (action=82)
#    current best f(x) = 27.200952 (best action=453)
#
# 0295-th step: f(x) = 11.857812 (action=190)
#    current best f(x) = 27.200952 (best action=453)
#
# 0296-th step: f(x) = 11.785598 (action=195)
#    current best f(x) = 27.200952 (best action=453)
#
# 0297-th step: f(x) = 9.148296 (action=478)
#    current best f(x) = 27.200952 (best action=453)
#
# 0298-th step: f(x) = 8.940435 (action=119)
#    current best f(x) = 27.200952 (best action=453)
#
# 0299-th step: f(x) = 17.019654 (action=310)
#    current best f(x) = 27.200952 (best action=453)
#
# 0300-th step: f(x) = 8.175553 (action=5)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 726.7722009155722
# 50-th epoch, marginal likelihood 724.6995627302143
# 100-th epoch, marginal likelihood 723.9412596914444
# 150-th epoch, marginal likelihood 723.6046275211306
# 200-th epoch, marginal likelihood 723.1255854174283
# 250-th epoch, marginal likelihood 722.8017652607832
# 300-th epoch, marginal likelihood 722.5767841859775
# 350-th epoch, marginal likelihood 722.2844685763902
# 400-th epoch, marginal likelihood 721.9204413596121
# 450-th epoch, marginal likelihood 721.5801366823705
# 500-th epoch, marginal likelihood 721.4374079024909
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [9.8368983]
#  scale  =  6.101798213057937
#  scale2 =  37.231941432877036
#
#
# 0301-th step: f(x) = 10.167070 (action=23)
#    current best f(x) = 27.200952 (best action=453)
#
# 0302-th step: f(x) = 12.806394 (action=62)
#    current best f(x) = 27.200952 (best action=453)
#
# 0303-th step: f(x) = 10.309692 (action=3)
#    current best f(x) = 27.200952 (best action=453)
#
# 0304-th step: f(x) = 8.224445 (action=485)
#    current best f(x) = 27.200952 (best action=453)
#
# 0305-th step: f(x) = 10.764082 (action=460)
#    current best f(x) = 27.200952 (best action=453)
#
# 0306-th step: f(x) = 9.779923 (action=151)
#    current best f(x) = 27.200952 (best action=453)
#
# 0307-th step: f(x) = 9.689279 (action=260)
#    current best f(x) = 27.200952 (best action=453)
#
# 0308-th step: f(x) = 17.022443 (action=214)
#    current best f(x) = 27.200952 (best action=453)
#
# 0309-th step: f(x) = 13.575485 (action=274)
#    current best f(x) = 27.200952 (best action=453)
#
# 0310-th step: f(x) = 9.300565 (action=390)
#    current best f(x) = 27.200952 (best action=453)
#
# 0311-th step: f(x) = 9.231417 (action=18)
#    current best f(x) = 27.200952 (best action=453)
#
# 0312-th step: f(x) = 10.768150 (action=134)
#    current best f(x) = 27.200952 (best action=453)
#
# 0313-th step: f(x) = 11.324984 (action=298)
#    current best f(x) = 27.200952 (best action=453)
#
# 0314-th step: f(x) = 10.176274 (action=12)
#    current best f(x) = 27.200952 (best action=453)
#
# 0315-th step: f(x) = 11.248858 (action=73)
#    current best f(x) = 27.200952 (best action=453)
#
# 0316-th step: f(x) = 13.191300 (action=265)
#    current best f(x) = 27.200952 (best action=453)
#
# 0317-th step: f(x) = 11.181507 (action=465)
#    current best f(x) = 27.200952 (best action=453)
#
# 0318-th step: f(x) = 10.485605 (action=379)
#    current best f(x) = 27.200952 (best action=453)
#
# 0319-th step: f(x) = 9.912928 (action=203)
#    current best f(x) = 27.200952 (best action=453)
#
# 0320-th step: f(x) = 9.474695 (action=277)
#    current best f(x) = 27.200952 (best action=453)
#
# 0321-th step: f(x) = 9.939516 (action=184)
#    current best f(x) = 27.200952 (best action=453)
#
# 0322-th step: f(x) = 8.305630 (action=172)
#    current best f(x) = 27.200952 (best action=453)
#
# 0323-th step: f(x) = 8.775160 (action=127)
#    current best f(x) = 27.200952 (best action=453)
#
# 0324-th step: f(x) = 10.620830 (action=268)
#    current best f(x) = 27.200952 (best action=453)
#
# 0325-th step: f(x) = 11.324810 (action=433)
#    current best f(x) = 27.200952 (best action=453)
#
# 0326-th step: f(x) = 10.277968 (action=173)
#    current best f(x) = 27.200952 (best action=453)
#
# 0327-th step: f(x) = 11.245583 (action=492)
#    current best f(x) = 27.200952 (best action=453)
#
# 0328-th step: f(x) = 12.159280 (action=480)
#    current best f(x) = 27.200952 (best action=453)
#
# 0329-th step: f(x) = 11.950303 (action=153)
#    current best f(x) = 27.200952 (best action=453)
#
# 0330-th step: f(x) = 10.293233 (action=430)
#    current best f(x) = 27.200952 (best action=453)
#
# 0331-th step: f(x) = 12.301324 (action=425)
#    current best f(x) = 27.200952 (best action=453)
#
# 0332-th step: f(x) = 8.592269 (action=336)
#    current best f(x) = 27.200952 (best action=453)
#
# 0333-th step: f(x) = 11.788995 (action=221)
#    current best f(x) = 27.200952 (best action=453)
#
# 0334-th step: f(x) = 11.569069 (action=316)
#    current best f(x) = 27.200952 (best action=453)
#
# 0335-th step: f(x) = 12.133077 (action=297)
#    current best f(x) = 27.200952 (best action=453)
#
# 0336-th step: f(x) = 9.398884 (action=104)
#    current best f(x) = 27.200952 (best action=453)
#
# 0337-th step: f(x) = 8.325543 (action=102)
#    current best f(x) = 27.200952 (best action=453)
#
# 0338-th step: f(x) = 9.303758 (action=417)
#    current best f(x) = 27.200952 (best action=453)
#
# 0339-th step: f(x) = 10.798158 (action=155)
#    current best f(x) = 27.200952 (best action=453)
#
# 0340-th step: f(x) = 8.193677 (action=270)
#    current best f(x) = 27.200952 (best action=453)
#
# 0341-th step: f(x) = 13.103882 (action=78)
#    current best f(x) = 27.200952 (best action=453)
#
# 0342-th step: f(x) = 11.288276 (action=237)
#    current best f(x) = 27.200952 (best action=453)
#
# 0343-th step: f(x) = 8.305276 (action=451)
#    current best f(x) = 27.200952 (best action=453)
#
# 0344-th step: f(x) = 11.181464 (action=97)
#    current best f(x) = 27.200952 (best action=453)
#
# 0345-th step: f(x) = 11.521340 (action=399)
#    current best f(x) = 27.200952 (best action=453)
#
# 0346-th step: f(x) = 8.459634 (action=437)
#    current best f(x) = 27.200952 (best action=453)
#
# 0347-th step: f(x) = 10.578804 (action=279)
#    current best f(x) = 27.200952 (best action=453)
#
# 0348-th step: f(x) = 11.106032 (action=38)
#    current best f(x) = 27.200952 (best action=453)
#
# 0349-th step: f(x) = 10.112508 (action=422)
#    current best f(x) = 27.200952 (best action=453)
#
# 0350-th step: f(x) = 10.154133 (action=50)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 834.8499674213131
# 50-th epoch, marginal likelihood 834.7089622601878
# 100-th epoch, marginal likelihood 834.0629149582949
# 150-th epoch, marginal likelihood 833.7269350723491
# 200-th epoch, marginal likelihood 833.1476939102965
# 250-th epoch, marginal likelihood 832.627944539183
# 300-th epoch, marginal likelihood 832.0850701612518
# 350-th epoch, marginal likelihood 831.5262668881237
# 400-th epoch, marginal likelihood 831.3593473615576
# 450-th epoch, marginal likelihood 831.1410188782264
# 500-th epoch, marginal likelihood 830.6699294573319
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [9.73691154]
#  scale  =  5.789874921052169
#  scale2 =  33.52265160142886
#
#
# 0351-th step: f(x) = 10.813239 (action=458)
#    current best f(x) = 27.200952 (best action=453)
#
# 0352-th step: f(x) = 10.176659 (action=486)
#    current best f(x) = 27.200952 (best action=453)
#
# 0353-th step: f(x) = 10.312649 (action=72)
#    current best f(x) = 27.200952 (best action=453)
#
# 0354-th step: f(x) = 10.281157 (action=103)
#    current best f(x) = 27.200952 (best action=453)
#
# 0355-th step: f(x) = 8.632794 (action=257)
#    current best f(x) = 27.200952 (best action=453)
#
# 0356-th step: f(x) = 9.546641 (action=445)
#    current best f(x) = 27.200952 (best action=453)
#
# 0357-th step: f(x) = 9.504382 (action=322)
#    current best f(x) = 27.200952 (best action=453)
#
# 0358-th step: f(x) = 11.556895 (action=231)
#    current best f(x) = 27.200952 (best action=453)
#
# 0359-th step: f(x) = 10.633020 (action=479)
#    current best f(x) = 27.200952 (best action=453)
#
# 0360-th step: f(x) = 8.484439 (action=447)
#    current best f(x) = 27.200952 (best action=453)
#
# 0361-th step: f(x) = 11.497698 (action=398)
#    current best f(x) = 27.200952 (best action=453)
#
# 0362-th step: f(x) = 10.994084 (action=116)
#    current best f(x) = 27.200952 (best action=453)
#
# 0363-th step: f(x) = 9.871811 (action=477)
#    current best f(x) = 27.200952 (best action=453)
#
# 0364-th step: f(x) = 8.965943 (action=355)
#    current best f(x) = 27.200952 (best action=453)
#
# 0365-th step: f(x) = 9.374820 (action=22)
#    current best f(x) = 27.200952 (best action=453)
#
# 0366-th step: f(x) = 10.202543 (action=275)
#    current best f(x) = 27.200952 (best action=453)
#
# 0367-th step: f(x) = 9.093463 (action=494)
#    current best f(x) = 27.200952 (best action=453)
#
# 0368-th step: f(x) = 11.512751 (action=456)
#    current best f(x) = 27.200952 (best action=453)
#
# 0369-th step: f(x) = 9.914487 (action=450)
#    current best f(x) = 27.200952 (best action=453)
#
# 0370-th step: f(x) = 10.243895 (action=25)
#    current best f(x) = 27.200952 (best action=453)
#
# 0371-th step: f(x) = 10.323454 (action=87)
#    current best f(x) = 27.200952 (best action=453)
#
# 0372-th step: f(x) = 9.593130 (action=251)
#    current best f(x) = 27.200952 (best action=453)
#
# 0373-th step: f(x) = 10.475035 (action=145)
#    current best f(x) = 27.200952 (best action=453)
#
# 0374-th step: f(x) = 11.522658 (action=225)
#    current best f(x) = 27.200952 (best action=453)
#
# 0375-th step: f(x) = 10.462989 (action=101)
#    current best f(x) = 27.200952 (best action=453)
#
# 0376-th step: f(x) = 10.103281 (action=431)
#    current best f(x) = 27.200952 (best action=453)
#
# 0377-th step: f(x) = 10.641013 (action=369)
#    current best f(x) = 27.200952 (best action=453)
#
# 0378-th step: f(x) = 10.108549 (action=85)
#    current best f(x) = 27.200952 (best action=453)
#
# 0379-th step: f(x) = 10.681088 (action=70)
#    current best f(x) = 27.200952 (best action=453)
#
# 0380-th step: f(x) = 10.746670 (action=309)
#    current best f(x) = 27.200952 (best action=453)
#
# 0381-th step: f(x) = 8.476657 (action=285)
#    current best f(x) = 27.200952 (best action=453)
#
# 0382-th step: f(x) = 11.060663 (action=368)
#    current best f(x) = 27.200952 (best action=453)
#
# 0383-th step: f(x) = 14.816282 (action=74)
#    current best f(x) = 27.200952 (best action=453)
#
# 0384-th step: f(x) = 9.473358 (action=65)
#    current best f(x) = 27.200952 (best action=453)
#
# 0385-th step: f(x) = 9.101019 (action=136)
#    current best f(x) = 27.200952 (best action=453)
#
# 0386-th step: f(x) = 10.005417 (action=169)
#    current best f(x) = 27.200952 (best action=453)
#
# 0387-th step: f(x) = 9.476697 (action=182)
#    current best f(x) = 27.200952 (best action=453)
#
# 0388-th step: f(x) = 8.410939 (action=376)
#    current best f(x) = 27.200952 (best action=453)
#
# 0389-th step: f(x) = 11.159947 (action=43)
#    current best f(x) = 27.200952 (best action=453)
#
# 0390-th step: f(x) = 8.867940 (action=162)
#    current best f(x) = 27.200952 (best action=453)
#
# 0391-th step: f(x) = 11.376817 (action=434)
#    current best f(x) = 27.200952 (best action=453)
#
# 0392-th step: f(x) = 9.482899 (action=31)
#    current best f(x) = 27.200952 (best action=453)
#
# 0393-th step: f(x) = 12.349684 (action=455)
#    current best f(x) = 27.200952 (best action=453)
#
# 0394-th step: f(x) = 11.549103 (action=271)
#    current best f(x) = 27.200952 (best action=453)
#
# 0395-th step: f(x) = 8.257007 (action=496)
#    current best f(x) = 27.200952 (best action=453)
#
# 0396-th step: f(x) = 11.530854 (action=32)
#    current best f(x) = 27.200952 (best action=453)
#
# 0397-th step: f(x) = 8.231807 (action=20)
#    current best f(x) = 27.200952 (best action=453)
#
# 0398-th step: f(x) = 11.389134 (action=154)
#    current best f(x) = 27.200952 (best action=453)
#
# 0399-th step: f(x) = 8.350529 (action=340)
#    current best f(x) = 27.200952 (best action=453)
#
# 0400-th step: f(x) = 9.298012 (action=484)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 933.5299195042267
# 50-th epoch, marginal likelihood 933.6665821840517
# 100-th epoch, marginal likelihood 933.448225836149
# 150-th epoch, marginal likelihood 932.8974552176455
# 200-th epoch, marginal likelihood 932.6511670103176
# 250-th epoch, marginal likelihood 931.8047495863452
# 300-th epoch, marginal likelihood 931.2125115562171
# 350-th epoch, marginal likelihood 930.8395851421311
# 400-th epoch, marginal likelihood 930.3542980533246
# 450-th epoch, marginal likelihood 930.1674339774218
# 500-th epoch, marginal likelihood 929.7793664337648
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [9.38264631]
#  scale  =  5.4983841274759975
#  scale2 =  30.232228013279986
#
#
# 0401-th step: f(x) = 10.646867 (action=308)
#    current best f(x) = 27.200952 (best action=453)
#
# 0402-th step: f(x) = 10.737033 (action=468)
#    current best f(x) = 27.200952 (best action=453)
#
# 0403-th step: f(x) = 9.769790 (action=41)
#    current best f(x) = 27.200952 (best action=453)
#
# 0404-th step: f(x) = 10.307702 (action=235)
#    current best f(x) = 27.200952 (best action=453)
#
# 0405-th step: f(x) = 8.466462 (action=56)
#    current best f(x) = 27.200952 (best action=453)
#
# 0406-th step: f(x) = 10.361846 (action=48)
#    current best f(x) = 27.200952 (best action=453)
#
# 0407-th step: f(x) = 12.331550 (action=26)
#    current best f(x) = 27.200952 (best action=453)
#
# 0408-th step: f(x) = 8.577983 (action=57)
#    current best f(x) = 27.200952 (best action=453)
#
# 0409-th step: f(x) = 8.765337 (action=339)
#    current best f(x) = 27.200952 (best action=453)
#
# 0410-th step: f(x) = 11.007414 (action=92)
#    current best f(x) = 27.200952 (best action=453)
#
# 0411-th step: f(x) = 9.837844 (action=313)
#    current best f(x) = 27.200952 (best action=453)
#
# 0412-th step: f(x) = 12.965340 (action=482)
#    current best f(x) = 27.200952 (best action=453)
#
# 0413-th step: f(x) = 8.621496 (action=470)
#    current best f(x) = 27.200952 (best action=453)
#
# 0414-th step: f(x) = 8.752795 (action=202)
#    current best f(x) = 27.200952 (best action=453)
#
# 0415-th step: f(x) = 9.631272 (action=449)
#    current best f(x) = 27.200952 (best action=453)
#
# 0416-th step: f(x) = 9.597451 (action=166)
#    current best f(x) = 27.200952 (best action=453)
#
# 0417-th step: f(x) = 8.541929 (action=178)
#    current best f(x) = 27.200952 (best action=453)
#
# 0418-th step: f(x) = 10.020662 (action=187)
#    current best f(x) = 27.200952 (best action=453)
#
# 0419-th step: f(x) = 9.184536 (action=69)
#    current best f(x) = 27.200952 (best action=453)
#
# 0420-th step: f(x) = 11.381385 (action=68)
#    current best f(x) = 27.200952 (best action=453)
#
# 0421-th step: f(x) = 13.048880 (action=328)
#    current best f(x) = 27.200952 (best action=453)
#
# 0422-th step: f(x) = 12.601440 (action=7)
#    current best f(x) = 27.200952 (best action=453)
#
# 0423-th step: f(x) = 8.927517 (action=123)
#    current best f(x) = 27.200952 (best action=453)
#
# 0424-th step: f(x) = 8.388450 (action=106)
#    current best f(x) = 27.200952 (best action=453)
#
# 0425-th step: f(x) = 8.648269 (action=99)
#    current best f(x) = 27.200952 (best action=453)
#
# 0426-th step: f(x) = 8.344087 (action=19)
#    current best f(x) = 27.200952 (best action=453)
#
# 0427-th step: f(x) = 11.993764 (action=448)
#    current best f(x) = 27.200952 (best action=453)
#
# 0428-th step: f(x) = 11.472193 (action=293)
#    current best f(x) = 27.200952 (best action=453)
#
# 0429-th step: f(x) = 8.552751 (action=263)
#    current best f(x) = 27.200952 (best action=453)
#
# 0430-th step: f(x) = 9.275903 (action=332)
#    current best f(x) = 27.200952 (best action=453)
#
# 0431-th step: f(x) = 8.547200 (action=377)
#    current best f(x) = 27.200952 (best action=453)
#
# 0432-th step: f(x) = 9.883999 (action=410)
#    current best f(x) = 27.200952 (best action=453)
#
# 0433-th step: f(x) = 9.479436 (action=243)
#    current best f(x) = 27.200952 (best action=453)
#
# 0434-th step: f(x) = 9.501531 (action=10)
#    current best f(x) = 27.200952 (best action=453)
#
# 0435-th step: f(x) = 8.409145 (action=474)
#    current best f(x) = 27.200952 (best action=453)
#
# 0436-th step: f(x) = 12.072616 (action=213)
#    current best f(x) = 27.200952 (best action=453)
#
# 0437-th step: f(x) = 9.812435 (action=299)
#    current best f(x) = 27.200952 (best action=453)
#
# 0438-th step: f(x) = 8.558220 (action=481)
#    current best f(x) = 27.200952 (best action=453)
#
# 0439-th step: f(x) = 11.797766 (action=365)
#    current best f(x) = 27.200952 (best action=453)
#
# 0440-th step: f(x) = 10.232971 (action=483)
#    current best f(x) = 27.200952 (best action=453)
#
# 0441-th step: f(x) = 10.819696 (action=52)
#    current best f(x) = 27.200952 (best action=453)
#
# 0442-th step: f(x) = 12.186645 (action=146)
#    current best f(x) = 27.200952 (best action=453)
#
# 0443-th step: f(x) = 11.208855 (action=443)
#    current best f(x) = 27.200952 (best action=453)
#
# 0444-th step: f(x) = 9.597560 (action=61)
#    current best f(x) = 27.200952 (best action=453)
#
# 0445-th step: f(x) = 10.113003 (action=36)
#    current best f(x) = 27.200952 (best action=453)
#
# 0446-th step: f(x) = 8.813346 (action=409)
#    current best f(x) = 27.200952 (best action=453)
#
# 0447-th step: f(x) = 8.731186 (action=30)
#    current best f(x) = 27.200952 (best action=453)
#
# 0448-th step: f(x) = 8.989613 (action=405)
#    current best f(x) = 27.200952 (best action=453)
#
# 0449-th step: f(x) = 10.006865 (action=391)
#    current best f(x) = 27.200952 (best action=453)
#
# 0450-th step: f(x) = 8.485168 (action=60)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 1018.6404577303308
# 50-th epoch, marginal likelihood 1020.0550401623568
# 100-th epoch, marginal likelihood 1021.4415778654372
# 150-th epoch, marginal likelihood 1021.4522488775302
# 200-th epoch, marginal likelihood 1020.3577285444534
# 250-th epoch, marginal likelihood 1022.2013640299126
# 300-th epoch, marginal likelihood 1021.7297775466673
# 350-th epoch, marginal likelihood 1021.224589232808
# 400-th epoch, marginal likelihood 1020.2765153765714
# 450-th epoch, marginal likelihood 1020.6811793623392
# 500-th epoch, marginal likelihood 1021.1951583529246
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [9.3848066]
#  scale  =  5.344759257518835
#  scale2 =  28.566451520833294
#
#
# 0451-th step: f(x) = 8.700341 (action=388)
#    current best f(x) = 27.200952 (best action=453)
#
# 0452-th step: f(x) = 10.330342 (action=75)
#    current best f(x) = 27.200952 (best action=453)
#
# 0453-th step: f(x) = 8.553799 (action=150)
#    current best f(x) = 27.200952 (best action=453)
#
# 0454-th step: f(x) = 10.058481 (action=186)
#    current best f(x) = 27.200952 (best action=453)
#
# 0455-th step: f(x) = 12.016624 (action=71)
#    current best f(x) = 27.200952 (best action=453)
#
# 0456-th step: f(x) = 11.709692 (action=259)
#    current best f(x) = 27.200952 (best action=453)
#
# 0457-th step: f(x) = 9.204538 (action=129)
#    current best f(x) = 27.200952 (best action=453)
#
# 0458-th step: f(x) = 8.925313 (action=396)
#    current best f(x) = 27.200952 (best action=453)
#
# 0459-th step: f(x) = 8.743393 (action=418)
#    current best f(x) = 27.200952 (best action=453)
#
# 0460-th step: f(x) = 11.093591 (action=194)
#    current best f(x) = 27.200952 (best action=453)
#
# 0461-th step: f(x) = 11.353074 (action=217)
#    current best f(x) = 27.200952 (best action=453)
#
# 0462-th step: f(x) = 14.548176 (action=423)
#    current best f(x) = 27.200952 (best action=453)
#
# 0463-th step: f(x) = 9.048077 (action=152)
#    current best f(x) = 27.200952 (best action=453)
#
# 0464-th step: f(x) = 8.286171 (action=142)
#    current best f(x) = 27.200952 (best action=453)
#
# 0465-th step: f(x) = 8.413187 (action=135)
#    current best f(x) = 27.200952 (best action=453)
#
# 0466-th step: f(x) = 11.572382 (action=290)
#    current best f(x) = 27.200952 (best action=453)
#
# 0467-th step: f(x) = 9.868855 (action=253)
#    current best f(x) = 27.200952 (best action=453)
#
# 0468-th step: f(x) = 10.696403 (action=234)
#    current best f(x) = 27.200952 (best action=453)
#
# 0469-th step: f(x) = 10.047177 (action=183)
#    current best f(x) = 27.200952 (best action=453)
#
# 0470-th step: f(x) = 12.106479 (action=49)
#    current best f(x) = 27.200952 (best action=453)
#
# 0471-th step: f(x) = 9.120140 (action=191)
#    current best f(x) = 27.200952 (best action=453)
#
# 0472-th step: f(x) = 8.764844 (action=105)
#    current best f(x) = 27.200952 (best action=453)
#
# 0473-th step: f(x) = 11.111703 (action=424)
#    current best f(x) = 27.200952 (best action=453)
#
# 0474-th step: f(x) = 8.187441 (action=266)
#    current best f(x) = 27.200952 (best action=453)
#
# 0475-th step: f(x) = 8.651240 (action=324)
#    current best f(x) = 27.200952 (best action=453)
#
# 0476-th step: f(x) = 10.557070 (action=412)
#    current best f(x) = 27.200952 (best action=453)
#
# 0477-th step: f(x) = 9.487480 (action=256)
#    current best f(x) = 27.200952 (best action=453)
#
# 0478-th step: f(x) = 8.937088 (action=341)
#    current best f(x) = 27.200952 (best action=453)
#
# 0479-th step: f(x) = 10.755536 (action=16)
#    current best f(x) = 27.200952 (best action=453)
#
# 0480-th step: f(x) = 9.264374 (action=415)
#    current best f(x) = 27.200952 (best action=453)
#
# 0481-th step: f(x) = 10.865881 (action=11)
#    current best f(x) = 27.200952 (best action=453)
#
# 0482-th step: f(x) = 8.895531 (action=334)
#    current best f(x) = 27.200952 (best action=453)
#
# 0483-th step: f(x) = 10.122503 (action=314)
#    current best f(x) = 27.200952 (best action=453)
#
# 0484-th step: f(x) = 10.157350 (action=98)
#    current best f(x) = 27.200952 (best action=453)
#
# 0485-th step: f(x) = 8.795967 (action=354)
#    current best f(x) = 27.200952 (best action=453)
#
# 0486-th step: f(x) = 12.638871 (action=76)
#    current best f(x) = 27.200952 (best action=453)
#
# 0487-th step: f(x) = 8.348254 (action=392)
#    current best f(x) = 27.200952 (best action=453)
#
# 0488-th step: f(x) = 8.472652 (action=432)
#    current best f(x) = 27.200952 (best action=453)
#
# 0489-th step: f(x) = 9.836043 (action=125)
#    current best f(x) = 27.200952 (best action=453)
#
# 0490-th step: f(x) = 8.994670 (action=170)
#    current best f(x) = 27.200952 (best action=453)
#
# 0491-th step: f(x) = 11.075580 (action=46)
#    current best f(x) = 27.200952 (best action=453)
#
# 0492-th step: f(x) = 9.023424 (action=300)
#    current best f(x) = 27.200952 (best action=453)
#
# 0493-th step: f(x) = 8.565179 (action=325)
#    current best f(x) = 27.200952 (best action=453)
#
# 0494-th step: f(x) = 12.150470 (action=397)
#    current best f(x) = 27.200952 (best action=453)
#
# 0495-th step: f(x) = 9.464192 (action=81)
#    current best f(x) = 27.200952 (best action=453)
#
# 0496-th step: f(x) = 11.639690 (action=148)
#    current best f(x) = 27.200952 (best action=453)
#
# 0497-th step: f(x) = 10.256079 (action=45)
#    current best f(x) = 27.200952 (best action=453)
#
# 0498-th step: f(x) = 9.875474 (action=464)
#    current best f(x) = 27.200952 (best action=453)
#
# 0499-th step: f(x) = 8.994589 (action=88)
#    current best f(x) = 27.200952 (best action=453)
#
# 0500-th step: f(x) = 9.629406 (action=473)
#    current best f(x) = 27.200952 (best action=453)

# %%
COMBO_EI_Henry_H2O_unrelevant = COMBO(Data_unrelevant_features_Henry_H2O, 'EI')
# Out:
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 126.16405652556539
# 50-th epoch, marginal likelihood 106.3128654802206
# 100-th epoch, marginal likelihood 93.516855017446
# 150-th epoch, marginal likelihood 85.08211186675123
# 200-th epoch, marginal likelihood 80.07957791040582
# 250-th epoch, marginal likelihood 76.72947167263035
# 300-th epoch, marginal likelihood 74.37097683457849
# 350-th epoch, marginal likelihood 72.82285115159661
# 400-th epoch, marginal likelihood 71.65306326741191
# 450-th epoch, marginal likelihood 70.84009345504086
# 500-th epoch, marginal likelihood 70.16149202931157
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [3.]
#  scale  =  1.0
#  scale2 =  1.0
#
#
# 0101-th step: f(x) = 9.259340 (action=329)
#    current best f(x) = 9.259340 (best action=329)
#
# 0102-th step: f(x) = 8.646613 (action=421)
#    current best f(x) = 9.259340 (best action=329)
#
# 0103-th step: f(x) = 9.985689 (action=276)
#    current best f(x) = 9.985689 (best action=276)
#
# 0104-th step: f(x) = 9.672967 (action=446)
#    current best f(x) = 9.985689 (best action=276)
#
# 0105-th step: f(x) = 14.000021 (action=107)
#    current best f(x) = 14.000021 (best action=107)
#
# 0106-th step: f(x) = 10.654156 (action=370)
#    current best f(x) = 14.000021 (best action=107)
#
# 0107-th step: f(x) = 11.791428 (action=438)
#    current best f(x) = 14.000021 (best action=107)
#
# 0108-th step: f(x) = 10.125094 (action=444)
#    current best f(x) = 14.000021 (best action=107)
#
# 0109-th step: f(x) = 10.066571 (action=367)
#    current best f(x) = 14.000021 (best action=107)
#
# 0110-th step: f(x) = 12.082989 (action=130)
#    current best f(x) = 14.000021 (best action=107)
#
# 0111-th step: f(x) = 12.036363 (action=261)
#    current best f(x) = 14.000021 (best action=107)
#
# 0112-th step: f(x) = 15.329956 (action=0)
#    current best f(x) = 15.329956 (best action=0)
#
# 0113-th step: f(x) = 12.390168 (action=427)
#    current best f(x) = 15.329956 (best action=0)
#
# 0114-th step: f(x) = 12.981825 (action=393)
#    current best f(x) = 15.329956 (best action=0)
#
# 0115-th step: f(x) = 13.382275 (action=77)
#    current best f(x) = 15.329956 (best action=0)
#
# 0116-th step: f(x) = 14.760148 (action=114)
#    current best f(x) = 15.329956 (best action=0)
#
# 0117-th step: f(x) = 9.998502 (action=159)
#    current best f(x) = 15.329956 (best action=0)
#
# 0118-th step: f(x) = 16.048959 (action=411)
#    current best f(x) = 16.048959 (best action=411)
#
# 0119-th step: f(x) = 13.161024 (action=63)
#    current best f(x) = 16.048959 (best action=411)
#
# 0120-th step: f(x) = 8.229530 (action=109)
#    current best f(x) = 16.048959 (best action=411)
#
# 0121-th step: f(x) = 11.342833 (action=216)
#    current best f(x) = 16.048959 (best action=411)
#
# 0122-th step: f(x) = 20.178811 (action=426)
#    current best f(x) = 20.178811 (best action=426)
#
# 0123-th step: f(x) = 23.786587 (action=493)
#    current best f(x) = 23.786587 (best action=493)
#
# 0124-th step: f(x) = 19.112447 (action=35)
#    current best f(x) = 23.786587 (best action=493)
#
# 0125-th step: f(x) = 20.940093 (action=366)
#    current best f(x) = 23.786587 (best action=493)
#
# 0126-th step: f(x) = 23.321055 (action=250)
#    current best f(x) = 23.786587 (best action=493)
#
# 0127-th step: f(x) = 20.745086 (action=112)
#    current best f(x) = 23.786587 (best action=493)
#
# 0128-th step: f(x) = 23.417488 (action=372)
#    current best f(x) = 23.786587 (best action=493)
#
# 0129-th step: f(x) = 10.227301 (action=158)
#    current best f(x) = 23.786587 (best action=493)
#
# 0130-th step: f(x) = 17.891501 (action=240)
#    current best f(x) = 23.786587 (best action=493)
#
# 0131-th step: f(x) = 11.286286 (action=401)
#    current best f(x) = 23.786587 (best action=493)
#
# 0132-th step: f(x) = 8.764844 (action=105)
#    current best f(x) = 23.786587 (best action=493)
#
# 0133-th step: f(x) = 12.872524 (action=408)
#    current best f(x) = 23.786587 (best action=493)
#
# 0134-th step: f(x) = 13.536260 (action=220)
#    current best f(x) = 23.786587 (best action=493)
#
# 0135-th step: f(x) = 10.412183 (action=247)
#    current best f(x) = 23.786587 (best action=493)
#
# 0136-th step: f(x) = 19.219957 (action=39)
#    current best f(x) = 23.786587 (best action=493)
#
# 0137-th step: f(x) = 24.074734 (action=462)
#    current best f(x) = 24.074734 (best action=462)
#
# 0138-th step: f(x) = 15.242032 (action=284)
#    current best f(x) = 24.074734 (best action=462)
#
# 0139-th step: f(x) = 19.961039 (action=164)
#    current best f(x) = 24.074734 (best action=462)
#
# 0140-th step: f(x) = 19.627496 (action=338)
#    current best f(x) = 24.074734 (best action=462)
#
# 0141-th step: f(x) = 25.446139 (action=223)
#    current best f(x) = 25.446139 (best action=223)
#
# 0142-th step: f(x) = 17.234512 (action=472)
#    current best f(x) = 25.446139 (best action=223)
#
# 0143-th step: f(x) = 10.098647 (action=209)
#    current best f(x) = 25.446139 (best action=223)
#
# 0144-th step: f(x) = 15.741864 (action=93)
#    current best f(x) = 25.446139 (best action=223)
#
# 0145-th step: f(x) = 12.701915 (action=387)
#    current best f(x) = 25.446139 (best action=223)
#
# 0146-th step: f(x) = 9.149075 (action=64)
#    current best f(x) = 25.446139 (best action=223)
#
# 0147-th step: f(x) = 9.349041 (action=362)
#    current best f(x) = 25.446139 (best action=223)
#
# 0148-th step: f(x) = 10.714462 (action=131)
#    current best f(x) = 25.446139 (best action=223)
#
# 0149-th step: f(x) = 8.663025 (action=343)
#    current best f(x) = 25.446139 (best action=223)
#
# 0150-th step: f(x) = 16.032274 (action=229)
#    current best f(x) = 25.446139 (best action=223)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 321.9439839480686
# 50-th epoch, marginal likelihood 321.52088178515083
# 100-th epoch, marginal likelihood 321.3483140630275
# 150-th epoch, marginal likelihood 321.3769648963533
# 200-th epoch, marginal likelihood 321.39678387740463
# 250-th epoch, marginal likelihood 321.4324675241035
# 300-th epoch, marginal likelihood 321.4016463237129
# 350-th epoch, marginal likelihood 321.8862421111004
# 400-th epoch, marginal likelihood 321.83153882779493
# 450-th epoch, marginal likelihood 321.9491876598205
# 500-th epoch, marginal likelihood 322.0276212144724
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [6.18143854]
#  scale  =  0.6115722485976133
#  scale2 =  0.3740206152547409
#
#
# 0151-th step: f(x) = 20.044179 (action=176)
#    current best f(x) = 25.446139 (best action=223)
#
# 0152-th step: f(x) = 19.434830 (action=281)
#    current best f(x) = 25.446139 (best action=223)
#
# 0153-th step: f(x) = 20.785715 (action=357)
#    current best f(x) = 25.446139 (best action=223)
#
# 0154-th step: f(x) = 19.386560 (action=295)
#    current best f(x) = 25.446139 (best action=223)
#
# 0155-th step: f(x) = 19.788790 (action=498)
#    current best f(x) = 25.446139 (best action=223)
#
# 0156-th step: f(x) = 19.635584 (action=245)
#    current best f(x) = 25.446139 (best action=223)
#
# 0157-th step: f(x) = 18.367571 (action=118)
#    current best f(x) = 25.446139 (best action=223)
#
# 0158-th step: f(x) = 20.385631 (action=242)
#    current best f(x) = 25.446139 (best action=223)
#
# 0159-th step: f(x) = 19.661390 (action=475)
#    current best f(x) = 25.446139 (best action=223)
#
# 0160-th step: f(x) = 18.700761 (action=53)
#    current best f(x) = 25.446139 (best action=223)
#
# 0161-th step: f(x) = 24.230367 (action=177)
#    current best f(x) = 25.446139 (best action=223)
#
# 0162-th step: f(x) = 24.720306 (action=219)
#    current best f(x) = 25.446139 (best action=223)
#
# 0163-th step: f(x) = 19.121564 (action=323)
#    current best f(x) = 25.446139 (best action=223)
#
# 0164-th step: f(x) = 22.669884 (action=463)
#    current best f(x) = 25.446139 (best action=223)
#
# 0165-th step: f(x) = 18.991240 (action=83)
#    current best f(x) = 25.446139 (best action=223)
#
# 0166-th step: f(x) = 21.085091 (action=311)
#    current best f(x) = 25.446139 (best action=223)
#
# 0167-th step: f(x) = 19.127824 (action=47)
#    current best f(x) = 25.446139 (best action=223)
#
# 0168-th step: f(x) = 27.200952 (action=453)
#    current best f(x) = 27.200952 (best action=453)
#
# 0169-th step: f(x) = 13.413145 (action=363)
#    current best f(x) = 27.200952 (best action=453)
#
# 0170-th step: f(x) = 11.758832 (action=201)
#    current best f(x) = 27.200952 (best action=453)
#
# 0171-th step: f(x) = 15.736654 (action=330)
#    current best f(x) = 27.200952 (best action=453)
#
# 0172-th step: f(x) = 15.506670 (action=44)
#    current best f(x) = 27.200952 (best action=453)
#
# 0173-th step: f(x) = 26.956130 (action=440)
#    current best f(x) = 27.200952 (best action=453)
#
# 0174-th step: f(x) = 24.460583 (action=8)
#    current best f(x) = 27.200952 (best action=453)
#
# 0175-th step: f(x) = 20.617683 (action=51)
#    current best f(x) = 27.200952 (best action=453)
#
# 0176-th step: f(x) = 10.696245 (action=111)
#    current best f(x) = 27.200952 (best action=453)
#
# 0177-th step: f(x) = 10.921497 (action=320)
#    current best f(x) = 27.200952 (best action=453)
#
# 0178-th step: f(x) = 10.314477 (action=197)
#    current best f(x) = 27.200952 (best action=453)
#
# 0179-th step: f(x) = 9.774005 (action=196)
#    current best f(x) = 27.200952 (best action=453)
#
# 0180-th step: f(x) = 21.201857 (action=306)
#    current best f(x) = 27.200952 (best action=453)
#
# 0181-th step: f(x) = 17.765992 (action=206)
#    current best f(x) = 27.200952 (best action=453)
#
# 0182-th step: f(x) = 25.615406 (action=359)
#    current best f(x) = 27.200952 (best action=453)
#
# 0183-th step: f(x) = 18.368629 (action=84)
#    current best f(x) = 27.200952 (best action=453)
#
# 0184-th step: f(x) = 12.162878 (action=86)
#    current best f(x) = 27.200952 (best action=453)
#
# 0185-th step: f(x) = 17.862973 (action=96)
#    current best f(x) = 27.200952 (best action=453)
#
# 0186-th step: f(x) = 15.402149 (action=288)
#    current best f(x) = 27.200952 (best action=453)
#
# 0187-th step: f(x) = 20.166710 (action=461)
#    current best f(x) = 27.200952 (best action=453)
#
# 0188-th step: f(x) = 20.809906 (action=371)
#    current best f(x) = 27.200952 (best action=453)
#
# 0189-th step: f(x) = 22.536448 (action=180)
#    current best f(x) = 27.200952 (best action=453)
#
# 0190-th step: f(x) = 20.552601 (action=318)
#    current best f(x) = 27.200952 (best action=453)
#
# 0191-th step: f(x) = 10.092387 (action=128)
#    current best f(x) = 27.200952 (best action=453)
#
# 0192-th step: f(x) = 9.459370 (action=319)
#    current best f(x) = 27.200952 (best action=453)
#
# 0193-th step: f(x) = 17.033093 (action=211)
#    current best f(x) = 27.200952 (best action=453)
#
# 0194-th step: f(x) = 13.215019 (action=491)
#    current best f(x) = 27.200952 (best action=453)
#
# 0195-th step: f(x) = 19.065142 (action=439)
#    current best f(x) = 27.200952 (best action=453)
#
# 0196-th step: f(x) = 10.990948 (action=495)
#    current best f(x) = 27.200952 (best action=453)
#
# 0197-th step: f(x) = 13.537182 (action=189)
#    current best f(x) = 27.200952 (best action=453)
#
# 0198-th step: f(x) = 17.599405 (action=198)
#    current best f(x) = 27.200952 (best action=453)
#
# 0199-th step: f(x) = 20.592638 (action=394)
#    current best f(x) = 27.200952 (best action=453)
#
# 0200-th step: f(x) = 24.073749 (action=342)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 492.3341358264365
# 50-th epoch, marginal likelihood 492.2303011150475
# 100-th epoch, marginal likelihood 492.25119374868757
# 150-th epoch, marginal likelihood 492.2238058899983
# 200-th epoch, marginal likelihood 492.1141230937759
# 250-th epoch, marginal likelihood 492.15575159994086
# 300-th epoch, marginal likelihood 492.072837332898
# 350-th epoch, marginal likelihood 492.04172219167367
# 400-th epoch, marginal likelihood 491.9863553076399
# 450-th epoch, marginal likelihood 491.91489452635295
# 500-th epoch, marginal likelihood 491.8493342162351
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [13.20539894]
#  scale  =  5.492343036160611
#  scale2 =  30.165832026861963
#
#
# 0201-th step: f(x) = 24.150111 (action=407)
#    current best f(x) = 27.200952 (best action=453)
#
# 0202-th step: f(x) = 24.477783 (action=333)
#    current best f(x) = 27.200952 (best action=453)
#
# 0203-th step: f(x) = 22.410886 (action=488)
#    current best f(x) = 27.200952 (best action=453)
#
# 0204-th step: f(x) = 19.575174 (action=6)
#    current best f(x) = 27.200952 (best action=453)
#
# 0205-th step: f(x) = 18.974373 (action=267)
#    current best f(x) = 27.200952 (best action=453)
#
# 0206-th step: f(x) = 14.540598 (action=345)
#    current best f(x) = 27.200952 (best action=453)
#
# 0207-th step: f(x) = 20.806511 (action=416)
#    current best f(x) = 27.200952 (best action=453)
#
# 0208-th step: f(x) = 17.255800 (action=457)
#    current best f(x) = 27.200952 (best action=453)
#
# 0209-th step: f(x) = 18.947412 (action=54)
#    current best f(x) = 27.200952 (best action=453)
#
# 0210-th step: f(x) = 17.797239 (action=283)
#    current best f(x) = 27.200952 (best action=453)
#
# 0211-th step: f(x) = 14.454270 (action=296)
#    current best f(x) = 27.200952 (best action=453)
#
# 0212-th step: f(x) = 10.867616 (action=420)
#    current best f(x) = 27.200952 (best action=453)
#
# 0213-th step: f(x) = 10.353763 (action=331)
#    current best f(x) = 27.200952 (best action=453)
#
# 0214-th step: f(x) = 10.849139 (action=272)
#    current best f(x) = 27.200952 (best action=453)
#
# 0215-th step: f(x) = 10.887112 (action=55)
#    current best f(x) = 27.200952 (best action=453)
#
# 0216-th step: f(x) = 15.516782 (action=317)
#    current best f(x) = 27.200952 (best action=453)
#
# 0217-th step: f(x) = 19.565801 (action=344)
#    current best f(x) = 27.200952 (best action=453)
#
# 0218-th step: f(x) = 11.201268 (action=181)
#    current best f(x) = 27.200952 (best action=453)
#
# 0219-th step: f(x) = 11.117079 (action=218)
#    current best f(x) = 27.200952 (best action=453)
#
# 0220-th step: f(x) = 9.150378 (action=228)
#    current best f(x) = 27.200952 (best action=453)
#
# 0221-th step: f(x) = 16.795142 (action=238)
#    current best f(x) = 27.200952 (best action=453)
#
# 0222-th step: f(x) = 8.549548 (action=435)
#    current best f(x) = 27.200952 (best action=453)
#
# 0223-th step: f(x) = 18.494091 (action=37)
#    current best f(x) = 27.200952 (best action=453)
#
# 0224-th step: f(x) = 8.649175 (action=459)
#    current best f(x) = 27.200952 (best action=453)
#
# 0225-th step: f(x) = 9.521568 (action=90)
#    current best f(x) = 27.200952 (best action=453)
#
# 0226-th step: f(x) = 8.518273 (action=100)
#    current best f(x) = 27.200952 (best action=453)
#
# 0227-th step: f(x) = 11.616195 (action=212)
#    current best f(x) = 27.200952 (best action=453)
#
# 0228-th step: f(x) = 12.262703 (action=466)
#    current best f(x) = 27.200952 (best action=453)
#
# 0229-th step: f(x) = 23.648870 (action=95)
#    current best f(x) = 27.200952 (best action=453)
#
# 0230-th step: f(x) = 12.722584 (action=436)
#    current best f(x) = 27.200952 (best action=453)
#
# 0231-th step: f(x) = 13.712758 (action=327)
#    current best f(x) = 27.200952 (best action=453)
#
# 0232-th step: f(x) = 9.807213 (action=40)
#    current best f(x) = 27.200952 (best action=453)
#
# 0233-th step: f(x) = 11.039188 (action=140)
#    current best f(x) = 27.200952 (best action=453)
#
# 0234-th step: f(x) = 10.346104 (action=350)
#    current best f(x) = 27.200952 (best action=453)
#
# 0235-th step: f(x) = 8.192244 (action=403)
#    current best f(x) = 27.200952 (best action=453)
#
# 0236-th step: f(x) = 8.723741 (action=346)
#    current best f(x) = 27.200952 (best action=453)
#
# 0237-th step: f(x) = 9.947423 (action=179)
#    current best f(x) = 27.200952 (best action=453)
#
# 0238-th step: f(x) = 24.325384 (action=303)
#    current best f(x) = 27.200952 (best action=453)
#
# 0239-th step: f(x) = 9.745295 (action=307)
#    current best f(x) = 27.200952 (best action=453)
#
# 0240-th step: f(x) = 8.214925 (action=262)
#    current best f(x) = 27.200952 (best action=453)
#
# 0241-th step: f(x) = 11.784874 (action=278)
#    current best f(x) = 27.200952 (best action=453)
#
# 0242-th step: f(x) = 16.932531 (action=254)
#    current best f(x) = 27.200952 (best action=453)
#
# 0243-th step: f(x) = 10.553975 (action=454)
#    current best f(x) = 27.200952 (best action=453)
#
# 0244-th step: f(x) = 10.031485 (action=294)
#    current best f(x) = 27.200952 (best action=453)
#
# 0245-th step: f(x) = 8.184408 (action=161)
#    current best f(x) = 27.200952 (best action=453)
#
# 0246-th step: f(x) = 8.675277 (action=17)
#    current best f(x) = 27.200952 (best action=453)
#
# 0247-th step: f(x) = 9.912229 (action=15)
#    current best f(x) = 27.200952 (best action=453)
#
# 0248-th step: f(x) = 11.303103 (action=67)
#    current best f(x) = 27.200952 (best action=453)
#
# 0249-th step: f(x) = 9.538002 (action=239)
#    current best f(x) = 27.200952 (best action=453)
#
# 0250-th step: f(x) = 20.162669 (action=117)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 616.7071324888832
# 50-th epoch, marginal likelihood 616.7003256340749
# 100-th epoch, marginal likelihood 616.7223772351562
# 150-th epoch, marginal likelihood 616.6653729521179
# 200-th epoch, marginal likelihood 617.104077118833
# 250-th epoch, marginal likelihood 616.8081826155728
# 300-th epoch, marginal likelihood 616.6032797650582
# 350-th epoch, marginal likelihood 616.7131093288252
# 400-th epoch, marginal likelihood 616.4906164494782
# 450-th epoch, marginal likelihood 616.4393783420034
# 500-th epoch, marginal likelihood 616.420743392854
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [10.95537257]
#  scale  =  6.715281724728665
#  scale2 =  45.09500864247479
#
#
# 0251-th step: f(x) = 25.032813 (action=413)
#    current best f(x) = 27.200952 (best action=453)
#
# 0252-th step: f(x) = 22.780712 (action=286)
#    current best f(x) = 27.200952 (best action=453)
#
# 0253-th step: f(x) = 19.087295 (action=144)
#    current best f(x) = 27.200952 (best action=453)
#
# 0254-th step: f(x) = 18.179882 (action=404)
#    current best f(x) = 27.200952 (best action=453)
#
# 0255-th step: f(x) = 12.753520 (action=467)
#    current best f(x) = 27.200952 (best action=453)
#
# 0256-th step: f(x) = 19.124220 (action=185)
#    current best f(x) = 27.200952 (best action=453)
#
# 0257-th step: f(x) = 18.574627 (action=9)
#    current best f(x) = 27.200952 (best action=453)
#
# 0258-th step: f(x) = 10.040245 (action=442)
#    current best f(x) = 27.200952 (best action=453)
#
# 0259-th step: f(x) = 10.886919 (action=305)
#    current best f(x) = 27.200952 (best action=453)
#
# 0260-th step: f(x) = 12.102233 (action=24)
#    current best f(x) = 27.200952 (best action=453)
#
# 0261-th step: f(x) = 17.679511 (action=384)
#    current best f(x) = 27.200952 (best action=453)
#
# 0262-th step: f(x) = 12.995970 (action=246)
#    current best f(x) = 27.200952 (best action=453)
#
# 0263-th step: f(x) = 10.155557 (action=315)
#    current best f(x) = 27.200952 (best action=453)
#
# 0264-th step: f(x) = 9.836070 (action=381)
#    current best f(x) = 27.200952 (best action=453)
#
# 0265-th step: f(x) = 9.027180 (action=94)
#    current best f(x) = 27.200952 (best action=453)
#
# 0266-th step: f(x) = 11.019247 (action=188)
#    current best f(x) = 27.200952 (best action=453)
#
# 0267-th step: f(x) = 10.562600 (action=139)
#    current best f(x) = 27.200952 (best action=453)
#
# 0268-th step: f(x) = 8.604392 (action=395)
#    current best f(x) = 27.200952 (best action=453)
#
# 0269-th step: f(x) = 10.802941 (action=13)
#    current best f(x) = 27.200952 (best action=453)
#
# 0270-th step: f(x) = 9.166123 (action=21)
#    current best f(x) = 27.200952 (best action=453)
#
# 0271-th step: f(x) = 10.325013 (action=489)
#    current best f(x) = 27.200952 (best action=453)
#
# 0272-th step: f(x) = 11.122735 (action=133)
#    current best f(x) = 27.200952 (best action=453)
#
# 0273-th step: f(x) = 13.124802 (action=280)
#    current best f(x) = 27.200952 (best action=453)
#
# 0274-th step: f(x) = 10.906387 (action=252)
#    current best f(x) = 27.200952 (best action=453)
#
# 0275-th step: f(x) = 8.764908 (action=232)
#    current best f(x) = 27.200952 (best action=453)
#
# 0276-th step: f(x) = 11.888701 (action=383)
#    current best f(x) = 27.200952 (best action=453)
#
# 0277-th step: f(x) = 14.557415 (action=80)
#    current best f(x) = 27.200952 (best action=453)
#
# 0278-th step: f(x) = 10.001095 (action=66)
#    current best f(x) = 27.200952 (best action=453)
#
# 0279-th step: f(x) = 11.323582 (action=361)
#    current best f(x) = 27.200952 (best action=453)
#
# 0280-th step: f(x) = 10.619391 (action=124)
#    current best f(x) = 27.200952 (best action=453)
#
# 0281-th step: f(x) = 8.879206 (action=302)
#    current best f(x) = 27.200952 (best action=453)
#
# 0282-th step: f(x) = 12.510394 (action=168)
#    current best f(x) = 27.200952 (best action=453)
#
# 0283-th step: f(x) = 8.213658 (action=287)
#    current best f(x) = 27.200952 (best action=453)
#
# 0284-th step: f(x) = 10.451722 (action=292)
#    current best f(x) = 27.200952 (best action=453)
#
# 0285-th step: f(x) = 12.303462 (action=358)
#    current best f(x) = 27.200952 (best action=453)
#
# 0286-th step: f(x) = 9.614772 (action=122)
#    current best f(x) = 27.200952 (best action=453)
#
# 0287-th step: f(x) = 8.308253 (action=29)
#    current best f(x) = 27.200952 (best action=453)
#
# 0288-th step: f(x) = 8.687422 (action=208)
#    current best f(x) = 27.200952 (best action=453)
#
# 0289-th step: f(x) = 10.549001 (action=471)
#    current best f(x) = 27.200952 (best action=453)
#
# 0290-th step: f(x) = 8.701103 (action=120)
#    current best f(x) = 27.200952 (best action=453)
#
# 0291-th step: f(x) = 9.872121 (action=269)
#    current best f(x) = 27.200952 (best action=453)
#
# 0292-th step: f(x) = 14.481328 (action=28)
#    current best f(x) = 27.200952 (best action=453)
#
# 0293-th step: f(x) = 12.216533 (action=4)
#    current best f(x) = 27.200952 (best action=453)
#
# 0294-th step: f(x) = 18.436723 (action=82)
#    current best f(x) = 27.200952 (best action=453)
#
# 0295-th step: f(x) = 11.857812 (action=190)
#    current best f(x) = 27.200952 (best action=453)
#
# 0296-th step: f(x) = 8.940435 (action=119)
#    current best f(x) = 27.200952 (best action=453)
#
# 0297-th step: f(x) = 11.785598 (action=195)
#    current best f(x) = 27.200952 (best action=453)
#
# 0298-th step: f(x) = 9.148296 (action=478)
#    current best f(x) = 27.200952 (best action=453)
#
# 0299-th step: f(x) = 8.175553 (action=5)
#    current best f(x) = 27.200952 (best action=453)
#
# 0300-th step: f(x) = 10.764082 (action=460)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 726.4043869128078
# 50-th epoch, marginal likelihood 725.9992680798132
# 100-th epoch, marginal likelihood 725.7612769912566
# 150-th epoch, marginal likelihood 725.1420814523032
# 200-th epoch, marginal likelihood 725.0941722357944
# 250-th epoch, marginal likelihood 724.5954399481016
# 300-th epoch, marginal likelihood 724.2693958926351
# 350-th epoch, marginal likelihood 724.0187294462226
# 400-th epoch, marginal likelihood 723.5934717280314
# 450-th epoch, marginal likelihood 723.512987345867
# 500-th epoch, marginal likelihood 723.2542604791847
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [9.92717011]
#  scale  =  6.127694051651627
#  scale2 =  37.54863439064673
#
#
# 0301-th step: f(x) = 17.019654 (action=310)
#    current best f(x) = 27.200952 (best action=453)
#
# 0302-th step: f(x) = 10.167070 (action=23)
#    current best f(x) = 27.200952 (best action=453)
#
# 0303-th step: f(x) = 12.806394 (action=62)
#    current best f(x) = 27.200952 (best action=453)
#
# 0304-th step: f(x) = 10.309692 (action=3)
#    current best f(x) = 27.200952 (best action=453)
#
# 0305-th step: f(x) = 8.224445 (action=485)
#    current best f(x) = 27.200952 (best action=453)
#
# 0306-th step: f(x) = 9.689279 (action=260)
#    current best f(x) = 27.200952 (best action=453)
#
# 0307-th step: f(x) = 9.779923 (action=151)
#    current best f(x) = 27.200952 (best action=453)
#
# 0308-th step: f(x) = 17.022443 (action=214)
#    current best f(x) = 27.200952 (best action=453)
#
# 0309-th step: f(x) = 13.575485 (action=274)
#    current best f(x) = 27.200952 (best action=453)
#
# 0310-th step: f(x) = 9.300565 (action=390)
#    current best f(x) = 27.200952 (best action=453)
#
# 0311-th step: f(x) = 10.768150 (action=134)
#    current best f(x) = 27.200952 (best action=453)
#
# 0312-th step: f(x) = 9.231417 (action=18)
#    current best f(x) = 27.200952 (best action=453)
#
# 0313-th step: f(x) = 11.324984 (action=298)
#    current best f(x) = 27.200952 (best action=453)
#
# 0314-th step: f(x) = 10.176274 (action=12)
#    current best f(x) = 27.200952 (best action=453)
#
# 0315-th step: f(x) = 11.248858 (action=73)
#    current best f(x) = 27.200952 (best action=453)
#
# 0316-th step: f(x) = 13.191300 (action=265)
#    current best f(x) = 27.200952 (best action=453)
#
# 0317-th step: f(x) = 11.181507 (action=465)
#    current best f(x) = 27.200952 (best action=453)
#
# 0318-th step: f(x) = 10.485605 (action=379)
#    current best f(x) = 27.200952 (best action=453)
#
# 0319-th step: f(x) = 9.912928 (action=203)
#    current best f(x) = 27.200952 (best action=453)
#
# 0320-th step: f(x) = 9.474695 (action=277)
#    current best f(x) = 27.200952 (best action=453)
#
# 0321-th step: f(x) = 8.305630 (action=172)
#    current best f(x) = 27.200952 (best action=453)
#
# 0322-th step: f(x) = 9.939516 (action=184)
#    current best f(x) = 27.200952 (best action=453)
#
# 0323-th step: f(x) = 8.775160 (action=127)
#    current best f(x) = 27.200952 (best action=453)
#
# 0324-th step: f(x) = 10.620830 (action=268)
#    current best f(x) = 27.200952 (best action=453)
#
# 0325-th step: f(x) = 10.277968 (action=173)
#    current best f(x) = 27.200952 (best action=453)
#
# 0326-th step: f(x) = 11.324810 (action=433)
#    current best f(x) = 27.200952 (best action=453)
#
# 0327-th step: f(x) = 12.159280 (action=480)
#    current best f(x) = 27.200952 (best action=453)
#
# 0328-th step: f(x) = 11.950303 (action=153)
#    current best f(x) = 27.200952 (best action=453)
#
# 0329-th step: f(x) = 10.293233 (action=430)
#    current best f(x) = 27.200952 (best action=453)
#
# 0330-th step: f(x) = 11.245583 (action=492)
#    current best f(x) = 27.200952 (best action=453)
#
# 0331-th step: f(x) = 8.592269 (action=336)
#    current best f(x) = 27.200952 (best action=453)
#
# 0332-th step: f(x) = 12.301324 (action=425)
#    current best f(x) = 27.200952 (best action=453)
#
# 0333-th step: f(x) = 11.569069 (action=316)
#    current best f(x) = 27.200952 (best action=453)
#
# 0334-th step: f(x) = 11.788995 (action=221)
#    current best f(x) = 27.200952 (best action=453)
#
# 0335-th step: f(x) = 9.398884 (action=104)
#    current best f(x) = 27.200952 (best action=453)
#
# 0336-th step: f(x) = 12.133077 (action=297)
#    current best f(x) = 27.200952 (best action=453)
#
# 0337-th step: f(x) = 8.325543 (action=102)
#    current best f(x) = 27.200952 (best action=453)
#
# 0338-th step: f(x) = 9.303758 (action=417)
#    current best f(x) = 27.200952 (best action=453)
#
# 0339-th step: f(x) = 8.193677 (action=270)
#    current best f(x) = 27.200952 (best action=453)
#
# 0340-th step: f(x) = 10.798158 (action=155)
#    current best f(x) = 27.200952 (best action=453)
#
# 0341-th step: f(x) = 13.103882 (action=78)
#    current best f(x) = 27.200952 (best action=453)
#
# 0342-th step: f(x) = 11.288276 (action=237)
#    current best f(x) = 27.200952 (best action=453)
#
# 0343-th step: f(x) = 8.305276 (action=451)
#    current best f(x) = 27.200952 (best action=453)
#
# 0344-th step: f(x) = 11.181464 (action=97)
#    current best f(x) = 27.200952 (best action=453)
#
# 0345-th step: f(x) = 11.521340 (action=399)
#    current best f(x) = 27.200952 (best action=453)
#
# 0346-th step: f(x) = 8.459634 (action=437)
#    current best f(x) = 27.200952 (best action=453)
#
# 0347-th step: f(x) = 10.578804 (action=279)
#    current best f(x) = 27.200952 (best action=453)
#
# 0348-th step: f(x) = 11.106032 (action=38)
#    current best f(x) = 27.200952 (best action=453)
#
# 0349-th step: f(x) = 10.112508 (action=422)
#    current best f(x) = 27.200952 (best action=453)
#
# 0350-th step: f(x) = 10.154133 (action=50)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 834.7496945582101
# 50-th epoch, marginal likelihood 834.3174113183893
# 100-th epoch, marginal likelihood 834.0518805108155
# 150-th epoch, marginal likelihood 833.6799814035197
# 200-th epoch, marginal likelihood 833.3294542394335
# 250-th epoch, marginal likelihood 832.7779297317895
# 300-th epoch, marginal likelihood 832.5542440288998
# 350-th epoch, marginal likelihood 832.07631340712
# 400-th epoch, marginal likelihood 831.9426791709784
# 450-th epoch, marginal likelihood 831.6429682830271
# 500-th epoch, marginal likelihood 831.4555784252473
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [9.62508201]
#  scale  =  5.769066385700208
#  scale2 =  33.28212696261606
#
#
# 0351-th step: f(x) = 10.813239 (action=458)
#    current best f(x) = 27.200952 (best action=453)
#
# 0352-th step: f(x) = 10.176659 (action=486)
#    current best f(x) = 27.200952 (best action=453)
#
# 0353-th step: f(x) = 10.312649 (action=72)
#    current best f(x) = 27.200952 (best action=453)
#
# 0354-th step: f(x) = 10.281157 (action=103)
#    current best f(x) = 27.200952 (best action=453)
#
# 0355-th step: f(x) = 8.632794 (action=257)
#    current best f(x) = 27.200952 (best action=453)
#
# 0356-th step: f(x) = 9.546641 (action=445)
#    current best f(x) = 27.200952 (best action=453)
#
# 0357-th step: f(x) = 9.504382 (action=322)
#    current best f(x) = 27.200952 (best action=453)
#
# 0358-th step: f(x) = 8.484439 (action=447)
#    current best f(x) = 27.200952 (best action=453)
#
# 0359-th step: f(x) = 10.994084 (action=116)
#    current best f(x) = 27.200952 (best action=453)
#
# 0360-th step: f(x) = 9.871811 (action=477)
#    current best f(x) = 27.200952 (best action=453)
#
# 0361-th step: f(x) = 11.556895 (action=231)
#    current best f(x) = 27.200952 (best action=453)
#
# 0362-th step: f(x) = 8.965943 (action=355)
#    current best f(x) = 27.200952 (best action=453)
#
# 0363-th step: f(x) = 11.497698 (action=398)
#    current best f(x) = 27.200952 (best action=453)
#
# 0364-th step: f(x) = 10.633020 (action=479)
#    current best f(x) = 27.200952 (best action=453)
#
# 0365-th step: f(x) = 9.374820 (action=22)
#    current best f(x) = 27.200952 (best action=453)
#
# 0366-th step: f(x) = 9.093463 (action=494)
#    current best f(x) = 27.200952 (best action=453)
#
# 0367-th step: f(x) = 9.914487 (action=450)
#    current best f(x) = 27.200952 (best action=453)
#
# 0368-th step: f(x) = 10.202543 (action=275)
#    current best f(x) = 27.200952 (best action=453)
#
# 0369-th step: f(x) = 10.243895 (action=25)
#    current best f(x) = 27.200952 (best action=453)
#
# 0370-th step: f(x) = 11.512751 (action=456)
#    current best f(x) = 27.200952 (best action=453)
#
# 0371-th step: f(x) = 10.323454 (action=87)
#    current best f(x) = 27.200952 (best action=453)
#
# 0372-th step: f(x) = 9.593130 (action=251)
#    current best f(x) = 27.200952 (best action=453)
#
# 0373-th step: f(x) = 10.641013 (action=369)
#    current best f(x) = 27.200952 (best action=453)
#
# 0374-th step: f(x) = 10.475035 (action=145)
#    current best f(x) = 27.200952 (best action=453)
#
# 0375-th step: f(x) = 11.522658 (action=225)
#    current best f(x) = 27.200952 (best action=453)
#
# 0376-th step: f(x) = 10.462989 (action=101)
#    current best f(x) = 27.200952 (best action=453)
#
# 0377-th step: f(x) = 10.103281 (action=431)
#    current best f(x) = 27.200952 (best action=453)
#
# 0378-th step: f(x) = 10.108549 (action=85)
#    current best f(x) = 27.200952 (best action=453)
#
# 0379-th step: f(x) = 10.681088 (action=70)
#    current best f(x) = 27.200952 (best action=453)
#
# 0380-th step: f(x) = 10.746670 (action=309)
#    current best f(x) = 27.200952 (best action=453)
#
# 0381-th step: f(x) = 8.476657 (action=285)
#    current best f(x) = 27.200952 (best action=453)
#
# 0382-th step: f(x) = 11.060663 (action=368)
#    current best f(x) = 27.200952 (best action=453)
#
# 0383-th step: f(x) = 14.816282 (action=74)
#    current best f(x) = 27.200952 (best action=453)
#
# 0384-th step: f(x) = 9.473358 (action=65)
#    current best f(x) = 27.200952 (best action=453)
#
# 0385-th step: f(x) = 9.101019 (action=136)
#    current best f(x) = 27.200952 (best action=453)
#
# 0386-th step: f(x) = 10.005417 (action=169)
#    current best f(x) = 27.200952 (best action=453)
#
# 0387-th step: f(x) = 9.476697 (action=182)
#    current best f(x) = 27.200952 (best action=453)
#
# 0388-th step: f(x) = 8.410939 (action=376)
#    current best f(x) = 27.200952 (best action=453)
#
# 0389-th step: f(x) = 11.159947 (action=43)
#    current best f(x) = 27.200952 (best action=453)
#
# 0390-th step: f(x) = 9.482899 (action=31)
#    current best f(x) = 27.200952 (best action=453)
#
# 0391-th step: f(x) = 8.867940 (action=162)
#    current best f(x) = 27.200952 (best action=453)
#
# 0392-th step: f(x) = 11.376817 (action=434)
#    current best f(x) = 27.200952 (best action=453)
#
# 0393-th step: f(x) = 12.349684 (action=455)
#    current best f(x) = 27.200952 (best action=453)
#
# 0394-th step: f(x) = 11.549103 (action=271)
#    current best f(x) = 27.200952 (best action=453)
#
# 0395-th step: f(x) = 8.257007 (action=496)
#    current best f(x) = 27.200952 (best action=453)
#
# 0396-th step: f(x) = 11.530854 (action=32)
#    current best f(x) = 27.200952 (best action=453)
#
# 0397-th step: f(x) = 8.231807 (action=20)
#    current best f(x) = 27.200952 (best action=453)
#
# 0398-th step: f(x) = 11.389134 (action=154)
#    current best f(x) = 27.200952 (best action=453)
#
# 0399-th step: f(x) = 8.350529 (action=340)
#    current best f(x) = 27.200952 (best action=453)
#
# 0400-th step: f(x) = 9.298012 (action=484)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 933.3917320166306
# 50-th epoch, marginal likelihood 932.7345228929657
# 100-th epoch, marginal likelihood 932.481046572793
# 150-th epoch, marginal likelihood 932.384598150893
# 200-th epoch, marginal likelihood 932.1374582303731
# 250-th epoch, marginal likelihood 931.5666742691699
# 300-th epoch, marginal likelihood 930.9531675206955
# 350-th epoch, marginal likelihood 930.7166869079663
# 400-th epoch, marginal likelihood 930.4827029057997
# 450-th epoch, marginal likelihood 930.513733016563
# 500-th epoch, marginal likelihood 929.9345967922076
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [9.45510501]
#  scale  =  5.541260334751093
#  scale2 =  30.705566097485793
#
#
# 0401-th step: f(x) = 10.646867 (action=308)
#    current best f(x) = 27.200952 (best action=453)
#
# 0402-th step: f(x) = 10.737033 (action=468)
#    current best f(x) = 27.200952 (best action=453)
#
# 0403-th step: f(x) = 9.769790 (action=41)
#    current best f(x) = 27.200952 (best action=453)
#
# 0404-th step: f(x) = 10.307702 (action=235)
#    current best f(x) = 27.200952 (best action=453)
#
# 0405-th step: f(x) = 8.466462 (action=56)
#    current best f(x) = 27.200952 (best action=453)
#
# 0406-th step: f(x) = 10.361846 (action=48)
#    current best f(x) = 27.200952 (best action=453)
#
# 0407-th step: f(x) = 8.577983 (action=57)
#    current best f(x) = 27.200952 (best action=453)
#
# 0408-th step: f(x) = 12.331550 (action=26)
#    current best f(x) = 27.200952 (best action=453)
#
# 0409-th step: f(x) = 8.765337 (action=339)
#    current best f(x) = 27.200952 (best action=453)
#
# 0410-th step: f(x) = 11.007414 (action=92)
#    current best f(x) = 27.200952 (best action=453)
#
# 0411-th step: f(x) = 9.837844 (action=313)
#    current best f(x) = 27.200952 (best action=453)
#
# 0412-th step: f(x) = 8.621496 (action=470)
#    current best f(x) = 27.200952 (best action=453)
#
# 0413-th step: f(x) = 12.965340 (action=482)
#    current best f(x) = 27.200952 (best action=453)
#
# 0414-th step: f(x) = 8.752795 (action=202)
#    current best f(x) = 27.200952 (best action=453)
#
# 0415-th step: f(x) = 8.541929 (action=178)
#    current best f(x) = 27.200952 (best action=453)
#
# 0416-th step: f(x) = 9.631272 (action=449)
#    current best f(x) = 27.200952 (best action=453)
#
# 0417-th step: f(x) = 9.597451 (action=166)
#    current best f(x) = 27.200952 (best action=453)
#
# 0418-th step: f(x) = 10.020662 (action=187)
#    current best f(x) = 27.200952 (best action=453)
#
# 0419-th step: f(x) = 9.184536 (action=69)
#    current best f(x) = 27.200952 (best action=453)
#
# 0420-th step: f(x) = 11.381385 (action=68)
#    current best f(x) = 27.200952 (best action=453)
#
# 0421-th step: f(x) = 13.048880 (action=328)
#    current best f(x) = 27.200952 (best action=453)
#
# 0422-th step: f(x) = 12.601440 (action=7)
#    current best f(x) = 27.200952 (best action=453)
#
# 0423-th step: f(x) = 8.927517 (action=123)
#    current best f(x) = 27.200952 (best action=453)
#
# 0424-th step: f(x) = 8.388450 (action=106)
#    current best f(x) = 27.200952 (best action=453)
#
# 0425-th step: f(x) = 8.648269 (action=99)
#    current best f(x) = 27.200952 (best action=453)
#
# 0426-th step: f(x) = 8.344087 (action=19)
#    current best f(x) = 27.200952 (best action=453)
#
# 0427-th step: f(x) = 11.993764 (action=448)
#    current best f(x) = 27.200952 (best action=453)
#
# 0428-th step: f(x) = 11.472193 (action=293)
#    current best f(x) = 27.200952 (best action=453)
#
# 0429-th step: f(x) = 8.552751 (action=263)
#    current best f(x) = 27.200952 (best action=453)
#
# 0430-th step: f(x) = 9.275903 (action=332)
#    current best f(x) = 27.200952 (best action=453)
#
# 0431-th step: f(x) = 8.547200 (action=377)
#    current best f(x) = 27.200952 (best action=453)
#
# 0432-th step: f(x) = 9.883999 (action=410)
#    current best f(x) = 27.200952 (best action=453)
#
# 0433-th step: f(x) = 9.479436 (action=243)
#    current best f(x) = 27.200952 (best action=453)
#
# 0434-th step: f(x) = 9.501531 (action=10)
#    current best f(x) = 27.200952 (best action=453)
#
# 0435-th step: f(x) = 8.409145 (action=474)
#    current best f(x) = 27.200952 (best action=453)
#
# 0436-th step: f(x) = 9.812435 (action=299)
#    current best f(x) = 27.200952 (best action=453)
#
# 0437-th step: f(x) = 8.558220 (action=481)
#    current best f(x) = 27.200952 (best action=453)
#
# 0438-th step: f(x) = 12.072616 (action=213)
#    current best f(x) = 27.200952 (best action=453)
#
# 0439-th step: f(x) = 10.232971 (action=483)
#    current best f(x) = 27.200952 (best action=453)
#
# 0440-th step: f(x) = 11.797766 (action=365)
#    current best f(x) = 27.200952 (best action=453)
#
# 0441-th step: f(x) = 10.819696 (action=52)
#    current best f(x) = 27.200952 (best action=453)
#
# 0442-th step: f(x) = 12.186645 (action=146)
#    current best f(x) = 27.200952 (best action=453)
#
# 0443-th step: f(x) = 9.597560 (action=61)
#    current best f(x) = 27.200952 (best action=453)
#
# 0444-th step: f(x) = 11.208855 (action=443)
#    current best f(x) = 27.200952 (best action=453)
#
# 0445-th step: f(x) = 10.113003 (action=36)
#    current best f(x) = 27.200952 (best action=453)
#
# 0446-th step: f(x) = 8.813346 (action=409)
#    current best f(x) = 27.200952 (best action=453)
#
# 0447-th step: f(x) = 8.731186 (action=30)
#    current best f(x) = 27.200952 (best action=453)
#
# 0448-th step: f(x) = 8.485168 (action=60)
#    current best f(x) = 27.200952 (best action=453)
#
# 0449-th step: f(x) = 10.006865 (action=391)
#    current best f(x) = 27.200952 (best action=453)
#
# 0450-th step: f(x) = 8.989613 (action=405)
#    current best f(x) = 27.200952 (best action=453)
#
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0-th epoch, marginal likelihood 1018.5387023284794
# 50-th epoch, marginal likelihood 1020.5660026437474
# 100-th epoch, marginal likelihood 1021.8786535719867
# 150-th epoch, marginal likelihood 1021.3783618598163
# 200-th epoch, marginal likelihood 1021.352221967559
# 250-th epoch, marginal likelihood 1021.1079214980239
# 300-th epoch, marginal likelihood 1021.368251660747
# 350-th epoch, marginal likelihood 1020.7954430492314
# 400-th epoch, marginal likelihood 1020.8239801143651
# 450-th epoch, marginal likelihood 1019.9731689221762
# 500-th epoch, marginal likelihood 1019.6959386490877
# Done
#
#  Parameters of Gaussian kernel
#
#  width  =  [9.45469333]
#  scale  =  5.351259153192439
#  scale2 =  28.63597452462586
#
#
# 0451-th step: f(x) = 8.700341 (action=388)
#    current best f(x) = 27.200952 (best action=453)
#
# 0452-th step: f(x) = 10.330342 (action=75)
#    current best f(x) = 27.200952 (best action=453)
#
# 0453-th step: f(x) = 8.553799 (action=150)
#    current best f(x) = 27.200952 (best action=453)
#
# 0454-th step: f(x) = 12.016624 (action=71)
#    current best f(x) = 27.200952 (best action=453)
#
# 0455-th step: f(x) = 10.058481 (action=186)
#    current best f(x) = 27.200952 (best action=453)
#
# 0456-th step: f(x) = 11.709692 (action=259)
#    current best f(x) = 27.200952 (best action=453)
#
# 0457-th step: f(x) = 8.925313 (action=396)
#    current best f(x) = 27.200952 (best action=453)
#
# 0458-th step: f(x) = 9.204538 (action=129)
#    current best f(x) = 27.200952 (best action=453)
#
# 0459-th step: f(x) = 8.743393 (action=418)
#    current best f(x) = 27.200952 (best action=453)
#
# 0460-th step: f(x) = 11.093591 (action=194)
#    current best f(x) = 27.200952 (best action=453)
#
# 0461-th step: f(x) = 11.353074 (action=217)
#    current best f(x) = 27.200952 (best action=453)
#
# 0462-th step: f(x) = 14.548176 (action=423)
#    current best f(x) = 27.200952 (best action=453)
#
# 0463-th step: f(x) = 9.048077 (action=152)
#    current best f(x) = 27.200952 (best action=453)
#
# 0464-th step: f(x) = 8.286171 (action=142)
#    current best f(x) = 27.200952 (best action=453)
#
# 0465-th step: f(x) = 8.413187 (action=135)
#    current best f(x) = 27.200952 (best action=453)
#
# 0466-th step: f(x) = 11.572382 (action=290)
#    current best f(x) = 27.200952 (best action=453)
#
# 0467-th step: f(x) = 9.868855 (action=253)
#    current best f(x) = 27.200952 (best action=453)
#
# 0468-th step: f(x) = 10.696403 (action=234)
#    current best f(x) = 27.200952 (best action=453)
#
# 0469-th step: f(x) = 10.047177 (action=183)
#    current best f(x) = 27.200952 (best action=453)
#
# 0470-th step: f(x) = 12.106479 (action=49)
#    current best f(x) = 27.200952 (best action=453)
#
# 0471-th step: f(x) = 9.120140 (action=191)
#    current best f(x) = 27.200952 (best action=453)
#
# 0472-th step: f(x) = 11.111703 (action=424)
#    current best f(x) = 27.200952 (best action=453)
#
# 0473-th step: f(x) = 8.187441 (action=266)
#    current best f(x) = 27.200952 (best action=453)
#
# 0474-th step: f(x) = 8.651240 (action=324)
#    current best f(x) = 27.200952 (best action=453)
#
# 0475-th step: f(x) = 9.011190 (action=360)
#    current best f(x) = 27.200952 (best action=453)
#
# 0476-th step: f(x) = 10.557070 (action=412)
#    current best f(x) = 27.200952 (best action=453)
#
# 0477-th step: f(x) = 9.487480 (action=256)
#    current best f(x) = 27.200952 (best action=453)
#
# 0478-th step: f(x) = 8.937088 (action=341)
#    current best f(x) = 27.200952 (best action=453)
#
# 0479-th step: f(x) = 10.755536 (action=16)
#    current best f(x) = 27.200952 (best action=453)
#
# 0480-th step: f(x) = 9.264374 (action=415)
#    current best f(x) = 27.200952 (best action=453)
#
# 0481-th step: f(x) = 10.865881 (action=11)
#    current best f(x) = 27.200952 (best action=453)
#
# 0482-th step: f(x) = 8.895531 (action=334)
#    current best f(x) = 27.200952 (best action=453)
#
# 0483-th step: f(x) = 10.122503 (action=314)
#    current best f(x) = 27.200952 (best action=453)
#
# 0484-th step: f(x) = 10.157350 (action=98)
#    current best f(x) = 27.200952 (best action=453)
#
# 0485-th step: f(x) = 8.795967 (action=354)
#    current best f(x) = 27.200952 (best action=453)
#
# 0486-th step: f(x) = 12.638871 (action=76)
#    current best f(x) = 27.200952 (best action=453)
#
# 0487-th step: f(x) = 8.348254 (action=392)
#    current best f(x) = 27.200952 (best action=453)
#
# 0488-th step: f(x) = 8.472652 (action=432)
#    current best f(x) = 27.200952 (best action=453)
#
# 0489-th step: f(x) = 9.836043 (action=125)
#    current best f(x) = 27.200952 (best action=453)
#
# 0490-th step: f(x) = 8.994670 (action=170)
#    current best f(x) = 27.200952 (best action=453)
#
# 0491-th step: f(x) = 11.075580 (action=46)
#    current best f(x) = 27.200952 (best action=453)
#
# 0492-th step: f(x) = 9.023424 (action=300)
#    current best f(x) = 27.200952 (best action=453)
#
# 0493-th step: f(x) = 8.565179 (action=325)
#    current best f(x) = 27.200952 (best action=453)
#
# 0494-th step: f(x) = 12.150470 (action=397)
#    current best f(x) = 27.200952 (best action=453)
#
# 0495-th step: f(x) = 9.464192 (action=81)
#    current best f(x) = 27.200952 (best action=453)
#
# 0496-th step: f(x) = 11.639690 (action=148)
#    current best f(x) = 27.200952 (best action=453)
#
# 0497-th step: f(x) = 10.256079 (action=45)
#    current best f(x) = 27.200952 (best action=453)
#
# 0498-th step: f(x) = 9.875474 (action=464)
#    current best f(x) = 27.200952 (best action=453)
#
# 0499-th step: f(x) = 8.994589 (action=88)
#    current best f(x) = 27.200952 (best action=453)
#
# 0500-th step: f(x) = 9.629406 (action=473)
#    current best f(x) = 27.200952 (best action=453)

# %%
index_Henry_H2O_unrelevant = np.argmax(Data_unrelevant_features_Henry_H2O.iloc[:, -1].values)
import numpy as np
from sklearn.manifold import TSNE

X_embedded = TSNE(n_components=2).fit_transform(Data_relevant_features_Henry_CO2.iloc[:, :-1].values)
X_embedded.shape

SC1 = np.transpose(X_embedded)[0]
SC2 = np.transpose(X_embedded)[1]

fig, ax = plt.subplots(figsize=(3,3), dpi=150)
ax.scatter(SC1, SC2, c='tab:blue', alpha=0.3)
initial_set = ax.scatter(SC1[minima], SC2[minima], c='gold', label = 'Initial set', alpha = 0.5)
optimum = ax.scatter(SC1[index_Henry_H2O_unrelevant], SC2[index_Henry_H2O_unrelevant], c='red', label = 'Optimum')

ax.legend([initial_set, optimum], ['Initial set', 'Optimum'], loc = 'best')
#labels = ['Initial set', 'Optimum']
#ax.legend(labels)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
plt.show()

# %% [markdown]
# ## Squential Learning results summary (with Kriging)

# %% [markdown]
# ### Henry_CO2

# %%
labels = ['RF-MEI', 'RF-MLI', 'RF-MU', 'K-MEI', 'K-MLI', 'K-MU', 'COMBO-\nPI', 'COMBO-\nEI' ]
relevant = [111/200, 74/200, 134/200, 129/200, 253/200, 393/200, 139/200, 139/200]
unrelevant = [114/200, 39/200, 123/200, 104/200, 31/200, 354/200, 124/200, 17/200]

x = np.arange(len(labels))  # the label locations
width = 0.38  # the width of the bars

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(8, 3)  , dpi=190)

#ax.hlines(1, xmin = men_means[3], xmax = men_means[4])
#fig, ax = plt.subplots(figsize=(7,3)  , dpi=140)
rects1 = ax.bar(x - width/2, relevant, width, label='33 features')
rects2 = ax.bar(x + width/2, unrelevant, width, label='100 features')
plt.axhline(y=1, color = 'k', linewidth = 1, linestyle="--")
# Add some text for labels, title and custom x-axis tick labels, etc.

ax.set_ylabel('Number of experiments/\n number of random experiments')
#ax.set_title('Results for synthetic data')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
ax.set_title('Sequential Learning for Henry coefficient CO$_2$')


ax.annotate('random choice', xy=(1.5, 1), xytext=(2, 1.2),
            arrowprops=dict(facecolor='black', width = .1, headwidth=4),
            )


fig.tight_layout()

plt.show()

# %% [markdown]
# ### Working capacity

# %%
labels = ['RF-MEI', 'RF-MLI', 'RF-MU', 'K-MEI', 'K-MLI', 'K-MU', 'COMBO-\nPI', 'COMBO-\nEI' ]
relevant = [89/200, 169/200, 134/200, 41/200, 127/200, 242/200, 151/200, 154/200]
unrelevant = [84/200, 172/200, 136/200, 17/200, 133/200, 253/200, 119/200, 122/200]

x = np.arange(len(labels))  # the label locations
width = 0.38  # the width of the bars

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(8, 3)  , dpi=190)

#ax.hlines(1, xmin = men_means[3], xmax = men_means[4])
#fig, ax = plt.subplots(figsize=(7,3)  , dpi=140)
rects1 = ax.bar(x - width/2, relevant, width, label='62 features')
rects2 = ax.bar(x + width/2, unrelevant, width, label='100 features')
plt.axhline(y=1, color = 'k', linewidth = 1, linestyle="--")
# Add some text for labels, title and custom x-axis tick labels, etc.

ax.set_ylabel('Number of experiments/\n number of random experiments')
#ax.set_title('Results for synthetic data')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
ax.set_title('Sequential Learning for working capacity CO$_2$')


ax.annotate('random choice', xy=(1.5, 1), xytext=(2, 1.2),
            arrowprops=dict(facecolor='black', width = .1, headwidth=4),
            )


fig.tight_layout()

plt.show()

# %% [markdown]
# ### Henry H2O

# %%
labels = ['RF-MEI', 'RF-MLI', 'RF-MU', 'K-MEI', 'K-MLI', 'K-MU', 'COMBO-\nPI', 'COMBO-\nEI' ]
relevant = [145/200, 60/200, 186/200, 59/200, 37/200, 221/200, 80/200, 81/200]
unrelevant = [126/200, 45/200, 146/200, 153/200, 67/200, 305/200, 77/200, 68/200]

x = np.arange(len(labels))  # the label locations
width = 0.38  # the width of the bars

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(8, 3)  , dpi=190)

#ax.hlines(1, xmin = men_means[3], xmax = men_means[4])
#fig, ax = plt.subplots(figsize=(7,3)  , dpi=140)
rects1 = ax.bar(x - width/2, relevant, width, label='15 features')
rects2 = ax.bar(x + width/2, unrelevant, width, label='100 features')
plt.axhline(y=1, color = 'k', linewidth = 1, linestyle="--")
# Add some text for labels, title and custom x-axis tick labels, etc.

ax.set_ylabel('Number of experiments/\n number of random experiments')
#ax.set_title('Results for synthetic data')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
ax.set_title('Sequential Learning for Henry coefficient H$_2$O')


ax.annotate('random choice', xy=(1.5, 1), xytext=(2, 1.2),
            arrowprops=dict(facecolor='black', width = .1, headwidth=4),
            )


fig.tight_layout()

plt.show()
